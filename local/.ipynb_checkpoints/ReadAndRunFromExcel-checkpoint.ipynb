# %%
import FINE as fn
import pandas as pd
import ast
import inspect
from openpyxl import load_workbook

# %load_ext autoreload
# %autoreload 2

# %%
file = pd.ExcelFile('test.xlsx')

esMData =pd.read_excel('test.xlsx', sheetname='EnergySystemModel', index_col=0, squeeze=True)
esMData=esMData.apply(lambda v: ast.literal_eval(v) if type(v) == str and v[0] == '{' else v)

kw=inspect.getargspec(fn.EnergySystemModel.__init__).args
esM = fn.EnergySystemModel(**esMData[esMData.index.isin(kw)])

for comp in esMData['componentClasses']:
    data=pd.read_excel(file, sheetname=comp)
    dataKeys=set(data['name'].values)
    if comp + 'LocSpecs' in file.sheet_names:
        dataLoc=pd.read_excel(file, sheetname = comp + 'LocSpecs', index_col=[0,1,2]).sort_index()
        dataLocKeys=set(dataLoc.index.get_level_values(0).unique())
        if not dataLocKeys <= dataKeys:
            raise ValueError('Invalid key(s) detected in ' + comp + '\n', dataLocKeys-dataKeys)
        if dataLoc.isnull().any().any():
            print(comp)
            break
    if comp + 'TimeSeries' in file.sheet_names:
        dataTS=pd.read_excel(file, sheetname = comp + 'TimeSeries', index_col=[0,1,2]).sort_index()
        dataTSKeys=set(dataTS.index.get_level_values(0).unique())
        if not dataTSKeys <= dataKeys:
            raise ValueError('Invalid key(s) detected in ' + comp + '\n', dataTSKeys-dataKeys)
        if dataTS.isnull().any().any():
            print(comp)
            break

    for key, row in data.iterrows():
        temp = {}
        temp=row.dropna()
        temp=temp.drop(temp[temp == 'None'].index)  
        temp=temp.apply(lambda v: ast.literal_eval(v) if type(v) == str and v[0] == '{' else v)

        if comp + 'LocSpecs' in file.sheet_names:
            dataLoc_ = dataLoc[dataLoc.index.get_level_values(0) == temp['name']]
            for ix in dataLoc_.index.get_level_values(1).unique():
                temp.set_value(ix,dataLoc.loc[(temp['name'],ix)].squeeze())

        if comp + 'TimeSeries' in file.sheet_names:
            dataTS_ = dataTS[dataTS.index.get_level_values(0) == temp['name']]
            for ix in dataTS_.index.get_level_values(1).unique():
                temp.set_value(ix,dataTS_.loc[(temp['name'],ix)].T)

        kwargs = temp
        esM.add(getattr(fn, comp)(esM, **kwargs))
        
if esMData['cluster'] != {}:
    esM.cluster(**esMData['cluster'])
esM.optimize(**esMData['optimize'])

writer = pd.ExcelWriter(esMData['output']['outputFileName'] + '.xlsx')

for name in esM.componentModelingDict.keys():
    oL = esMData['output']['optimizationSummaryOutputLevel']
    oL_ = oL[name] if type(oL) == dict else oL
    esM.getOptimizationSummary(name, outputLevel=oL_).to_excel(writer,name[:-5] + 'OptSummary')
    
    data=esM.componentModelingDict[name].getOptimalValues()
    oL = esMData['output']['optValOutputLevel']
    oL_ = oL[name] if type(oL) == dict else oL
    dataTD, indexTD = [], []
    dataTI, indexTI = [], []
    for key, d in data.items():
        if d['timeDependent']:
            dataTD.append(d['values']), indexTD.append(key)
        else:
            dataTI.append(d['values']), indexTI.append(key)
    if dataTD != []:
        dfTD = pd.concat(dataTD, keys=indexTD)
        if oL_ == 1:
            dfTD = dfTD.loc[((dfTD != 0) & (~dfTD.isnull())).any(axis=1)]
        dfTD.to_excel(writer, name[:-5] + 'TDoptVar')
    if dataTI != []:
        dfTI = pd.concat(dataTI, keys=indexTI)
        if oL_ == 1:
            dfTD = dfTD.loc[((dfTD != 0) & (~dfTD.isnull())).any(axis=1)]
        dfTI.to_excel(writer, name[:-5] + 'TIoptVar')
        
periodsOrder = pd.DataFrame([esM.periodsOrder], index=['periodsOrder'], columns=esM.periods)
periodsOrder.to_excel(writer, 'Misc')
    
writer.save()
# Out:
# The distances of a component are set to a normalized values of 1.
#
# Clustering time series data with 3 typical periods and 24 time steps per period...
# 		(3.3340 sec)
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(35.3360 sec)
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(5.7980 sec)
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(28.2080 sec)
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(35.0220 sec)
# Declaring shared potential constraint...
# 		(0.0020 sec)
# Declaring commodity balances...
# 		(40.5270 sec)
# Declaring objective function...
# 		(18.9510 sec)
# Academic license - for non-commercial use only
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Parameter LogToConsole unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter OptimalityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Changed value of parameter Threads to 3
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Changed value of parameter cuts to 0
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Changed value of parameter logfile to job
#    Prev: gurobi.log  Default:
# Changed value of parameter method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Optimize a model with 2689630 rows, 2181552 columns and 8469962 nonzeros
# Coefficient statistics:
#   Matrix range     [2e-08, 5e+02]
#   Objective range  [2e-06, 3e-01]
#   Bounds range     [6e-01, 6e+04]
#   RHS range        [4e-02, 5e+01]
# Presolve removed 1035440 rows and 439702 columns
# Presolve time: 4.92s
# Presolved: 1654190 rows, 1741850 columns, 6346622 nonzeros
#
# Elapsed ordering time = 5s
# Ordering time: 10.37s
#
# Barrier statistics:
#  Dense cols : 80
#  AA' NZ     : 5.998e+06
#  Factor NZ  : 4.151e+07 (roughly 1.7 GBytes of memory)
#  Factor Ops : 4.601e+09 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.15241261e+03 -3.88180605e+04  1.57e+05 8.54e-05  2.87e+01    18s
#    1   3.36207174e+03 -7.67382084e+04  1.04e+05 6.09e-02  2.08e+01    19s
#    2   3.21789244e+03 -1.22508619e+05  9.52e+04 3.33e-02  1.70e+01    21s
#    3   2.80524409e+03 -2.20503873e+05  7.52e+04 5.60e-03  1.18e+01    22s
#    4   1.92901376e+03 -2.29500465e+05  3.19e+04 2.60e-03  5.49e+00    24s
#    5   1.73925340e+03 -2.45668010e+05  1.86e+04 1.25e-03  3.74e+00    25s
#    6   1.41080363e+03 -2.40159451e+05  3.73e+03 1.01e-03  1.90e+00    26s
#    7   1.39706878e+03 -3.68810443e+05  3.23e+03 1.96e-04  1.60e+00    27s
#    8   1.21855538e+03 -3.10857631e+05  6.16e+01 9.60e-05  7.98e-01    29s
#    9   1.68741936e+03 -2.65249327e+05  3.40e+01 5.20e-05  4.51e-01    30s
#  135   7.71375701e+01  7.71375202e+01  2.19e-08 8.13e-10  3.11e-13   197s
#  136   7.71375701e+01  7.71375202e+01  2.19e-08 8.13e-10  3.11e-13   199s
#  137   7.71375701e+01  7.71375202e+01  2.19e-08 8.13e-10  3.11e-13   201s
#
# Barrier solved model in 137 iterations and 200.70 seconds
# Optimal objective 7.71375711e+01
#
# Crossover log...
#
#    93493 DPushes remaining with DInf 1.6425902e+01               202s
#        0 DPushes remaining with DInf 5.0409464e+00               203s
#
#   866893 PPushes remaining with PInf 1.4856874e-02               203s
#   549644 PPushes remaining with PInf 5.4854756e-02               205s
#   386931 PPushes remaining with PInf 1.6738117e-02               210s
#   318151 PPushes remaining with PInf 8.2999088e-03               215s
#   289119 PPushes remaining with PInf 7.2050602e-03               220s
#   264716 PPushes remaining with PInf 6.6787543e-03               225s
#   240851 PPushes remaining with PInf 6.3539655e-03               230s
#   219686 PPushes remaining with PInf 6.1134231e-03               235s
#   202351 PPushes remaining with PInf 5.9781872e-03               240s
#   190673 PPushes remaining with PInf 7.9631435e-03               246s
#   173624 PPushes remaining with PInf 7.7465200e-03               251s
#   162780 PPushes remaining with PInf 3.7213999e-01               255s
#   122321 PPushes remaining with PInf 3.2580846e-01               262s
#    95964 PPushes remaining with PInf 3.2556360e-01               268s
#    83653 PPushes remaining with PInf 3.2538374e-01               270s
#    74734 PPushes remaining with PInf 6.9337569e-01               275s
#    66153 PPushes remaining with PInf 2.1414924e+01               280s
#    55937 PPushes remaining with PInf 1.7483278e+01               286s
#    37369 PPushes remaining with PInf 9.2530135e+00               291s
#    17358 PPushes remaining with PInf 3.2420234e+00               295s
#       20 PPushes remaining with PInf 1.7640300e+00               301s
#        0 PPushes remaining with PInf 3.0479729e-03               302s
#
#   Push phase complete: Pinf 3.0479729e-03, Dinf 1.1502762e+01    302s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   958373    7.7137570e+01   0.000000e+00   5.873218e+00    302s
#   958683    7.7137570e+01   0.000000e+00   5.629780e-01    308s
#   958993    7.7137570e+01   0.000000e+00   3.472452e-01    313s
#   959293    7.7137570e+01   0.000000e+00   8.859214e-02    319s
#   959393    7.7137570e+01   0.000000e+00   0.000000e+00    322s
#   959393    7.7137570e+01   0.000000e+00   0.000000e+00    325s
#
# Solved in 959393 iterations and 324.72 seconds
# Optimal objective  7.713757011e+01
# Freed default Gurobi environment
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 324.724000931
# Error rc: 0
# Time: 346.3580000400543
#
#
# Name: x2181552
# Lower bound: 77.1375701103
# Upper bound: 77.1375701103
# Number of objectives: 1
# Number of constraints: 2689630
# Number of variables: 2181552
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 2181552
# Number of nonzeros: 8469962
# Sense: minimize
#
# 		(563.3130 sec)
#
# Processing optimization output...
# for SourceSinkModel ...    (33.1930sec)
# for ConversionModel ...    (16.7590sec)
# for StorageModel ...       (35.0240sec)
# for TransmissionModel ...  (84.7870sec)
# 		(169.7630 sec)
