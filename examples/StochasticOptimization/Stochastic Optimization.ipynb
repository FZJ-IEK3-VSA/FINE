# %% [markdown]
# # Workflow for a stoachstic opimization
#
# In this example of the FINE framework, a stochastic optimization is performed. It allows  a energy system optimization to consider several years of operation input (e.g. different wind power due to different weather conditions) in the optimization of the energy system design. By optimizing a system considering several years of input data for operation, a more robust energy system is achieved.

# %% [markdown]
# ## 1. Import packages

# %%
import FINE as fn
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Initialize energy system model
# Initialize an esM which has two years.

# %%
numberOfTimeSteps = 4
hoursPerTimeStep = 2190
numberOfYears = 2  # new test, before =1
investmentPeriodInterval = 1

# Create an energy system model instance
esM = fn.EnergySystemModel(
    locations={"PerfectLand"},
    commodities={"electricity"},
    numberOfTimeSteps=numberOfTimeSteps,
    commodityUnitsDict={"electricity": r"kW$_{el}$"},
    hoursPerTimeStep=hoursPerTimeStep,
    costUnit="1 Euro",
    numberOfInvestmentPeriods=numberOfYears,
    investmentPeriodInterval=investmentPeriodInterval,
    lengthUnit="km",
    verboseLogLevel=2,
)

# %% [markdown]
# ## 3. Add a wind source
# Either pass the parameters in a dict per investment period (modification per investment period possible) or constant (only one dataframe, value ...)

# %%
windOperationRateMax = {}
windOperationRateMax[0] = pd.DataFrame(
    [
        np.array(
            [
                0.4,
                0.4,
                0.6,
                0.6,
            ]
        )
    ],
    index=["PerfectLand"],
).T
windOperationRateMax[1] = pd.DataFrame(
    [
        np.array(
            [
                0.2,
                0.2,
                0.3,
                0.5,
            ]
        )
    ],
    index=["PerfectLand"],
).T
# different opexPerOperation per investmentperiod
windOpexPerOperation = {}
windOpexPerOperation[0] = 0.01
windOpexPerOperation[1] = 0.02

esM.add(
    fn.Source(
        esM=esM,
        name="Wind",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=windOperationRateMax,
        capacityMax=4e6,
        investPerCapacity=2 * 2190,
        opexPerCapacity=0,
        interestRate=0,
        opexPerOperation=windOpexPerOperation,  # 0.01,
        economicLifetime=1,
    )
)

# %% [markdown]
# ## 3. Add a electricity market

# %%
costs = pd.DataFrame(
    [np.array([ 1, 1, 1, 1, ] )],
    index=["PerfectLand"],
).T


revenues = {}
revenues[0] = pd.DataFrame(
    [
        np.array(
            [
                0.0,
                0.0,
                0.0,
                0.0,
            ]
        )
    ],
    index=["PerfectLand"],
).T
revenues[1] = pd.DataFrame(
    [
        np.array(
            [
                0.0,
                0.0,
                0.0,
                0.0,
            ]
        )
    ],
    index=["PerfectLand"],
).T

maxpurchase = {}
maxpurchase[0] = pd.DataFrame(
    [
        np.array(
            [
                0.5e3,
                0.5e3,
                4e3,
                4e3,
            ]
        )
    ],
    index=["PerfectLand"],
).T
maxpurchase[1] = pd.DataFrame(
    [
        np.array(
            [
                0.5e3,
                0.5e3,
                4e3,
                4e3,
            ]
        )
    ],
    index=["PerfectLand"],
).T

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Electricity market",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateMax=maxpurchase,
        commodityCostTimeSeries=costs,
        # commodityCost= 1,
        commodityRevenueTimeSeries=revenues,
    )
)  # eur/kWh

# %% [markdown]
# ## 5. Add a industry sink

# %%
revenuesDemand = {}
revenuesDemand[0] = pd.DataFrame(
    [
        np.array(
            [
                0.1,
                0.1,
                0.1,
                0.1,
            ]
        )
    ],
    index=["PerfectLand"],
).T
revenuesDemand[1] = pd.DataFrame(
    [
        np.array(
            [
                0.2,
                0.2,
                0.2,
                0.2,
            ]
        )
    ],
    index=["PerfectLand"],
).T

demand = {}
demand[0] = pd.DataFrame(
    [
        np.array(
            [
                2e3,
                1e3,
                1e3,
                1e3,
            ]
        )
    ],
    index=["PerfectLand"],
).T  # first investmentperiod
demand[1] = pd.DataFrame(
    [
        np.array(
            [
                2e3,
                1e3,
                1e3,
                1e3,
            ]
        )
    ],
    index=["PerfectLand"],
).T  # second investmentperiod

esM.add(
    fn.Sink(
        esM=esM,
        name="EDemand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=demand,
        commodityRevenueTimeSeries=revenuesDemand,  # new compared to original model
    )
)

# %% [markdown]
# ## 6. Optimize

# %%
esM.optimize(timeSeriesAggregation=False, solver="glpk")
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\RAEF3F~1.MAI\AppData\Local\Temp\tmpp79lqujb.glpk.raw --wglp
#  C:\Users\RAEF3F~1.MAI\AppData\Local\Temp\tmpewivjv_o.glpk.glp --cpxlp C:\Users\RAEF3F~1.MAI\AppData\Local\Temp\tmpewpzv2e9.pyomo.lp
# Reading problem data from 'C:\Users\RAEF3F~1.MAI\AppData\Local\Temp\tmpewpzv2e9.pyomo.lp'...
# 38 rows, 33 columns, 70 non-zeros
# 250 lines were read
# Writing problem data to 'C:\Users\RAEF3F~1.MAI\AppData\Local\Temp\tmpewivjv_o.glpk.glp'...
# 197 lines were written
# GLPK Simplex Optimizer, v4.65
# 38 rows, 33 columns, 70 non-zeros
# Preprocessing...
# 11 rows, 12 columns, 23 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.314e+03  ratio =  1.314e+03
# GM: min|aij| =  9.353e-01  max|aij| =  1.069e+00  ratio =  1.143e+00
# EQ: min|aij| =  8.975e-01  max|aij| =  1.000e+00  ratio =  1.114e+00
# Constructing initial basis...
# Size of triangular part is 11
#       0: obj =   4.411851852e+03 inf =   2.955e+01 (4)
#       5: obj =   2.691185185e+04 inf =   0.000e+00 (0)
# *    11: obj =   2.217203704e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.1 Mb (56584 bytes)
# Writing basic solution to 'C:\Users\RAEF3F~1.MAI\AppData\Local\Temp\tmpp79lqujb.glpk.raw'...
# 80 lines were written

# %% [markdown]
# ## 7. Get results of robust energy system, optimized for two years of operations

# %%
esM.getOptimizationSummary('SourceSinkModel').loc['Wind','capacity','[kW$_{el}$]']['PerfectLand']
# Out:
# 1.71232876712329
