# %% [markdown]
# # Using Excel for parameter input and model runs
#
# Besides using a python script or a jupyter notebook it is also possible to read and run a model using excel files.
#
# The energySystemModelRunFromExcel() function reads a model from excel, optimizes it and stores it to an excel file.
#
# The readEnergySystemModelFromExcel() function reads a model from excel.
#
# The model run can also be started on double-klicking on the run.bat Windows batch script in the folder where this notebook is located (still requires that a Python version, the FINE package and an optmization solver are installed).
#
# Moreover, it is possible to run the model inside the Excel file with a VBA Macro (see scenarioInputWithMacro.xlsx)

# %% [markdown]
# # Import FINE package

# %%
import FINE as fn 
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Call energySystemModelRunFromExcel function

# %% [markdown]
# ### Read model from excel file, optimize and store to excel file
# Checkout the output excel file in the folder where this notebook is located

# %%
esM = fn.energySystemModelRunFromExcel()
# Out:
# The distances of a component are set to a normalized value of 1.
#
# Clustering time series data with 3 typical periods and 24 time steps per period...
# 		(4.8426 sec)
#
# Time series aggregation specifications:
# Number of typical periods:3, number of time steps per periods:24
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.2028 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0469 sec)
#
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.2031 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.6558 sec)
#
# Declaring shared potential constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.3749 sec)
#
# Declaring objective function...
# 		(0.1562 sec)
#
# Using license file C:\Users\LaraWelder\gurobi.lic
# Academic license - for non-commercial use only
# Read LP format model from file C:\Users\LARAWE~1\AppData\Local\Temp\tmp41oyplro.pyomo.lp
# Reading time = 0.30 seconds
# x27264: 50111 rows, 27264 columns, 147376 nonzeros
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Changed value of parameter Threads to 3
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Parameter logfile unchanged
#    Value:   Default:
# Changed value of parameter OptimalityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Changed value of parameter cuts to 0
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Changed value of parameter method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 50111 rows, 27264 columns and 147376 nonzeros
# Model fingerprint: 0xf96a5502
# Variable types: 27226 continuous, 38 integer (28 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 5e+02]
#   Objective range  [2e-06, 3e-01]
#   Bounds range     [1e+00, 6e+04]
#   RHS range        [4e-02, 5e+01]
# Presolve removed 13620 rows and 10101 columns
# Presolve time: 0.36s
# Presolved: 36491 rows, 17163 columns, 119873 nonzeros
# Variable types: 17139 continuous, 24 integer (14 binary)
# Root barrier log...
#
# Ordering time: 0.48s
#
# Barrier statistics:
#  Dense cols : 168
#  Free vars  : 552
#  AA' NZ     : 4.919e+05
#  Factor NZ  : 1.876e+06 (roughly 40 MBytes of memory)
#  Factor Ops : 3.721e+08 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.24214535e+04 -1.09882080e+06  1.61e+05 1.39e-02  4.57e+02     1s
#    1   5.78179208e+04 -7.90481120e+05  1.07e+05 1.75e-01  2.67e+02     1s
#    2   2.30878061e+04 -6.35715479e+05  3.92e+04 1.11e-01  1.17e+02     1s
#    3   6.54179305e+03 -2.03375624e+05  6.41e+03 5.56e-03  1.72e+01     2s
#    4   3.69117021e+03 -9.78583063e+04  2.29e+03 1.43e-03  6.12e+00     2s
#    5   2.20618442e+03 -3.25205470e+04  7.27e+02 1.52e-04  1.71e+00     2s
#   37   4.47901776e+01  4.47762846e+01  1.52e-07 1.02e-08  2.32e-07     3s
#   38   4.47887492e+01  4.47801867e+01  1.00e-07 6.14e-09  1.43e-07     3s
#   39   4.47878619e+01  4.47817434e+01  7.05e-08 4.51e-09  1.02e-07     3s
#   40   4.47869990e+01  4.47847442e+01  4.08e-08 1.38e-09  3.77e-08     4s
#   41   4.47867638e+01  4.47847607e+01  3.35e-08 1.27e-09  3.35e-08     4s
#   42   4.47864733e+01  4.47852243e+01  2.41e-08 6.31e-10  2.09e-08     4s
#   43   4.47859661e+01  4.47854664e+01  8.94e-09 4.93e-10  8.35e-09     4s
#   44   4.47858732e+01  4.47854799e+01  6.58e-09 4.26e-10  6.58e-09     4s
#   45   4.47858348e+01  4.47855372e+01  5.49e-09 2.78e-10  4.97e-09     4s
#   46   4.47857771e+01  4.47856031e+01  3.89e-09 8.44e-11  2.91e-09     4s
#   47   4.47856625e+01  4.47856200e+01  1.04e-09 4.07e-11  7.10e-10     4s
#   48   4.47856447e+01  4.47856326e+01  3.26e-10 4.55e-12  2.02e-10     4s
#   49   4.47856407e+01  4.47856341e+01  1.96e-10 2.02e-12  1.11e-10     4s
#   50   4.47856357e+01  4.47856350e+01  2.10e-10 1.31e-10  1.16e-11     4s
#   51   4.47856352e+01  4.47856351e+01  4.39e-09 7.74e-11  1.94e-12     4s
#
# Barrier solved model in 51 iterations and 4.16 seconds
# Optimal objective 4.47856352e+01
#
#
# Root relaxation: objective 4.478564e+01, 5822 iterations, 3.94 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   44.78564    0   14          -   44.78564      -     -    4s
# H    0     0                      45.5389686   44.78564  1.65%     -    6s
#      0     0     cutoff    0        45.53897   45.53897  0.00%     -    6s
#
# Explored 1 nodes (5838 simplex iterations) in 6.48 seconds
# Thread count was 3 (of 4 available processors)
#
# Solution count 1: 45.539
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.7835e-06) exceeds tolerance
# Best objective 4.553896855278e+01, best bound 4.553896855278e+01, gap 0.0000%
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 6.482841491699219
# Error rc: 0
# Time: 7.326419830322266
#
#
# Name: x27264
# Lower bound: 45.538968552776126
# Upper bound: 45.538968552776126
# Number of objectives: 1
# Number of constraints: 50111
# Number of variables: 27264
# Number of binary variables: 28
# Number of integer variables: 38
# Number of continuous variables: 27226
# Number of nonzeros: 147376
# Sense: minimize
#
# Solve time: 9.497755527496338 sec.
#
# Processing optimization output...
# for SourceSinkModel ...    (0.9060sec)
# for ConversionModel ...    (0.5936sec)
# for TransmissionModel ...  (1.8277sec)
# for StorageModel ...       (4.8113sec)
# 		(8.1387 sec)
#
#
# Writing output to Excel...
# 	Processing SourceSinkModel ...
# 	Processing ConversionModel ...
# 	Processing TransmissionModel ...
# 	Processing StorageModel ...
# 	Saving file...
# Done. (50.0663 sec)

# %% [markdown]
# ### Read only

# %%
esM, esMData = fn.readEnergySystemModelFromExcel()
# Out:
# The distances of a component are set to a normalized value of 1.
