# %% [markdown]
# # Using Excel for parameter input and model runs
#
# Besides using a python script or a jupyter notebook it is also possible to read and run a model using excel files.
#
# The energySystemModelRunFromExcel() function reads a model from excel, optimizes it and stores it to an excel file.
#
# The readEnergySystemModelFromExcel() function reads a model from excel.
#
# The model run can also be started on double-klicking on the run.bat Windows batch script in the folder where this notebook is located (still requires that a Python version, the FINE package and an optmization solver are installed).
#
# Moreover, it is possible to run the model inside the Excel file with a VBA Macro (see scenarioInputWithMacro.xlsx)

# %% [markdown]
# # Import FINE package

# %%
import FINE as fn 
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Call energySystemModelRunFromExcel function

# %% [markdown]
# ### Read model from excel file, optimize and store to excel file
# Checkout the output excel file in the folder where this notebook is located

# %%
esM = fn.energySystemModelRunFromExcel()
# Out:
# The distances of a component are set to a normalized value of 1.
#
# Clustering time series data with 3 typical periods and 24 time steps per period...
# 		(3.9540 sec)
#
# Time series aggregation specifications:
# Number of typical periods:3, number of time steps per periods:24
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0530 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.8650 sec)
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.2280 sec)
#
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.1580 sec)
#
# Declaring shared potential constraint...
# 		(0.0020 sec)
#
# Declaring commodity balances...
# 		(0.3850 sec)
#
# Declaring objective function...
# 		(0.2720 sec)
#
# Academic license - for non-commercial use only
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Changed value of parameter logfile to
#    Prev: gurobi.log  Default:
# Changed value of parameter Threads to 3
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Changed value of parameter method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Changed value of parameter OptimalityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Changed value of parameter cuts to 0
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Optimize a model with 50111 rows, 27264 columns and 147376 nonzeros
# Variable types: 27226 continuous, 38 integer (28 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 5e+02]
#   Objective range  [2e-06, 3e-01]
#   Bounds range     [1e+00, 6e+04]
#   RHS range        [4e-02, 5e+01]
# Presolve removed 13620 rows and 10101 columns
# Presolve time: 0.27s
# Presolved: 36491 rows, 17163 columns, 119873 nonzeros
# Variable types: 17139 continuous, 24 integer (14 binary)
# Presolve removed 14 rows and 14 columns
# Presolved: 36477 rows, 17149 columns, 119845 nonzeros
#
# Root barrier log...
#
# Ordering time: 0.30s
#
# Barrier statistics:
#  Dense cols : 168
#  Free vars  : 552
#  AA' NZ     : 4.919e+05
#  Factor NZ  : 1.898e+06 (roughly 40 MBytes of memory)
#  Factor Ops : 4.060e+08 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7
#   36   4.47928293e+01  4.47703008e+01  2.61e-07 1.73e-08  3.77e-07     2s
#   37   4.47897295e+01  4.47786686e+01  1.40e-07 8.10e-09  1.85e-07     2s
#   38   4.47884046e+01  4.47803441e+01  8.84e-08 6.26e-09  1.35e-07     2s
#   39   4.47882316e+01  4.47821516e+01  8.21e-08 4.07e-09  1.02e-07     2s
#   40   4.47871931e+01  4.47844299e+01  4.27e-08 2.74e-09  4.62e-08     2s
#   41   4.47865133e+01  4.47845310e+01  1.89e-08 2.02e-09  3.31e-08     2s
#   42   4.47861175e+01  4.47851722e+01  9.32e-09 1.03e-09  1.58e-08     2s
#   43   4.47860231e+01  4.47855724e+01  4.25e-09 4.62e-10  7.53e-09     2s
#   44   4.47859814e+01  4.47856540e+01  2.83e-09 3.43e-10  5.47e-09     2s
#   45   4.47859498e+01  4.47857216e+01  1.75e-09 2.48e-10  3.81e-09     2s
#   46   4.47859283e+01  4.47858086e+01  1.93e-09 1.24e-10  2.00e-09     2s
#   47   4.47859114e+01  4.47858313e+01  1.38e-09 8.78e-11  1.34e-09     2s
#   48   4.47858965e+01  4.47858654e+01  6.67e-10 4.42e-11  5.22e-10     3s
#   49   4.47858888e+01  4.47858857e+01  3.42e-10 1.60e-09  5.51e-11     3s
#   50   4.47858877e+01  4.47858839e+01  1.41e-10 2.28e-08  2.28e-11     3s
#   51   4.47858871e+01  4.47858866e+01  9.27e-10 1.39e-09  4.63e-12     3s
#
# Barrier solved model in 51 iterations and 2.61 seconds
# Optimal objective 4.47858871e+01
#
#
# Root relaxation: objective 4.478589e+01, 6046 iterations, 2.47 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   44.78589    0   14          -   44.78589      -     -    3s
# H    0     0                      45.5411239   44.78589  1.66%     -    4s
#      0     0     cutoff    0        45.54112   45.54112  0.00%     -    4s
#
# Explored 1 nodes (6060 simplex iterations) in 4.31 seconds
# Thread count was 3 (of 8 available processors)
#
# Solution count 1: 45.5411
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.1062e-06) exceeds tolerance
# Best objective 4.554112393757e+01, best bound 4.554112393757e+01, gap 0.0000%
# Freed default Gurobi environment
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 4.31299972534
# Error rc: 0
# Time: 4.828000068664551
#
#
# Name: x27264
# Lower bound: 45.5411239376
# Upper bound: 45.5411239376
# Number of objectives: 1
# Number of constraints: 50111
# Number of variables: 27264
# Number of binary variables: 28
# Number of integer variables: 38
# Number of continuous variables: 27226
# Number of nonzeros: 147376
# Sense: minimize
#
# Solve time: 7.92900013923645 sec.
#
# Processing optimization output...
# for ConversionModel ...    (0.5390sec)
# for StorageModel ...       (2.3030sec)
# for SourceSinkModel ...    (0.8720sec)
# for TransmissionModel ...  (1.6900sec)
# 		(5.4050 sec)
#
#
# Writing output to Excel...
# 		(24.5320 sec)

# %% [markdown]
# ### Read only

# %%
esM, esMData = fn.readEnergySystemModelFromExcel()
# Out:
# The distances of a component are set to a normalized value of 1.
