# %%
import os
import sys

import pandas as pd
import xarray as xr

import fine as fn
import fine.IOManagement.xarrayIO as xrIO

cwd=os.getcwd()

# %% [markdown]
# # Workflow for spatial aggregation of an energy system model
#
# This example notebook shows how model regions can be merged to obtain fewer regions
#
# <img src="figures/spatial_aggregation_for_example_notebook.png" style="width: 1000px;"/>
#
# The figure above dipicts the basic idea behind spatial aggregation. The term spatial aggregation refers to grouping
# and subsequently merging the regions that are similar in some sense (NOTE: Please look into the documentation for
# different methods to group regions).

# %% [markdown]
# ## STEP 1. Set up your ESM instance

# %%
from getModel import getModel
cwd=os.getcwd()
esM = getModel()
# Out:
# The distances of a component are set to a normalized value of 1.
# /fast/home/k-okosun/iek3-models/fine/fine/utils.py:1213: UserWarning: A declaration of bigM is not necessary if hasIsBuiltBinaryVariable is set to false. The value of bigM will be ignored in the optimization.
#   warnings.warn(

# %%
esM.locations
# Out:
# {'cluster_0',
#  'cluster_1',
#  'cluster_2',
#  'cluster_3',
#  'cluster_4',
#  'cluster_5',
#  'cluster_6',
#  'cluster_7'}

# %% [markdown]
# ## STEP 2. Spatial Aggregation

# %%
# The input data to spatial aggregation are esM instance and the shapefile containing model regions' geometries

SHAPEFILE_PATH = os.path.join(cwd,
    "InputData/SpatialData/ShapeFiles/clusteredRegions.shp",
)

# %%
# Once the regions are grouped, the data witin each region group needs to be aggregated. Through the aggregation_function_dict
# parameter, it is possible to define/change how each variable show be aggregated. Please refer to the documentation for more
# information.

aggregation_function_dict = {
    "operationRateMax": ("weighted mean", "capacityMax"),
    "operationRateFix": ("sum", None),
}

# %%
# You can provide a path to save the results with desired file names. Two files are saved - a shapefile containing
# the merged region geometries and a netcdf file containing the aggregated esM instance data.
shp_name = "aggregated_regions"
aggregated_xr_filename = "aggregated_xr_ds.nc"

# %%
# Spatial aggregation
aggregated_esM = esM.aggregateSpatially(
    shapefile=SHAPEFILE_PATH,
    grouping_mode="parameter_based",
    n_groups=4,
    aggregatedResultsPath=os.path.join(cwd, "output_data"),
    aggregation_function_dict=aggregation_function_dict,
    shp_name=shp_name,
    aggregated_xr_filename=aggregated_xr_filename,
    solver="glpk",
)
# Out:
# 0 iteration: Solving instance
# Total distance: 2201.2932322735014 with solving time: 0.01094508171081543
# 2 contiguity constraints/cuts added, adding to a total number of 2 cuts within time: 0.0020482540130615234
# 1 iteration: Solving instance
# Total distance: 2764.01027082518 with solving time: 0.007772684097290039
# 6 contiguity constraints/cuts added, adding to a total number of 8 cuts within time: 0.005990266799926758
# 2 iteration: Solving instance
# Total distance: 3208.31542914801 with solving time: 0.007917642593383789
# 0 contiguity constraints/cuts added, adding to a total number of 8 cuts within time: 0.00022482872009277344
# elapsed time for perform_parameter_based_grouping: 0.00 minutes
# elapsed time for perform_spatial_aggregation: 0.05 minutes
# /fast/home/k-okosun/iek3-models/fine/fine/utils.py:1213: UserWarning: A declaration of bigM is not necessary if hasIsBuiltBinaryVariable is set to false. The value of bigM will be ignored in the optimization.
#   warnings.warn(

# %%
# Original spatial resolution
fig, ax = fn.plotLocations(SHAPEFILE_PATH, plotLocNames=True, indexColumn="index")

# %%
# Spatial resolution after aggregation
AGGREGATED_SHP_PATH = os.path.join(cwd, "output_data", f"{shp_name}.shp")

fig, ax = fn.plotLocations(AGGREGATED_SHP_PATH, plotLocNames=True, indexColumn="space")

# %%
# The locations in the resulting esM instance are now 4.
aggregated_esM.locations
# Out:
# {'cluster_0_cluster_2',
#  'cluster_1_cluster_3_cluster_5_cluster_6',
#  'cluster_4',
#  'cluster_7'}

# %%
#  And corresponding data has also been aggregated
aggregated_esM.getComponentAttribute("Wind (onshore)", "operationRateMax")
# Out:
# space  cluster_0_cluster_2  cluster_1_cluster_3_cluster_5_cluster_6  \
# time
# 0                 0.778801                                 0.896089
# 1                 0.779175                                 0.889352
# 2                 0.772609                                 0.875346
# 3                 0.762311                                 0.851198
# 4                 0.740985                                 0.824188
# ...                    ...                                      ...
# 8755              0.535852                                 0.515689
# 8756              0.510271                                 0.474827
# 8757              0.530000                                 0.432508
# 8758              0.529114                                 0.393702
# 8759              0.480871                                 0.386609
#
# space  cluster_4  cluster_7
# time
# 0       0.276660   0.623974
# 1       0.275148   0.667338
# 2       0.286690   0.696272
# 3       0.303492   0.705269
# 4       0.324501   0.710336
# ...          ...        ...
# 8755    0.155183   0.426975
# 8756    0.119844   0.429161
# 8757    0.101342   0.507018
# 8758    0.093761   0.396641
# 8759    0.101512   0.313036
#
# [8760 rows x 4 columns]

# %% [markdown]
# # Step 3. Temporal Aggregation
#
# Although spatial aggregation aids in reducing the computational complexity of optimization, temporal aggregation is still necessary.
#
# Spatial aggregation is not here is replace temporal aggregation. They both go hand-in-hand.
#
# Imagine performing temporal aggregation on a model with too many regions. You have to reduce the temporal resolution to a large extent. Or you can take too few regions and reduce the temporal resolution to a smaller extent.
#
# With spatial and temporal aggregation, you need not compromise on either the temporal or spatial resolution of your model.

# %%
aggregated_esM.aggregateTemporally(numberOfTypicalPeriods=7)
# Out:
# Clustering time series data with 7 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(3.1512 sec)

# %% [markdown]
# # Step 5. Optimization

# %%
aggregated_esM.optimize(timeSeriesAggregation=True)
# The following `optimizationSpecs` are recommended if you use the Gurobi solver.
# aggregated_esM.optimize(timeSeriesAggregation=True,
#                         optimizationSpecs='OptimalityTol=1e-3 method=2 cuts=0')
# Out:
# Time series aggregation specifications:
# Number of typical periods:7, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0981 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0249 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.3197 sec)
#
# Declaring sets, variables and constraints for LOPFModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0311 sec)
#
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.1864 sec)
#
# Declaring shared potential constraint...
# 		(0.0005 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.0403 sec)
#
# 		(0.0000 sec)
#
# Declaring objective function...
# 		(0.3755 sec)
#
# Either solver not selected or specified solver not available.gurobi is set as solver.
# Set parameter ServerPassword
# Set parameter TSPort to value 41955
# Set parameter GURO_PAR_SPECIAL
# Set parameter TokenServer to value "iek3028"
# Read LP format model from file /tmp/tmpspfhraym.pyomo.lp
# Reading time = 0.03 seconds
# x1: 15910 rows, 8034 columns, 46799 nonzeros
# Set parameter QCPDual to value 1
# Set parameter Threads to value 3
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (linux64 - "Rocky Linux 8.8 (Green Obsidian)")
#
# CPU model: Intel(R) Xeon(R) Gold 6154 CPU @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 36 physical cores, 72 logical processors, using up to 3 threads
#
# Optimize a model with 15910 rows, 8034 columns and 46799 nonzeros
# Model fingerprint: 0x479ba6e8
# Coefficient statistics:
#   Matrix range     [2e-07, 5e+02]
#   Objective range  [6e-04, 1e-01]
#   Bounds range     [2e-01, 3e+04]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 6353 rows and 3591 columns
# Presolve time: 0.06s
# Presolved: 9557 rows, 4443 columns, 39743 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier statistics:
#  Dense cols : 102
#  Free vars  : 84
#  AA' NZ     : 1.258e+05
#  Factor NZ  : 5.158e+05 (roughly 10 MB of memory)
#  Factor Ops : 7.484e+07 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.30479448e+03 -1.12657401e+04  1.51e+04 7.58e-01  2.76e+02     0s
#    1   1.69921057e+03 -6.79523635e+03  1.02e+04 3.60e-01  1.66e+02     0s
#    2   1.06120654e+03 -5.07636353e+03  4.37e+03 1.79e-01  7.89e+01     0s
#    3   5.64077880e+02 -3.81725862e+03  5.92e+02 3.78e-02  1.89e+01     0s
#    4   3.80003322e+02 -1.58511276e+03  1.30e+01 2.85e-03  1.98e+00     0s
#    5   2.38457188e+02 -1.06670339e+03  4.28e+00 1.33e-03  8.82e-01     0s
#    6   1.30980050e+02 -4.49187274e+02  2.96e-01 3.54e-04  2.66e-01     0s
#    7   1.12448495e+02 -1.37333139e+02  1.39e-01 1.33e-04  1.04e-01     0s
#    8   1.08781752e+02 -1.26421445e+02  1.21e-01 9.12e-05  8.68e-02     0s
#    9   9.69986143e+01 -4.64383662e+01  6.64e-02 4.97e-05  4.94e-02     0s
#   10   9.15830978e+01 -3.91398834e+01  5.08e-02 4.50e-05  4.40e-02     0s
#   11   6.68737457e+01  1.01082573e+01  7.82e-03 1.48e-05  1.69e-02     0s
#   12   5.21680229e+01  8.14875388e+00  3.45e-03 1.99e-05  1.21e-02     0s
#   13   4.17129933e+01  2.34995542e+01  9.41e-04 8.73e-06  4.87e-03     0s
#   14   3.84479238e+01  2.98518062e+01  3.79e-04 5.72e-06  2.27e-03     0s
#   15   3.74185181e+01  3.29870640e+01  2.26e-04 2.31e-06  1.17e-03     0s
#   16   3.70525587e+01  3.43929918e+01  1.74e-04 1.60e-06  6.98e-04     0s
#   17   3.66687490e+01  3.53981772e+01  8.12e-05 1.33e-06  3.33e-04     0s
#   18   3.64498284e+01  3.58062457e+01  3.02e-05 1.03e-06  1.69e-04     0s
#   19   3.63893468e+01  3.60789987e+01  1.58e-05 5.44e-07  8.13e-05     0s
#   20   3.63551042e+01  3.62369646e+01  8.41e-06 7.66e-07  3.09e-05     0s
#   21   3.63262660e+01  3.62643310e+01  3.20e-06 1.53e-06  1.62e-05     0s
#   22   3.63180103e+01  3.62887042e+01  1.84e-06 1.58e-06  7.66e-06     0s
#   23   3.63137985e+01  3.62951157e+01  1.19e-06 1.15e-06  4.88e-06     0s
#   24   3.63128526e+01  3.63012738e+01  1.02e-06 9.45e-07  3.02e-06     0s
#   25   3.63105960e+01  3.63034094e+01  6.21e-07 6.16e-07  1.88e-06     0s
#   26   3.63083115e+01  3.63063183e+01  1.92e-07 1.37e-07  5.19e-07     0s
#   27   3.63076818e+01  3.63069092e+01  8.12e-08 1.86e-07  2.01e-07     0s
#   28   3.63074429e+01  3.63071080e+01  4.11e-08 1.49e-07  8.72e-08     0s
#   29   3.63073380e+01  3.63071665e+01  2.36e-08 3.86e-08  4.46e-08     0s
#   30   3.63072179e+01  3.63071840e+01  3.56e-09 1.60e-08  8.82e-09     0s
#   31   3.63072068e+01  3.63071921e+01  1.76e-09 5.20e-09  3.81e-09     1s
#   32   3.63072024e+01  3.63071949e+01  1.07e-09 1.74e-09  1.96e-09     1s
#   33   3.63071964e+01  3.63071953e+01  2.99e-10 1.12e-09  2.75e-10     1s
#   34   3.63071958e+01  3.63071957e+01  1.35e-08 9.28e-10  3.71e-11     1s
#
# Barrier solved model in 34 iterations and 0.56 seconds (0.40 work units)
# Optimal objective 3.63071958e+01
#
# Crossover log...
#
#     1795 DPushes remaining with DInf 2.2511043e-05                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1317 PPushes remaining with PInf 2.6428348e-03                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.9135581e-03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2360    3.6307198e+01   0.000000e+00   3.913558e-03      1s
#
# Solved with barrier
#     2401    3.6307196e+01   0.000000e+00   0.000000e+00      1s
#
# Solved in 2401 iterations and 0.66 seconds (0.52 work units)
# Optimal objective  3.630719578e+01
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 0.66090989112854
# Error rc: 0
# Time: 0.9566736221313477
#
#
# Name: x1
# Lower bound: 36.30719577985106
# Upper bound: 36.30719577985106
# Number of objectives: 1
# Number of constraints: 15910
# Number of variables: 8034
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 8034
# Number of nonzeros: 46799
# Sense: minimize
#
# Solve time: 1.257824182510376 sec.
#
# Processing optimization output...
# for SourceSinkModel ...    (0.4818sec)
# for ConversionModel ...    (0.2023sec)
# /fast/home/k-okosun/iek3-models/fine/fine/storage.py:1984: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# for StorageModel ...       (0.8432sec)
# for LOPFModel ...          (0.4399sec)
# for TransmissionModel ...  (0.6768sec)
# 		(2.6553 sec)
