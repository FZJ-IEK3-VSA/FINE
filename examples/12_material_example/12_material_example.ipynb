# %% [markdown]
# # Workflow for a multi-regional energy system
#
# In this application of the ETHOS.FINE framework, a multi-regional energy system is modeled and optimized.
#
# All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
# The workflow is structures as follows:
# 1. Required packages are imported and the input data path is set
# 2. An energy system model instance is created
# 3. Commodity sources are added to the energy system model
# 4. Commodity conversion components are added to the energy system model
# 5. Commodity storages are added to the energy system model
# 6. Commodity transmission components are added to the energy system model
# 7. Commodity sinks are added to the energy system model
# 8. The energy system model is optimized
# 9. Selected optimization results are presented

# %% [markdown]
# # 1. Import required packages and set input data path
#
# The ETHOS.FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import fine as fn
import matplotlib.pyplot as plt
from getData import getData
import pandas as pd
import os

cwd = os.getcwd()
data = getData()

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Index(['GermanyRegion', 'FranceRegion'], dtype='object')
# GermanyRegion    45.068240
# FranceRegion     65.918145
# Name: 0, dtype: float64

# %% [markdown]
# # 2. Create an energy system model instance
#
# The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
# The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {"GermanyRegion", "FranceRegion"}
onlycommodityUnitsDict = {
    "electricity": r"GW$_{el}$",
    "methane": r"GW$_{CH_{4},LHV}$",
    "biogas": r"GW$_{biogas,LHV}$",
    "CO2": r"Mio. t$_{CO_2}$/h",
    "hydrogen": r"GW$_{H_{2},LHV}$",
}
onlycommodities = {"electricity", "hydrogen", "methane", "biogas", "CO2"}
onlymaterials={"steel", "copper", "lithium"}
onlymaterialUnitsDict={"steel": r"tons", "copper": r"tons" , "lithium": r"tons"}
numberOfTimeSteps = 8760
hoursPerTimeStep = 1


pathwayBalanceLimit = pd.DataFrame(columns=["GermanyRegion", "FranceRegion", "lowerBound"], index=["Copper_Resources", "Steel_Resources", "Lithium_Resources"])
pathwayBalanceLimit.loc["Copper_Resources"] = [5555000, 5555000, False]
pathwayBalanceLimit.loc["Steel_Resources"] = [5555000, 5555000, False]
pathwayBalanceLimit.loc["Lithium_Resources"] = [5555000, 5555000, False]

# %%
numberOfInvestmentPeriods=3
startYear=2020
interval=5

# %%
esM = fn.EnergySystemModel(
    locations=locations,
    onlycommodities=onlycommodities,
    onlymaterials=onlymaterials,
    numberOfInvestmentPeriods=numberOfInvestmentPeriods,
    startYear=startYear, 
    investmentPeriodInterval=interval,
    numberOfTimeSteps=8760,
    onlycommodityUnitsDict=onlycommodityUnitsDict,
    onlymaterialUnitsDict=onlymaterialUnitsDict,
    hoursPerTimeStep=1,
    costUnit="1e9 Euro",
    lengthUnit="km",
    verboseLogLevel=0,
    pathwayBalanceLimit=pathwayBalanceLimit,
)

# %%
CO2_reductionTarget = 1

# %% [markdown]
# # 3. Add commodity sources to the energy system model

# %% [markdown]
# ## 3.1. Electricity sources

# %% [markdown]
# ### Wind onshore

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Wind (onshore)",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=1.1,
        opexPerCapacity=1.1 * 0.02,
        interestRate=0.08,
        economicLifetime=5,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({  2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'copper': pd.Series({  2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64')
 
            },
             'FranceRegion': {
                'steel': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'copper': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64')
               
            }
        },
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'copper': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64')
            },
            'FranceRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'copper': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64')
            }
        }
        
    )
)

# %% [markdown]
# Full load hours:

# %%
data["Wind (onshore), operationRateMax"].sum()
# Out:
# FranceRegion     2350.292663
# GermanyRegion    1572.003960
# dtype: float64

# %% [markdown]
# ### Wind offshore

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Wind (offshore)",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (offshore), operationRateMax"],
        capacityMax=data["Wind (offshore), capacityMax"],
        investPerCapacity=2.3,
        opexPerCapacity=2.3 * 0.02,
        interestRate=0.08,
        economicLifetime=5,
         
    )
)

# %% [markdown]
# Full load hours:

# %%
data["Wind (offshore), operationRateMax"].sum()
# Out:
# FranceRegion     4301.655834
# GermanyRegion    4435.420314
# dtype: float64

# %% [markdown]
# ### PV

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="PV",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["PV, operationRateMax"],
        capacityMax=data["PV, capacityMax"],
        investPerCapacity=0.65,
        opexPerCapacity=0.65 * 0.02,
        interestRate=0.08,
        economicLifetime=25,
    )
)

# %% [markdown]
# Full load hours:

# %%
data["PV, operationRateMax"].sum()
# Out:
# FranceRegion     1053.579422
# GermanyRegion    1113.216464
# dtype: float64

# %% [markdown]
# ### Exisisting run-of-river hydroelectricity plants

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Existing run-of-river plants",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateFix=data["Existing run-of-river plants, operationRateFix"],
        tsaWeight=0.01,
        capacityFix=data["Existing run-of-river plants, capacityFix"],
        investPerCapacity=0,
        opexPerCapacity=0.208,
    )
)

# %% [markdown]
# ## 3.2. Methane (natural gas and biogas)

# %% [markdown]
# ### Natural gas

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Natural gas purchase",
        commodity="methane",
        hasCapacityVariable=False,
        commodityCost=0.0331 * 1e-3,
    )
)

# %% [markdown]
# ### Biogas

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Biogas purchase",
        commodity="biogas",
        operationRateMax=data["Biogas, operationRateMax"],
        hasCapacityVariable=False,
        commodityCost=0.05409 * 1e-3,
    )
)

# %% [markdown]
# # 4. Add conversion components to the energy system model

# %% [markdown]
# ### Combined cycle gas turbine plants

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="CCGT plants (methane)",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={
            "electricity": 1,
            "methane": -1 / 0.6,
            "CO2": 201 * 1e-6 / 0.6,
        },
        hasCapacityVariable=True,
        investPerCapacity=0.65,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=5,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({  2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'copper': pd.Series({  2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64')
 
            },
             'FranceRegion': {
                'steel': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'copper': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64')
               
            }
        },
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'copper': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64')
            },
            'FranceRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'copper': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64')
            }
        }
    )
)

# %% [markdown]
# ### New combined cycle gas turbine plants for biogas

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="New CCGT plants (biogas)",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": 1, "biogas": -1 / 0.63},
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

# %% [markdown]
# ### New combined cycly gas turbines for hydrogen

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="New CCGT plants (hydrogen)",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": 1, "hydrogen": -1 / 0.63},
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

# %% [markdown]
# ### Electrolyzers

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Electrolyzer",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.7},
        hasCapacityVariable=True,
        investPerCapacity=0.5,
        opexPerCapacity=0.5 * 0.025,
        interestRate=0.08,
        economicLifetime=10,
    )
)

# %% [markdown]
# ### rSOC

# %%
capexRSOC = 1.5

esM.add(
    fn.Conversion(
        esM=esM,
        name="rSOEC",
        physicalUnit=r"GW$_{el}$",
        linkedConversionCapacityID="rSOC",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.6},
        hasCapacityVariable=True,
        investPerCapacity=capexRSOC / 2,
        opexPerCapacity=capexRSOC * 0.02 / 2,
        interestRate=0.08,
        economicLifetime=10,
    )
)

esM.add(
    fn.Conversion(
        esM=esM,
        name="rSOFC",
        physicalUnit=r"GW$_{el}$",
        linkedConversionCapacityID="rSOC",
        commodityConversionFactors={"electricity": 1, "hydrogen": -1 / 0.6},
        hasCapacityVariable=True,
        investPerCapacity=capexRSOC / 2,
        opexPerCapacity=capexRSOC * 0.02 / 2,
        interestRate=0.08,
        economicLifetime=10,
    )
)

# %% [markdown]
# # 5. Add commodity storages to the energy system model

# %% [markdown]
# ## 5.1. Electricity storage

# %% [markdown]
# ### Lithium ion batteries
#
# The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Li-ion batteries",
        commodity="electricity",
        hasCapacityVariable=True,
        chargeEfficiency=0.95,
        cyclicLifetime=10000,
        dischargeEfficiency=0.95,
        selfDischarge=1 - (1 - 0.03) ** (1 / (30 * 24)),
        chargeRate=1,
        dischargeRate=1,
        doPreciseTsaModeling=False,
        investPerCapacity=0.151,
        opexPerCapacity=0.002,
        interestRate=0.08,
        economicLifetime=5,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({  2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'lithium': pd.Series({  2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64')
 
            },
             'FranceRegion': {
                'steel': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'lithium': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64')
               
            }
        },
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'lithium': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64')
            },
            'FranceRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'lithium': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64')
            }
        }
         
    )
)

# %% [markdown]
# ## 5.2. Hydrogen storage

# %% [markdown]
# ### Hydrogen filled salt caverns
# The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (hydrogen)",
        commodity="hydrogen",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=133,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (hydrogen), capacityMax"],
        investPerCapacity=0.00011,
        opexPerCapacity=0.00057,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
# ## 5.3. Methane storage

# %% [markdown]
# ### Methane filled salt caverns

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (biogas)",
        commodity="biogas",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=443,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (methane), capacityMax"],
        investPerCapacity=0.00004,
        opexPerCapacity=0.00001,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
# ## 5.4 Pumped hydro storage

# %% [markdown]
# ### Pumped hydro storage

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Pumped hydro storage",
        commodity="electricity",
        chargeEfficiency=0.88,
        dischargeEfficiency=0.88,
        hasCapacityVariable=True,
        selfDischarge=1 - (1 - 0.00375) ** (1 / (30 * 24)),
        chargeRate=0.16,
        dischargeRate=0.12,
        capacityFix=data["Pumped hydro storage, capacityFix"],
        investPerCapacity=0,
        opexPerCapacity=0.000153,
    )
)

# %% [markdown]
# # 6. Add commodity transmission components to the energy system model

# %% [markdown]
# ## 6.1. Electricity transmission

# %% [markdown]
# ### AC cables

# %% [markdown]
# esM.add(fn.LinearOptimalPowerFlow(esM=esM, name='AC cables', commodity='electricity',
#                                   hasCapacityVariable=True, capacityFix=data['AC cables, capacityFix'],
#                                   reactances=data['AC cables, reactances']))

# %%
esM.add(
    fn.Transmission(
        esM=esM,
        name="AC cables",
        commodity="electricity",
        hasCapacityVariable=True,
        capacityFix=data["AC cables, capacityFix"],
    )
)
# Out:
# The distances of a component are set to a normalized value of 1.

# %% [markdown]
# ### DC cables

# %%
# esM.add(
#     fn.Transmission(
#         esM=esM,
#         name="DC cables",
#         commodity="electricity",
#         losses=data["DC cables, losses"],
#         distances=data["DC cables, distances"],
#         hasCapacityVariable=True,
#         capacityFix=data["DC cables, capacityFix"],
#     )
# )

# %% [markdown]
# ## 6.2 Methane transmission

# %% [markdown]
# ### Methane pipeline

# %%
esM.add(
    fn.Transmission(
        esM=esM,
        name="Pipelines (biogas)",
        commodity="biogas",
        distances=data["Pipelines, distances"],
        hasCapacityVariable=True,
        hasIsBuiltBinaryVariable=True,
        bigM=300,
        locationalEligibility=data["Pipelines, eligibility"],
        capacityMax=data["Pipelines, eligibility"] * 15,
        sharedPotentialID="pipelines",
        investPerCapacity=0.000037,
        investIfBuilt=0.000314,
        interestRate=0.08,
        economicLifetime=40,
    )
)

# %% [markdown]
# ## 6.3 Hydrogen transmission

# %% [markdown]
# ### Hydrogen pipelines

# %%
esM.add(
    fn.Transmission(
        esM=esM,
        name="Pipelines (hydrogen)",
        commodity="hydrogen",
        distances=data["Pipelines, distances"],
        hasCapacityVariable=True,
        hasIsBuiltBinaryVariable=True,
        bigM=300,
        locationalEligibility=data["Pipelines, eligibility"],
        capacityMax=data["Pipelines, eligibility"] * 15,
        sharedPotentialID="pipelines",
        investPerCapacity=0.000177,
        investIfBuilt=0.00033,
        interestRate=0.08,
        economicLifetime=40,
    )
)

# %% [markdown]
# # 7. Add commodity sinks to the energy system model

# %% [markdown]
# ## 7.1. Electricity sinks

# %% [markdown]
# ### Electricity demand

# %%
esM.add(
    fn.Sink(
        esM=esM,
        name="Electricity demand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=data["Electricity demand, operationRateFix"],
    )
)

# %% [markdown]
# ## 7.2. Hydrogen sinks

# %% [markdown]
# ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration = 0.5
esM.add(
    fn.Sink(
        esM=esM,
        name="Hydrogen demand",
        commodity="hydrogen",
        hasCapacityVariable=False,
        operationRateFix=data["Hydrogen demand, operationRateFix"] * FCEV_penetration,
    )
)

# %% [markdown]
# ## 7.3. CO2 sinks

# %% [markdown]
# ### CO2 exiting the system's boundary

# %%
esM.add(
    fn.Sink(
        esM=esM,
        name="CO2 to enviroment",
        commodity="CO2",
        hasCapacityVariable=False,
        commodityLimitID="CO2 limit",
        yearlyLimit=366 * (1 - CO2_reductionTarget),
    )
)

# %%
sink = esM.add(
    fn.Sink(
        esM=esM,
        name="Steel demand",
        hasCapacityVariable=False,
        commodity="steel",
        material=True,      
    )
)

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Steel recovery",
        hasCapacityVariable=False,
        commodity="steel",
        material=True,      
    )
)
 


esM.add(
    fn.Source(
        esM=esM,
        name="Steel supply",
        hasCapacityVariable=False,
        commodity="steel", 
        pathwayBalanceLimitID="Steel_Resources"
    )
)
 

esM.add(
    fn.Source(
        esM=esM,
        name="Copper recovery",
        hasCapacityVariable=False,
        commodity="copper",
        material=True,      
    )
)
 


esM.add(
    fn.Source(
        esM=esM,
        name="Copper supply",
        hasCapacityVariable=False,
        commodity="copper", 
        pathwayBalanceLimitID="Copper_Resources"
    )
)

esM.add(
    fn.Source(
        esM=esM,
        name="Lithium recovery",
        hasCapacityVariable=False,
        commodity="lithium",
        material=True,     
    )
)
 


esM.add(
    fn.Source(
        esM=esM,
        name="Lithium supply",
        hasCapacityVariable=False,
        commodity="lithium",
        pathwayBalanceLimitID="Lithium_Resources"
    )
)

# %%
esM.generationMaterialSinks()
# Out:
# Existing material sinks: {'steel'}
# Missing materials sinks: {'lithium', 'copper'}
# New sink added: Lithium demand
# New sink added: Copper demand

# %% [markdown]
# All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %% [markdown]
# # 8 Temporal Aggregation

# %%
esM.aggregateTemporally(numberOfTypicalPeriods=3)
# Out:
# Clustering time series data with 3 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(4.9299 sec)

# %% [markdown]
# ### Optimization

# %%
esM.optimize(timeSeriesAggregation=True, solver="gurobi")
# Out:
# Time series aggregation specifications:
# Number of typical periods:3, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0949 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.1783 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(2.4350 sec)
#
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0136 sec)
#
# Declaring shared potential constraint...
# 		(0.0006 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.0524 sec)
#
# Declaring material balances...
# ('FranceRegion', 'Steel demand', 'steel', 0)
# ('FranceRegion', 'Steel demand', 'steel', 1)
# ('FranceRegion', 'Steel demand', 'steel', 2)
# ('GermanyRegion', 'Steel demand', 'steel', 0)
# ('GermanyRegion', 'Steel demand', 'steel', 1)
# ('GermanyRegion', 'Steel demand', 'steel', 2)
# ('FranceRegion', 'Lithium demand', 'lithium', 0)
# ('FranceRegion', 'Lithium demand', 'lithium', 1)
# ('FranceRegion', 'Lithium demand', 'lithium', 2)
# ('GermanyRegion', 'Lithium demand', 'lithium', 0)
# ('GermanyRegion', 'Lithium demand', 'lithium', 1)
# ('GermanyRegion', 'Lithium demand', 'lithium', 2)
# ('FranceRegion', 'Copper demand', 'copper', 0)
# ('FranceRegion', 'Copper demand', 'copper', 1)
# ('FranceRegion', 'Copper demand', 'copper', 2)
# ('GermanyRegion', 'Copper demand', 'copper', 0)
# ('GermanyRegion', 'Copper demand', 'copper', 1)
# ('GermanyRegion', 'Copper demand', 'copper', 2)
# LHS_demand 79*op_srcSnk[FranceRegion,Steel demand,0,0,0] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,1] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,2] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,3] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,4] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,5] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,6] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,7] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,8] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,9] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,10] + 79*op_srcSnk[FranceRegion,Steel demand,0,0,11] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,0] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,1] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,2] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,3] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,4] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,5] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,6] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,7] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,8] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,9] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,10] + 170*op_srcSnk[FranceRegion,Steel demand,0,1,11] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,0] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,1] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,2] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,3] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,4] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,5] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,6] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,7] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,8] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,9] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,10] + 116*op_srcSnk[FranceRegion,Steel demand,0,2,11]
# RHS_demand 3.1*commis_srcSnk[FranceRegion,'Wind (onshore)',0] + 3.1*commis_conv[FranceRegion,'CCGT plants (methane)',0] + 3.1*commis_stor[FranceRegion,Li-ion batteries,0]
# LHS_demand 79*op_srcSnk[FranceRegion,Steel demand,1,0,0] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,1] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,2] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,3] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,4] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,5] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,6] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,7] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,8] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,9] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,10] + 79*op_srcSnk[FranceRegion,Steel demand,1,0,11] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,0] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,1] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,2] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,3] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,4] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,5] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,6] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,7] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,8] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,9] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,10] + 170*op_srcSnk[FranceRegion,Steel demand,1,1,11] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,0] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,1] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,2] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,3] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,4] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,5] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,6] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,7] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,8] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,9] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,10] + 116*op_srcSnk[FranceRegion,Steel demand,1,2,11]
# RHS_demand 3.0*commis_srcSnk[FranceRegion,'Wind (onshore)',1] + 3.0*commis_conv[FranceRegion,'CCGT plants (methane)',1] + 3.0*commis_stor[FranceRegion,Li-ion batteries,1]
# LHS_demand 79*op_srcSnk[FranceRegion,Steel demand,2,0,0] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,1] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,2] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,3] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,4] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,5] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,6] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,7] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,8] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,9] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,10] + 79*op_srcSnk[FranceRegion,Steel demand,2,0,11] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,0] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,1] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,2] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,3] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,4] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,5] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,6] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,7] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,8] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,9] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,10] + 170*op_srcSnk[FranceRegion,Steel demand,2,1,11] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,0] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,1] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,2] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,3] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,4] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,5] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,6] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,7] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,8] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,9] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,10] + 116*op_srcSnk[FranceRegion,Steel demand,2,2,11]
# RHS_demand 2.9*commis_srcSnk[FranceRegion,'Wind (onshore)',2] + 2.9*commis_conv[FranceRegion,'CCGT plants (methane)',2] + 2.9*commis_stor[FranceRegion,Li-ion batteries,2]
# LHS_demand 79*op_srcSnk[GermanyRegion,Steel demand,0,0,0] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,1] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,2] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,3] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,4] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,5] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,6] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,7] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,8] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,9] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,10] + 79*op_srcSnk[GermanyRegion,Steel demand,0,0,11] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,0] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,1] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,2] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,3] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,4] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,5] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,6] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,7] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,8] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,9] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,10] + 170*op_srcSnk[GermanyRegion,Steel demand,0,1,11] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,0] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,1] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,2] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,3] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,4] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,5] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,6] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,7] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,8] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,9] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,10] + 116*op_srcSnk[GermanyRegion,Steel demand,0,2,11]
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,'Wind (onshore)',0] + 3.1*commis_conv[GermanyRegion,'CCGT plants (methane)',0] + 3.1*commis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_demand 79*op_srcSnk[GermanyRegion,Steel demand,1,0,0] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,1] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,2] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,3] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,4] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,5] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,6] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,7] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,8] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,9] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,10] + 79*op_srcSnk[GermanyRegion,Steel demand,1,0,11] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,0] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,1] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,2] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,3] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,4] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,5] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,6] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,7] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,8] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,9] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,10] + 170*op_srcSnk[GermanyRegion,Steel demand,1,1,11] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,0] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,1] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,2] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,3] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,4] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,5] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,6] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,7] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,8] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,9] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,10] + 116*op_srcSnk[GermanyRegion,Steel demand,1,2,11]
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,'Wind (onshore)',1] + 3.0*commis_conv[GermanyRegion,'CCGT plants (methane)',1] + 3.0*commis_stor[GermanyRegion,Li-ion batteries,1]
# LHS_demand 79*op_srcSnk[GermanyRegion,Steel demand,2,0,0] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,1] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,2] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,3] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,4] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,5] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,6] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,7] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,8] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,9] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,10] + 79*op_srcSnk[GermanyRegion,Steel demand,2,0,11] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,0] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,1] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,2] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,3] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,4] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,5] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,6] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,7] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,8] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,9] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,10] + 170*op_srcSnk[GermanyRegion,Steel demand,2,1,11] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,0] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,1] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,2] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,3] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,4] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,5] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,6] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,7] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,8] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,9] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,10] + 116*op_srcSnk[GermanyRegion,Steel demand,2,2,11]
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,'Wind (onshore)',2] + 2.9*commis_conv[GermanyRegion,'CCGT plants (methane)',2] + 2.9*commis_stor[GermanyRegion,Li-ion batteries,2]
# LHS_demand 79*op_srcSnk[FranceRegion,Lithium demand,0,0,0] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,1] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,2] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,3] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,4] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,5] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,6] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,7] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,8] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,9] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,10] + 79*op_srcSnk[FranceRegion,Lithium demand,0,0,11] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,0] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,1] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,2] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,3] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,4] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,5] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,6] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,7] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,8] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,9] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,10] + 170*op_srcSnk[FranceRegion,Lithium demand,0,1,11] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,0] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,1] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,2] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,3] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,4] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,5] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,6] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,7] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,8] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,9] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,10] + 116*op_srcSnk[FranceRegion,Lithium demand,0,2,11]
# RHS_demand 3.1*commis_stor[FranceRegion,Li-ion batteries,0]
# LHS_demand 79*op_srcSnk[FranceRegion,Lithium demand,1,0,0] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,1] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,2] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,3] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,4] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,5] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,6] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,7] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,8] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,9] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,10] + 79*op_srcSnk[FranceRegion,Lithium demand,1,0,11] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,0] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,1] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,2] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,3] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,4] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,5] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,6] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,7] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,8] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,9] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,10] + 170*op_srcSnk[FranceRegion,Lithium demand,1,1,11] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,0] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,1] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,2] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,3] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,4] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,5] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,6] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,7] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,8] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,9] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,10] + 116*op_srcSnk[FranceRegion,Lithium demand,1,2,11]
# RHS_demand 3.0*commis_stor[FranceRegion,Li-ion batteries,1]
# LHS_demand 79*op_srcSnk[FranceRegion,Lithium demand,2,0,0] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,1] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,2] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,3] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,4] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,5] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,6] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,7] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,8] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,9] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,10] + 79*op_srcSnk[FranceRegion,Lithium demand,2,0,11] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,0] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,1] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,2] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,3] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,4] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,5] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,6] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,7] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,8] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,9] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,10] + 170*op_srcSnk[FranceRegion,Lithium demand,2,1,11] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,0] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,1] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,2] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,3] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,4] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,5] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,6] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,7] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,8] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,9] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,10] + 116*op_srcSnk[FranceRegion,Lithium demand,2,2,11]
# RHS_demand 2.9*commis_stor[FranceRegion,Li-ion batteries,2]
# LHS_demand 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,0] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,1] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,2] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,3] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,4] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,5] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,6] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,7] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,8] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,9] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,10] + 79*op_srcSnk[GermanyRegion,Lithium demand,0,0,11] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,0] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,1] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,2] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,3] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,4] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,5] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,6] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,7] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,8] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,9] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,10] + 170*op_srcSnk[GermanyRegion,Lithium demand,0,1,11] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,0] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,1] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,2] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,3] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,4] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,5] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,6] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,7] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,8] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,9] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,10] + 116*op_srcSnk[GermanyRegion,Lithium demand,0,2,11]
# RHS_demand 3.1*commis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_demand 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,0] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,1] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,2] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,3] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,4] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,5] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,6] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,7] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,8] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,9] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,10] + 79*op_srcSnk[GermanyRegion,Lithium demand,1,0,11] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,0] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,1] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,2] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,3] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,4] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,5] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,6] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,7] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,8] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,9] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,10] + 170*op_srcSnk[GermanyRegion,Lithium demand,1,1,11] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,0] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,1] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,2] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,3] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,4] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,5] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,6] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,7] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,8] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,9] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,10] + 116*op_srcSnk[GermanyRegion,Lithium demand,1,2,11]
# RHS_demand 3.0*commis_stor[GermanyRegion,Li-ion batteries,1]
# LHS_demand 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,0] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,1] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,2] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,3] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,4] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,5] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,6] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,7] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,8] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,9] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,10] + 79*op_srcSnk[GermanyRegion,Lithium demand,2,0,11] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,0] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,1] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,2] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,3] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,4] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,5] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,6] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,7] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,8] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,9] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,10] + 170*op_srcSnk[GermanyRegion,Lithium demand,2,1,11] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,0] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,1] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,2] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,3] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,4] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,5] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,6] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,7] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,8] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,9] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,10] + 116*op_srcSnk[GermanyRegion,Lithium demand,2,2,11]
# RHS_demand 2.9*commis_stor[GermanyRegion,Li-ion batteries,2]
# LHS_demand 79*op_srcSnk[FranceRegion,Copper demand,0,0,0] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,1] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,2] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,3] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,4] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,5] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,6] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,7] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,8] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,9] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,10] + 79*op_srcSnk[FranceRegion,Copper demand,0,0,11] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,0] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,1] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,2] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,3] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,4] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,5] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,6] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,7] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,8] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,9] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,10] + 170*op_srcSnk[FranceRegion,Copper demand,0,1,11] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,0] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,1] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,2] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,3] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,4] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,5] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,6] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,7] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,8] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,9] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,10] + 116*op_srcSnk[FranceRegion,Copper demand,0,2,11]
# RHS_demand 3.1*commis_srcSnk[FranceRegion,'Wind (onshore)',0] + 3.1*commis_conv[FranceRegion,'CCGT plants (methane)',0]
# LHS_demand 79*op_srcSnk[FranceRegion,Copper demand,1,0,0] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,1] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,2] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,3] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,4] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,5] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,6] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,7] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,8] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,9] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,10] + 79*op_srcSnk[FranceRegion,Copper demand,1,0,11] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,0] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,1] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,2] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,3] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,4] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,5] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,6] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,7] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,8] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,9] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,10] + 170*op_srcSnk[FranceRegion,Copper demand,1,1,11] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,0] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,1] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,2] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,3] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,4] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,5] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,6] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,7] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,8] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,9] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,10] + 116*op_srcSnk[FranceRegion,Copper demand,1,2,11]
# RHS_demand 3.0*commis_srcSnk[FranceRegion,'Wind (onshore)',1] + 3.0*commis_conv[FranceRegion,'CCGT plants (methane)',1]
# LHS_demand 79*op_srcSnk[FranceRegion,Copper demand,2,0,0] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,1] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,2] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,3] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,4] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,5] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,6] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,7] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,8] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,9] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,10] + 79*op_srcSnk[FranceRegion,Copper demand,2,0,11] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,0] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,1] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,2] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,3] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,4] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,5] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,6] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,7] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,8] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,9] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,10] + 170*op_srcSnk[FranceRegion,Copper demand,2,1,11] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,0] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,1] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,2] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,3] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,4] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,5] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,6] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,7] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,8] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,9] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,10] + 116*op_srcSnk[FranceRegion,Copper demand,2,2,11]
# RHS_demand 2.9*commis_srcSnk[FranceRegion,'Wind (onshore)',2] + 2.9*commis_conv[FranceRegion,'CCGT plants (methane)',2]
# LHS_demand 79*op_srcSnk[GermanyRegion,Copper demand,0,0,0] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,1] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,2] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,3] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,4] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,5] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,6] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,7] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,8] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,9] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,10] + 79*op_srcSnk[GermanyRegion,Copper demand,0,0,11] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,0] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,1] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,2] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,3] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,4] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,5] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,6] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,7] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,8] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,9] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,10] + 170*op_srcSnk[GermanyRegion,Copper demand,0,1,11] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,0] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,1] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,2] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,3] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,4] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,5] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,6] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,7] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,8] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,9] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,10] + 116*op_srcSnk[GermanyRegion,Copper demand,0,2,11]
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,'Wind (onshore)',0] + 3.1*commis_conv[GermanyRegion,'CCGT plants (methane)',0]
# LHS_demand 79*op_srcSnk[GermanyRegion,Copper demand,1,0,0] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,1] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,2] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,3] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,4] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,5] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,6] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,7] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,8] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,9] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,10] + 79*op_srcSnk[GermanyRegion,Copper demand,1,0,11] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,0] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,1] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,2] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,3] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,4] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,5] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,6] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,7] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,8] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,9] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,10] + 170*op_srcSnk[GermanyRegion,Copper demand,1,1,11] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,0] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,1] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,2] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,3] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,4] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,5] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,6] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,7] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,8] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,9] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,10] + 116*op_srcSnk[GermanyRegion,Copper demand,1,2,11]
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,'Wind (onshore)',1] + 3.0*commis_conv[GermanyRegion,'CCGT plants (methane)',1]
# LHS_demand 79*op_srcSnk[GermanyRegion,Copper demand,2,0,0] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,1] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,2] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,3] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,4] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,5] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,6] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,7] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,8] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,9] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,10] + 79*op_srcSnk[GermanyRegion,Copper demand,2,0,11] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,0] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,1] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,2] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,3] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,4] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,5] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,6] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,7] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,8] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,9] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,10] + 170*op_srcSnk[GermanyRegion,Copper demand,2,1,11] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,0] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,1] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,2] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,3] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,4] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,5] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,6] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,7] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,8] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,9] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,10] + 116*op_srcSnk[GermanyRegion,Copper demand,2,2,11]
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,'Wind (onshore)',2] + 2.9*commis_conv[GermanyRegion,'CCGT plants (methane)',2]
# 		(0.0080 sec)
#
# Declaring material balances...
# ('FranceRegion', 'Steel recovery', 'steel', 0)
# ('FranceRegion', 'Steel recovery', 'steel', 1)
# ('FranceRegion', 'Steel recovery', 'steel', 2)
# ('GermanyRegion', 'Steel recovery', 'steel', 0)
# ('GermanyRegion', 'Steel recovery', 'steel', 1)
# ('GermanyRegion', 'Steel recovery', 'steel', 2)
# ('FranceRegion', 'Copper recovery', 'copper', 0)
# ('FranceRegion', 'Copper recovery', 'copper', 1)
# ('FranceRegion', 'Copper recovery', 'copper', 2)
# ('GermanyRegion', 'Copper recovery', 'copper', 0)
# ('GermanyRegion', 'Copper recovery', 'copper', 1)
# ('GermanyRegion', 'Copper recovery', 'copper', 2)
# ('FranceRegion', 'Lithium recovery', 'lithium', 0)
# ('FranceRegion', 'Lithium recovery', 'lithium', 1)
# ('FranceRegion', 'Lithium recovery', 'lithium', 2)
# ('GermanyRegion', 'Lithium recovery', 'lithium', 0)
# ('GermanyRegion', 'Lithium recovery', 'lithium', 1)
# ('GermanyRegion', 'Lithium recovery', 'lithium', 2)
# LHS_recovery 79*op_srcSnk[FranceRegion,Steel recovery,0,0,0] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,1] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,2] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,3] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,4] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,5] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,6] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,7] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,8] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,9] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,10] + 79*op_srcSnk[FranceRegion,Steel recovery,0,0,11] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,0] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,1] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,2] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,3] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,4] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,5] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,6] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,7] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,8] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,9] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,10] + 170*op_srcSnk[FranceRegion,Steel recovery,0,1,11] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,0] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,1] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,2] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,3] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,4] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,5] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,6] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,7] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,8] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,9] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,10] + 116*op_srcSnk[FranceRegion,Steel recovery,0,2,11]
# RHS_recovery 1.1*decommis_srcSnk[FranceRegion,'Wind (onshore)',0] + 1.1*decommis_conv[FranceRegion,'CCGT plants (methane)',0] + 1.1*decommis_stor[FranceRegion,Li-ion batteries,0]
# LHS_recovery 79*op_srcSnk[FranceRegion,Steel recovery,1,0,0] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,1] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,2] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,3] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,4] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,5] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,6] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,7] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,8] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,9] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,10] + 79*op_srcSnk[FranceRegion,Steel recovery,1,0,11] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,0] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,1] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,2] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,3] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,4] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,5] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,6] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,7] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,8] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,9] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,10] + 170*op_srcSnk[FranceRegion,Steel recovery,1,1,11] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,0] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,1] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,2] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,3] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,4] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,5] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,6] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,7] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,8] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,9] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,10] + 116*op_srcSnk[FranceRegion,Steel recovery,1,2,11]
# RHS_recovery 2.635*decommis_srcSnk[FranceRegion,'Wind (onshore)',1] + 2.635*decommis_conv[FranceRegion,'CCGT plants (methane)',1] + 2.635*decommis_stor[FranceRegion,Li-ion batteries,1]
# LHS_recovery 79*op_srcSnk[FranceRegion,Steel recovery,2,0,0] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,1] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,2] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,3] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,4] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,5] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,6] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,7] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,8] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,9] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,10] + 79*op_srcSnk[FranceRegion,Steel recovery,2,0,11] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,0] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,1] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,2] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,3] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,4] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,5] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,6] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,7] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,8] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,9] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,10] + 170*op_srcSnk[FranceRegion,Steel recovery,2,1,11] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,0] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,1] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,2] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,3] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,4] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,5] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,6] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,7] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,8] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,9] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,10] + 116*op_srcSnk[FranceRegion,Steel recovery,2,2,11]
# RHS_recovery 2.7*decommis_srcSnk[FranceRegion,'Wind (onshore)',2] + 2.7*decommis_conv[FranceRegion,'CCGT plants (methane)',2] + 2.7*decommis_stor[FranceRegion,Li-ion batteries,2]
# LHS_recovery 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,0] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,1] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,2] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,3] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,4] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,5] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,6] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,7] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,8] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,9] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,10] + 79*op_srcSnk[GermanyRegion,Steel recovery,0,0,11] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,0] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,1] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,2] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,3] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,4] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,5] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,6] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,7] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,8] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,9] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,10] + 170*op_srcSnk[GermanyRegion,Steel recovery,0,1,11] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,0] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,1] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,2] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,3] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,4] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,5] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,6] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,7] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,8] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,9] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,10] + 116*op_srcSnk[GermanyRegion,Steel recovery,0,2,11]
# RHS_recovery 1.1*decommis_srcSnk[GermanyRegion,'Wind (onshore)',0] + 1.1*decommis_conv[GermanyRegion,'CCGT plants (methane)',0] + 1.1*decommis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_recovery 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,0] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,1] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,2] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,3] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,4] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,5] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,6] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,7] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,8] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,9] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,10] + 79*op_srcSnk[GermanyRegion,Steel recovery,1,0,11] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,0] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,1] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,2] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,3] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,4] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,5] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,6] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,7] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,8] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,9] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,10] + 170*op_srcSnk[GermanyRegion,Steel recovery,1,1,11] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,0] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,1] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,2] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,3] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,4] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,5] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,6] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,7] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,8] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,9] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,10] + 116*op_srcSnk[GermanyRegion,Steel recovery,1,2,11]
# RHS_recovery 2.635*decommis_srcSnk[GermanyRegion,'Wind (onshore)',1] + 2.635*decommis_conv[GermanyRegion,'CCGT plants (methane)',1] + 2.635*decommis_stor[GermanyRegion,Li-ion batteries,1]
# ...
# RHS_recovery 2.7*decommis_srcSnk[GermanyRegion,'Wind (onshore)',2] + 2.7*decommis_conv[GermanyRegion,'CCGT plants (methane)',2]
# LHS_recovery 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,0] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,1] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,2] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,3] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,4] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,5] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,6] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,7] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,8] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,9] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,10] + 79*op_srcSnk[FranceRegion,Lithium recovery,0,0,11] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,0] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,1] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,2] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,3] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,4] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,5] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,6] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,7] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,8] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,9] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,10] + 170*op_srcSnk[FranceRegion,Lithium recovery,0,1,11] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,0] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,1] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,2] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,3] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,4] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,5] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,6] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,7] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,8] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,9] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,10] + 116*op_srcSnk[FranceRegion,Lithium recovery,0,2,11]
# RHS_recovery 1.1*decommis_stor[FranceRegion,Li-ion batteries,0]
# LHS_recovery 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,0] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,1] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,2] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,3] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,4] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,5] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,6] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,7] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,8] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,9] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,10] + 79*op_srcSnk[FranceRegion,Lithium recovery,1,0,11] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,0] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,1] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,2] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,3] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,4] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,5] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,6] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,7] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,8] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,9] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,10] + 170*op_srcSnk[FranceRegion,Lithium recovery,1,1,11] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,0] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,1] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,2] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,3] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,4] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,5] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,6] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,7] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,8] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,9] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,10] + 116*op_srcSnk[FranceRegion,Lithium recovery,1,2,11]
# RHS_recovery 2.635*decommis_stor[FranceRegion,Li-ion batteries,1]
# LHS_recovery 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,0] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,1] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,2] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,3] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,4] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,5] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,6] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,7] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,8] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,9] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,10] + 79*op_srcSnk[FranceRegion,Lithium recovery,2,0,11] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,0] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,1] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,2] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,3] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,4] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,5] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,6] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,7] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,8] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,9] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,10] + 170*op_srcSnk[FranceRegion,Lithium recovery,2,1,11] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,0] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,1] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,2] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,3] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,4] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,5] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,6] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,7] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,8] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,9] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,10] + 116*op_srcSnk[FranceRegion,Lithium recovery,2,2,11]
# RHS_recovery 2.7*decommis_stor[FranceRegion,Li-ion batteries,2]
# LHS_recovery 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,0] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,1] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,2] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,3] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,4] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,5] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,6] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,7] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,8] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,9] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,10] + 79*op_srcSnk[GermanyRegion,Lithium recovery,0,0,11] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,0] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,1] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,2] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,3] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,4] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,5] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,6] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,7] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,8] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,9] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,10] + 170*op_srcSnk[GermanyRegion,Lithium recovery,0,1,11] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,0] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,1] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,2] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,3] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,4] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,5] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,6] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,7] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,8] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,9] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,10] + 116*op_srcSnk[GermanyRegion,Lithium recovery,0,2,11]
# RHS_recovery 1.1*decommis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_recovery 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,0] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,1] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,2] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,3] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,4] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,5] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,6] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,7] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,8] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,9] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,10] + 79*op_srcSnk[GermanyRegion,Lithium recovery,1,0,11] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,0] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,1] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,2] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,3] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,4] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,5] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,6] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,7] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,8] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,9] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,10] + 170*op_srcSnk[GermanyRegion,Lithium recovery,1,1,11] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,0] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,1] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,2] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,3] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,4] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,5] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,6] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,7] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,8] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,9] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,10] + 116*op_srcSnk[GermanyRegion,Lithium recovery,1,2,11]
# RHS_recovery 2.635*decommis_stor[GermanyRegion,Li-ion batteries,1]
# LHS_recovery 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,0] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,1] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,2] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,3] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,4] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,5] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,6] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,7] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,8] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,9] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,10] + 79*op_srcSnk[GermanyRegion,Lithium recovery,2,0,11] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,0] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,1] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,2] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,3] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,4] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,5] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,6] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,7] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,8] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,9] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,10] + 170*op_srcSnk[GermanyRegion,Lithium recovery,2,1,11] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,0] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,1] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,2] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,3] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,4] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,5] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,6] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,7] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,8] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,9] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,10] + 116*op_srcSnk[GermanyRegion,Lithium recovery,2,2,11]
# RHS_recovery 2.7*decommis_stor[GermanyRegion,Li-ion batteries,2]
# 		(0.0085 sec)
#
# 		(0.0020 sec)
#
# Declaring objective function...
# 		(0.7538 sec)
#
# Set parameter ServerPassword
# Set parameter TSPort to value 41955
# Set parameter TokenServer to value "iek3079"
# Read LP format model from file /tmp/tmp9s4qn_s9.pyomo.lp
# Reading time = 0.06 seconds
# x1: 34458 rows, 14922 columns, 94820 nonzeros
# Set parameter QCPDual to value 1
# Set parameter Threads to value 3
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (linux64 - "Rocky Linux 8.8 (Green Obsidian)")
#
# CPU model: Intel(R) Xeon(R) Gold 6154 CPU @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 36 physical cores, 72 logical processors, using up to 3 threads
#
# Optimize a model with 34458 rows, 14922 columns and 94820 nonzeros
# Model fingerprint: 0xe9480739
# Variable types: 14910 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 2e+03]
#   Objective range  [3e-05, 3e+00]
#   Bounds range     [4e-02, 7e+01]
#   RHS range        [1e+00, 6e+06]
# Presolve removed 13778 rows and 8114 columns
# Presolve time: 0.15s
# Presolved: 20680 rows, 6808 columns, 66766 nonzeros
# Variable types: 6802 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 1.592889e+03, 10000 iterations, 0.68 seconds (0.65 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1592.88885    0    2          - 1592.88885      -     -    0s
#      0     0 1592.88885    0    2          - 1592.88885      -     -    0s
#      0     2 1592.88885    0    2          - 1592.88885      -     -    0s
# *    4     5               2    1593.1112705 1593.01896  0.01%  95.0    0s
#
# Explored 6 nodes (10381 simplex iterations) in 1.00 seconds (1.12 work units)
# Thread count was 3 (of 72 available processors)
#
# Solution count 2: 1593.11 1593.11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.593111270456e+03, best bound 1.593018963910e+03, gap 0.0058%
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 1.0021569728851318
# Error rc: 0
# Time: 1.3434500694274902
#
#
# Name: x1
# Lower bound: 1593.0189639103287
# Upper bound: 1593.1112704562524
# Number of objectives: 1
# Number of constraints: 34458
# Number of variables: 14922
# Number of binary variables: 12
# Number of integer variables: 12
# Number of continuous variables: 14910
# Number of nonzeros: 94820
# Sense: minimize
#
# Solve time: 2.1236507892608643 sec.
#
# Processing optimization output...
# for SourceSinkModel ...    (1.6150sec)
# for ConversionModel ...    (0.6032sec)
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2083: UserWarning: Charge and discharge at the same time for component Salt caverns (biogas)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2083: UserWarning: Charge and discharge at the same time for component Pumped hydro storage
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2083: UserWarning: Charge and discharge at the same time for component Salt caverns (biogas)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2083: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2083: UserWarning: Charge and discharge at the same time for component Salt caverns (biogas)
#   warnings.warn(
# for StorageModel ...       (2.1791sec)
# for TransmissionModel ...  (1.1352sec)
# 		(5.5559 sec)

# %% [markdown]
# # 9. Selected results output
#
# Plot locations (GeoPandas required)

# %%
# Import the geopandas package for plotting the locations
import geopandas as gpd

# %%
locFilePath = os.path.join(
    cwd, "InputData", "SpatialData", "ShapeFiles", "clusteredRegions.shp"
)

# %%
fig, ax = fn.plotLocations(locFilePath, plotLocNames=True, indexColumn="index")

# %% [markdown]
# ### Sources and Sink
#
# Show optimization summary

# %%
esM.getOptimizationSummary("SourceSinkModel", outputLevel=2, ip=2025)
# Out:
#                                                                       FranceRegion  \
# Component                    Property        Unit
# Biogas purchase              NPVcontribution [1e9 Euro]                   0.472284
#                              TAC             [1e9 Euro/a]                 0.160928
#                              commodCosts     [1e9 Euro/a]                 0.160928
#                              operation       [GW$_{biogas,LHV}$*h/a]   2975.180901
#                                              [GW$_{biogas,LHV}$*h]     2975.180901
# Copper demand                operation       [tons/a]                   197.754434
# Copper recovery              operation       [tons/a]                   173.694311
# Copper supply                operation       [tons/a]                    24.060123
# Electricity demand           operation       [GW$_{el}$*h/a]          66115.987455
#                                              [GW$_{el}$*h]            66115.987455
# Existing run-of-river plants NPVcontribution [1e9 Euro]                   0.022864
#                              TAC             [1e9 Euro/a]                 0.007791
#                              capacity        [GW$_{el}$]                  0.037456
#                              operation       [GW$_{el}$*h/a]            170.988002
#                                              [GW$_{el}$*h]              170.988002
#                              opexCap         [1e9 Euro/a]                 0.007791
# Hydrogen demand              operation       [GW$_{H_{2},LHV}$*h/a]   11007.056882
#                                              [GW$_{H_{2},LHV}$*h]     11007.056882
# Lithium demand               operation       [tons/a]                  9021.755045
# Lithium recovery             operation       [tons/a]                  8507.823081
# Lithium supply               operation       [tons/a]                   513.931964
# PV                           NPVcontribution [1e9 Euro]                   5.605296
#                              TAC             [1e9 Euro/a]                 1.909967
#                              capacity        [GW$_{el}$]                 25.848365
#                              capexCap        [1e9 Euro/a]                 1.573938
#                              operation       [GW$_{el}$*h/a]          23816.214088
#                                              [GW$_{el}$*h]            23816.214088
#                              opexCap         [1e9 Euro/a]                 0.336029
# Steel demand                 operation       [tons/a]                  9219.509479
# Steel recovery               operation       [tons/a]                  8681.517392
# Steel supply                 operation       [tons/a]                   537.992087
# Wind (offshore)              NPVcontribution [1e9 Euro]                   7.302271
#                              TAC             [1e9 Euro/a]                 2.488199
#                              capacity        [GW$_{el}$]                       4.0
#                              capexCap        [1e9 Euro/a]                 2.304199
#                              commissioning   [GW$_{el}$]                       4.0
#                              decommissioning [GW$_{el}$]                       4.0
#                              invest          [1e9 Euro]                        9.2
#                              operation       [GW$_{el}$*h/a]          12262.026595
#                                              [GW$_{el}$*h]            12262.026595
#                              opexCap         [1e9 Euro/a]                    0.184
# Wind (onshore)               NPVcontribution [1e9 Euro]                  57.552973
#                              TAC             [1e9 Euro/a]                19.610786
#                              capacity        [GW$_{el}$]                 65.918145
#                              capexCap        [1e9 Euro/a]                18.160587
#                              commissioning   [GW$_{el}$]                 65.918145
#                              decommissioning [GW$_{el}$]                 65.918145
#                              invest          [1e9 Euro]                  72.509959
#                              operation       [GW$_{el}$*h/a]          96538.084362
#                                              [GW$_{el}$*h]            96538.084362
#                              opexCap         [1e9 Euro/a]                 1.450199
#
#                                                                       GermanyRegion
# Component                    Property        Unit
# Biogas purchase              NPVcontribution [1e9 Euro]                    0.517309
#                              TAC             [1e9 Euro/a]                  0.176269
#                              commodCosts     [1e9 Euro/a]                  0.176269
#                              operation       [GW$_{biogas,LHV}$*h/a]    3258.816739
#                                              [GW$_{biogas,LHV}$*h]      3258.816739
# Copper demand                operation       [tons/a]                     135.20472
# Copper recovery              operation       [tons/a]                    118.754812
# Copper supply                operation       [tons/a]                     16.449908
# Electricity demand           operation       [GW$_{el}$*h/a]          133963.451433
#                                              [GW$_{el}$*h]            133963.451433
# Existing run-of-river plants NPVcontribution [1e9 Euro]                    0.423534
#                              TAC             [1e9 Euro/a]                  0.144316
#                              capacity        [GW$_{el}$]                   0.693828
#                              operation       [GW$_{el}$*h/a]            3167.329183
#                                              [GW$_{el}$*h]              3167.329183
#                              opexCap         [1e9 Euro/a]                  0.144316
# Hydrogen demand              operation       [GW$_{H_{2},LHV}$*h/a]    15855.229091
#                                              [GW$_{H_{2},LHV}$*h]      15855.229091
# Lithium demand               operation       [tons/a]                    736.957365
# Lithium recovery             operation       [tons/a]                     63.579358
# Lithium supply               operation       [tons/a]                    673.378006
# PV                           NPVcontribution [1e9 Euro]                    9.392862
#                              TAC             [1e9 Euro/a]                  3.200554
#                              capacity        [GW$_{el}$]                  43.314414
#                              capexCap        [1e9 Euro/a]                  2.637467
#                              operation       [GW$_{el}$*h/a]           44174.765526
#                                              [GW$_{el}$*h]             44174.765526
#                              opexCap         [1e9 Euro/a]                  0.563087
# Steel demand                 operation       [tons/a]                    872.162085
# Steel recovery               operation       [tons/a]                    182.334171
# Steel supply                 operation       [tons/a]                    689.827914
# Wind (offshore)              NPVcontribution [1e9 Euro]                    3.651135
#                              TAC             [1e9 Euro/a]                    1.2441
#                              capacity        [GW$_{el}$]                        2.0
#                              capexCap        [1e9 Euro/a]                    1.1521
#                              commissioning   [GW$_{el}$]                        2.0
#                              decommissioning [GW$_{el}$]                        2.0
#                              invest          [1e9 Euro]                         4.6
#                              operation       [GW$_{el}$*h/a]            6495.183258
#                                              [GW$_{el}$*h]              6495.183258
#                              opexCap         [1e9 Euro/a]                     0.092
# Wind (onshore)               NPVcontribution [1e9 Euro]                   39.348971
#                              TAC             [1e9 Euro/a]                 13.407896
#                              capacity        [GW$_{el}$]                   45.06824
#                              capexCap        [1e9 Euro/a]                 12.416395
#                              commissioning   [GW$_{el}$]                   45.06824
#                              decommissioning [GW$_{el}$]                   45.06824
#                              invest          [1e9 Euro]                   49.575064
#                              operation       [GW$_{el}$*h/a]           54986.186226
#                                              [GW$_{el}$*h]             54986.186226
#                              opexCap         [1e9 Euro/a]                  0.991501

# %% [markdown]
# Plot installed capacities

# %%
fig, ax = fn.plotLocationalColorMap(
    esM, "Wind (offshore)", locFilePath, "index", perArea=False
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 fig, ax = fn.plotLocationalColorMap(
#       2     esM, "Wind (offshore)", locFilePath, "index", perArea=False
#       3 )
#
# File ~/code/fine/fine/IOManagement/standardIO.py:1185, in plotLocationalColorMap(esM, compName, locationsShapeFileName, indexColumn, ip, perArea, areaFactor, crs, variableName, doSum, cmap, vmin, vmax, zlabel, figsize, fontsize, save, fileName, dpi, **kwargs)
#    1082 def plotLocationalColorMap(
#    1083     esM,
#    1084     compName,
#    (...)
#    1102     **kwargs,
#    1103 ):
#    1104     """
#    1105     Plot the data of a component for each location.
#    1106
#    (...)
#    1183     :type dpi: scalar > 0
#    1184     """
# -> 1185     data = esM.componentModelingDict[esM.componentNames[compName]].getOptimalValues(
#    1186         variableName, ip=ip
#    1187     )
#    1188     data = data["values"].loc[(compName)]
#    1190     if doSum:
#
# File ~/code/fine/fine/sourceSink.py:1567, in SourceSinkModel.getOptimalValues(self, name, ip)
#    1546 def getOptimalValues(self, name="all", ip=0):
#    1547     """
#    1548     Return optimal values of the components.
#    1549
#    (...)
#    1565     :rtype: dict
#    1566     """
# -> 1567     return super().getOptimalValues(name, ip=ip)
#
# File ~/code/fine/fine/component.py:4544, in ComponentModel.getOptimalValues(self, name, ip)
#    4521 """
#    4522 Return optimal values of the components.
#    4523
#    (...)
#    4540 :rtype: dict
#    4541 """
#    4542 if name == "capacityVariablesOptimum":
#    4543     return {
# -> 4544         "values": self._capacityVariablesOptimum[ip],
#    4545         "timeDependent": False,
#    4546         "dimension": self.dimension,
#    4547     }
#    4548 elif name == "isBuiltVariablesOptimum":
#    4549     return {
#    4550         "values": self._isBuiltVariablesOptimum[ip],
#    4551         "timeDependent": False,
#    4552         "dimension": self.dimension,
#    4553     }
#
# KeyError: 0

# %%
fig, ax = fn.plotLocationalColorMap(
    esM, "Wind (onshore)", locFilePath, "index", perArea=False
)

# %%
fig, ax = fn.plotLocationalColorMap(esM, "PV", locFilePath, "index", perArea=False)

# %% [markdown]
# Plot operation time series (either one or two dimensional)

# %%
fig, ax = fn.plotOperationColorMap(esM, "Electricity demand", "GermanyRegion")

# %%
fig, ax = fn.plotOperationColorMap(esM, "Electricity demand", "FranceRegion", ip = 2020)

# %% [markdown]
# ### Conversion
#
# Show optimization summary

# %%
esM.getOptimizationSummary("ConversionModel", outputLevel=2)

# %%
fig, ax = fn.plotLocationalColorMap(
    esM, "Electrolyzer", locFilePath, "index", perArea=False
)

# %%
fig, ax = fn.plotOperationColorMap(esM, "New CCGT plants (biogas)", "GermanyRegion")

# %%
fig, ax = fn.plotOperationColorMap(esM, "New CCGT plants (biogas)", "FranceRegion")

# %% [markdown]
# ### Storage
#
# Show optimization summary

# %%
esM.getOptimizationSummary("StorageModel", outputLevel=2)

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Li-ion batteries",
    "FranceRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
)

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Pumped hydro storage",
    "FranceRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
)

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (biogas)",
    "FranceRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
)

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (hydrogen)",
    "FranceRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
)

# %% [markdown]
# ## Transmission
#
# Show optimization summary

# %%
esM.getOptimizationSummary("TransmissionModel", outputLevel=2)

# %%
esM.getOptimizationSummary("TransmissionModel", outputLevel=2).loc[
    "Pipelines (hydrogen)"
]

# %% [markdown]
# Check that the shared capacity of the pipelines are not exceeded

# %%
df = esM.componentModelingDict["TransmissionModel"].capacityVariablesOptimum
df.loc["Pipelines (biogas)"] + df.loc["Pipelines (hydrogen)"]
