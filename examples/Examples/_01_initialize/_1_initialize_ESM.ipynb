# %% [markdown]
# # Initializing an Energy System Model
#
# In this notebook, we introduce the first step in building an energy system model with **FINE**: initializing the `EnergySystemModel`. It acts as the central container of the model and defines the basic structure of the energy system that will be analyzed.
#
# When initializing the model, we specify key properties such as the considered **locations**, **commodities**, and **temporal resolution**. These parameters define the scope of the energy system and determine how components can interact within the model.
#
# This notebook explains all arguments of the `EnergySystemModel` in detail and describes how they influence the structure of the model. At the end of this notebook, you will have created a basic energy system model instance that can be extended by adding components such as sources, sinks, storages, transmissions, and conversions.
#
# ## Importing required packages
#
# Before initializing the energy system model, we first import the required Python packages.

# %%
import fine as fn  # Provides objects and functions to model an energy system
import numpy as np  # Used to generate random input data
np.random.seed(42)  # Sets a "seed" to produce the same random input data in each model run

# %% [markdown]
# ### Initialize the Energy System Model
#
# The Energy System Model is initialized using the `EnergySystemModel` class.

# %%
locations = {"regionN", "regionS"}
commodities = {"electricity", "naturalGas", "CO2"}
commodityUnitsDict = {
    "electricity": r"GW$_{el}$",
    "naturalGas": r"GW$_{CH_{4},LHV}$",
    "CO2": r"Mio. t$_{CO_2}$/h",
}
costUnit ="1e6 Euro"


# Code
esM = fn.EnergySystemModel(
    locations = {"regionN", "regionS"},
    commodities = {"electricity", "naturalGas", "CO2"},
    commodityUnitsDict = {
    "electricity": r"GW$_{el}$",
    "naturalGas": r"GW$_{CH_{4},LHV}$",
    "CO2": r"Mio. t$_{CO_2}$/h",
    }
    )

# %% [markdown]
# ## Required Arguments

# %% [markdown]
# ### locations

# %% [markdown]
# `locations` is a **set of strings**, where each string represents a region or node in the modeled energy system. Components such as sources, sinks, or converters are always assigned to one or more of these locations.
#
# Examples:
# - Countries (e.g. "Germany", "France")
# - Regions within a country
# - Individual sites such as industrial plants or cities
#
# In this example, we consider two regions:

# %% [markdown]
# ### commodities

# %% [markdown]
# `commodities` defines the **energy carriers** or **materials** that are considered in the energy system model.
#
# It is a **set of strings**, where each string represents a commodity that can be produced, consumed, converted, or transported within the model.
#
# Examples:
# - electricity
# - hydrogen
# - natural gas
# - heat
# - CO<sub>2</sub>
#
# In this example, we consider the following commodities:

# %% [markdown]
# ### commodityUnitsDict

# %% [markdown]
# `commodityUnitsDict` defines the **unit used for each commodity**.
#
# It is a dictionary that maps every commodity to a **quantitative unit per time**. These units are mainly used for interpreting and presenting results.
#
# Examples:
# - GW<sub>el</sub>
# - GW<sub>H<sub>2</sub></sub>
# - GW<sub>CH<sub>4</sub>, LHV </sub>
# - Mio. t<sub>CO<sub>2</sub></sub>/h
#
# Choosing appropriate units is important for the **interpretability of results**. For example, electricity might be expressed in GW<sub>el</sub>, while hydrogen flows might be given in t/h.
#
# The three commodities included in this example will be assigned to their units as follows:

# %% [markdown]
# ## Default Arguments

# %% [markdown]
# The following arguments have **default values** and are optional.

# %% [markdown]
# ### numberOfTimeSteps

# %% [markdown]
# `numberOfTimeSteps` defines the **number of time steps considered when modeling the energy system**.
#
# For each time step, the model creates variables and constraints describing the operation of the system. Together with the `hoursPerTimeStep`, the total number of hours considered can be derived. The total number of hours is again used for scaling the arising costs to the arising **total annual costs (TAC)**, which are minimized during optimization.
#
# Type: strictly positive integer<br>
# Default value: 8760 (corresponds to **one time step per hour for a full year**)

# %% [markdown]
# ### hoursPerTimeStep

# %% [markdown]
# `hoursPerTimeStep` defines how many **hours are represented by a single time step**.
#
# Type: strictly positive float<br>
# Default value: 1

# %% [markdown]
# ### numberOfInvestmentPeriods

# %% [markdown]
# MISSING

# %% [markdown]
# ### investmentPeriodInterval

# %% [markdown]
# `investmentPeriodInterval` defines the **time distance between investment period**.
#
# This parameter is relevant when performing **multi-period planning** or **transformation pathway analyses**.
#
# Example:<br>
# If the investment periods are 2020, 2025 and 2030, the `investmentPeriodInterval` is 5.
#
# Type: strictly positive integer<br>
# Default value: 1

# %% [markdown]
# ### startYear

# %% [markdown]
# `startYear` defines the **year of the first investment period**.
#
# Example:<br>
# If the investment periods are 2020, 2025 and 2030, the `startYear` is 5.
#
# Type: integer<br>
# Default value: 0

# %% [markdown]
# ### stochasticModel

# %% [markdown]
# `stochasticModel` determines whether the optimization problem is solved as a **stochastic optimization**.
#
# In stochastic optimization, the model considers multiple possible future conditions and finds a system design that performs well under all of them.
#
# Examples of uncertainties that could be modeled include:
# - different weather years
# - varying demand scenarios
# - uncertain fuel prices
#
# In this case, the investment periods represent **different scenarios** rather than a transformation pathway.
#
# Type: boolean<br>
# Default value: False

# %% [markdown]
# ### costUnit

# %% [markdown]
# `costUnit` defines the **unit used for all cost values** in the energy system model.
#
# Examples:
# - 10^9 Euro (billion euros), which can be a suitable scale for national energy systems.
# - 1e6 Euro (million euros)
#
# Type: string<br>
# Default value: "10^9 Euro"

# %% [markdown]
# ### lengthUnit

# %% [markdown]
# `lengthUnit` defines the unit used for **all length-related values** in the energy system.
#
# This is relevant for components such as **transmission infrastructure**.
#
# Type: string
# Default value: 'km'

# %% [markdown]
# ### verboseLogLevel

# %% [markdown]
# `verboseLogLevel` controls the **amount of logging printed to the console**.
#
# Available options:
# | Value | Behavior |
# | --- | --- |
# | 0 | General model logging, warnings and optimization solver logging are displayed |
# | 1 | Only warnings are displayed |
# | 2 | No general model logging or warnings are displayed, optimization solver logging is set to a minimum |
#
# If required, solver logging can also be configured separately during the optimization step.

# %% [markdown]
# ### balanceLimit

# %% [markdown]
# `balanceLimit` defines constraints that limit **commodity balances** in the system such as production, consumption, imports, or emissions.
#
# Examples:
# - CO<sub>2</sub> emission limits
# - Minimal renewable generation
# - Maximum fuel extraction
#
# Because this concept is more complex, it is explained in detail on a separate documentation page.
#
# Type:
# - pd.DataFrame
# - dictionary with investment periods as keys, and pd.DataFrame as values
#
# Default value: None

# %% [markdown]
# ### pathwayBalanceLimit

# %% [markdown]
# `pathwayBalanceLimit` defines **commodity balance limits for the entire transformation pathway**.
#
# Unlike `balanceLimit`, this constraint applies to the **whole pathway instead of individual investment periods**.
#
# Example:
# - total CO<sub>2</sub> budget across the entire transformation pathway
#
# Type: pd.DataFrame <br>
# Default value: None

# %% [markdown]
# ### annuityPerpetuity

# %% [markdown]
# `annuityPerpetuity` determines whether the model assumes that the design of the last investment period continues indefinitely.
#
# If enabled:
# - the system design of the final investment period is assumed to remain unchanged forever
# - costs are adjusted using the component's interest rate to represent perpetuity costs
#
# To use this feature, **all components must have an interest rate greater than zero**.
#
# Type: boolean<br>
# Default value: False

# %% [markdown]
# ## List of all parameters
#
# Below, after executing the code cell, you will find the list of all parameters of a Energy System Model, along with their description, type, and default value.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "NetCDF"))
from docstringTable import display_param_table


display_param_table(fn.EnergySystemModel)
# Out:
# <style type="text/css">
# #T_7ec8c table {
#   border-collapse: collapse;
# }
# #T_7ec8c th {
#   text-align: left;
#   background-color: white;
#   color: black;
#   vertical-align: top;
#   border: 2px solid black;
# }
# #T_7ec8c td {
#   border: 2px solid black;
#   padding: 6px 10px;
#   color: black;
#   background-color: white;
# }
# #T_7ec8c th.row_heading {
#   font-weight: bold;
#   font-size: 1.15em;
# }
# #T_7ec8c_row0_col0, #T_7ec8c_row0_col1, #T_7ec8c_row0_col2, #T_7ec8c_row1_col0, #T_7ec8c_row1_col1, #T_7ec8c_row1_col2, #T_7ec8c_row2_col0, #T_7ec8c_row2_col1, #T_7ec8c_row2_col2 {
#   font-weight: bold;
#   text-align: left;
#   vertical-align: top;
#   white-space: normal;
#   max-width: 420px;
#   color: black;
#   background-color: white;
# }
# #T_7ec8c_row3_col0, #T_7ec8c_row3_col1, #T_7ec8c_row3_col2, #T_7ec8c_row4_col0, #T_7ec8c_row4_col1, #T_7ec8c_row4_col2, #T_7ec8c_row5_col0, #T_7ec8c_row5_col1, #T_7ec8c_row5_col2, #T_7ec8c_row6_col0, #T_7ec8c_row6_col1, #T_7ec8c_row6_col2, #T_7ec8c_row7_col0, #T_7ec8c_row7_col1, #T_7ec8c_row7_col2, #T_7ec8c_row8_col0, #T_7ec8c_row8_col1, #T_7ec8c_row8_col2, #T_7ec8c_row9_col0, #T_7ec8c_row9_col1, #T_7ec8c_row9_col2, #T_7ec8c_row10_col0, #T_7ec8c_row10_col1, #T_7ec8c_row10_col2, #T_7ec8c_row11_col0, #T_7ec8c_row11_col1, #T_7ec8c_row11_col2, #T_7ec8c_row12_col0, #T_7ec8c_row12_col1, #T_7ec8c_row12_col2, #T_7ec8c_row13_col0, #T_7ec8c_row13_col1, #T_7ec8c_row13_col2, #T_7ec8c_row14_col0, #T_7ec8c_row14_col1, #T_7ec8c_row14_col2 {
#   font-weight: normal;
#   text-align: left;
#   vertical-align: top;
#   white-space: normal;
#   max-width: 420px;
#   color: black;
#   background-color: white;
# }
# </style>
# <table id="T_7ec8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ec8c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7ec8c_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_7ec8c_level0_col2" class="col_heading level0 col2" >Default</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Argument</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ec8c_level0_row0" class="row_heading level0 row0" >locations</th>
#       <td id="T_7ec8c_row0_col0" class="data row0 col0" >locations considered in the energy system</td>
#       <td id="T_7ec8c_row0_col1" class="data row0 col1" >set of strings</td>
#       <td id="T_7ec8c_row0_col2" class="data row0 col2" >/</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row1" class="row_heading level0 row1" >commodities</th>
#       <td id="T_7ec8c_row1_col0" class="data row1 col0" >commodities considered in the energy system</td>
#       <td id="T_7ec8c_row1_col1" class="data row1 col1" >set of strings</td>
#       <td id="T_7ec8c_row1_col2" class="data row1 col2" >/</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row2" class="row_heading level0 row2" >commodityUnitsDict</th>
#       <td id="T_7ec8c_row2_col0" class="data row2 col0" >dictionary which assigns each commodity a quantitative unit per time (e.g. GW_el, GW_H2, Mio.t_CO2/h). The dictionary is used for results output. .. note:: Note for advanced users: the scale of these units can influence the numerical stability of the optimization solver, cf. http://files.gurobi.com/Numerics.pdf where a reasonable range of model coefficients is suggested.</td>
#       <td id="T_7ec8c_row2_col1" class="data row2 col1" >dictionary of strings</td>
#       <td id="T_7ec8c_row2_col2" class="data row2 col2" >/</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row3" class="row_heading level0 row3" >numberOfTimeSteps</th>
#       <td id="T_7ec8c_row3_col0" class="data row3 col0" >number of time steps considered when modeling the energy system (for each time step, or each representative time step, variables and constraints are constituted). Together with the hoursPerTimeStep, the total number of hours considered can be derived. The total number of hours is again used for scaling the arising costs to the arising total annual costs (TAC) which are minimized during optimization.</td>
#       <td id="T_7ec8c_row3_col1" class="data row3 col1" ></td>
#       <td id="T_7ec8c_row3_col2" class="data row3 col2" >8760</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row4" class="row_heading level0 row4" >hoursPerTimeStep</th>
#       <td id="T_7ec8c_row4_col0" class="data row4 col0" >hours per time step</td>
#       <td id="T_7ec8c_row4_col1" class="data row4 col1" >strictly positive float</td>
#       <td id="T_7ec8c_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row5" class="row_heading level0 row5" >startYear</th>
#       <td id="T_7ec8c_row5_col0" class="data row5 col0" >year name of first investment period, e.g. for a transformation pathway from 2020 to 2030 with the years 2020, 2025, 2030, the startYear is 2020</td>
#       <td id="T_7ec8c_row5_col1" class="data row5 col1" >integer</td>
#       <td id="T_7ec8c_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row6" class="row_heading level0 row6" >numberOfInvestmentPeriods</th>
#       <td id="T_7ec8c_row6_col0" class="data row6 col0" >number of investment periods of transformation path analysis, e.g. for a transformation pathway from 2020 to 2030 with the years 2020, 2025, 2030, the numberOfInvestmentPeriods is 3</td>
#       <td id="T_7ec8c_row6_col1" class="data row6 col1" >strictly positive integer</td>
#       <td id="T_7ec8c_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row7" class="row_heading level0 row7" >investmentPeriodInterval</th>
#       <td id="T_7ec8c_row7_col0" class="data row7 col0" >interval between the investment of transformation path analysis, e.g. for a transformation pathway from 2020 to 2030 with the years 2020, 2025, 2030, the investmentPeriodInterval is 5</td>
#       <td id="T_7ec8c_row7_col1" class="data row7 col1" >strictly positive integer</td>
#       <td id="T_7ec8c_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row8" class="row_heading level0 row8" >stochasticModel</th>
#       <td id="T_7ec8c_row8_col0" class="data row8 col0" >defines whether to set up a stochastic optimization. The goal of the stochastic optimization is to find a more robust energy system by considering different requirements to find a single energy system design (e.g. various weather years or demand forecasts). These requirements are represented in different investment periods of the model. In contrast to the classical perfect foresight optimization the investment periods do not represent steps of a tranformation pathway but possible boundary conditions for the energy system, which need to be considered for the system design and operation</td>
#       <td id="T_7ec8c_row8_col1" class="data row8 col1" ></td>
#       <td id="T_7ec8c_row8_col2" class="data row8 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row9" class="row_heading level0 row9" >costUnit</th>
#       <td id="T_7ec8c_row9_col0" class="data row9 col0" >cost unit of all cost related values in the energy system. This argument sets the unit of all cost parameters which are given as an input to the EnergySystemModel instance (e.g. for the invest per capacity or the cost per operation). .. note:: Note for advanced users: the scale of this unit can influence the numerical stability of the optimization solver, cf. http://files.gurobi.com/Numerics.pdf where a reasonable range of model coefficients is suggested. energy systems.</td>
#       <td id="T_7ec8c_row9_col1" class="data row9 col1" >string</td>
#       <td id="T_7ec8c_row9_col2" class="data row9 col2" >'10^9 Euro' (billion euros)</td>
#     </tr>
#     <tr>
#       <th id="T_7ec8c_level0_row10" class="row_heading level0 row10" >lengthUnit</th>
#       <td id="T_7ec8c_row10_col0" class="data row10 col0" >length unit for all length-related values in the energy system. .. note:: Note
