# %% [markdown]
# # Optimize the Energy System Model

# %% [markdown]
# All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
import fine.IOManagement.xarrayIO as xrIO
import fine as fn
from pathlib import Path
cwd = Path.cwd().resolve()
base_path = cwd.parents[2]
nc_file = base_path / "examples" / "Examples" / "NetCDF" / "basic_esm.nc"

esM = xrIO.readNetCDFtoEnergySystemModel(nc_file)

#You can ignore these lines for now. They are here to download a pre-existing model to be optimized, for simplicity. The esm downloaded corresponds exactly to the one described in the previous notebooks.
#Normally, you would simply write each code section of the notebooks one after another and the script would run. For users already familiar with the example, this refers to the 07_NETCDF_to_save_and_set_up_model_instance.

# %% [markdown]
# # Perform TimeSerieAggregation

# %%
# Input parameters
numberOfTypicalPeriods = 30

esM.aggregateTemporally(numberOfTypicalPeriods=numberOfTypicalPeriods)
# Out:
# Clustering time series data with 30 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(5.2504 sec)

# %% [markdown]
# # Optimize model

# %%
# Input parameters
timeSeriesAggregation = True
solver = fn.utils.ImplementedSolvers.STANDARD_SOLVER.value

esM.optimize(timeSeriesAggregation=timeSeriesAggregation, solver=solver)
# Out:
# Time series aggregation specifications:
# Number of typical periods:30, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.1763 sec)
#
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0728 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0358 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.2749 sec)
#
# Declaring shared potential constraint...
# 		(0.0002 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.0458 sec)
#
# 		(0.0000 sec)
#
# Declaring objective function...
# 		(0.1263 sec)
#
# Set parameter OutputFlag to value 1
# Set parameter Threads to value 3
# Set parameter LogFile to value ""
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) Ultra 7 255U, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 14 logical processors, using up to 3 threads
#
# Non-default parameters:
# QCPDual  1
# Threads  3
#
# Optimize a model with 11598 rows, 6712 columns and 31854 nonzeros (Min)
# Model fingerprint: 0xd21eacb0
# Model has 6 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [3e-04, 5e+02]
#   Objective range  [2e-02, 1e+02]
#   Bounds range     [2e+01, 4e+02]
#   RHS range        [0e+00, 0e+00]
#
# Presolve removed 5442 rows and 3448 columns
# Presolve time: 0.02s
# Presolved: 6156 rows, 3264 columns, 25954 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.10s
#
# Barrier statistics:
#  Dense cols : 48
#  Free vars  : 62
#  AA' NZ     : 9.435e+04
#  Factor NZ  : 9.298e+05 (roughly 11 MB of memory)
#  Factor Ops : 4.762e+08 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.12767244e+04  1.68218339e+04  5.71e+03 1.06e+01  5.58e+03     0s
#    1   1.16588873e+05 -2.81574377e+05  3.88e+03 1.06e+02  3.71e+03     0s
#    2   1.19589316e+05 -5.54927279e+05  2.09e+03 4.90e+01  2.01e+03     0s
#    3   9.32293949e+04 -5.45919888e+05  3.94e+02 9.44e+00  5.14e+02     0s
#    4   8.85940625e+04 -1.73274990e+05  7.83e+01 1.52e+00  1.02e+02     0s
#    5   8.69617477e+04 -4.02729413e+04  2.32e-08 6.43e-01  4.28e+01     0s
#    6   7.05089312e+04  1.88149915e+04  8.16e-09 2.27e-01  1.73e+01     0s
#    7   6.41384467e+04  3.77353263e+04  5.39e-09 1.25e-01  9.61e+00     0s
#    8   5.85746244e+04  4.81775915e+04  3.71e-09 6.29e-02  4.87e+00     0s
#    9   5.32118484e+04  5.04355229e+04  2.32e-09 3.34e-02  2.63e+00     0s
#   10   5.08374453e+04  4.98897956e+04  1.34e-09 1.27e-02  1.07e+00     0s
#   11   4.95941615e+04  4.94811353e+04  9.27e-10 6.26e-03  5.41e-01     0s
#   12   4.84712168e+04  4.91453490e+04  2.38e-09 4.13e-03  3.46e-01     0s
#   13   4.79704943e+04  4.88225347e+04  1.40e-09 3.09e-03  2.63e-01     0s
#   14   4.75393634e+04  4.84906817e+04  2.49e-09 2.40e-03  2.08e-01     1s
#   15   4.73011789e+04  4.83083809e+04  1.59e-09 2.12e-03  1.85e-01     1s
#   16   4.69228566e+04  4.79604860e+04  1.16e-09 1.54e-03  1.28e-01     1s
#   17   4.67575192e+04  4.76247952e+04  1.09e-09 1.13e-03  9.31e-02     1s
#   18   4.65798265e+04  4.74834763e+04  1.28e-09 9.86e-04  8.19e-02     1s
#   19   4.64509761e+04  4.73304313e+04  1.14e-09 8.60e-04  7.47e-02     1s
#   20   4.63298605e+04  4.71419667e+04  7.41e-10 7.05e-04  6.17e-02     1s
#   21   4.61241026e+04  4.69859921e+04  1.84e-09 6.05e-04  5.28e-02     1s
#   22   4.60782670e+04  4.69394002e+04  1.60e-09 5.75e-04  5.02e-02     1s
#   23   4.59925657e+04  4.67215941e+04  1.47e-09 4.43e-04  3.87e-02     1s
#   24   4.58982545e+04  4.66346266e+04  1.28e-09 4.00e-04  3.66e-02     1s
#   25   4.58557457e+04  4.65217212e+04  1.26e-09 3.52e-04  3.46e-02     1s
#   26   4.58015221e+04  4.64459902e+04  1.15e-09 3.22e-04  3.24e-02     1s
#   27   4.57348952e+04  4.64080552e+04  1.30e-09 3.05e-04  2.98e-02     1s
#   28   4.57203116e+04  4.62040034e+04  1.39e-09 2.20e-04  2.26e-02     1s
#
# Barrier performed 28 iterations in 0.87 seconds (0.56 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4137    4.5196001e+04   0.000000e+00   0.000000e+00      1s
#
# Solved in 4137 iterations and 0.88 seconds (1.08 work units)
# Optimal objective  4.519600105e+04
#
# Name: Gurobi 13.01
# Status: ok
# Wallclock time: 0.8840000629425049
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#
#
# Name: unknown
# Lower bound: 45196.00105401521
# Upper bound: 45196.00105401521
# Number of objectives: 1
# Number of constraints: 11598
# Number of variables: 6712
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 6712
# Number of nonzeros: 31854
# Sense: minimize
# Number of solutions: 1
#
# Solve time: 1.6498475074768066 sec.
#
# Processing optimization output...
# for SourceSinkModel ...    (0.3089sec)
# for TransmissionModel ...  (0.3241sec)
# for ConversionModel ...    (0.1566sec)
# for StorageModel ...       (0.5021sec)
# 		(1.3038 sec)
