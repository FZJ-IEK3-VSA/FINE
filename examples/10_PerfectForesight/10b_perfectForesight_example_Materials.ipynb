# %% [markdown]
#  # Workflow for a transformation pathway of a single node energy system with perfect foresight
#
#  In this application of the ETHOS.FINE framework, a transformation pathway of a energy system is modeled and optimized.
#
#  All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
#  The workflow is structures as follows:
#  1. Required packages are imported and the input data path is set
#  2. An energy system model instance is created
#  3. Commodity sources are added to the energy system model
#  4. Commodity conversion components are added to the energy system model
#  5. Commodity storages are added to the energy system model
#  6. Commodity sinks are added to the energy system model
#  7. Material sinks are added to the energy system model
#  8. Material sources are addeed to the energy system model
#  9. Material conversions are added to the energy system model for recycling processes
#  10. The energy system model is optimized
#  11. Selected optimization results are presented

# %% [markdown]
#  # 1. Import required packages and set input data path
#
#  The ETHOS.FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import fine as fn
from getData import getData
from pathlib import Path
import pandas as pd


cwd = Path.cwd()
data = getData()

# %% [markdown]
#  # 2. Create an energy system model instance
#
#  The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
#  The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {"GermanyRegion"}
commodityUnitsDict = {"electricity": r"GW$_{el}$", "hydrogen": r"GW$_{H_{2},LHV}$"}
commodities = {"electricity", "hydrogen"}
materials = {"steel", "copper"}
materialUnitsDict = {"steel": "tons/h", "copper": "tons/h"}

numberOfTimeSteps = 8760
hoursPerTimeStep = 1

# %% [markdown]
#  # 2.1 define Transformation Pathway parameters
#
#  Transformation Pathway Analyses can be run by setting a number of investment periods
#  larger than 1, which is the default value and results in a single year optimization.

# %%
numberOfInvestmentPeriods = 3
startYear = 2020
interval = 5

# %%
pathwayBalanceLimit = pd.DataFrame(
    columns=["GermanyRegion", "Total", "lowerBound"],
    index=["Copper_Resources", "Steel_Resources"],
)
pathwayBalanceLimit.loc["Copper_Resources"] = [None, 150, False]
pathwayBalanceLimit.loc["Steel_Resources"] = [None, 150, False]

# %%
initial_material_cost = {
    "steel": pd.Series(
        {
            "GermanyRegion": 0.1,
        }
    ),
    "copper": pd.Series(
        {
            "GermanyRegion": 0.1,
        }
    ),
}

# %%
esM = fn.EnergySystemModel(
    locations=locations,
    commodities=commodities,
    materials=materials,
    numberOfInvestmentPeriods=numberOfInvestmentPeriods,
    startYear=startYear,
    investmentPeriodInterval=interval,
    numberOfTimeSteps=8760,
    commodityUnitsDict=commodityUnitsDict,
    materialUnitsDict=materialUnitsDict,
    hoursPerTimeStep=1,
    costUnit="1e9 Euro",
    lengthUnit="km",
    verboseLogLevel=0,
    pathwayBalanceLimit=pathwayBalanceLimit,
    initialMaterialCost=initial_material_cost,
)

# %% [markdown]
#  # 3. Add commodity sources to the energy system model

# %% [markdown]
#  ## 3.1. Electricity sources

# %% [markdown]
#  ### Wind onshore

# %% [markdown]
#  change weather conditions for the different investment periods

# %%
operationRateMax = {}
operationRateMax[2020] = 1.2 * data["Wind (onshore), operationRateMax"]
operationRateMax[2025] = 0.7 * data["Wind (onshore), operationRateMax"]
operationRateMax[2030] = 1 * data["Wind (onshore), operationRateMax"]

# %% [markdown]
#  define existing stock for wind onshore turbines

# %%
stockWindonshoreCommissioning = {
    2015: 10,
}

stockWindoffshoreCommissioning = {
    2015: 15,
}

# %% [markdown]
#  define invest and opex per capacity for wind onshore turbines

# %%
investPerCapacityWind = {2015: 1.25, 2020: 1.1, 2025: 1, 2030: 0.95}

opexPerCapacityWind = {
    2015: 1.25 * 0.02,
    2020: 1.1 * 0.02,
    2025: 1 * 0.02,
    2030: 0.95 * 0.02,
}

# %% [markdown]
#  add wind onshore source to esM

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="windonshore",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=3.1,
        opexPerCapacity=3.1 * 0.02,
        interestRate=0.08,
        economicLifetime=5,
        stockCommissioning=stockWindonshoreCommissioning,
        materialIntensity={
            2015: {  # IP für 2015
                "steel": pd.Series({"GermanyRegion": 4.1}),
                "copper": pd.Series({"GermanyRegion": 4.1}),
            },
            2020: {  # IP für 2020
                "steel": pd.Series({"GermanyRegion": 3.1}),
                "copper": pd.Series({"GermanyRegion": 3.1}),
            },
            2025: {  # IP für 2025
                "steel": pd.Series({"GermanyRegion": 3.0}),
                "copper": pd.Series({"GermanyRegion": 3.0}),
            },
            2030: {  # IP für 2030
                "steel": pd.Series({"GermanyRegion": 2.9}),
                "copper": pd.Series({"GermanyRegion": 2.9}),
            },
        },
        materialCollection={
            2020: {  # IP für 2020
                "steel": pd.Series({"GermanyRegion": 0.7}),
                "copper": pd.Series({"GermanyRegion": 0.7}),
            },
            2025: {  # IP für 2025
                "steel": pd.Series({"GermanyRegion": 0.8}),
                "copper": pd.Series({"GermanyRegion": 0.8}),
            },
            2030: {  # IP für 2030
                "steel": pd.Series({"GermanyRegion": 0.9}),
                "copper": pd.Series({"GermanyRegion": 0.9}),
            },
        },
    )
)

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="windoffshore",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=3.1,
        opexPerCapacity=3.1 * 0.015,
        interestRate=0.08,
        economicLifetime=5,
        stockCommissioning=stockWindoffshoreCommissioning,
        materialIntensity={
            2015: {  # IP für 2015
                "steel": pd.Series({"GermanyRegion": 5.1}, dtype="float64"),
                "copper": pd.Series({"GermanyRegion": 5.1}, dtype="float64"),
            },
            2020: {  # IP für 2020
                "steel": pd.Series({"GermanyRegion": 4.1}, dtype="float64"),
                "copper": pd.Series({"GermanyRegion": 4.1}, dtype="float64"),
            },
            2025: {  # IP für 2025
                "steel": pd.Series({"GermanyRegion": 4.0}, dtype="float64"),
                "copper": pd.Series({"GermanyRegion": 4.0}, dtype="float64"),
            },
            2030: {  # IP für 2030
                "steel": pd.Series({"GermanyRegion": 3.9}, dtype="float64"),
                "copper": pd.Series({"GermanyRegion": 3.9}, dtype="float64"),
            },
        },
        materialCollection={
            2020: {  # IP für 2020
                "steel": pd.Series({"GermanyRegion": 0.7}, dtype="float64"),
                "copper": pd.Series({"GermanyRegion": 0.7}, dtype="float64"),
            },
            2025: {  # IP für 2025
                "steel": pd.Series({"GermanyRegion": 0.8}, dtype="float64"),
                "copper": pd.Series({"GermanyRegion": 0.8}, dtype="float64"),
            },
            2030: {  # IP für 2030
                "steel": pd.Series({"GermanyRegion": 0.9}, dtype="float64"),
                "copper": pd.Series({"GermanyRegion": 0.9}, dtype="float64"),
            },
        },
    )
)

# %% [markdown]
#  Full load hours:

# %%
data["Wind (onshore), operationRateMax"].sum()
# Out:
# 2300.4069071646272

# %% [markdown]
#  # 4. Add conversion components to the energy system model

# %% [markdown]
#  ### Electrolyzers

# %% [markdown]
#  add component with constant invest and opex per capacity

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Electroylzers",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.7},
        hasCapacityVariable=True,
        investPerCapacity=0.5,
        opexPerCapacity=0.5 * 0.025,
        interestRate=0.08,
        economicLifetime=5,
    )
)

# %% [markdown]
#  # 5. Add commodity storages to the energy system model

# %% [markdown]
#  ## 5.1. Electricity storage

# %% [markdown]
#  ### Lithium ion batteries
#
#  The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Li-ion batteries",
        commodity="electricity",
        hasCapacityVariable=True,
        chargeEfficiency=0.95,
        cyclicLifetime=10000,
        dischargeEfficiency=0.95,
        selfDischarge=1 - (1 - 0.03) ** (1 / (30 * 24)),
        chargeRate=1,
        dischargeRate=1,
        doPreciseTsaModeling=False,
        investPerCapacity=0.151,
        opexPerCapacity=0.002,
        interestRate=0.08,
        economicLifetime=15,
    )
)

# %% [markdown]
#  ## 5.2. Hydrogen storage

# %% [markdown]
#  ### Hydrogen filled salt caverns
#  The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (hydrogen)",
        commodity="hydrogen",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=133,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (hydrogen), capacityMax"],
        investPerCapacity={2020: 0.00011, 2025: 0.00009, 2030: 0.00009},
        opexPerCapacity=0.00057,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
#  # 6. Add commodity sinks to the energy system model

# %% [markdown]
#  ## 6.1. Electricity sinks

# %% [markdown]
#  ### Electricity demand

# %% [markdown]
#  vary the demand with the years - increasing demand by 30% per year

# %%
electricityDemand = {}
electricityDemand[2020] = (1 + 0 * 0.3) * data["Electricity demand, operationRateFix"]
electricityDemand[2025] = (1 + 1 * 0.3) * data["Electricity demand, operationRateFix"]
electricityDemand[2030] = (1 + 2 * 0.3) * data["Electricity demand, operationRateFix"]

esM.add(
    fn.Sink(
        esM=esM,
        name="Electricity demand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=electricityDemand,
    )
)

# %% [markdown]
#  ## 6.2. Hydrogen sinks

# %% [markdown]
#  ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration = 0.5

# vary the demand with the years - increasing demand by 25% per year
hydrogendDemand = {}
hydrogendDemand[2020] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)
hydrogendDemand[2025] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)
hydrogendDemand[2030] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)


esM.add(
    fn.Sink(
        esM=esM,
        name="Hydrogen demand",
        commodity="hydrogen",
        hasCapacityVariable=False,
        operationRateFix=hydrogendDemand,
    )
)

# %% [markdown]
# # 7. Add material sinks to the energy system model

# %%
esM.generationMaterialSinks()
# Out:
# Existing material sinks: set()
# Missing materials sinks: {'copper', 'steel'}
# New sink added: Copper demand
# New sink added: Steel demand

# %%
# sink = esM.add(
#     fn.Sink(
#         esM=esM,
#         name="Steel demand",
#         hasCapacityVariable=False,
#         commodity="steel",
#         material=True,
#     )
# )

# sink = esM.add(
#     fn.Sink(
#         esM=esM,
#         name="Copper demand",
#         hasCapacityVariable=False,
#         commodity="copper",
#         material=True,
#     )
# )

# %% [markdown]
# # 8. Add material sources to the energy system model

# %% [markdown]
# ## 8.1 Add primary material sources with pathway balance limit

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Steel supply",
        hasCapacityVariable=False,
        commodity="steel",
        pathwayBalanceLimitID="Steel_Resources",
    )
)

esM.add(
    fn.Source(
        esM=esM,
        name="Copper supply",
        hasCapacityVariable=False,
        commodity="copper",
        pathwayBalanceLimitID="Copper_Resources",
    )
)

# %%
esM.generationSecondaryMaterialSources()
# Out:
# Scrap commodities : {'windoffshore_copper_scrap', 'windonshore_steel_scrap', 'windoffshore_steel_scrap', 'windonshore_copper_scrap'}
# Existing secondary material sources: set()
# Missing secondary material sources: {'windoffshore_copper_scrap', 'windonshore_steel_scrap', 'windoffshore_steel_scrap', 'windonshore_copper_scrap'}
# New scrap source added: windoffshore_copper_scrap
# New scrap source added: windonshore_steel_scrap
# New scrap source added: windoffshore_steel_scrap
# New scrap source added: windonshore_copper_scrap
# Existing secondary material sinks: set()
# Missing secondary material sinks: {'windoffshore_copper_scrap', 'windonshore_steel_scrap', 'windoffshore_steel_scrap', 'windonshore_copper_scrap'}
# New scrap sink added: windoffshore_copper_scrap_rec
# New scrap sink added: windonshore_steel_scrap_rec
# New scrap sink added: windoffshore_steel_scrap_rec
# New scrap sink added: windonshore_copper_scrap_rec

# %%
# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windonshore_steel_scrap",
#         commodity="windonshore_steel_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windoffshore_steel_scrap",
#         commodity="windoffshore_steel_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windonshore_copper_scrap",
#         commodity="windonshore_copper_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windoffshore_copper_scrap",
#         commodity="windoffshore_copper_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# %% [markdown]
# # 9. Add recycling plants

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Recycler Onshore",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={
            "windonshore_steel_scrap": -1,
            "steel": 0.5,
            "windonshore_copper_scrap": -1,
            "copper": 0.4,
        },
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

esM.add(
    fn.Conversion(
        esM=esM,
        name="Recycler Offshore",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={
            "windoffshore_steel_scrap": -1,
            "steel": 0.5,
            "windoffshore_copper_scrap": -1,
            "copper": 0.4,
        },
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

# %% [markdown]
#  # 10. Optimize energy system model

# %% [markdown]
#  All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
esM.aggregateTemporally(numberOfTypicalPeriods=30)
# Out:
# Clustering time series data with 30 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(16.6830 sec)

# %%
esM.optimize(timeSeriesAggregation=True, solver="gurobi")
# Out:
# Time series aggregation specifications:
# Number of typical periods:30, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.9270 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.3326 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.8835 sec)
#
# 		(0.0002 sec)
#
# Declaring shared potential constraint...
# 		(0.0012 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.2594 sec)
#
# Declaring material demand constraints...
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,windonshore,0] + 4.1*commis_srcSnk[GermanyRegion,windoffshore,0]
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,windonshore,1] + 4.0*commis_srcSnk[GermanyRegion,windoffshore,1]
# LHS_demand 75*op_srcSnk[GermanyRegion,Copper demand,0,0,0] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,1] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,2] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,3] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,4] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,5] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,6] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,7] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,8] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,9] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,10] + 75*op_srcSnk[GermanyRegion,Copper demand,0,0,11] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,0] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,1] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,2] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,3] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,4] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,5] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,6] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,7] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,8] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,9] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,10] + 55*op_srcSnk[GermanyRegion,Copper demand,0,1,11] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,0] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,1] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,2] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,3] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,4] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,5] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,6] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,7] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,8] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,9] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,10] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,11] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,0] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,1] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,2] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,3] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,4] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,5] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,6] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,7] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,8] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,9] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,10] + 105*op_srcSnk[GermanyRegion,Copper demand,0,3,11] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,0] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,1] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,2] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,3] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,4] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,5] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,6] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,7] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,8] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,9] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,10] + 150*op_srcSnk[GermanyRegion,Copper demand,0,4,11] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,0] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,1] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,2] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,3] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,4] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,5] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,6] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,7] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,8] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,9] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,10] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,11] + 105*op_srcSnk[GermanyRegion,Copper demand,0,6,0] + 105*op_srcSnk[GermanyRegion,Copper demand,0,6,1] + 105*op_srcSnk[GermanyRegion,Copper demand,0,6,2] + 105*op_srcSnk[GermanyRegion,Copper demand,0,6,3] + 105*op_srcSnk[GermanyRegion,Copper demand,0,6,4] + 105*op_srcSnk[GermanyRegion,Copper demand,0,6,5] + 105*op_srcSnk[GermanyRegion,Copper demand,0,6,6 ...
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,windonshore,2] + 3.9*commis_srcSnk[GermanyRegion,windoffshore,2]
# LHS_demand 75*op_srcSnk[GermanyRegion,Copper demand,1,0,0] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,1] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,2] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,3] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,4] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,5] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,6] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,7] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,8] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,9] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,10] + 75*op_srcSnk[GermanyRegion,Copper demand,1,0,11] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,0] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,1] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,2] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,3] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,4] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,5] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,6] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,7] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,8] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,9] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,10] + 55*op_srcSnk[GermanyRegion,Copper demand,1,1,11] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,0] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,1] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,2] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,3] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,4] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,5] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,6] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,7] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,8] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,9] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,10] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,11] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,0] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,1] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,2] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,3] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,4] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,5] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,6] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,7] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,8] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,9] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,10] + 105*op_srcSnk[GermanyRegion,Copper demand,1,3,11] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,0] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,1] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,2] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,3] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,4] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,5] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,6] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,7] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,8] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,9] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,10] + 150*op_srcSnk[GermanyRegion,Copper demand,1,4,11] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,0] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,1] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,2] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,3] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,4] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,5] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,6] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,7] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,8] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,9] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,10] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,11] + 105*op_srcSnk[GermanyRegion,Copper demand,1,6,0] + 105*op_srcSnk[GermanyRegion,Copper demand,1,6,1] + 105*op_srcSnk[GermanyRegion,Copper demand,1,6,2] + 105*op_srcSnk[GermanyRegion,Copper demand,1,6,3] + 105*op_srcSnk[GermanyRegion,Copper demand,1,6,4] + 105*op_srcSnk[GermanyRegion,Copper demand,1,6,5] + 105*op_srcSnk[GermanyRegion,Copper demand,1,6,6 ...
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,windonshore,0] + 4.1*commis_srcSnk[GermanyRegion,windoffshore,0]
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,windonshore,1] + 4.0*commis_srcSnk[GermanyRegion,windoffshore,1]
# LHS_demand 75*op_srcSnk[GermanyRegion,Steel demand,0,0,0] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,1] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,2] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,3] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,4] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,5] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,6] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,7] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,8] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,9] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,10] + 75*op_srcSnk[GermanyRegion,Steel demand,0,0,11] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,0] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,1] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,2] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,3] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,4] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,5] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,6] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,7] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,8] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,9] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,10] + 55*op_srcSnk[GermanyRegion,Steel demand,0,1,11] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,0] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,1] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,2] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,3] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,4] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,5] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,6] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,7] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,8] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,9] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,10] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,11] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,0] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,1] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,2] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,3] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,4] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,5] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,6] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,7] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,8] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,9] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,10] + 105*op_srcSnk[GermanyRegion,Steel demand,0,3,11] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,0] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,1] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,2] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,3] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,4] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,5] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,6] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,7] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,8] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,9] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,10] + 150*op_srcSnk[GermanyRegion,Steel demand,0,4,11] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,0] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,1] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,2] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,3] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,4] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,5] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,6] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,7] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,8] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,9] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,10] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,11] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,0] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,1] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,2] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,3] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,4] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,5] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,6] + 105*op_srcSnk[GermanyRegion,Steel demand,0,6,7] + 105*op_srcSnk[GermanyRegi ...
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,windonshore,2] + 3.9*commis_srcSnk[GermanyRegion,windoffshore,2]
# LHS_demand 75*op_srcSnk[GermanyRegion,Steel demand,1,0,0] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,1] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,2] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,3] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,4] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,5] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,6] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,7] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,8] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,9] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,10] + 75*op_srcSnk[GermanyRegion,Steel demand,1,0,11] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,0] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,1] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,2] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,3] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,4] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,5] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,6] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,7] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,8] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,9] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,10] + 55*op_srcSnk[GermanyRegion,Steel demand,1,1,11] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,0] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,1] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,2] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,3] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,4] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,5] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,6] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,7] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,8] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,9] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,10] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,11] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,0] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,1] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,2] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,3] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,4] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,5] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,6] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,7] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,8] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,9] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,10] + 105*op_srcSnk[GermanyRegion,Steel demand,1,3,11] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,0] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,1] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,2] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,3] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,4] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,5] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,6] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,7] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,8] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,9] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,10] + 150*op_srcSnk[GermanyRegion,Steel demand,1,4,11] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,0] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,1] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,2] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,3] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,4] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,5] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,6] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,7] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,8] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,9] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,10] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,11] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,0] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,1] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,2] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,3] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,4] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,5] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,6] + 105*op_srcSnk[GermanyRegion,Steel demand,1,6,7] + 105*op_srcSnk[GermanyRegi ...
# 		(0.0213 sec)
#
# Declaring material recovery constraints...
# LHS_recovery 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,0] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,1] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,2] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,3] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,4] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,5] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,6] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,7] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,8] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,9] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,10] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,0,11] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,0] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,1] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,2] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,3] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,4] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,5] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,6] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,7] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,8] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,9] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,10] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,1,11] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,0] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,1] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,2] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,3] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,4] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,5] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,6] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,7] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,8] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,9] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,10] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,2,11] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,0] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,1] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,2] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,3] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,4] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,5] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,6] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,7] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,8] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,9] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,10] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,3,11] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,0] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,1] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,2] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,3] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,4] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,5] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,6] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,7] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,8] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,9] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,10] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,4,11] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,5,0] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,5,1] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,0,5,2] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_ ...
# RHS_recovery 3.5699999999999994*decommis_srcSnk[GermanyRegion,windoffshore,0]
# Constraint: windoffshore_copper_scrap mat: copper
# LHS_recovery 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,0] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,1] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,2] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,3] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,4] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,5] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,6] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,7] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,8] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,9] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,10] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,11] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,0] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,1] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,2] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,3] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,4] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,5] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,6] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,7] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,8] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,9] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,10] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,11] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,0] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,1] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,2] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,3] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,4] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,5] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,6] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,7] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,8] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,9] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,10] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,11] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,0] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,1] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,2] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,3] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,4] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,5] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,6] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,7] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,8] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,9] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,10] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,11] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,0] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,1] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,2] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,3] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,4] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,5] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,6] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,7] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,8] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,9] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,10] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,11] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,5,0] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,5,1] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,5,2] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_ ...
# RHS_recovery 3.28*decommis_srcSnk[GermanyRegion,windoffshore,1]
# Constraint: windoffshore_copper_scrap mat: copper
# LHS_recovery 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,0] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,1] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,2] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,3] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,4] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,5] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,6] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,7] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,8] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,9] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,10] + 75*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,11] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,0] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,1] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,2] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,3] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,4] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,5] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,6] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,7] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,8] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,9] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,10] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,11] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,0] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,1] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,2] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,3] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,4] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,5] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,6] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,7] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,8] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,9] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,10] + 55*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,11] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,0] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,1] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,2] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,3] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,4] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,5] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,6] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,7] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,8] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,9] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,10] + 105*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,11] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,0] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,1] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,2] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,3] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,4] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,5] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,6] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,7] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,8] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,9] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,10] + 150*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,11] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,5,0] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,5,1] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,5,2] + 50*op_srcSnk[GermanyRegion,windoffshore_copper_ ...
# RHS_recovery 3.6*decommis_srcSnk[GermanyRegion,windoffshore,2]
# Constraint: windoffshore_copper_scrap mat: copper
# LHS_recovery 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,0] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,1] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,2] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,3] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,4] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,5] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,6] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,7] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,8] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,9] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,10] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,11] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,0] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,1] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,2] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,3] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,4] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,5] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,6] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,7] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,8] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,9] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,10] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,11] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,0] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,1] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,2] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,3] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,4] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,5] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,6] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,7] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,8] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,9] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,10] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,11] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,0] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,1] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,2] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,3] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,4] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,5] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,6] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,7] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,8] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,9] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,10] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,11] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,0] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,1] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,2] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,3] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,4] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,5] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,6] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,7] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,8] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,9] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,10] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,4] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0, ...
# RHS_recovery 2.8699999999999997*decommis_srcSnk[GermanyRegion,windonshore,0]
# Constraint: windonshore_steel_scrap mat: steel
# LHS_recovery 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,0] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,1] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,2] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,3] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,4] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,5] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,6] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,7] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,8] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,9] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,10] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,11] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,0] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,1] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,2] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,3] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,4] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,5] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,6] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,7] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,8] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,9] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,10] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,11] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,0] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,1] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,2] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,3] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,4] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,5] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,6] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,7] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,8] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,9] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,10] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,11] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,0] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,1] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,2] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,3] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,4] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,5] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,6] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,7] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,8] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,9] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,10] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,11] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,0] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,1] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,2] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,3] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,4] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,5] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,6] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,7] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,8] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,9] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,10] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,4] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1, ...
# RHS_recovery 2.4800000000000004*decommis_srcSnk[GermanyRegion,windonshore,1]
# Constraint: windonshore_steel_scrap mat: steel
# LHS_recovery 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,0] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,1] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,2] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,3] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,4] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,5] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,6] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,7] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,8] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,9] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,10] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,11] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,0] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,1] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,2] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,3] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,4] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,5] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,6] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,7] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,8] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,9] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,10] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,11] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,0] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,1] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,2] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,3] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,4] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,5] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,6] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,7] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,8] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,9] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,10] + 55*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,11] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,0] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,1] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,2] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,3] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,4] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,5] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,6] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,7] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,8] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,9] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,10] + 105*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,11] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,0] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,1] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,2] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,3] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,4] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,5] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,6] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,7] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,8] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,9] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,10] + 150*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,4] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2, ...
# RHS_recovery 2.7*decommis_srcSnk[GermanyRegion,windonshore,2]
# Constraint: windonshore_steel_scrap mat: steel
# LHS_recovery 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,0] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,1] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,2] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,3] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,4] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,5] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,6] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,7] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,8] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,9] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,10] + 75*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,11] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,0] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,1] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,2] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,3] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,4] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,5] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,6] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,7] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,8] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,9] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,10] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,11] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,0] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,1] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,2] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,3] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,4] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,5] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,6] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,7] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,8] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,9] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,10] + 55*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,11] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,0] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,1] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,2] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,3] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,4] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,5] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,6] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,7] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,8] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,9] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,10] + 105*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,11] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,0] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,1] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,2] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,3] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,4] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,5] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,6] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,7] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,8] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,9] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,10] + 150*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,11] + 50*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,0] + 50*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,1] + 50*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,2] + 50*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,3] + 50*op_srcSnk[GermanyRegion,windoffshore_steel_scr ...
# RHS_recovery 3.5699999999999994*decommis_srcSnk[GermanyRegion,windoffshore,0]
# Constraint: windoffshore_steel_scrap mat: steel
# ...
# RHS_recovery 2.8699999999999997*decommis_srcSnk[GermanyRegion,windonshore,0]
# Constraint: windonshore_copper_scrap mat: copper
# LHS_recovery 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,0] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,1] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,2] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,3] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,4] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,5] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,6] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,7] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,8] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,9] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,10] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,11] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,0] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,1] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,2] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,3] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,4] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,5] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,6] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,7] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,8] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,9] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,10] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,11] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,0] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,1] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,2] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,3] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,4] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,5] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,6] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,7] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,8] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,9] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,10] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,11] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,0] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,1] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,2] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,3] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,4] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,5] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,6] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,7] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,8] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,9] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,10] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,11] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,0] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,1] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,2] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,3] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,4] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,5] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,6] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,7] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,8] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,9] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,10] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scr ...
# RHS_recovery 2.4800000000000004*decommis_srcSnk[GermanyRegion,windonshore,1]
# Constraint: windonshore_copper_scrap mat: copper
# LHS_recovery 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,0] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,1] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,2] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,3] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,4] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,5] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,6] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,7] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,8] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,9] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,10] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,11] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,0] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,1] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,2] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,3] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,4] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,5] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,6] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,7] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,8] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,9] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,10] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,11] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,0] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,1] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,2] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,3] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,4] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,5] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,6] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,7] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,8] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,9] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,10] + 55*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,11] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,0] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,1] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,2] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,3] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,4] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,5] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,6] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,7] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,8] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,9] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,10] + 105*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,11] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,0] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,1] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,2] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,3] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,4] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,5] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,6] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,7] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,8] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,9] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,10] + 150*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scr ...
# RHS_recovery 2.7*decommis_srcSnk[GermanyRegion,windonshore,2]
# Constraint: windonshore_copper_scrap mat: copper
# 		(0.0650 sec)
#
# 		(0.2439 sec)
#
# Declaring objective function...
# Initial material costs: 0.1*initialMaterialSupply[GermanyRegion,steel] + 0.1*initialMaterialSupply[GermanyRegion,copper]
# 		(2.6206 sec)
#
# Set parameter Threads to value 3
# Set parameter LogFile to value ""
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 13.0.2 build v13.0.2rc1 (linux64 - "Rocky Linux 9.5 (Blue Onyx)")
#
# CPU model: Intel(R) Xeon(R) Gold 6144 CPU @ 3.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 16 physical cores, 32 logical processors, using up to 3 threads
#
# Non-default parameters:
# TSPort  41955
# QCPDual  1
# Threads  3
#
# Optimize a model with 33697 rows, 29824 columns and 101307 nonzeros (Min)
# Model fingerprint: 0xa8426ed5
# Model has 23 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [8e-04, 7e+02]
#   Objective range  [1e-03, 4e+00]
#   Bounds range     [5e-02, 1e+03]
#   RHS range        [1e+00, 2e+02]
#
# Presolve removed 13849 rows and 19674 columns
# Presolve time: 0.17s
# Presolved: 19848 rows, 10150 columns, 81495 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.34s
#
# Barrier statistics:
#  Dense cols : 79
#  Free vars  : 90
#  AA' NZ     : 3.303e+05
#  Factor NZ  : 2.500e+06 (roughly 30 MB of memory)
#  Factor Ops : 1.050e+09 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.08100874e+04 -6.64188818e+05  1.31e+06 3.47e-01  1.64e+03     1s
#    1   7.16356698e+04 -5.86471747e+05  9.65e+05 3.86e-01  1.13e+03     1s
#    2   5.75222685e+04 -6.30900475e+05  7.23e+05 1.26e-01  7.63e+02     1s
#    3   1.85583438e+04 -4.96067480e+05  1.78e+05 2.97e-02  2.00e+02     1s
#    4   7.94574020e+03 -3.66162889e+05  2.45e+04 9.21e-03  4.43e+01     1s
#    5   6.82142270e+03 -2.38953595e+05  1.17e+04 3.93e-03  2.11e+01     1s
#    6   5.78011696e+03 -1.14368726e+05  4.43e+03 1.05e-03  7.28e+00     1s
#    7   4.49698255e+03 -4.16850988e+04  1.83e+03 2.90e-04  2.35e+00     1s
#    8   4.19902586e+03 -1.81989949e+04  1.62e+03 1.25e-04  1.21e+00     1s
#    9   3.36928472e+03 -1.36650091e+04  1.14e+03 9.43e-05  9.00e-01     1s
#   10   2.24014263e+03 -9.07584376e+03  5.71e+02 9.52e-05  5.64e-01     1s
#   11   1.71467148e+03 -4.64830983e+03  3.36e+02 1.55e-04  3.11e-01     1s
#   12   1.17152820e+03 -2.55132664e+03  1.17e+02 9.14e-05  1.70e-01     1s
#   13   9.12160832e+02 -9.27190656e+02  4.12e+01 4.39e-05  8.13e-02     2s
#   14   6.27332733e+02 -3.22698565e+02  1.22e+01 2.39e-05  4.28e-02     2s
#   15   5.38457140e+02  1.16889822e+02  6.03e+00 9.03e-06  1.84e-02     2s
#   16   4.89181129e+02  2.09315294e+02  3.16e+00 6.23e-06  1.23e-02     2s
#   17   4.74074388e+02  2.68075281e+02  2.24e+00 4.54e-06  9.04e-03     2s
#   18   4.60072731e+02  3.08680301e+02  1.45e+00 1.99e-05  6.71e-03     2s
#   19   4.52975781e+02  3.80200117e+02  1.06e+00 8.24e-06  3.07e-03     2s
#   20   4.45448263e+02  4.08803582e+02  5.91e-01 8.78e-06  1.48e-03     2s
#   21   4.39990584e+02  4.27131458e+02  2.57e-01 2.79e-06  4.86e-04     2s
#   22   4.37342284e+02  4.29582164e+02  1.28e-01 2.00e-06  3.02e-04     2s
#   23   4.36422206e+02  4.32901400e+02  8.60e-02 9.55e-07  1.28e-04     2s
#   24   4.35661520e+02  4.33553966e+02  5.32e-02 3.96e-06  7.39e-05     2s
#   25   4.34999314e+02  4.34053213e+02  2.43e-02 1.79e-06  3.12e-05     2s
#   26   4.34714497e+02  4.34342850e+02  1.11e-02 4.86e-07  1.08e-05     2s
#   27   4.34485380e+02  4.34422409e+02  8.63e-04 9.87e-07  1.74e-06     2s
#   28   4.34468709e+02  4.34455042e+02  1.80e-04 6.27e-07  4.55e-07     3s
#   29   4.34465312e+02  4.34467080e+02  5.26e-05 7.12e-07  1.35e-07     3s
#   30   4.34463817e+02  4.34465964e+02  6.79e-06 2.18e-07  3.23e-08     3s
#   31   4.34463664e+02  4.34466666e+02  2.72e-06 1.43e-07  1.15e-08     3s
#   32   4.34463568e+02  4.34466806e+02  3.59e-07 9.16e-08  1.67e-09     3s
#   33   4.34463554e+02  4.34463653e+02  2.27e-08 4.17e-09  2.16e-10     3s
#   34   4.34463553e+02  4.34463668e+02  1.41e-08 2.64e-09  3.03e-11     3s
#
# Barrier solved model in 34 iterations and 2.94 seconds (1.68 work units)
# Optimal objective 4.34463553e+02
#
# Crossover log...
#
#     1422 DPushes remaining with DInf 3.0263948e-05                 3s
#        0 DPushes remaining with DInf 1.6744840e-04                 3s
#
#     2900 PPushes remaining with PInf 3.1433660e-04                 3s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.7153299e-06      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4046    4.3446355e+02   0.000000e+00   3.715329e-06      3s
# Crossover time: 0.22 seconds (0.25 work units)
#
# Solved with barrier
#     4048    4.3446355e+02   0.000000e+00   0.000000e+00      3s
#
# Solved in 4048 iterations and 3.19 seconds (1.94 work units)
# Optimal objective  4.344635523e+02
#
# Name: Gurobi 13.02
# Status: ok
# Wallclock time: 3.189594030380249
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#
#
# Name: unknown
# Lower bound: 434.463552270528
# Upper bound: 434.463552270528
# Number of objectives: 1
# Number of constraints: 33697
# Number of variables: 29824
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 29824
# Number of nonzeros: 101307
# Sense: minimize
# Number of solutions: 1
#
# Solve time: 6.261088132858276 sec.
#
# Processing optimization output...
# for SourceSinkModel ...(3.4840sec)
# for ConversionModel ...(0.8457sec)
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# for StorageModel ...  (2.8478sec)
# 		(7.2795 sec)

# %% [markdown]
#  # 11. Selected results output

# %% [markdown]
#  ### Sources and Sink
#
#  Show optimization summary

# %%
total_cost = 0.0

for loc, mat in esM.pyM.initialMaterialSet:
    quantity = esM.pyM.initialMaterialSupply[loc, mat].value
    unit_cost = esM.initialMaterialCost[mat][loc]
    material_cost = quantity * unit_cost

    print(f"{mat}:")
    print(f"  Initial supply [tons]: {quantity:.6f}")
    print(f"  Unit cost: {unit_cost:.8f} [USD/tons]")
    print(f"  Cost contribution : {material_cost:.6f} [USD]")

    total_cost += material_cost

print(f"\nTotal cost initial supply: {total_cost:.6f} [USD]")
# Out:
# steel:
#   Initial supply [tons]: 80.103007
#   Unit cost: 0.10000000 [USD/tons]
#   Cost contribution : 8.010301 [USD]
# copper:
#   Initial supply [tons]: 80.103007
#   Unit cost: 0.10000000 [USD/tons]
#   Cost contribution : 8.010301 [USD]
#
# Total cost initial supply: 16.020601 [USD]

# %%
import pyomo.environ as pyomo

initial_cost = sum(
    esM.pyM.initialMaterialSupply[loc, mat] * esM.initialMaterialCost[mat][loc]
    for loc, mat in esM.pyM.initialMaterialSet
)

print("Initial material cost:", pyomo.value(initial_cost))
print("Total Objective:", pyomo.value(esM.pyM.Obj))
# Out:
# Initial material cost: 16.020601354520945
# Total Objective: 434.4635522705278

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of SourceSinkModel for year {year}")
    print(esM.getOptimizationSummary("SourceSinkModel", outputLevel=2, ip=year))
# Out:
#  Results of SourceSinkModel for year 2020
#                                                                  GermanyRegion
# Component                 Property        Unit
# Copper demand             operation       [tons/h*h/a]               19.386542
#                                           [tons/h*h]                 19.386542
# Copper supply             operation       [tons/h*h/a]               12.806542
#                                           [tons/h*h]                 12.806542
# Electricity demand        operation       [GW$_{el}$*h/a]         30957.888055
#                                           [GW$_{el}$*h]           30957.888055
# Hydrogen demand           operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                           [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand              operation       [tons/h*h/a]               19.386542
#                                           [tons/h*h]                 19.386542
# Steel supply              operation       [tons/h*h/a]               11.161542
#                                           [tons/h*h]                 11.161542
# windoffshore              decommissioning [GW$_{el}$]                     15.0
# windoffshore_copper_scrap operation       [tons/h*h/a]                   10.71
#                                           [tons/h*h]                     10.71
# windoffshore_steel_scrap  operation       [tons/h*h/a]                   10.71
#                                           [tons/h*h]                     10.71
# windonshore               NPVcontribution [1e9 Euro]                 93.419534
#                           TAC             [1e9 Euro/a]               21.664375
#                           capacity        [GW$_{el}$]                 25.83968
#                           capexCap        [1e9 Euro/a]               20.062315
#                           commissioning   [GW$_{el}$]                 25.83968
#                           decommissioning [GW$_{el}$]                     10.0
#                           invest          [1e9 Euro]                 80.103007
#                           operation       [GW$_{el}$*h/a]          49239.34202
#                                           [GW$_{el}$*h]            49239.34202
#                           opexCap         [1e9 Euro/a]                 1.60206
# windonshore_copper_scrap  operation       [tons/h*h/a]                    5.74
#                                           [tons/h*h]                      5.74
# windonshore_steel_scrap   operation       [tons/h*h/a]                    5.74
#                                           [tons/h*h]                      5.74
#
#  Results of SourceSinkModel for year 2025
#                                                                 GermanyRegion
# Component                Property        Unit
# Copper demand            operation       [tons/h*h/a]                22.32005
#                                          [tons/h*h]                  22.32005
# Copper supply            operation       [tons/h*h/a]               17.193458
#                                          [tons/h*h]                 17.193458
# Electricity demand       operation       [GW$_{el}$*h/a]         40245.254471
#                                          [GW$_{el}$*h]           40245.254471
# Hydrogen demand          operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                          [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand             operation       [tons/h*h/a]                22.32005
#                                          [tons/h*h]                  22.32005
# Steel supply             operation       [tons/h*h/a]                15.91181
#                                          [tons/h*h]                  15.91181
# windonshore              NPVcontribution [1e9 Euro]                 79.502521
#                          TAC             [1e9 Euro/a]               27.089947
#                          capacity        [GW$_{el}$]                32.310904
#                          capexCap        [1e9 Euro/a]               25.086671
#                          commissioning   [GW$_{el}$]                32.310904
#                          decommissioning [GW$_{el}$]                 25.83968
#                          invest          [1e9 Euro]                100.163802
#                          operation       [GW$_{el}$*h/a]          62015.68088
#                                          [GW$_{el}$*h]            62015.68088
#                          opexCap         [1e9 Euro/a]                2.003276
# windonshore_copper_scrap operation       [tons/h*h/a]               12.816481
#                                          [tons/h*h]                 12.816481
# windonshore_steel_scrap  operation       [tons/h*h/a]               12.816481
#                                          [tons/h*h]                 12.816481
#
#  Results of SourceSinkModel for year 2030
#                                                                     GermanyRegion
# Component                    Property        Unit
# Electricity demand           operation       [GW$_{el}$*h/a]         49532.620887
#                                              [GW$_{el}$*h]           49532.620887
# Hydrogen demand              operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                              [GW$_{H_{2},LHV}$*h]     4765.074877
# windonshore                  NPVcontribution [1e9 Euro]                 64.443658
#                              TAC             [1e9 Euro/a]               32.264595
#                              capacity        [GW$_{el}$]                38.482845
#                              capexCap        [1e9 Euro/a]               29.878658
#                              commissioning   [GW$_{el}$]                38.482845
#                              decommissioning [GW$_{el}$]                32.310904
#                              invest          [1e9 Euro]                119.296819
#                              operation       [GW$_{el}$*h/a]         74841.906305
#                                              [GW$_{el}$*h]           74841.906305
#                              opexCap         [1e9 Euro/a]                2.385936
# windonshore_copper_scrap     operation       [tons/h*h/a]               17.447888
#                                              [tons/h*h]                 17.447888
# windonshore_copper_scrap_rec operation       [tons/h*h/a]               17.447888
#                                              [tons/h*h]                 17.447888
# windonshore_steel_scrap      operation       [tons/h*h/a]               17.447888
#                                              [tons/h*h]                 17.447888
# windonshore_steel_scrap_rec  operation       [tons/h*h/a]               17.447888
#                                              [tons/h*h]                 17.447888

# %% [markdown]
#  ### Conversion
#
#  Show optimization summary

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of ConversionMpdel for year {year}")
    print(esM.getOptimizationSummary("ConversionModel", outputLevel=2, ip=year))
# Out:
#  Results of ConversionMpdel for year 2020
#                                                                   GermanyRegion
# Component         Property                        Unit
# Electroylzers     NPVcontribution                 [1e9 Euro]           1.724179
#                   TAC                             [1e9 Euro/a]         0.399844
#                   capacity                        [GW$_{el}$]          2.903139
#                   capexCap                        [1e9 Euro/a]         0.363555
#                   commissioning                   [GW$_{el}$]          2.903139
#                   invest                          [1e9 Euro]            1.45157
#                   operation                       [GW$_{el}$*h/a]   6807.249824
#                                                   [GW$_{el}$*h]     6807.249824
#                   opexCap                         [1e9 Euro/a]         0.036289
# Recycler Offshore NPVcontribution                 [1e9 Euro]           0.000431
#                   TAC                             [1e9 Euro/a]           0.0001
#                   capacity                        [GW$_{el}$]          0.001223
#                   capexCap                        [1e9 Euro/a]         0.000074
#                   commissioning                   [GW$_{el}$]          0.001223
#                   invest                          [1e9 Euro]           0.000856
#                   operation                       [GW$_{el}$*h/a]         10.71
#                                                   [GW$_{el}$*h]           10.71
#                   opexCap                         [1e9 Euro/a]         0.000026
#                   revenueLifetimeShorteningResale [1e9 Euro]           0.000078
# Recycler Onshore  NPVcontribution                 [1e9 Euro]           0.000231
#                   TAC                             [1e9 Euro/a]         0.000054
#                   capacity                        [GW$_{el}$]          0.000655
#                   capexCap                        [1e9 Euro/a]          0.00004
#                   commissioning                   [GW$_{el}$]          0.000655
#                   invest                          [1e9 Euro]           0.000459
#                   operation                       [GW$_{el}$*h/a]          5.74
#                                                   [GW$_{el}$*h]            5.74
#                   opexCap                         [1e9 Euro/a]         0.000014
#                   revenueLifetimeShorteningResale [1e9 Euro]           0.000042
#
#  Results of ConversionMpdel for year 2025
#                                                                   GermanyRegion
# Component         Property                        Unit
# Electroylzers     NPVcontribution                 [1e9 Euro]            1.19998
#                   TAC                             [1e9 Euro/a]         0.408885
#                   capacity                        [GW$_{el}$]          2.968782
#                   capexCap                        [1e9 Euro/a]         0.371775
#                   commissioning                   [GW$_{el}$]          2.968782
#                   decommissioning                 [GW$_{el}$]          2.903139
#                   invest                          [1e9 Euro]           1.484391
#                   operation                       [GW$_{el}$*h/a]   6807.249824
#                                                   [GW$_{el}$*h]     6807.249824
#                   opexCap                         [1e9 Euro/a]          0.03711
# Recycler Offshore NPVcontribution                 [1e9 Euro]           0.000293
#                   TAC                             [1e9 Euro/a]           0.0001
#                   capacity                        [GW$_{el}$]          0.001223
#                   capexCap                        [1e9 Euro/a]         0.000074
#                   opexCap                         [1e9 Euro/a]         0.000026
# Recycler Onshore  NPVcontribution                 [1e9 Euro]           0.000351
#                   TAC                             [1e9 Euro/a]          0.00012
#                   capacity                        [GW$_{el}$]          0.001463
#                   capexCap                        [1e9 Euro/a]         0.000089
#                   commissioning                   [GW$_{el}$]          0.000808
#                   invest                          [1e9 Euro]           0.000565
#                   operation                       [GW$_{el}$*h/a]     12.816481
#                                                   [GW$_{el}$*h]       12.816481
#                   opexCap                         [1e9 Euro/a]         0.000031
#                   revenueLifetimeShorteningResale [1e9 Euro]           0.000051
#
#  Results of ConversionMpdel for year 2030
#                                                   GermanyRegion
# Component         Property        Unit
# Electroylzers     NPVcontribution [1e9 Euro]           0.870394
#                   TAC             [1e9 Euro/a]         0.435774
#                   capacity        [GW$_{el}$]          3.164017
#                   capexCap        [1e9 Euro/a]         0.396224
#                   commissioning   [GW$_{el}$]          3.164017
#                   decommissioning [GW$_{el}$]          2.968782
#                   invest          [1e9 Euro]           1.582009
#                   operation       [GW$_{el}$*h/a]   6807.249824
#                                   [GW$_{el}$*h]     6807.249824
#                   opexCap         [1e9 Euro/a]          0.03955
# Recycler Offshore NPVcontribution [1e9 Euro]             0.0002
#                   TAC             [1e9 Euro/a]           0.0001
#                   capacity        [GW$_{el}$]          0.001223
#                   capexCap        [1e9 Euro/a]         0.000074
#                   opexCap         [1e9 Euro/a]         0.000026
# Recycler Onshore  NPVcontribution [1e9 Euro]           0.000239
#                   TAC             [1e9 Euro/a]          0.00012
#                   capacity        [GW$_{el}$]          0.001463
#                   capexCap        [1e9 Euro/a]         0.000089
#                   opexCap         [1e9 Euro/a]         0.000031

# %% [markdown]
#  ### Storage
#
#  Show optimization summary

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of StorageModel for year {year}")
    print(esM.getOptimizationSummary("StorageModel", outputLevel=2, ip=year))
# Out:
#  Results of StorageModel for year 2020
#                                                                    GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                  62.364963
#                         TAC                [1e9 Euro/a]                14.462692
#                         capacity           [GW$_{el}$*h]              736.342338
#                         capexCap           [1e9 Euro/a]                12.990008
#                         commissioning      [GW$_{el}$*h]              736.342338
#                         invest             [1e9 Euro]                 111.187693
#                         operationCharge    [GW$_{el}$*h/a]         116373.891673
#                                            [GW$_{el}$*h]           116373.891673
#                         operationDischarge [GW$_{el}$*h/a]         104899.687532
#                                            [GW$_{el}$*h]           104899.687532
#                         opexCap            [1e9 Euro/a]                 1.472685
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                   2.292277
#                         TAC                [1e9 Euro/a]                 0.531589
#                         capacity           [GW$_{H_{2},LHV}$*h]       916.893966
#                         capexCap           [1e9 Euro/a]                 0.008959
#                         commissioning      [GW$_{H_{2},LHV}$*h]       916.893966
#                         invest             [1e9 Euro]                   0.100858
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   13648.928623
#                                            [GW$_{H_{2},LHV}$*h]     13648.928623
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   13648.928623
#                                            [GW$_{H_{2},LHV}$*h]     13648.928623
#                         opexCap            [1e9 Euro/a]                  0.52263
#
#  Results of StorageModel for year 2025
#                                                                    GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                  58.526846
#                         TAC                [1e9 Euro/a]                19.942627
#                         capacity           [GW$_{el}$*h]             1015.343512
#                         capexCap           [1e9 Euro/a]                 17.91194
#                         commissioning      [GW$_{el}$*h]              279.001174
#                         invest             [1e9 Euro]                  42.129177
#                         operationCharge    [GW$_{el}$*h/a]         151631.974965
#                                            [GW$_{el}$*h]           151631.974965
#                         operationDischarge [GW$_{el}$*h/a]          136668.79838
#                                            [GW$_{el}$*h]            136668.79838
#                         opexCap            [1e9 Euro/a]                 2.030687
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                   1.595333
#                         TAC                [1e9 Euro/a]                 0.543599
#                         capacity           [GW$_{H_{2},LHV}$*h]       937.673487
#                         capexCap           [1e9 Euro/a]                 0.009125
#                         commissioning      [GW$_{H_{2},LHV}$*h]        20.779521
#                         invest             [1e9 Euro]                    0.00187
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   14096.090379
#                                            [GW$_{H_{2},LHV}$*h]     14096.090379
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   14096.090379
#                                            [GW$_{H_{2},LHV}$*h]     14096.090379
#                         opexCap            [1e9 Euro/a]                 0.534474
#
#  Results of StorageModel for year 2030
#                                                                    GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                  51.339499
#                         TAC                [1e9 Euro/a]                25.703819
#                         capacity           [GW$_{el}$*h]             1308.664371
#                         capexCap           [1e9 Euro/a]                 23.08649
#                         commissioning      [GW$_{el}$*h]              293.320859
#                         invest             [1e9 Euro]                   44.29145
#                         operationCharge    [GW$_{el}$*h/a]         187384.608258
#                                            [GW$_{el}$*h]           187384.608258
#                         operationDischarge [GW$_{el}$*h/a]         168882.572664
#                                            [GW$_{el}$*h]           168882.572664
#                         opexCap            [1e9 Euro/a]                 2.617329
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                    1.16202
#                         TAC                [1e9 Euro/a]                 0.581781
#                         capacity           [GW$_{H_{2},LHV}$*h]       1003.73298
#                         capexCap           [1e9 Euro/a]                 0.009653
#                         commissioning      [GW$_{H_{2},LHV}$*h]        66.059493
#                         invest             [1e9 Euro]                   0.005945
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]    15191.39759
#                                            [GW$_{H_{2},LHV}$*h]      15191.39759
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]    15191.39759
#                                            [GW$_{H_{2},LHV}$*h]      15191.39759
#                         opexCap            [1e9 Euro/a]                 0.572128
