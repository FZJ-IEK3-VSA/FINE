# %% [markdown]
#  # Workflow for a transformation pathway of a single node energy system with perfect foresight
#
#  In this application of the ETHOS.FINE framework, a transformation pathway of a energy system is modeled and optimized.
#
#  All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
#  The workflow is structures as follows:
#  1. Required packages are imported and the input data path is set
#  2. An energy system model instance is created
#  3. Commodity sources are added to the energy system model
#  4. Commodity conversion components are added to the energy system model
#  5. Commodity storages are added to the energy system model
#  6. Commodity sinks are added to the energy system model
#  7. Material sinks are added to the energy system model
#  8. Material sources are addeed to the energy system model
#  9. Material conversions are added to the energy system model for recycling processes
#  10. The energy system model is optimized
#  11. Selected optimization results are presented

# %% [markdown]
#  # 1. Import required packages and set input data path
#
#  The ETHOS.FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import fine as fn
from getData import getData
from pathlib import Path
import pandas as pd


cwd = Path.cwd()
data = getData()

# %% [markdown]
#  # 2. Create an energy system model instance
#
#  The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
#  The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {"GermanyRegion"}
commodityUnitsDict = {
    "electricity": r"GW$_{el}$",
    "hydrogen": r"GW$_{H_{2},LHV}$",
}
commodities = {"electricity", "hydrogen"}
materials = {
    "steel",
    "copper",
    "windonshore_steel_scrap",
    "windoffshore_steel_scrap",
    "windonshore_copper_scrap",
    "windoffshore_copper_scrap",
}

materialUnitsDict = {
    "steel": "tons",
    "copper": "tons",
    "windonshore_steel_scrap": "tons",
    "windoffshore_steel_scrap": "tons",
    "windonshore_copper_scrap": "tons",
    "windoffshore_copper_scrap": "tons",
}


numberOfTimeSteps = 8760
hoursPerTimeStep = 1

# %% [markdown]
#  # 2.1 define Transformation Pathway parameters
#
#  Transformation Pathway Analyses can be run by setting a number of investment periods
#  larger than 1, which is the default value and results in a single year optimization.

# %%
numberOfInvestmentPeriods = 3
startYear = 2020
interval = 5

# %%
pathwayBalanceLimit = pd.DataFrame(
    columns=["GermanyRegion", "Total", "lowerBound"],
    index=["Copper_Resources", "Steel_Resources"],
)
pathwayBalanceLimit.loc["Copper_Resources"] = [None, 650, False]
pathwayBalanceLimit.loc["Steel_Resources"] = [None, 650, False]

# %%
esM = fn.EnergySystemModel(
    locations=locations,
    commodities=commodities,
    materials=materials,
    numberOfInvestmentPeriods=numberOfInvestmentPeriods,
    startYear=startYear,
    investmentPeriodInterval=interval,
    numberOfTimeSteps=8760,
    commodityUnitsDict=commodityUnitsDict,
    materialUnitsDict=materialUnitsDict,
    hoursPerTimeStep=1,
    costUnit="1e9 Euro",
    lengthUnit="km",
    verboseLogLevel=0,
    pathwayBalanceLimit=pathwayBalanceLimit,
)

# %% [markdown]
#  # 3. Add commodity sources to the energy system model

# %% [markdown]
#  ## 3.1. Electricity sources

# %% [markdown]
#  ### Wind onshore

# %% [markdown]
#  change weather conditions for the different investment periods

# %%
operationRateMax = {}
operationRateMax[2020] = 1.2 * data["Wind (onshore), operationRateMax"]
operationRateMax[2025] = 0.7 * data["Wind (onshore), operationRateMax"]
operationRateMax[2030] = 1 * data["Wind (onshore), operationRateMax"]

# %% [markdown]
#  define existing stock for wind onshore turbines

# %%
stockWindonshoreCommissioning = {
    2015: 10,
}

stockWindoffshoreCommissioning = {
    2015: 15,
}

# %% [markdown]
#  define invest and opex per capacity for wind onshore turbines

# %%
investPerCapacityWind = {2015: 1.25, 2020: 1.1, 2025: 1, 2030: 0.95}

opexPerCapacityWind = {
    2015: 1.25 * 0.02,
    2020: 1.1 * 0.02,
    2025: 1 * 0.02,
    2030: 0.95 * 0.02,
}

# %% [markdown]
#  add wind onshore source to esM

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="windonshore",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=3.1,
        opexPerCapacity=3.1 * 0.02,
        interestRate=0.08,
        economicLifetime=5,
        stockCommissioning=stockWindonshoreCommissioning,
        materialIntensity={
            "GermanyRegion": {
                "steel": pd.Series(
                    {2015: 4.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype="float64"
                ),
                "copper": pd.Series(
                    {2015: 4.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype="float64"
                ),
            },
        },
        materialCollection={
            "GermanyRegion": {
                "steel": pd.Series({2020: 0.7, 2025: 0.8, 2030: 0.9}, dtype="float64"),
                "copper": pd.Series({2020: 0.7, 2025: 0.8, 2030: 0.9}, dtype="float64"),
            },
        },
    )
)

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="windoffshore",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=3.1,
        opexPerCapacity=3.1 * 0.015,
        interestRate=0.08,
        economicLifetime=5,
        stockCommissioning=stockWindoffshoreCommissioning,
        materialIntensity={
            "GermanyRegion": {
                "steel": pd.Series(
                    {2015: 5.1, 2020: 4.1, 2025: 4.0, 2030: 3.9}, dtype="float64"
                ),
                "copper": pd.Series(
                    {2015: 5.1, 2020: 4.1, 2025: 4.0, 2030: 3.9}, dtype="float64"
                ),
            },
        },
        materialCollection={
            "GermanyRegion": {
                "steel": pd.Series({2020: 0.7, 2025: 0.8, 2030: 0.9}, dtype="float64"),
                "copper": pd.Series({2020: 0.7, 2025: 0.8, 2030: 0.9}, dtype="float64"),
            },
        },
    )
)

# %% [markdown]
#  Full load hours:

# %%
data["Wind (onshore), operationRateMax"].sum()
# Out:
# 2300.4069071646272

# %% [markdown]
#  # 4. Add conversion components to the energy system model

# %% [markdown]
#  ### Electrolyzers

# %% [markdown]
#  add component with constant invest and opex per capacity

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Electroylzers",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.7},
        hasCapacityVariable=True,
        investPerCapacity=0.5,
        opexPerCapacity=0.5 * 0.025,
        interestRate=0.08,
        economicLifetime=5,
    )
)

# %% [markdown]
#  # 5. Add commodity storages to the energy system model

# %% [markdown]
#  ## 5.1. Electricity storage

# %% [markdown]
#  ### Lithium ion batteries
#
#  The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Li-ion batteries",
        commodity="electricity",
        hasCapacityVariable=True,
        chargeEfficiency=0.95,
        cyclicLifetime=10000,
        dischargeEfficiency=0.95,
        selfDischarge=1 - (1 - 0.03) ** (1 / (30 * 24)),
        chargeRate=1,
        dischargeRate=1,
        doPreciseTsaModeling=False,
        investPerCapacity=0.151,
        opexPerCapacity=0.002,
        interestRate=0.08,
        economicLifetime=15,
    )
)

# %% [markdown]
#  ## 5.2. Hydrogen storage

# %% [markdown]
#  ### Hydrogen filled salt caverns
#  The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (hydrogen)",
        commodity="hydrogen",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=133,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (hydrogen), capacityMax"],
        investPerCapacity={2020: 0.00011, 2025: 0.00009, 2030: 0.00009},
        opexPerCapacity=0.00057,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
#  # 6. Add commodity sinks to the energy system model

# %% [markdown]
#  ## 6.1. Electricity sinks

# %% [markdown]
#  ### Electricity demand

# %% [markdown]
#  vary the demand with the years - increasing demand by 30% per year

# %%
electricityDemand = {}
electricityDemand[2020] = (1 + 0 * 0.3) * data["Electricity demand, operationRateFix"]
electricityDemand[2025] = (1 + 1 * 0.3) * data["Electricity demand, operationRateFix"]
electricityDemand[2030] = (1 + 2 * 0.3) * data["Electricity demand, operationRateFix"]

esM.add(
    fn.Sink(
        esM=esM,
        name="Electricity demand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=electricityDemand,
    )
)

# %% [markdown]
#  ## 6.2. Hydrogen sinks

# %% [markdown]
#  ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration = 0.5

# vary the demand with the years - increasing demand by 25% per year
hydrogendDemand = {}
hydrogendDemand[2020] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)
hydrogendDemand[2025] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)
hydrogendDemand[2030] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)


esM.add(
    fn.Sink(
        esM=esM,
        name="Hydrogen demand",
        commodity="hydrogen",
        hasCapacityVariable=False,
        operationRateFix=hydrogendDemand,
    )
)

# %% [markdown]
# # 7. Add material sinks to the energy system model

# %%
sink = esM.add(
    fn.Sink(
        esM=esM,
        name="Steel demand",
        hasCapacityVariable=False,
        commodity="steel",
        material=True,
    )
)

sink = esM.add(
    fn.Sink(
        esM=esM,
        name="Copper demand",
        hasCapacityVariable=False,
        commodity="copper",
        material=True,
    )
)

# %% [markdown]
# # 8. Add material sources to the energy system model

# %% [markdown]
# ## 8.1 Add primary material sources with pathway balance limit

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Steel supply",
        hasCapacityVariable=False,
        commodity="steel",
        pathwayBalanceLimitID="Steel_Resources",
    )
)

esM.add(
    fn.Source(
        esM=esM,
        name="Copper supply",
        hasCapacityVariable=False,
        commodity="copper",
        pathwayBalanceLimitID="Copper_Resources",
    )
)

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="windonshore_steel_scrap",
        commodity="windonshore_steel_scrap",
        hasCapacityVariable=False,
        material=True,
    )
)

esM.add(
    fn.Source(
        esM=esM,
        name="windoffshore_steel_scrap",
        commodity="windoffshore_steel_scrap",
        hasCapacityVariable=False,
        material=True,
    )
)

esM.add(
    fn.Source(
        esM=esM,
        name="windonshore_copper_scrap",
        commodity="windonshore_copper_scrap",
        hasCapacityVariable=False,
        material=True,
    )
)

esM.add(
    fn.Source(
        esM=esM,
        name="windoffshore_copper_scrap",
        commodity="windoffshore_copper_scrap",
        hasCapacityVariable=False,
        material=True,
    )
)

# %% [markdown]
# # 9. Add recycling plants

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Recycler Onshore",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={
            "windonshore_steel_scrap": -1,
            "steel": 0.5,
            "windonshore_copper_scrap": -1,
            "copper": 0.4,
        },
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

esM.add(
    fn.Conversion(
        esM=esM,
        name="Recycler Offshore",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={
            "windoffshore_steel_scrap": -1,
            "steel": 0.5,
            "windoffshore_copper_scrap": -1,
            "copper": 0.4,
        },
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

# %% [markdown]
#  # 10. Optimize energy system model

# %% [markdown]
#  All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
esM.aggregateTemporally(numberOfTypicalPeriods=30)
# Out:
# Clustering time series data with 30 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(13.7721 sec)

# %%
esM.optimize(timeSeriesAggregation=True, solver="gurobi")
# Out:
# Time series aggregation specifications:
# Number of typical periods:30, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.7850 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.2193 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.4560 sec)
#
# Declaring shared potential constraint...
# 		(0.0004 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.3041 sec)
#
# Declaring material demand constraints...
# LHS_demand 15*op_srcSnk[GermanyRegion,Steel demand,0,0,0] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,1] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,2] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,3] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,4] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,5] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,6] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,7] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,8] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,9] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,10] + 15*op_srcSnk[GermanyRegion,Steel demand,0,0,11] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,0] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,1] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,2] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,3] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,4] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,5] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,6] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,7] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,8] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,9] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,10] + 11*op_srcSnk[GermanyRegion,Steel demand,0,1,11] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,0] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,1] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,2] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,3] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,4] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,5] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,6] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,7] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,8] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,9] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,10] + 11*op_srcSnk[GermanyRegion,Steel demand,0,2,11] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,0] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,1] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,2] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,3] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,4] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,5] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,6] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,7] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,8] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,9] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,10] + 21*op_srcSnk[GermanyRegion,Steel demand,0,3,11] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,0] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,1] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,2] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,3] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,4] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,5] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,6] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,7] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,8] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,9] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,10] + 30*op_srcSnk[GermanyRegion,Steel demand,0,4,11] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,0] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,1] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,2] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,3] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,4] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,5] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,6] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,7] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,8] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,9] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,10] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,11] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,0] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,1] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,2] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,3] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,4] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,5] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,6] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,7] + 21*op_srcSnk[GermanyRegion,Steel demand,0,6,8] + 21*op_sr ...
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,windonshore,0] + 4.1*commis_srcSnk[GermanyRegion,windoffshore,0]
# LHS_demand 15*op_srcSnk[GermanyRegion,Steel demand,1,0,0] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,1] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,2] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,3] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,4] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,5] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,6] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,7] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,8] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,9] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,10] + 15*op_srcSnk[GermanyRegion,Steel demand,1,0,11] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,0] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,1] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,2] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,3] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,4] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,5] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,6] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,7] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,8] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,9] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,10] + 11*op_srcSnk[GermanyRegion,Steel demand,1,1,11] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,0] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,1] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,2] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,3] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,4] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,5] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,6] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,7] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,8] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,9] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,10] + 11*op_srcSnk[GermanyRegion,Steel demand,1,2,11] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,0] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,1] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,2] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,3] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,4] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,5] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,6] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,7] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,8] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,9] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,10] + 21*op_srcSnk[GermanyRegion,Steel demand,1,3,11] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,0] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,1] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,2] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,3] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,4] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,5] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,6] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,7] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,8] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,9] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,10] + 30*op_srcSnk[GermanyRegion,Steel demand,1,4,11] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,0] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,1] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,2] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,3] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,4] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,5] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,6] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,7] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,8] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,9] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,10] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,11] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,0] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,1] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,2] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,3] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,4] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,5] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,6] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,7] + 21*op_srcSnk[GermanyRegion,Steel demand,1,6,8] + 21*op_sr ...
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,windonshore,1] + 4.0*commis_srcSnk[GermanyRegion,windoffshore,1]
# LHS_demand 15*op_srcSnk[GermanyRegion,Steel demand,2,0,0] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,1] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,2] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,3] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,4] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,5] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,6] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,7] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,8] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,9] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,10] + 15*op_srcSnk[GermanyRegion,Steel demand,2,0,11] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,0] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,1] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,2] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,3] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,4] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,5] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,6] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,7] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,8] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,9] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,10] + 11*op_srcSnk[GermanyRegion,Steel demand,2,1,11] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,0] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,1] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,2] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,3] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,4] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,5] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,6] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,7] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,8] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,9] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,10] + 11*op_srcSnk[GermanyRegion,Steel demand,2,2,11] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,0] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,1] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,2] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,3] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,4] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,5] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,6] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,7] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,8] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,9] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,10] + 21*op_srcSnk[GermanyRegion,Steel demand,2,3,11] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,0] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,1] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,2] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,3] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,4] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,5] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,6] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,7] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,8] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,9] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,10] + 30*op_srcSnk[GermanyRegion,Steel demand,2,4,11] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,0] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,1] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,2] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,3] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,4] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,5] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,6] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,7] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,8] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,9] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,10] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,11] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,0] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,1] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,2] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,3] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,4] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,5] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,6] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,7] + 21*op_srcSnk[GermanyRegion,Steel demand,2,6,8] + 21*op_sr ...
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,windonshore,2] + 3.9*commis_srcSnk[GermanyRegion,windoffshore,2]
# LHS_demand 15*op_srcSnk[GermanyRegion,Copper demand,0,0,0] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,1] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,2] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,3] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,4] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,5] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,6] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,7] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,8] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,9] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,10] + 15*op_srcSnk[GermanyRegion,Copper demand,0,0,11] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,0] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,1] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,2] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,3] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,4] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,5] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,6] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,7] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,8] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,9] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,10] + 11*op_srcSnk[GermanyRegion,Copper demand,0,1,11] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,0] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,1] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,2] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,3] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,4] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,5] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,6] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,7] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,8] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,9] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,10] + 11*op_srcSnk[GermanyRegion,Copper demand,0,2,11] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,0] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,1] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,2] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,3] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,4] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,5] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,6] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,7] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,8] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,9] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,10] + 21*op_srcSnk[GermanyRegion,Copper demand,0,3,11] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,0] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,1] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,2] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,3] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,4] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,5] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,6] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,7] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,8] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,9] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,10] + 30*op_srcSnk[GermanyRegion,Copper demand,0,4,11] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,0] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,1] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,2] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,3] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,4] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,5] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,6] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,7] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,8] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,9] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,10] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,11] + 21*op_srcSnk[GermanyRegion,Copper demand,0,6,0] + 21*op_srcSnk[GermanyRegion,Copper demand,0,6,1] + 21*op_srcSnk[GermanyRegion,Copper demand,0,6,2] + 21*op_srcSnk[GermanyRegion,Copper demand,0,6,3] + 21*op_srcSnk[GermanyRegion,Copper demand,0,6,4] + 21*op_srcSnk[GermanyRegion,Copper demand,0,6,5] + 21*op_srcSnk[GermanyRegion,Copper demand,0,6,6] + 21*op_srcSnk[GermanyRegion, ...
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,windonshore,0] + 4.1*commis_srcSnk[GermanyRegion,windoffshore,0]
# LHS_demand 15*op_srcSnk[GermanyRegion,Copper demand,1,0,0] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,1] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,2] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,3] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,4] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,5] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,6] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,7] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,8] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,9] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,10] + 15*op_srcSnk[GermanyRegion,Copper demand,1,0,11] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,0] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,1] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,2] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,3] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,4] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,5] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,6] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,7] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,8] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,9] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,10] + 11*op_srcSnk[GermanyRegion,Copper demand,1,1,11] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,0] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,1] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,2] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,3] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,4] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,5] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,6] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,7] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,8] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,9] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,10] + 11*op_srcSnk[GermanyRegion,Copper demand,1,2,11] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,0] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,1] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,2] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,3] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,4] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,5] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,6] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,7] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,8] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,9] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,10] + 21*op_srcSnk[GermanyRegion,Copper demand,1,3,11] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,0] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,1] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,2] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,3] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,4] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,5] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,6] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,7] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,8] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,9] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,10] + 30*op_srcSnk[GermanyRegion,Copper demand,1,4,11] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,0] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,1] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,2] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,3] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,4] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,5] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,6] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,7] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,8] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,9] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,10] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,11] + 21*op_srcSnk[GermanyRegion,Copper demand,1,6,0] + 21*op_srcSnk[GermanyRegion,Copper demand,1,6,1] + 21*op_srcSnk[GermanyRegion,Copper demand,1,6,2] + 21*op_srcSnk[GermanyRegion,Copper demand,1,6,3] + 21*op_srcSnk[GermanyRegion,Copper demand,1,6,4] + 21*op_srcSnk[GermanyRegion,Copper demand,1,6,5] + 21*op_srcSnk[GermanyRegion,Copper demand,1,6,6] + 21*op_srcSnk[GermanyRegion, ...
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,windonshore,1] + 4.0*commis_srcSnk[GermanyRegion,windoffshore,1]
# LHS_demand 15*op_srcSnk[GermanyRegion,Copper demand,2,0,0] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,1] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,2] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,3] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,4] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,5] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,6] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,7] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,8] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,9] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,10] + 15*op_srcSnk[GermanyRegion,Copper demand,2,0,11] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,0] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,1] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,2] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,3] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,4] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,5] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,6] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,7] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,8] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,9] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,10] + 11*op_srcSnk[GermanyRegion,Copper demand,2,1,11] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,0] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,1] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,2] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,3] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,4] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,5] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,6] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,7] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,8] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,9] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,10] + 11*op_srcSnk[GermanyRegion,Copper demand,2,2,11] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,0] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,1] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,2] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,3] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,4] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,5] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,6] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,7] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,8] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,9] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,10] + 21*op_srcSnk[GermanyRegion,Copper demand,2,3,11] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,0] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,1] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,2] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,3] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,4] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,5] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,6] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,7] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,8] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,9] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,10] + 30*op_srcSnk[GermanyRegion,Copper demand,2,4,11] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,0] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,1] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,2] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,3] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,4] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,5] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,6] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,7] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,8] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,9] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,10] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,11] + 21*op_srcSnk[GermanyRegion,Copper demand,2,6,0] + 21*op_srcSnk[GermanyRegion,Copper demand,2,6,1] + 21*op_srcSnk[GermanyRegion,Copper demand,2,6,2] + 21*op_srcSnk[GermanyRegion,Copper demand,2,6,3] + 21*op_srcSnk[GermanyRegion,Copper demand,2,6,4] + 21*op_srcSnk[GermanyRegion,Copper demand,2,6,5] + 21*op_srcSnk[GermanyRegion,Copper demand,2,6,6] + 21*op_srcSnk[GermanyRegion, ...
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,windonshore,2] + 3.9*commis_srcSnk[GermanyRegion,windoffshore,2]
# 		(0.0194 sec)
#
# Declaring material recovery constraints...
# LHS_recovery 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,0] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,1] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,2] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,3] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,4] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,5] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,6] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,7] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,8] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,9] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,10] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,11] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,0] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,1] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,2] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,3] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,4] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,5] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,6] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,7] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,8] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,9] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,10] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,11] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,0] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,1] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,2] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,3] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,4] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,5] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,6] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,7] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,8] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,9] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,10] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,11] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,0] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,1] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,2] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,3] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,4] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,5] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,6] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,7] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,8] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,9] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,10] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,11] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,0] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,1] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,2] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,3] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,4] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,5] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,6] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,7] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,8] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,9] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,10] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,11] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,0] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,1] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,2] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,3] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,4] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,5] + 10*op_srcSnk[Germ ...
# RHS_recovery 2.8699999999999997*decommis_srcSnk[GermanyRegion,windonshore,0]
# LHS_recovery 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,0] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,1] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,2] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,3] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,4] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,5] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,6] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,7] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,8] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,9] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,10] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,11] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,0] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,1] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,2] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,3] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,4] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,5] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,6] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,7] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,8] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,9] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,10] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,11] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,0] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,1] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,2] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,3] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,4] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,5] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,6] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,7] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,8] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,9] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,10] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,11] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,0] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,1] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,2] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,3] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,4] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,5] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,6] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,7] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,8] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,9] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,10] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,11] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,0] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,1] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,2] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,3] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,4] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,5] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,6] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,7] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,8] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,9] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,10] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,11] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,0] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,1] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,2] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,3] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,4] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,5] + 10*op_srcSnk[Germ ...
# RHS_recovery 2.4800000000000004*decommis_srcSnk[GermanyRegion,windonshore,1]
# LHS_recovery 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,0] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,1] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,2] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,3] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,4] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,5] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,6] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,7] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,8] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,9] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,10] + 15*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,11] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,0] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,1] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,2] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,3] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,4] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,5] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,6] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,7] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,8] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,9] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,10] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,11] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,0] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,1] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,2] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,3] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,4] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,5] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,6] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,7] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,8] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,9] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,10] + 11*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,11] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,0] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,1] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,2] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,3] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,4] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,5] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,6] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,7] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,8] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,9] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,10] + 21*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,11] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,0] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,1] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,2] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,3] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,4] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,5] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,6] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,7] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,8] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,9] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,10] + 30*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,11] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,0] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,1] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,2] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,3] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,4] + 10*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,5] + 10*op_srcSnk[Germ ...
# RHS_recovery 2.7*decommis_srcSnk[GermanyRegion,windonshore,2]
# LHS_recovery 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,0] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,1] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,2] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,3] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,4] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,5] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,6] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,7] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,8] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,9] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,10] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,0,11] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,0] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,1] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,2] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,3] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,4] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,5] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,6] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,7] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,8] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,9] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,10] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,1,11] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,0] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,1] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,2] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,3] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,4] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,5] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,6] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,7] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,8] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,9] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,10] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,2,11] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,0] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,1] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,2] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,3] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,4] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,5] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,6] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,7] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,8] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,9] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,10] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,3,11] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,0] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,1] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,2] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,3] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,4] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,5] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,6] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,7] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,8] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,9] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,10] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,4,11] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,0] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,1] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,2] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,3] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,0,5,4] + 10*op_srcSnk ...
# RHS_recovery 3.5699999999999994*decommis_srcSnk[GermanyRegion,windoffshore,0]
# LHS_recovery 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,0] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,1] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,2] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,3] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,4] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,5] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,6] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,7] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,8] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,9] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,10] + 15*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,0,11] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,0] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,1] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,2] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,3] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,4] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,5] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,6] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,7] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,8] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,9] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,10] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,1,11] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,0] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,1] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,2] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,3] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,4] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,5] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,6] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,7] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,8] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,9] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,10] + 11*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,2,11] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,0] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,1] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,2] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,3] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,4] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,5] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,6] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,7] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,8] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,9] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,10] + 21*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,3,11] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,0] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,1] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,2] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,3] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,4] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,5] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,6] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,7] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,8] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,9] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,10] + 30*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,4,11] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,5,0] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,5,1] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,5,2] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,5,3] + 10*op_srcSnk[GermanyRegion,windoffshore_steel_scrap,1,5,4] + 10*op_srcSnk ...
# RHS_recovery 3.28*decommis_srcSnk[GermanyRegion,windoffshore,1]
# ...
# RHS_recovery 3.5699999999999994*decommis_srcSnk[GermanyRegion,windoffshore,0]
# LHS_recovery 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,0] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,1] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,2] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,3] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,4] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,5] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,6] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,7] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,8] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,9] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,10] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,0,11] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,0] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,1] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,2] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,3] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,4] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,5] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,6] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,7] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,8] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,9] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,10] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,1,11] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,0] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,1] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,2] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,3] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,4] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,5] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,6] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,7] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,8] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,9] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,10] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,2,11] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,0] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,1] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,2] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,3] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,4] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,5] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,6] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,7] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,8] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,9] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,10] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,3,11] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,0] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,1] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,2] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,3] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,4] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,5] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,6] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,7] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,8] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,9] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,10] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,4,11] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,5,0] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,5,1] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,5,2] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,1,5,3] + 10*op_src ...
# RHS_recovery 3.28*decommis_srcSnk[GermanyRegion,windoffshore,1]
# LHS_recovery 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,0] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,1] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,2] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,3] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,4] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,5] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,6] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,7] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,8] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,9] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,10] + 15*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,0,11] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,0] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,1] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,2] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,3] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,4] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,5] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,6] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,7] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,8] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,9] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,10] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,1,11] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,0] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,1] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,2] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,3] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,4] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,5] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,6] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,7] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,8] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,9] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,10] + 11*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,2,11] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,0] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,1] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,2] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,3] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,4] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,5] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,6] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,7] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,8] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,9] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,10] + 21*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,3,11] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,0] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,1] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,2] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,3] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,4] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,5] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,6] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,7] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,8] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,9] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,10] + 30*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,4,11] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,5,0] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,5,1] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,5,2] + 10*op_srcSnk[GermanyRegion,windoffshore_copper_scrap,2,5,3] + 10*op_src ...
# RHS_recovery 3.6*decommis_srcSnk[GermanyRegion,windoffshore,2]
# 		(0.0410 sec)
#
# 		(0.0048 sec)
#
# Declaring objective function...
# 		(1.7415 sec)
#
# Set parameter ServerPassword
# Set parameter TSPort to value 41955
# Set parameter TokenServer to value "192.168.91.239"
# Read LP format model from file /tmp/tmpc6rya27r.pyomo.lp
# Reading time = 0.07 seconds
# x1: 33697 rows, 25502 columns, 99865 nonzeros
# Set parameter QCPDual to value 1
# Set parameter Threads to value 3
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (linux64 - "Rocky Linux 8.8 (Green Obsidian)")
#
# CPU model: Intel(R) Xeon(R) Gold 6154 CPU @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 36 physical cores, 72 logical processors, using up to 3 threads
#
# Optimize a model with 33697 rows, 25502 columns and 99865 nonzeros
# Model fingerprint: 0xb6eeac18
# Coefficient statistics:
#   Matrix range     [8e-04, 7e+02]
#   Objective range  [1e-03, 4e+00]
#   Bounds range     [5e-02, 1e+03]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 12691 rows and 14626 columns
# Presolve time: 0.14s
# Presolved: 21006 rows, 10876 columns, 86367 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.34s
#
# Barrier statistics:
#  Dense cols : 81
#  Free vars  : 330
#  AA' NZ     : 3.258e+05
#  Factor NZ  : 2.591e+06 (roughly 34 MB of memory)
#  Factor Ops : 1.169e+09 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.61054035e+04 -1.46480715e+06  4.59e+05 1.55e+00  3.64e+03     1s
#    1   9.09157121e+04 -1.32302967e+06  3.97e+05 1.24e+00  3.10e+03     1s
#    2   3.08246262e+04 -1.27239861e+06  1.65e+05 4.21e-01  1.25e+03     1s
#    3   1.52530692e+04 -1.00206066e+06  5.27e+04 1.41e-01  4.37e+02     1s
#    4   8.50094157e+03 -7.77966873e+05  8.69e+03 5.68e-02  1.34e+02     1s
#    5   7.79869992e+03 -3.95261160e+05  4.37e+03 1.18e-02  4.20e+01     1s
#    6   7.33266066e+03 -2.32107006e+05  2.36e+03 5.68e-03  2.17e+01     1s
#    7   6.79108198e+03 -1.50718164e+05  1.28e+03 3.35e-03  1.30e+01     1s
#    8   6.12349957e+03 -8.74115281e+04  5.17e+02 1.76e-03  6.56e+00     1s
#    9   5.19719152e+03 -3.84068446e+04  2.58e+02 7.64e-04  3.11e+00     1s
#   10   4.22660836e+03 -2.16277468e+04  1.33e+02 4.64e-04  1.83e+00     1s
#   11   3.77279107e+03 -1.47000697e+04  9.40e+01 3.36e-04  1.32e+00     1s
#   12   3.40199548e+03 -1.15452540e+04  7.07e+01 2.78e-04  1.08e+00     1s
#   13   2.98310208e+03 -9.84184684e+03  4.90e+01 2.39e-04  9.04e-01     1s
#   14   2.48086696e+03 -4.68518095e+03  2.65e+01 1.23e-04  4.77e-01     1s
#   15   1.86733843e+03 -6.43323466e+02  6.71e+00 2.78e-05  1.30e-01     1s
#   16   1.41973551e+03  5.89348085e+02  1.41e+00 5.45e-06  3.30e-02     2s
#   17   1.26311246e+03  7.33793818e+02  7.79e-01 8.17e-06  2.06e-02     2s
#   18   1.22459020e+03  8.70339074e+02  6.06e-01 2.80e-05  1.31e-02     2s
#   19   1.17222068e+03  9.56746985e+02  3.99e-01 2.73e-05  7.70e-03     2s
#   20   1.13680520e+03  1.02615001e+03  2.36e-01 1.54e-05  3.78e-03     2s
#   21   1.11105474e+03  1.05436173e+03  1.08e-01 8.04e-06  1.90e-03     2s
#   22   1.10128469e+03  1.07434280e+03  6.92e-02 1.08e-05  8.62e-04     2s
#   23   1.08837623e+03  1.08332844e+03  1.25e-02 1.40e-05  1.54e-04     2s
#   24   1.08665673e+03  1.08431310e+03  5.46e-03 6.60e-06  7.09e-05     2s
#   25   1.08616989e+03  1.08490912e+03  3.54e-03 4.60e-06  3.78e-05     2s
#   26   1.08554357e+03  1.08515264e+03  1.02e-03 3.32e-06  1.16e-05     2s
#   27   1.08548541e+03  1.08520076e+03  7.89e-04 2.17e-06  8.45e-06     2s
#   28   1.08540733e+03  1.08524057e+03  4.86e-04 1.76e-06  4.94e-06     2s
#   29   1.08535039e+03  1.08526362e+03  2.61e-04 2.27e-06  2.56e-06     2s
#   30   1.08531801e+03  1.08527686e+03  1.29e-04 1.21e-06  1.21e-06     2s
#   31   1.08529056e+03  1.08528456e+03  7.98e-06 6.30e-07  1.65e-07     2s
#   32   1.08528787e+03  1.08528717e+03  6.60e-07 9.91e-08  1.90e-08     2s
#   33   1.08528758e+03  1.08528756e+03  6.47e-09 4.28e-09  5.14e-10     3s
#   34   1.08528757e+03  1.08528757e+03  5.08e-10 9.54e-11  3.70e-12     3s
#
# Barrier solved model in 34 iterations and 2.62 seconds (2.08 work units)
# Optimal objective 1.08528757e+03
#
# Crossover log...
#
#     1472 DPushes remaining with DInf 0.0000000e+00                 3s
#        0 DPushes remaining with DInf 0.0000000e+00                 3s
#
#     1669 PPushes remaining with PInf 1.3231302e-05                 3s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.2690921e-11      3s
#
#
# Solved with barrier
# Extra simplex iterations after uncrush: 4
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3013    1.0852876e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 3013 iterations and 2.77 seconds (2.26 work units)
# Optimal objective  1.085287571e+03
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 2.770167827606201
# Error rc: 0
# Time: 3.2051384449005127
#
#
# Name: x1
# Lower bound: 1085.2875707722271
# Upper bound: 1085.2875707722271
# Number of objectives: 1
# Number of constraints: 33697
# Number of variables: 25502
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 25502
# Number of nonzeros: 99865
# Sense: minimize
#
# Solve time: 4.040435552597046 sec.
#
# Processing optimization output...
# for SourceSinkModel ...(2.1622sec)
# for ConversionModel ...(0.6629sec)
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# for StorageModel ...  (2.3365sec)
# 		(5.2182 sec)

# %% [markdown]
#  # 11. Selected results output

# %% [markdown]
#  ### Sources and Sink
#
#  Show optimization summary

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of SourceSinkModel for year {year}")
    print(esM.getOptimizationSummary("SourceSinkModel", outputLevel=2, ip=year))
# Out:
#  Results of SourceSinkModel for year 2020
#                                                                  GermanyRegion
# Component                 Property        Unit
# Copper demand             operation       [tons/a]                   61.682368
# Copper supply             operation       [tons/a]                   28.782368
# Electricity demand        operation       [GW$_{el}$*h/a]         30957.888055
#                                           [GW$_{el}$*h]           30957.888055
# Hydrogen demand           operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                           [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand              operation       [tons/a]                   61.682368
# Steel supply              operation       [tons/a]                   20.557368
# windoffshore              decommissioning [GW$_{el}$]                     15.0
# windoffshore_copper_scrap operation       [tons/a]                       53.55
# windoffshore_steel_scrap  operation       [tons/a]                       53.55
# windonshore               NPVcontribution [1e9 Euro]                 71.936602
#                           TAC             [1e9 Euro/a]               16.682395
#                           capacity        [GW$_{el}$]                19.897538
#                           capexCap        [1e9 Euro/a]               15.448747
#                           commissioning   [GW$_{el}$]                19.897538
#                           decommissioning [GW$_{el}$]                     10.0
#                           invest          [1e9 Euro]                 61.682368
#                           operation       [GW$_{el}$*h/a]         43477.601649
#                                           [GW$_{el}$*h]           43477.601649
#                           opexCap         [1e9 Euro/a]                1.233647
# windonshore_copper_scrap  operation       [tons/a]                        28.7
# windonshore_steel_scrap   operation       [tons/a]                        28.7
#
#  Results of SourceSinkModel for year 2025
#                                                                 GermanyRegion
# Component                Property        Unit
# Copper demand            operation       [tons/a]                   70.184109
# Copper supply            operation       [tons/a]                   50.445751
# Electricity demand       operation       [GW$_{el}$*h/a]         40245.254471
#                                          [GW$_{el}$*h]           40245.254471
# Hydrogen demand          operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                          [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand             operation       [tons/a]                   70.184109
# Steel supply             operation       [tons/a]                   45.511162
# windonshore              NPVcontribution [1e9 Euro]                 57.563783
#                          TAC             [1e9 Euro/a]                19.61447
#                          capacity        [GW$_{el}$]                23.394703
#                          capexCap        [1e9 Euro/a]               18.163999
#                          commissioning   [GW$_{el}$]                23.394703
#                          decommissioning [GW$_{el}$]                19.897538
#                          invest          [1e9 Euro]                 72.523579
#                          operation       [GW$_{el}$*h/a]         51369.360662
#                                          [GW$_{el}$*h]           51369.360662
#                          opexCap         [1e9 Euro/a]                1.450472
# windonshore_copper_scrap operation       [tons/a]                   49.345895
# windonshore_steel_scrap  operation       [tons/a]                   49.345895
#
#  Results of SourceSinkModel for year 2030
#                                                                 GermanyRegion
# Component                Property        Unit
# Copper demand            operation       [tons/a]                    76.03816
# Copper supply            operation       [tons/a]                   50.771881
# Electricity demand       operation       [GW$_{el}$*h/a]         49532.620887
#                                          [GW$_{el}$*h]           49532.620887
# Hydrogen demand          operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                          [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand             operation       [tons/a]                    76.03816
# Steel supply             operation       [tons/a]                   44.455311
# windonshore              NPVcontribution [1e9 Euro]                 43.908299
#                          TAC             [1e9 Euro/a]               21.983288
#                          capacity        [GW$_{el}$]                26.220055
#                          capexCap        [1e9 Euro/a]               20.357644
#                          commissioning   [GW$_{el}$]                26.220055
#                          decommissioning [GW$_{el}$]                23.394703
#                          invest          [1e9 Euro]                 81.282171
#                          operation       [GW$_{el}$*h/a]         60316.795898
#                                          [GW$_{el}$*h]           60316.795898
#                          opexCap         [1e9 Euro/a]                1.625643
# windonshore_copper_scrap operation       [tons/a]                   63.165698
# windonshore_steel_scrap  operation       [tons/a]                   63.165698

# %% [markdown]
#  ### Conversion
#
#  Show optimization summary

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of ConversionMpdel for year {year}")
    print(esM.getOptimizationSummary("ConversionModel", outputLevel=2, ip=year))
# Out:
#  Results of ConversionMpdel for year 2020
#                                                                   GermanyRegion
# Component         Property                        Unit
# Electroylzers     NPVcontribution                 [1e9 Euro]           2.230342
#                   TAC                             [1e9 Euro/a]         0.517226
#                   capacity                        [GW$_{el}$]          3.755407
#                   capexCap                        [1e9 Euro/a]         0.470283
#                   commissioning                   [GW$_{el}$]          3.755407
#                   invest                          [1e9 Euro]           1.877703
#                   operation                       [GW$_{el}$*h/a]   6807.249824
#                                                   [GW$_{el}$*h]     6807.249824
#                   opexCap                         [1e9 Euro/a]         0.046943
# Recycler Offshore NPVcontribution                 [1e9 Euro]           0.002156
#                   TAC                             [1e9 Euro/a]           0.0005
#                   capacity                        [GW$_{el}$]          0.006113
#                   capexCap                        [1e9 Euro/a]         0.000372
#                   commissioning                   [GW$_{el}$]          0.006113
#                   invest                          [1e9 Euro]           0.004279
#                   operation                       [GW$_{el}$*h/a]         53.55
#                                                   [GW$_{el}$*h]           53.55
#                   opexCap                         [1e9 Euro/a]         0.000128
#                   revenueLifetimeShorteningResale [1e9 Euro]           0.000389
# Recycler Onshore  NPVcontribution                 [1e9 Euro]           0.001156
#                   TAC                             [1e9 Euro/a]         0.000268
#                   capacity                        [GW$_{el}$]          0.003276
#                   capexCap                        [1e9 Euro/a]         0.000199
#                   commissioning                   [GW$_{el}$]          0.003276
#                   invest                          [1e9 Euro]           0.002293
#                   operation                       [GW$_{el}$*h/a]          28.7
#                                                   [GW$_{el}$*h]            28.7
#                   opexCap                         [1e9 Euro/a]         0.000069
#                   revenueLifetimeShorteningResale [1e9 Euro]           0.000208
#
#  Results of ConversionMpdel for year 2025
#                                                                   GermanyRegion
# Component         Property                        Unit
# Electroylzers     NPVcontribution                 [1e9 Euro]           1.512886
#                   TAC                             [1e9 Euro/a]         0.515506
#                   capacity                        [GW$_{el}$]           3.74292
#                   capexCap                        [1e9 Euro/a]         0.468719
#                   commissioning                   [GW$_{el}$]           3.74292
#                   decommissioning                 [GW$_{el}$]          3.755407
#                   invest                          [1e9 Euro]            1.87146
#                   operation                       [GW$_{el}$*h/a]   6807.249824
#                                                   [GW$_{el}$*h]     6807.249824
#                   opexCap                         [1e9 Euro/a]         0.046787
# Recycler Offshore NPVcontribution                 [1e9 Euro]           0.001467
#                   TAC                             [1e9 Euro/a]           0.0005
#                   capacity                        [GW$_{el}$]          0.006113
#                   capexCap                        [1e9 Euro/a]         0.000372
#                   opexCap                         [1e9 Euro/a]         0.000128
# Recycler Onshore  NPVcontribution                 [1e9 Euro]           0.001352
#                   TAC                             [1e9 Euro/a]         0.000461
#                   capacity                        [GW$_{el}$]          0.005633
#                   capexCap                        [1e9 Euro/a]         0.000342
#                   commissioning                   [GW$_{el}$]          0.002357
#                   invest                          [1e9 Euro]            0.00165
#                   operation                       [GW$_{el}$*h/a]     49.345895
#                                                   [GW$_{el}$*h]       49.345895
#                   opexCap                         [1e9 Euro/a]         0.000118
#                   revenueLifetimeShorteningResale [1e9 Euro]            0.00015
#
#  Results of ConversionMpdel for year 2030
#                                                                   GermanyRegion
# Component         Property                        Unit
# Electroylzers     NPVcontribution                 [1e9 Euro]           1.117033
#                   TAC                             [1e9 Euro/a]         0.559258
#                   capacity                        [GW$_{el}$]          4.060588
#                   capexCap                        [1e9 Euro/a]           0.5085
#                   commissioning                   [GW$_{el}$]          4.060588
#                   decommissioning                 [GW$_{el}$]           3.74292
#                   invest                          [1e9 Euro]           2.030294
#                   operation                       [GW$_{el}$*h/a]   6807.249824
#                                                   [GW$_{el}$*h]     6807.249824
#                   opexCap                         [1e9 Euro/a]         0.050757
# Recycler Offshore NPVcontribution                 [1e9 Euro]           0.000999
#                   TAC                             [1e9 Euro/a]           0.0005
#                   capacity                        [GW$_{el}$]          0.006113
#                   capexCap                        [1e9 Euro/a]         0.000372
#                   opexCap                         [1e9 Euro/a]         0.000128
# Recycler Onshore  NPVcontribution                 [1e9 Euro]           0.001178
#                   TAC                             [1e9 Euro/a]          0.00059
#                   capacity                        [GW$_{el}$]          0.007211
#                   capexCap                        [1e9 Euro/a]         0.000438
#                   commissioning                   [GW$_{el}$]          0.001578
#                   invest                          [1e9 Euro]           0.001104
#                   operation                       [GW$_{el}$*h/a]     63.165698
#                                                   [GW$_{el}$*h]       63.165698
#                   opexCap                         [1e9 Euro/a]         0.000151
#                   revenueLifetimeShorteningResale [1e9 Euro]             0.0001

# %% [markdown]
#  ### Storage
#
#  Show optimization summary

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of StorageModel for year {year}")
    print(esM.getOptimizationSummary("StorageModel", outputLevel=2, ip=year))
# Out:
#  Results of StorageModel for year 2020
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                 249.32389
#                         TAC                [1e9 Euro/a]               57.819239
#                         capacity           [GW$_{el}$*h]            2943.764032
#                         capexCap           [1e9 Euro/a]                51.93171
#                         commissioning      [GW$_{el}$*h]            2943.764032
#                         invest             [1e9 Euro]                444.508369
#                         operationCharge    [GW$_{el}$*h/a]         52268.452964
#                                            [GW$_{el}$*h]           52268.452964
#                         operationDischarge [GW$_{el}$*h/a]         46555.989194
#                                            [GW$_{el}$*h]           46555.989194
#                         opexCap            [1e9 Euro/a]                5.887528
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  3.088097
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         commissioning      [GW$_{H_{2},LHV}$*h]     1235.216115
#                         invest             [1e9 Euro]                  0.135874
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]  19678.574966
#                                            [GW$_{H_{2},LHV}$*h]    19678.574966
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]  19678.574966
#                                            [GW$_{H_{2},LHV}$*h]    19678.574966
#                         opexCap            [1e9 Euro/a]                0.704073
#
#  Results of StorageModel for year 2025
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                312.130551
#                         TAC                [1e9 Euro/a]              106.356376
#                         capacity           [GW$_{el}$*h]            5414.946329
#                         capexCap           [1e9 Euro/a]               95.526483
#                         commissioning      [GW$_{el}$*h]            2471.182297
#                         invest             [1e9 Euro]                373.148527
#                         operationCharge    [GW$_{el}$*h/a]         32480.452291
#                                            [GW$_{el}$*h]           32480.452291
#                         operationDischarge [GW$_{el}$*h/a]         28163.595924
#                                            [GW$_{el}$*h]           28163.595924
#                         opexCap            [1e9 Euro/a]               10.829893
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  2.101707
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]  19581.790385
#                                            [GW$_{H_{2},LHV}$*h]    19581.790385
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]  19581.790385
#                                            [GW$_{H_{2},LHV}$*h]    19581.790385
#                         opexCap            [1e9 Euro/a]                0.704073
#
#  Results of StorageModel for year 2030
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                338.935685
#                         TAC                [1e9 Euro/a]              169.692764
#                         capacity           [GW$_{el}$*h]            8639.606265
#                         capexCap           [1e9 Euro/a]              152.413552
#                         commissioning      [GW$_{el}$*h]            3224.659936
#                         invest             [1e9 Euro]                 486.92365
#                         operationCharge    [GW$_{el}$*h/a]         21766.900694
#                                            [GW$_{el}$*h]           21766.900694
#                         operationDischarge [GW$_{el}$*h/a]         17789.975507
#                                            [GW$_{el}$*h]           17789.975507
#                         opexCap            [1e9 Euro/a]               17.279213
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  1.430387
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   19346.79961
#                                            [GW$_{H_{2},LHV}$*h]     19346.79961
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   19346.79961
#                                            [GW$_{H_{2},LHV}$*h]     19346.79961
#                         opexCap            [1e9 Euro/a]                0.704073
