# %% [markdown]
#  # Workflow for a transformation pathway of a single node energy system with perfect foresight
#
#  In this application of the ETHOS.FINE framework, a transformation pathway of a energy system is modeled and optimized.
#
#  All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
#  The workflow is structures as follows:
#  1. Required packages are imported and the input data path is set
#  2. An energy system model instance is created
#  3. Commodity sources are added to the energy system model
#  4. Commodity conversion components are added to the energy system model
#  5. Commodity storages are added to the energy system model
#  6. Commodity sinks are added to the energy system model
#  7. Material sinks are added to the energy system model
#  8. Material sources are addeed to the energy system model
#  9. Material conversions are added to the energy system model for recycling processes
#  10. The energy system model is optimized
#  11. Selected optimization results are presented

# %% [markdown]
#  # 1. Import required packages and set input data path
#
#  The ETHOS.FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import fine as fn
from getData import getData
from pathlib import Path
import pandas as pd


cwd = Path.cwd()
data = getData()

# %% [markdown]
#  # 2. Create an energy system model instance
#
#  The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
#  The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {"GermanyRegion"}
commodityUnitsDict = {"electricity": r"GW$_{el}$", "hydrogen": r"GW$_{H_{2},LHV}$"}
commodities = {"electricity", "hydrogen"}
materials = {"steel", "copper"}
materialUnitsDict = {"steel": "tons/h", "copper": "tons/h"}

numberOfTimeSteps = 8760
hoursPerTimeStep = 1

# %% [markdown]
#  # 2.1 define Transformation Pathway parameters
#
#  Transformation Pathway Analyses can be run by setting a number of investment periods
#  larger than 1, which is the default value and results in a single year optimization.

# %%
numberOfInvestmentPeriods = 3
startYear = 2020
interval = 5

# %%
pathwayBalanceLimit = pd.DataFrame(
    columns=["GermanyRegion", "Total", "lowerBound"],
    index=["Copper_Resources", "Steel_Resources"],
)
pathwayBalanceLimit.loc["Copper_Resources"] = [None, 150, False]
pathwayBalanceLimit.loc["Steel_Resources"] = [None, 150, False]

# %%
initial_material_cost = {
    "steel": pd.Series(
        {
            "GermanyRegion": 0.1,
        }
    ),
    "copper": pd.Series(
        {
            "GermanyRegion": 0.1,
        }
    ),
}

# %%
esM = fn.EnergySystemModel(
    locations=locations,
    commodities=commodities,
    materials=materials,
    numberOfInvestmentPeriods=numberOfInvestmentPeriods,
    startYear=startYear,
    investmentPeriodInterval=interval,
    numberOfTimeSteps=8760,
    commodityUnitsDict=commodityUnitsDict,
    materialUnitsDict=materialUnitsDict,
    hoursPerTimeStep=1,
    costUnit="1e9 Euro",
    lengthUnit="km",
    verboseLogLevel=0,
    pathwayBalanceLimit=pathwayBalanceLimit,
    initialMaterialCost=initial_material_cost,
)

# %% [markdown]
#  # 3. Add commodity sources to the energy system model

# %% [markdown]
#  ## 3.1. Electricity sources

# %% [markdown]
#  ### Wind onshore

# %% [markdown]
#  change weather conditions for the different investment periods

# %%
operationRateMax = {}
operationRateMax[2020] = 1.2 * data["Wind (onshore), operationRateMax"]
operationRateMax[2025] = 0.7 * data["Wind (onshore), operationRateMax"]
operationRateMax[2030] = 1 * data["Wind (onshore), operationRateMax"]

# %% [markdown]
#  define existing stock for wind onshore turbines

# %%
stockWindonshoreCommissioning = {
    2015: 10,
}

stockWindoffshoreCommissioning = {
    2015: 15,
}

# %% [markdown]
#  define invest and opex per capacity for wind onshore turbines

# %%
investPerCapacityWind = {2015: 1.25, 2020: 1.1, 2025: 1, 2030: 0.95}

opexPerCapacityWind = {
    2015: 1.25 * 0.02,
    2020: 1.1 * 0.02,
    2025: 1 * 0.02,
    2030: 0.95 * 0.02,
}

# %% [markdown]
#  add wind onshore source to esM

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="windonshore",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=3.1,
        opexPerCapacity=3.1 * 0.02,
        interestRate=0.08,
        economicLifetime=5,
        stockCommissioning=stockWindonshoreCommissioning,
        materialIntensity={
            2015: {  # IP für 2015
                "steel": pd.Series({"GermanyRegion": 4.1}),
                "copper": pd.Series({"GermanyRegion": 0.041}),
            },
            2020: {  # IP für 2020
                "steel": pd.Series({"GermanyRegion": 3.1}),
                "copper": pd.Series({"GermanyRegion": 0.031}),
            },
            2025: {  # IP für 2025
                "steel": pd.Series({"GermanyRegion": 3.0}),
                "copper": pd.Series({"GermanyRegion": 0.03}),
            },
            2030: {  # IP für 2030
                "steel": pd.Series({"GermanyRegion": 2.9}),
                "copper": pd.Series({"GermanyRegion": 0.029}),
            },
        },
        materialCollection={
            2020: {  # IP für 2020
                "steel": pd.Series({"GermanyRegion": 0.7}),
                "copper": pd.Series({"GermanyRegion": 0.7}),
            },
            2025: {  # IP für 2025
                "steel": pd.Series({"GermanyRegion": 0.8}),
                "copper": pd.Series({"GermanyRegion": 0.8}),
            },
            2030: {  # IP für 2030
                "steel": pd.Series({"GermanyRegion": 0.9}),
                "copper": pd.Series({"GermanyRegion": 0.9}),
            },
        },
    )
)

# %%
# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windoffshore",
#         commodity="electricity",
#         hasCapacityVariable=True,
#         operationRateMax=data["Wind (onshore), operationRateMax"],
#         capacityMax=data["Wind (onshore), capacityMax"],
#         investPerCapacity=3.1,
#         opexPerCapacity=3.1 * 0.015,
#         interestRate=0.08,
#         economicLifetime=5,
#         stockCommissioning=stockWindoffshoreCommissioning,
#         materialIntensity={
#             2015: {  # IP für 2015
#                 "steel": pd.Series({"GermanyRegion": 5.1}, dtype="float64"),
#                 "copper": pd.Series({"GermanyRegion": 0.051}, dtype="float64"),
#             },
#             2020: {  # IP für 2020
#                 "steel": pd.Series({"GermanyRegion": 4.1}, dtype="float64"),
#                 "copper": pd.Series({"GermanyRegion": 0.041}, dtype="float64"),
#             },
#             2025: {  # IP für 2025
#                 "steel": pd.Series({"GermanyRegion": 4.0}, dtype="float64"),
#                 "copper": pd.Series({"GermanyRegion": 0.04}, dtype="float64"),
#             },
#             2030: {  # IP für 2030
#                 "steel": pd.Series({"GermanyRegion": 3.9}, dtype="float64"),
#                 "copper": pd.Series({"GermanyRegion": 0.039}, dtype="float64"),
#             },
#         },
#         materialCollection={
#             2020: {  # IP für 2020
#                 "steel": pd.Series({"GermanyRegion": 0.7}, dtype="float64"),
#                 "copper": pd.Series({"GermanyRegion": 0.7}, dtype="float64"),
#             },
#             2025: {  # IP für 2025
#                 "steel": pd.Series({"GermanyRegion": 0.8}, dtype="float64"),
#                 "copper": pd.Series({"GermanyRegion": 0.8}, dtype="float64"),
#             },
#             2030: {  # IP für 2030
#                 "steel": pd.Series({"GermanyRegion": 0.9}, dtype="float64"),
#                 "copper": pd.Series({"GermanyRegion": 0.9}, dtype="float64"),
#             },
#         },
#     )
# )

# %% [markdown]
#  Full load hours:

# %%
data["Wind (onshore), operationRateMax"].sum()
# Out:
# 2300.4069071646272

# %% [markdown]
#  # 4. Add conversion components to the energy system model

# %% [markdown]
#  ### Electrolyzers

# %% [markdown]
#  add component with constant invest and opex per capacity

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Electroylzers",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.7},
        hasCapacityVariable=True,
        investPerCapacity=0.5,
        opexPerCapacity=0.5 * 0.025,
        interestRate=0.08,
        economicLifetime=5,
    )
)

# %% [markdown]
#  # 5. Add commodity storages to the energy system model

# %% [markdown]
#  ## 5.1. Electricity storage

# %% [markdown]
#  ### Lithium ion batteries
#
#  The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Li-ion batteries",
        commodity="electricity",
        hasCapacityVariable=True,
        chargeEfficiency=0.95,
        cyclicLifetime=10000,
        dischargeEfficiency=0.95,
        selfDischarge=1 - (1 - 0.03) ** (1 / (30 * 24)),
        chargeRate=1,
        dischargeRate=1,
        doPreciseTsaModeling=False,
        investPerCapacity=0.151,
        opexPerCapacity=0.002,
        interestRate=0.08,
        economicLifetime=15,
    )
)

# %% [markdown]
#  ## 5.2. Hydrogen storage

# %% [markdown]
#  ### Hydrogen filled salt caverns
#  The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (hydrogen)",
        commodity="hydrogen",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=133,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (hydrogen), capacityMax"],
        investPerCapacity={2020: 0.00011, 2025: 0.00009, 2030: 0.00009},
        opexPerCapacity=0.00057,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
#  # 6. Add commodity sinks to the energy system model

# %% [markdown]
#  ## 6.1. Electricity sinks

# %% [markdown]
#  ### Electricity demand

# %% [markdown]
#  vary the demand with the years - increasing demand by 30% per year

# %%
electricityDemand = {}
electricityDemand[2020] = (1 + 0 * 0.3) * data["Electricity demand, operationRateFix"]
electricityDemand[2025] = (1 + 1 * 0.3) * data["Electricity demand, operationRateFix"]
electricityDemand[2030] = (1 + 2 * 0.3) * data["Electricity demand, operationRateFix"]

esM.add(
    fn.Sink(
        esM=esM,
        name="Electricity demand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=electricityDemand,
    )
)

# %% [markdown]
#  ## 6.2. Hydrogen sinks

# %% [markdown]
#  ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration = 0.5

# vary the demand with the years - increasing demand by 25% per year
hydrogendDemand = {}
hydrogendDemand[2020] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)
hydrogendDemand[2025] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)
hydrogendDemand[2030] = (
    (1 + 0 * 0.25) * data["Hydrogen demand, operationRateFix"] * FCEV_penetration
)


esM.add(
    fn.Sink(
        esM=esM,
        name="Hydrogen demand",
        commodity="hydrogen",
        hasCapacityVariable=False,
        operationRateFix=hydrogendDemand,
    )
)

# %% [markdown]
# # 7. Add material sinks to the energy system model

# %%
esM.generationMaterialSinks()
# Out:
# Existing material sinks: set()
# Missing materials sinks: {'copper', 'steel'}
# New sink added: Copper demand
# New sink added: Steel demand

# %%
# sink = esM.add(
#     fn.Sink(
#         esM=esM,
#         name="Steel demand",
#         hasCapacityVariable=False,
#         commodity="steel",
#         material=True,
#     )
# )

# sink = esM.add(
#     fn.Sink(
#         esM=esM,
#         name="Copper demand",
#         hasCapacityVariable=False,
#         commodity="copper",
#         material=True,
#     )
# )

# %% [markdown]
# # 8. Add material sources to the energy system model

# %% [markdown]
# ## 8.1 Add primary material sources with pathway balance limit

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Steel supply",
        hasCapacityVariable=False,
        commodity="steel",
        pathwayBalanceLimitID="Steel_Resources",
    )
)

esM.add(
    fn.Source(
        esM=esM,
        name="Copper supply",
        hasCapacityVariable=False,
        commodity="copper",
        pathwayBalanceLimitID="Copper_Resources",
    )
)

# %%
esM.generationSecondaryMaterialSources()
# Out:
# Scrap commodities : {'windonshore_steel_scrap', 'windonshore_copper_scrap'}
# Existing secondary material sources: set()
# Missing secondary material sources: {'windonshore_steel_scrap', 'windonshore_copper_scrap'}
# New scrap source added: windonshore_steel_scrap
# New scrap source added: windonshore_copper_scrap
# Existing secondary material sinks: set()
# Missing secondary material sinks: {'windonshore_steel_scrap', 'windonshore_copper_scrap'}
# New scrap sink added: windonshore_steel_scrap_rec
# New scrap sink added: windonshore_copper_scrap_rec

# %%
# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windonshore_steel_scrap",
#         commodity="windonshore_steel_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windoffshore_steel_scrap",
#         commodity="windoffshore_steel_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windonshore_copper_scrap",
#         commodity="windonshore_copper_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# esM.add(
#     fn.Source(
#         esM=esM,
#         name="windoffshore_copper_scrap",
#         commodity="windoffshore_copper_scrap",
#         hasCapacityVariable=False,
#         material=True,
#     )
# )

# %% [markdown]
# # 9. Add recycling plants

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Recycler Onshore",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={
            "windonshore_steel_scrap": -0.5,
            "steel": 0.45,
            "windonshore_copper_scrap": -0.07,
            "copper": 0.063,
        },
        hasCapacityVariable=True,
        investPerCapacity=0.7 * 8760,
        opexPerOperation=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

# esM.add(
#     fn.Conversion(
#         esM=esM,
#         name="Recycler Offshore",
#         physicalUnit=r"GW$_{el}$",
#         commodityConversionFactors={
#             "windoffshore_steel_scrap": -1,
#             "steel": 0.5,
#             "windoffshore_copper_scrap": -1,
#             "copper": 0.4,
#         },
#         hasCapacityVariable=True,
#         investPerCapacity=0.7,
#         opexPerCapacity=0.021,
#         interestRate=0.08,
#         economicLifetime=33,
#     )
# )

# %% [markdown]
#  # 10. Optimize energy system model

# %% [markdown]
#  All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
esM.aggregateTemporally(numberOfTypicalPeriods=30)
# Out:
# Clustering time series data with 30 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(9.3581 sec)

# %%
esM.optimize(timeSeriesAggregation=True, solver="gurobi")
# Out:
# Time series aggregation specifications:
# Number of typical periods:30, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.6206 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.1164 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.1691 sec)
#
# 		(0.0001 sec)
#
# Declaring shared potential constraint...
# 		(0.0003 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.2279 sec)
#
# Declaring material demand constraints...
# RHS_demand 0.031*commis_srcSnk[GermanyRegion,windonshore,0]
# RHS_demand 0.03*commis_srcSnk[GermanyRegion,windonshore,1]
# LHS_demand 115*op_srcSnk[GermanyRegion,Copper demand,0,0,0] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,1] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,2] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,3] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,4] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,5] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,6] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,7] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,8] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,9] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,10] + 115*op_srcSnk[GermanyRegion,Copper demand,0,0,11] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,0] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,1] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,2] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,3] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,4] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,5] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,6] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,7] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,8] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,9] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,10] + 75*op_srcSnk[GermanyRegion,Copper demand,0,1,11] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,0] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,1] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,2] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,3] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,4] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,5] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,6] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,7] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,8] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,9] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,10] + 275*op_srcSnk[GermanyRegion,Copper demand,0,2,11] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,0] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,1] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,2] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,3] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,4] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,5] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,6] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,7] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,8] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,9] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,10] + 40*op_srcSnk[GermanyRegion,Copper demand,0,3,11] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,0] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,1] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,2] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,3] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,4] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,5] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,6] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,7] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,8] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,9] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,10] + 40*op_srcSnk[GermanyRegion,Copper demand,0,4,11] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,0] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,1] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,2] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,3] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,4] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,5] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,6] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,7] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,8] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,9] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,10] + 50*op_srcSnk[GermanyRegion,Copper demand,0,5,11] + 20*op_srcSnk[GermanyRegion,Copper demand,0,6,0] + 20*op_srcSnk[GermanyRegion,Copper demand,0,6,1] + 20*op_srcSnk[GermanyRegion,Copper demand,0,6,2] + 20*op_srcSnk[GermanyRegion,Copper demand,0,6,3] + 20*op_srcSnk[GermanyRegion,Copper demand,0,6,4] + 20*op_srcSnk[GermanyRegion,Copper demand,0,6,5] + 20*op_srcSnk[GermanyRegion,Copper demand,0,6,6] + 20* ...
# RHS_demand 0.029*commis_srcSnk[GermanyRegion,windonshore,2]
# LHS_demand 115*op_srcSnk[GermanyRegion,Copper demand,1,0,0] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,1] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,2] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,3] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,4] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,5] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,6] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,7] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,8] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,9] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,10] + 115*op_srcSnk[GermanyRegion,Copper demand,1,0,11] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,0] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,1] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,2] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,3] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,4] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,5] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,6] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,7] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,8] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,9] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,10] + 75*op_srcSnk[GermanyRegion,Copper demand,1,1,11] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,0] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,1] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,2] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,3] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,4] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,5] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,6] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,7] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,8] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,9] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,10] + 275*op_srcSnk[GermanyRegion,Copper demand,1,2,11] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,0] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,1] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,2] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,3] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,4] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,5] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,6] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,7] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,8] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,9] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,10] + 40*op_srcSnk[GermanyRegion,Copper demand,1,3,11] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,0] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,1] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,2] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,3] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,4] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,5] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,6] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,7] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,8] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,9] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,10] + 40*op_srcSnk[GermanyRegion,Copper demand,1,4,11] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,0] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,1] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,2] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,3] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,4] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,5] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,6] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,7] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,8] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,9] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,10] + 50*op_srcSnk[GermanyRegion,Copper demand,1,5,11] + 20*op_srcSnk[GermanyRegion,Copper demand,1,6,0] + 20*op_srcSnk[GermanyRegion,Copper demand,1,6,1] + 20*op_srcSnk[GermanyRegion,Copper demand,1,6,2] + 20*op_srcSnk[GermanyRegion,Copper demand,1,6,3] + 20*op_srcSnk[GermanyRegion,Copper demand,1,6,4] + 20*op_srcSnk[GermanyRegion,Copper demand,1,6,5] + 20*op_srcSnk[GermanyRegion,Copper demand,1,6,6] + 20* ...
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,windonshore,0]
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,windonshore,1]
# LHS_demand 115*op_srcSnk[GermanyRegion,Steel demand,0,0,0] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,1] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,2] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,3] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,4] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,5] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,6] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,7] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,8] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,9] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,10] + 115*op_srcSnk[GermanyRegion,Steel demand,0,0,11] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,0] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,1] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,2] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,3] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,4] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,5] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,6] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,7] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,8] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,9] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,10] + 75*op_srcSnk[GermanyRegion,Steel demand,0,1,11] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,0] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,1] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,2] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,3] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,4] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,5] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,6] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,7] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,8] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,9] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,10] + 275*op_srcSnk[GermanyRegion,Steel demand,0,2,11] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,0] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,1] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,2] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,3] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,4] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,5] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,6] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,7] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,8] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,9] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,10] + 40*op_srcSnk[GermanyRegion,Steel demand,0,3,11] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,0] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,1] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,2] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,3] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,4] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,5] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,6] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,7] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,8] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,9] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,10] + 40*op_srcSnk[GermanyRegion,Steel demand,0,4,11] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,0] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,1] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,2] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,3] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,4] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,5] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,6] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,7] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,8] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,9] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,10] + 50*op_srcSnk[GermanyRegion,Steel demand,0,5,11] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,0] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,1] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,2] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,3] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,4] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,5] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,6] + 20*op_srcSnk[GermanyRegion,Steel demand,0,6,7] + 20*op_srcSnk[GermanyRegion,Steel  ...
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,windonshore,2]
# LHS_demand 115*op_srcSnk[GermanyRegion,Steel demand,1,0,0] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,1] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,2] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,3] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,4] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,5] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,6] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,7] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,8] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,9] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,10] + 115*op_srcSnk[GermanyRegion,Steel demand,1,0,11] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,0] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,1] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,2] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,3] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,4] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,5] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,6] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,7] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,8] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,9] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,10] + 75*op_srcSnk[GermanyRegion,Steel demand,1,1,11] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,0] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,1] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,2] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,3] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,4] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,5] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,6] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,7] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,8] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,9] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,10] + 275*op_srcSnk[GermanyRegion,Steel demand,1,2,11] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,0] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,1] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,2] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,3] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,4] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,5] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,6] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,7] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,8] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,9] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,10] + 40*op_srcSnk[GermanyRegion,Steel demand,1,3,11] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,0] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,1] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,2] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,3] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,4] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,5] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,6] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,7] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,8] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,9] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,10] + 40*op_srcSnk[GermanyRegion,Steel demand,1,4,11] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,0] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,1] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,2] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,3] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,4] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,5] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,6] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,7] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,8] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,9] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,10] + 50*op_srcSnk[GermanyRegion,Steel demand,1,5,11] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,0] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,1] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,2] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,3] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,4] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,5] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,6] + 20*op_srcSnk[GermanyRegion,Steel demand,1,6,7] + 20*op_srcSnk[GermanyRegion,Steel  ...
# 		(0.0129 sec)
#
# Declaring material recovery constraints...
# LHS_recovery 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,0] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,1] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,2] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,3] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,4] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,5] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,6] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,7] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,8] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,9] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,10] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,0,11] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,0] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,1] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,2] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,3] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,4] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,5] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,6] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,7] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,8] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,9] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,10] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,1,11] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,0] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,1] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,2] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,3] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,4] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,5] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,6] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,7] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,8] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,9] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,10] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,2,11] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,0] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,1] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,2] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,3] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,4] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,5] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,6] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,7] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,8] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,9] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,10] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,3,11] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,0] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,1] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,2] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,3] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,4] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,5] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,6] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,7] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,8] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,9] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,10] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0,5,4] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,0, ...
# RHS_recovery 2.8699999999999997*decommis_srcSnk[GermanyRegion,windonshore,0]
# Constraint: windonshore_steel_scrap mat: steel
# LHS_recovery 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,0] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,1] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,2] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,3] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,4] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,5] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,6] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,7] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,8] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,9] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,10] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,0,11] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,0] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,1] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,2] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,3] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,4] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,5] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,6] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,7] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,8] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,9] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,10] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,1,11] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,0] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,1] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,2] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,3] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,4] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,5] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,6] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,7] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,8] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,9] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,10] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,2,11] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,0] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,1] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,2] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,3] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,4] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,5] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,6] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,7] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,8] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,9] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,10] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,3,11] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,0] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,1] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,2] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,3] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,4] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,5] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,6] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,7] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,8] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,9] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,10] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1,5,4] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,1, ...
# RHS_recovery 2.4800000000000004*decommis_srcSnk[GermanyRegion,windonshore,1]
# Constraint: windonshore_steel_scrap mat: steel
# LHS_recovery 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,0] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,1] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,2] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,3] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,4] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,5] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,6] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,7] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,8] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,9] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,10] + 115*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,0,11] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,0] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,1] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,2] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,3] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,4] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,5] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,6] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,7] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,8] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,9] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,10] + 75*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,1,11] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,0] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,1] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,2] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,3] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,4] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,5] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,6] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,7] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,8] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,9] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,10] + 275*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,2,11] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,0] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,1] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,2] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,3] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,4] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,5] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,6] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,7] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,8] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,9] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,10] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,3,11] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,0] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,1] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,2] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,3] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,4] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,5] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,6] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,7] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,8] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,9] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,10] + 40*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2,5,4] + 50*op_srcSnk[GermanyRegion,windonshore_steel_scrap,2, ...
# RHS_recovery 2.7*decommis_srcSnk[GermanyRegion,windonshore,2]
# Constraint: windonshore_steel_scrap mat: steel
# LHS_recovery 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,0] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,1] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,2] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,3] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,4] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,5] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,6] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,7] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,8] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,9] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,10] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,0,11] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,0] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,1] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,2] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,3] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,4] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,5] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,6] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,7] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,8] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,9] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,10] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,1,11] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,0] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,1] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,2] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,3] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,4] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,5] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,6] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,7] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,8] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,9] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,10] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,2,11] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,0] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,1] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,2] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,3] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,4] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,5] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,6] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,7] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,8] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,9] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,10] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,3,11] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,0] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,1] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,2] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,3] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,4] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,5] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,6] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,7] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,8] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,9] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,10] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,0,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scr ...
# RHS_recovery 0.0287*decommis_srcSnk[GermanyRegion,windonshore,0]
# Constraint: windonshore_copper_scrap mat: copper
# LHS_recovery 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,0] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,1] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,2] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,3] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,4] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,5] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,6] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,7] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,8] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,9] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,10] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,0,11] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,0] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,1] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,2] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,3] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,4] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,5] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,6] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,7] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,8] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,9] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,10] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,1,11] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,0] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,1] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,2] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,3] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,4] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,5] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,6] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,7] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,8] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,9] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,10] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,2,11] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,0] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,1] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,2] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,3] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,4] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,5] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,6] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,7] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,8] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,9] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,10] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,3,11] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,0] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,1] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,2] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,3] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,4] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,5] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,6] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,7] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,8] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,9] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,10] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,1,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scr ...
# RHS_recovery 0.024800000000000003*decommis_srcSnk[GermanyRegion,windonshore,1]
# Constraint: windonshore_copper_scrap mat: copper
# LHS_recovery 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,0] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,1] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,2] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,3] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,4] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,5] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,6] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,7] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,8] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,9] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,10] + 115*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,0,11] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,0] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,1] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,2] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,3] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,4] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,5] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,6] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,7] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,8] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,9] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,10] + 75*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,1,11] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,0] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,1] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,2] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,3] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,4] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,5] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,6] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,7] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,8] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,9] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,10] + 275*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,2,11] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,0] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,1] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,2] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,3] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,4] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,5] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,6] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,7] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,8] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,9] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,10] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,3,11] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,0] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,1] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,2] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,3] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,4] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,5] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,6] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,7] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,8] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,9] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,10] + 40*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,4,11] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,0] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,1] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,2] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scrap,2,5,3] + 50*op_srcSnk[GermanyRegion,windonshore_copper_scr ...
# RHS_recovery 0.027*decommis_srcSnk[GermanyRegion,windonshore,2]
# Constraint: windonshore_copper_scrap mat: copper
# 		(0.0185 sec)
#
# 		(0.0043 sec)
#
# Declaring objective function...
# Initial material costs: 0.1*initialMaterialSupply[GermanyRegion,steel] + 0.1*initialMaterialSupply[GermanyRegion,copper]
# 		(1.3866 sec)
#
# Set parameter Threads to value 3
# Set parameter LogFile to value ""
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 13.0.2 build v13.0.2rc1 (linux64 - "Rocky Linux 9.5 (Blue Onyx)")
#
# CPU model: Intel(R) Xeon(R) Gold 6144 CPU @ 3.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 16 physical cores, 32 logical processors, using up to 3 threads
#
# Non-default parameters:
# TSPort  41955
# QCPDual  1
# Threads  3
#
# Optimize a model with 29352 rows, 23319 columns and 85052 nonzeros (Min)
# Model fingerprint: 0x3230f42d
# Model has 1097 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [7e-04, 7e+02]
#   Objective range  [1e-03, 5e+03]
#   Bounds range     [5e-02, 1e+03]
#   RHS range        [1e+00, 2e+02]
#
# Presolve removed 11391 rows and 15061 columns
# Presolve time: 0.12s
# Presolved: 17961 rows, 8258 columns, 74684 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.28s
#
# Barrier statistics:
#  Dense cols : 65
#  Free vars  : 78
#  AA' NZ     : 3.394e+05
#  Factor NZ  : 2.443e+06 (roughly 30 MB of memory)
#  Factor Ops : 1.043e+09 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.60709234e+06 -7.15376841e+06  9.96e+04 1.36e+02  5.13e+04     1s
#    1   2.38180938e+06 -7.06525596e+06  7.36e+04 1.25e+02  3.73e+04     1s
#    2   2.27666099e+06 -1.16321546e+07  6.26e+04 6.73e+01  2.75e+04     1s
#    3   1.69231777e+06 -1.28178091e+07  1.62e+04 5.24e+01  1.12e+04     1s
#    4   1.27454744e+06 -9.94488243e+06  2.35e+03 7.15e+00  1.88e+03     1s
#    5   8.34365703e+05 -6.45552924e+06  1.10e+03 3.54e+00  9.41e+02     1s
#    6   8.06722099e+05 -4.49885170e+06  1.05e+03 2.15e+00  6.58e+02     1s
#    7   5.86715742e+05 -3.19082477e+06  7.01e+02 1.19e+00  3.99e+02     1s
#    8   5.19881397e+05 -1.67626646e+06  6.22e+02 5.46e-01  2.42e+02     1s
#    9   4.06469393e+05 -1.08694365e+06  4.76e+02 3.56e-01  1.70e+02     1s
#   10   3.08977248e+05 -7.84970567e+05  3.57e+02 2.74e-01  1.30e+02     1s
#   11   2.63908477e+05 -4.54000913e+05  3.03e+02 2.04e-01  1.02e+02     1s
#   12   1.95962928e+05 -1.60797366e+05  2.24e+02 1.47e-01  7.46e+01     1s
#   13   1.43078798e+05 -2.26760959e+04  1.67e+02 1.02e-01  5.36e+01     1s
#   14   9.94954665e+04  2.60040296e+04  1.22e+02 7.58e-02  3.99e+01     1s
#   15   7.13042083e+04  5.48393755e+04  8.74e+01 6.43e-02  3.23e+01     1s
#   16   6.19258396e+04  8.94868086e+04  7.66e+01 5.89e-02  2.97e+01     1s
#   17   5.75427358e+04  1.18521698e+05  7.09e+01 5.03e-02  2.59e+01     1s
#   18   5.47753341e+04  1.32544908e+05  6.74e+01 4.74e-02  2.44e+01     1s
#   19   4.88208224e+04  1.95678118e+05  5.99e+01 4.29e-02  2.22e+01     2s
#   20   4.58873874e+04  2.46138947e+05  5.62e+01 4.08e-02  2.11e+01     2s
#   21   4.01047278e+04  2.94826418e+05  4.96e+01 3.79e-02  1.91e+01     2s
#   22   3.71512981e+04  3.00790729e+05  4.67e+01 3.57e-02  1.81e+01     2s
#   23   3.22616413e+04  2.87036082e+05  4.20e+01 3.27e-02  1.68e+01     2s
#   24   2.79664437e+04  2.08065523e+05  3.66e+01 2.39e-02  1.33e+01     2s
#   25   2.51593444e+04  1.89931743e+05  3.29e+01 2.21e-02  1.24e+01     2s
#   26   2.27933320e+04  1.84601752e+05  2.96e+01 2.04e-02  1.14e+01     2s
#   27   1.78925942e+04  1.58775935e+05  2.29e+01 1.58e-02  8.93e+00     2s
#   28   1.43067578e+04  9.18138304e+04  1.86e+01 8.92e-03  5.42e+00     2s
#   29   9.97747097e+03  7.39056527e+04  1.23e+01 6.91e-03  4.21e+00     2s
#   30   5.01083229e+03  1.86522751e+04  5.24e+00 1.89e-03  1.34e+00     2s
#   31   1.10209905e+03  7.74703211e+03  3.71e-02 7.92e-04  5.00e-01     2s
#   32   9.31478880e+02  2.16539945e+03  6.46e-05 1.89e-04  1.31e-01     2s
#   33   8.65519316e+02  1.94716466e+03  3.35e-05 1.74e-04  1.20e-01     2s
#
# Barrier performed 33 iterations in 2.27 seconds (1.60 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    15581    7.1347657e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 15581 iterations and 2.29 seconds (3.04 work units)
# Optimal objective  7.134765685e+02
#
# Name: Gurobi 13.02
# Status: ok
# Wallclock time: 2.2884650230407715
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#
#
# Name: unknown
# Lower bound: 713.4765684614163
# Upper bound: 713.4765684614163
# Number of objectives: 1
# Number of constraints: 29352
# Number of variables: 23319
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 23319
# Number of nonzeros: 85052
# Sense: minimize
# Number of solutions: 1
#
# Solve time: 4.004242420196533 sec.
#
# Processing optimization output...
# for SourceSinkModel ...(1.7631sec)
# for ConversionModel ...(0.5221sec)
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2036: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# for StorageModel ...  (2.1726sec)
# 		(4.5069 sec)

# %% [markdown]
#  # 11. Selected results output

# %% [markdown]
#  ### Sources and Sink
#
#  Show optimization summary

# %%
total_cost = 0.0

for loc, mat in esM.pyM.initialMaterialSet:
    quantity = esM.pyM.initialMaterialSupply[loc, mat].value
    unit_cost = esM.initialMaterialCost[mat][loc]
    material_cost = quantity * unit_cost

    print(f"{mat}:")
    print(f"  Initial supply [tons]: {quantity:.6f}")
    print(f"  Unit cost: {unit_cost:.8f} [USD/tons]")
    print(f"  Cost contribution : {material_cost:.6f} [USD]")

    total_cost += material_cost

print(f"\nTotal cost initial supply: {total_cost:.6f} [USD]")
# Out:
# steel:
#   Initial supply [tons]: 102.168297
#   Unit cost: 0.10000000 [USD/tons]
#   Cost contribution : 10.216830 [USD]
# copper:
#   Initial supply [tons]: 1.021683
#   Unit cost: 0.10000000 [USD/tons]
#   Cost contribution : 0.102168 [USD]
#
# Total cost initial supply: 10.318998 [USD]

# %%
import pyomo.environ as pyomo

initial_cost = sum(
    esM.pyM.initialMaterialSupply[loc, mat] * esM.initialMaterialCost[mat][loc]
    for loc, mat in esM.pyM.initialMaterialSet
)

print("Initial material cost:", pyomo.value(initial_cost))
print("Total Objective:", pyomo.value(esM.pyM.Obj))
# Out:
# Initial material cost: 10.318997965991459
# Total Objective: 713.4765684614122

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of SourceSinkModel for year {year}")
    print(esM.getOptimizationSummary("SourceSinkModel", outputLevel=2, ip=year))
# Out:
#  Results of SourceSinkModel for year 2020
#                                                                    GermanyRegion
# Component                   Property        Unit
# Copper demand               operation       [tons/h*h/a]                0.151483
#                                             [tons/h*h]                  0.151483
# Copper supply               operation       [tons/h*h/a]                0.099823
#                                             [tons/h*h]                  0.099823
# Electricity demand          operation       [GW$_{el}$*h/a]         30957.888055
#                                             [GW$_{el}$*h]           30957.888055
# Hydrogen demand             operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                             [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand                operation       [tons/h*h/a]               15.148341
#                                             [tons/h*h]                 15.148341
# Steel supply                operation       [tons/h*h/a]               14.779341
#                                             [tons/h*h]                 14.779341
# windonshore                 NPVcontribution [1e9 Euro]                119.153014
#                             TAC             [1e9 Euro/a]               27.632075
#                             capacity        [GW$_{el}$]                32.957515
#                             capexCap        [1e9 Euro/a]               25.588709
#                             commissioning   [GW$_{el}$]                32.957515
#                             decommissioning [GW$_{el}$]                     10.0
#                             invest          [1e9 Euro]                102.168297
#                             operation       [GW$_{el}$*h/a]         39828.330705
#                                             [GW$_{el}$*h]           39828.330705
#                             opexCap         [1e9 Euro/a]                2.043366
# windonshore_copper_scrap    operation       [tons/h*h/a]                  0.0574
#                                             [tons/h*h]                    0.0574
# windonshore_steel_scrap     operation       [tons/h*h/a]                    5.74
#                                             [tons/h*h]                      5.74
# windonshore_steel_scrap_rec operation       [tons/h*h/a]                    5.33
#                                             [tons/h*h]                      5.33
#
#  Results of SourceSinkModel for year 2025
#                                                                    GermanyRegion
# Component                   Property        Unit
# Copper demand               operation       [tons/h*h/a]                0.162715
#                                             [tons/h*h]                  0.162715
# Copper supply               operation       [tons/h*h/a]                0.015593
#                                             [tons/h*h]                  0.015593
# Electricity demand          operation       [GW$_{el}$*h/a]         40245.254471
#                                             [GW$_{el}$*h]           40245.254471
# Hydrogen demand             operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                             [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand                operation       [tons/h*h/a]               16.271533
#                                             [tons/h*h]                 16.271533
# Steel supply                operation       [tons/h*h/a]               15.220659
#                                             [tons/h*h]                 15.220659
# windonshore                 NPVcontribution [1e9 Euro]                 62.122025
#                             TAC             [1e9 Euro/a]                21.16766
#                             capacity        [GW$_{el}$]                25.247234
#                             capexCap        [1e9 Euro/a]               19.602332
#                             commissioning   [GW$_{el}$]                25.247234
#                             decommissioning [GW$_{el}$]                32.957515
#                             invest          [1e9 Euro]                 78.266426
#                             operation       [GW$_{el}$*h/a]         50870.602925
#                                             [GW$_{el}$*h]           50870.602925
#                             opexCap         [1e9 Euro/a]                1.565329
# windonshore_copper_scrap    operation       [tons/h*h/a]                0.163469
#                                             [tons/h*h]                  0.163469
# windonshore_steel_scrap     operation       [tons/h*h/a]               16.346927
#                                             [tons/h*h]                 16.346927
# windonshore_steel_scrap_rec operation       [tons/h*h/a]                15.17929
#                                             [tons/h*h]                  15.17929
#
#  Results of SourceSinkModel for year 2030
#                                                                     GermanyRegion
# Component                    Property        Unit
# Electricity demand           operation       [GW$_{el}$*h/a]         49532.620887
#                                              [GW$_{el}$*h]           49532.620887
# Hydrogen demand              operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                              [GW$_{H_{2},LHV}$*h]     4765.074877
# windonshore                  NPVcontribution [1e9 Euro]                 46.980053
#                              TAC             [1e9 Euro/a]               23.521203
#                              capacity        [GW$_{el}$]                28.054368
#                              capexCap        [1e9 Euro/a]               21.781832
#                              commissioning   [GW$_{el}$]                28.054368
#                              decommissioning [GW$_{el}$]                25.247234
#                              invest          [1e9 Euro]                  86.96854
#                              operation       [GW$_{el}$*h/a]         60887.400622
#                                              [GW$_{el}$*h]           60887.400622
#                              opexCap         [1e9 Euro/a]                1.739371
# windonshore_copper_scrap     operation       [tons/h*h/a]                0.136335
#                                              [tons/h*h]                  0.136335
# windonshore_copper_scrap_rec operation       [tons/h*h/a]                0.136335
#                                              [tons/h*h]                  0.136335
# windonshore_steel_scrap      operation       [tons/h*h/a]               13.633507
#                                              [tons/h*h]                 13.633507
# windonshore_steel_scrap_rec  operation       [tons/h*h/a]               13.633507
#                                              [tons/h*h]                 13.633507

# %% [markdown]
#  ### Conversion
#
#  Show optimization summary

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of ConversionMpdel for year {year}")
    print(esM.getOptimizationSummary("ConversionModel", outputLevel=2, ip=year))
# Out:
#  Results of ConversionMpdel for year 2020
#                                                                  GermanyRegion
# Component        Property                        Unit
# Electroylzers    NPVcontribution                 [1e9 Euro]           1.400358
#                  TAC                             [1e9 Euro/a]         0.324749
#                  capacity                        [GW$_{el}$]          2.357895
#                  capexCap                        [1e9 Euro/a]         0.295275
#                  commissioning                   [GW$_{el}$]          2.357895
#                  invest                          [1e9 Euro]           1.178948
#                  operation                       [GW$_{el}$*h/a]   6807.249824
#                                                  [GW$_{el}$*h]     6807.249824
#                  opexCap                         [1e9 Euro/a]         0.029474
# Recycler Onshore NPVcontribution                 [1e9 Euro]           0.289227
#                  TAC                             [1e9 Euro/a]         0.067073
#                  capacity                        [GW$_{el}$]          0.000094
#                  capexCap                        [1e9 Euro/a]         0.049853
#                  commissioning                   [GW$_{el}$]          0.000094
#                  invest                          [1e9 Euro]              0.574
#                  operation                       [GW$_{el}$*h/a]          0.82
#                                                  [GW$_{el}$*h]            0.82
#                  opexOp                          [1e9 Euro/a]          0.01722
#                  revenueLifetimeShorteningResale [1e9 Euro]           0.052182
#
#  Results of ConversionMpdel for year 2025
#                                                                  GermanyRegion
# Component        Property                        Unit
# Electroylzers    NPVcontribution                 [1e9 Euro]            1.28372
#                  TAC                             [1e9 Euro/a]         0.437419
#                  capacity                        [GW$_{el}$]          3.175957
#                  capexCap                        [1e9 Euro/a]         0.397719
#                  commissioning                   [GW$_{el}$]          3.175957
#                  decommissioning                 [GW$_{el}$]          2.357895
#                  invest                          [1e9 Euro]           1.587978
#                  operation                       [GW$_{el}$*h/a]   6807.249824
#                                                  [GW$_{el}$*h]     6807.249824
#                  opexCap                         [1e9 Euro/a]         0.039699
# Recycler Onshore NPVcontribution                 [1e9 Euro]           0.560588
#                  TAC                             [1e9 Euro/a]         0.191017
#                  capacity                        [GW$_{el}$]          0.000267
#                  capexCap                        [1e9 Euro/a]         0.141976
#                  commissioning                   [GW$_{el}$]          0.000173
#                  invest                          [1e9 Euro]           1.060693
#                  operation                       [GW$_{el}$*h/a]      2.335275
#                                                  [GW$_{el}$*h]        2.335275
#                  opexOp                          [1e9 Euro/a]         0.049041
#                  revenueLifetimeShorteningResale [1e9 Euro]           0.096427
#
#  Results of ConversionMpdel for year 2030
#                                                  GermanyRegion
# Component        Property        Unit
# Electroylzers    NPVcontribution [1e9 Euro]           1.006654
#                  TAC             [1e9 Euro/a]         0.503995
#                  capacity        [GW$_{el}$]          3.659345
#                  capexCap        [1e9 Euro/a]         0.458253
#                  commissioning   [GW$_{el}$]          3.659345
#                  decommissioning [GW$_{el}$]          3.175957
#                  invest          [1e9 Euro]           1.829673
#                  operation       [GW$_{el}$*h/a]   6807.249824
#                                  [GW$_{el}$*h]     6807.249824
#                  opexCap         [1e9 Euro/a]         0.045742
# Recycler Onshore NPVcontribution [1e9 Euro]           0.283575
#                  TAC             [1e9 Euro/a]         0.141976
#                  capacity        [GW$_{el}$]          0.000267
#                  capexCap        [1e9 Euro/a]         0.141976

# %% [markdown]
#  ### Storage
#
#  Show optimization summary

# %%
for year in [2020, 2025, 2030]:
    print(f"\n Results of StorageModel for year {year}")
    print(esM.getOptimizationSummary("StorageModel", outputLevel=2, ip=year))
# Out:
#  Results of StorageModel for year 2020
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                 34.032188
#                         TAC                [1e9 Euro/a]                7.892205
#                         capacity           [GW$_{el}$*h]             401.817619
#                         capexCap           [1e9 Euro/a]                 7.08857
#                         commissioning      [GW$_{el}$*h]             401.817619
#                         invest             [1e9 Euro]                  60.67446
#                         operationCharge    [GW$_{el}$*h/a]         20462.508688
#                                            [GW$_{el}$*h]           20462.508688
#                         operationDischarge [GW$_{el}$*h/a]         18399.315862
#                                            [GW$_{el}$*h]           18399.315862
#                         opexCap            [1e9 Euro/a]                0.803635
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  2.141391
#                         TAC                [1e9 Euro/a]                0.496597
#                         capacity           [GW$_{H_{2},LHV}$*h]      856.540584
#                         capexCap           [1e9 Euro/a]                0.008369
#                         commissioning      [GW$_{H_{2},LHV}$*h]      856.540584
#                         invest             [1e9 Euro]                  0.094219
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   3087.458155
#                                            [GW$_{H_{2},LHV}$*h]     3087.458155
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   3087.458155
#                                            [GW$_{H_{2},LHV}$*h]     3087.458155
#                         opexCap            [1e9 Euro/a]                0.488228
#
#  Results of StorageModel for year 2025
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                184.108888
#                         TAC                [1e9 Euro/a]               62.733859
#                         capacity           [GW$_{el}$*h]            3193.983242
#                         capexCap           [1e9 Euro/a]               56.345893
#                         commissioning      [GW$_{el}$*h]            2792.165623
#                         invest             [1e9 Euro]                421.617009
#                         operationCharge    [GW$_{el}$*h/a]         32964.895272
#                                            [GW$_{el}$*h]           32964.895272
#                         operationDischarge [GW$_{el}$*h/a]         29146.796642
#                                            [GW$_{el}$*h]           29146.796642
#                         opexCap            [1e9 Euro/a]                6.387966
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  2.099733
#                         TAC                [1e9 Euro/a]                 0.71547
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.011397
#                         commissioning      [GW$_{H_{2},LHV}$*h]      378.675531
#                         invest             [1e9 Euro]                  0.034081
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   3205.687753
#                                            [GW$_{H_{2},LHV}$*h]     3205.687753
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   3205.687753
#                                            [GW$_{H_{2},LHV}$*h]     3205.687753
#                         opexCap            [1e9 Euro/a]                0.704073
#
#  Results of StorageModel for year 2030
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                246.267114
#                         TAC                [1e9 Euro/a]              123.296983
#                         capacity           [GW$_{el}$*h]            6277.447308
#                         capexCap           [1e9 Euro/a]              110.742088
#                         commissioning      [GW$_{el}$*h]            3083.464066
#                         invest             [1e9 Euro]                465.603074
#                         operationCharge    [GW$_{el}$*h/a]         34274.508378
#                                            [GW$_{el}$*h]           34274.508378
#                         operationDischarge [GW$_{el}$*h/a]         29726.978467
#                                            [GW$_{el}$*h]           29726.978467
#                         opexCap            [1e9 Euro/a]               12.554895
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  1.429043
#                         TAC                [1e9 Euro/a]                 0.71547
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.011397
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   3566.312089
#                                            [GW$_{H_{2},LHV}$*h]     3566.312089
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   3566.312089
#                                            [GW$_{H_{2},LHV}$*h]     3566.312089
#                         opexCap            [1e9 Euro/a]                0.704073
