# %% [markdown]
#  # Workflow for a transformation pathway of a single node energy system with perfect foresight
#
#  In this application of the ETHOS.FINE framework, a transformation pathway of a energy system is modeled and optimized.
#
#  All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
#  The workflow is structures as follows:
#  1. Required packages are imported and the input data path is set
#  2. An energy system model instance is created
#  3. Commodity sources are added to the energy system model
#  4. Commodity conversion components are added to the energy system model
#  5. Commodity storages are added to the energy system model
#  7. Commodity sinks are added to the energy system model
#  8. The energy system model is optimized
#  9. Selected optimization results are presented

# %% [markdown]
#  # 1. Import required packages and set input data path
#
#  The ETHOS.FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import fine as fn
from getData import getData

import os

cwd = os.getcwd()
data = getData()

# %% [markdown]
#  # 2. Create an energy system model instance
#
#  The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
#  The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {"GermanyRegion"}
onlycommodityUnitsDict = {"electricity": r"GW$_{el}$", "hydrogen": r"GW$_{H_{2},LHV}$"}
onlycommodities = {"electricity", "hydrogen"}
onlymaterials={"steel", "copper"}
onlymaterialUnitsDict={"steel": r"tons", "copper": r"tons"}
numberOfTimeSteps = 8760
hoursPerTimeStep = 1

# %%
import pandas as pd

pathwayBalanceLimit = pd.DataFrame(columns=["GermanyRegion", "Total", "lowerBound"], index=["Copper_Resources", "Steel_Resources"])
pathwayBalanceLimit.loc["Copper_Resources"] = [None, 20000, False]
pathwayBalanceLimit.loc["Steel_Resources"] = [None, 12000, False]

# %% [markdown]
#  # 2.1 define Transformation Pathway parameters
#
#  Transformation Pathway Analyses can be run by setting a number of investment periods
#  larger than 1, which is the default value and results in a single year optimization.

# %%
numberOfInvestmentPeriods=3
startYear=2020
interval=5

# %%
esM = fn.EnergySystemModel(
    locations=locations,
    onlycommodities=onlycommodities,
    onlymaterials=onlymaterials,
    numberOfInvestmentPeriods=numberOfInvestmentPeriods,
    startYear=startYear, 
    investmentPeriodInterval=interval,
    numberOfTimeSteps=8760,
    onlycommodityUnitsDict=onlycommodityUnitsDict,
    onlymaterialUnitsDict=onlymaterialUnitsDict,
    hoursPerTimeStep=1,
    costUnit="1e9 Euro",
    lengthUnit="km",
    verboseLogLevel=0,
    pathwayBalanceLimit=pathwayBalanceLimit
)

# %% [markdown]
#  # 3. Add commodity sources to the energy system model

# %% [markdown]
#  ## 3.1. Electricity sources

# %% [markdown]
#  ### Wind onshore

# %% [markdown]
#  change weather conditions for the different investment periods

# %%
operationRateMax={}
operationRateMax[2020]=1.2*data["Wind (onshore), operationRateMax"]
operationRateMax[2025]=0.7*data["Wind (onshore), operationRateMax"]
operationRateMax[2030]=1*data["Wind (onshore), operationRateMax"]

# %% [markdown]
#  define existing stock for wind onshore turbines

# %%
stockWindCommissioning={
    2015:10,
}

# %% [markdown]
#  define invest and opex per capacity for wind onshore turbines

# %%
investPerCapacityWind={
    2015:1.25, 
    2020:1.1, 
    2025:1, 
    2030:0.95
    }

opexPerCapacityWind={
    2015:1.25*0.02, 
    2020:1.1*0.02, 
    2025:1*0.02, 
    2030:0.95*0.02
    }

# %% [markdown]
#  add wind onshore source to esM

# %%
import pandas as pd
esM.add(
    fn.Source(
        esM=esM,
        name="Wind (onshore)",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=investPerCapacityWind,
        opexPerCapacity=opexPerCapacityWind,
        interestRate=0.08,
        economicLifetime=5,
        stockCommissioning=stockWindCommissioning,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'copper': pd.Series({2015:1.1, 2020: 5.3, 2025: 5.2, 2030: 5.1}, dtype='float64')  
            }
        },
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({2020: 0.9, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'copper': pd.Series({2020: 0.8, 2025: 0.85, 2030: 0.9}, dtype='float64')  
            }
        }
    )
)

# %% [markdown]
#  Full load hours:

# %%
data["Wind (onshore), operationRateMax"].sum()
# Out:
# 2300.4069071646272

# %% [markdown]
#  # 4. Add conversion components to the energy system model

# %% [markdown]
#  ### New combined cycly gas turbines for hydrogen

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="New CCGT plants (hydrogen)",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": 1, "hydrogen": -1 / 0.6},
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity={2020:0.021, 2025:0.018, 2030:0.025},
        interestRate=0.08,
        economicLifetime=5,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({ 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'copper': pd.Series({2015:1.1, 2020: 5.3, 2025: 5.2, 2030: 5.1}, dtype='float64')  
            }
        },
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'copper': pd.Series({2020: 0.8, 2025: 0.85, 2030: 0.9}, dtype='float64')  
            }
        }
        
    )
)

# %% [markdown]
#  ### Electrolyzers

# %% [markdown]
#  add component with constant invest and opex per capacity

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Electroylzers",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.7},
        hasCapacityVariable=True,
        investPerCapacity=0.5,
        opexPerCapacity=0.5 * 0.025,
        interestRate=0.08,
        economicLifetime=5
    )
)

# %% [markdown]
#  # 5. Add commodity storages to the energy system model

# %% [markdown]
#  ## 5.1. Electricity storage

# %% [markdown]
#  ### Lithium ion batteries
#
#  The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Li-ion batteries",
        commodity="electricity",
        hasCapacityVariable=True,
        chargeEfficiency=0.95,
        cyclicLifetime=10000,
        dischargeEfficiency=0.95,
        selfDischarge=1 - (1 - 0.03) ** (1 / (30 * 24)),
        chargeRate=1,
        dischargeRate=1,
        doPreciseTsaModeling=False,
        investPerCapacity=0.151,
        opexPerCapacity=0.002,
        interestRate=0.08,
        economicLifetime=15,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({2005: 1.1, 2010: 1.1, 2015: 1.1, 2020: 3.1, 2025: 3.0, 2030: 2.9}, dtype='float64'),
                'copper': pd.Series({2005: 1.1, 2010: 1.1, 2015:1.1, 2020: 5.3, 2025: 5.2, 2030: 5.1}, dtype='float64')  
            }
        },
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({2020: 1, 2025: 0.85, 2030: 0.9}, dtype='float64'),
                'copper': pd.Series({2020: 0.8, 2025: 0.85, 2030: 0.9}, dtype='float64')  
            }
        }
    )
)

# %% [markdown]
#  ## 5.2. Hydrogen storage

# %% [markdown]
#  ### Hydrogen filled salt caverns
#  The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (hydrogen)",
        commodity="hydrogen",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=133,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (hydrogen), capacityMax"],
        investPerCapacity={2020:0.00011,2025: 0.00009,2030:0.00009},
        opexPerCapacity=0.00057,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
#  # 7. Add commodity sinks to the energy system model

# %% [markdown]
#  ## 7.1. Electricity sinks

# %% [markdown]
#  ### Electricity demand

# %% [markdown]
#  vary the demand with the years - increasing demand by 30% per year

# %%
electricityDemand={}
electricityDemand[2020]=(1+0*0.3)*data["Electricity demand, operationRateFix"]
electricityDemand[2025]=(1+1*0.3)*data["Electricity demand, operationRateFix"]
electricityDemand[2030]=(1+2*0.3)*data["Electricity demand, operationRateFix"]

esM.add(
    fn.Sink(
        esM=esM,
        name="Electricity demand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=electricityDemand,
    )
)

# %% [markdown]
#  ## 7.2. Hydrogen sinks

# %% [markdown]
#  ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration = 0.5

# vary the demand with the years - increasing demand by 25% per year
hydrogendDemand={}
hydrogendDemand[2020]=(1+0*0.25)*data["Hydrogen demand, operationRateFix"] * FCEV_penetration
hydrogendDemand[2025]=(1+0*0.25)*data["Hydrogen demand, operationRateFix"] * FCEV_penetration
hydrogendDemand[2030]=(1+0*0.25)*data["Hydrogen demand, operationRateFix"] * FCEV_penetration


esM.add(
    fn.Sink(
        esM=esM,
        name="Hydrogen demand",
        commodity="hydrogen",
        hasCapacityVariable=False,
        operationRateFix=hydrogendDemand,
    )
)

# %%
# sink = esM.add(
#     fn.Sink(
#         esM=esM,
#         name="Steel demand",
#         hasCapacityVariable=False,
#         commodity="steel",
#         material=True,      
#     )
# )

# sink = esM.add(
#     fn.Sink(
#         esM=esM,
#         name="Copper demand",
#         hasCapacityVariable=False,
#         commodity="copper",
#         material=True,      
#     )
# )

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Steel recovery",
        hasCapacityVariable=False,
        commodity="steel",
        material=True,      
    )
)
 
esM.add(
    fn.Source(
        esM=esM,
        name="Copper recovery",
        hasCapacityVariable=False,
        commodity="copper",
        material=True,      
    )
) 


esM.add(
    fn.Source(
        esM=esM,
        name="Steel supply",
        hasCapacityVariable=False,
        commodity="steel", 
        pathwayBalanceLimitID="Copper_Resources" 
    )
)
 
esM.add(
    fn.Source(
        esM=esM,
        name="Copper supply",
        hasCapacityVariable=False,
        commodity="copper",
        pathwayBalanceLimitID="Steel_Resources"
    )
)

# %% [markdown]
#  # 8. Optimize energy system model

# %% [markdown]
#  All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
esM.generationMaterialSinks()
# Out:
# Existing material sinks: set()
# Missing materials sinks: {'copper', 'steel'}
# New sink added: Copper demand
# New sink added: Steel demand

# %%
esM.aggregateTemporally(numberOfTypicalPeriods=30)
# Out:
# Clustering time series data with 30 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(11.1000 sec)

# %%
print(dir(esM.pyM))
# Out:
# ['__bool__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
#esM.declareOptimizationProblem(timeSeriesAggregation=True)

# %%
esM.optimize(timeSeriesAggregation=True, solver="gurobi")
# Out:
# Time series aggregation specifications:
# Number of typical periods:30, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.5131 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.1458 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.8304 sec)
#
# Declaring shared potential constraint...
# 		(0.0003 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.0900 sec)
#
# Declaring material balances...
# ('GermanyRegion', 'Copper demand', 'copper', 0)
# ('GermanyRegion', 'Copper demand', 'copper', 1)
# ('GermanyRegion', 'Copper demand', 'copper', 2)
# ('GermanyRegion', 'Steel demand', 'steel', 0)
# ('GermanyRegion', 'Steel demand', 'steel', 1)
# ('GermanyRegion', 'Steel demand', 'steel', 2)
# LHS_demand 23*op_srcSnk[GermanyRegion,Copper demand,0,0,0] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,1] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,2] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,3] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,4] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,5] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,6] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,7] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,8] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,9] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,10] + 23*op_srcSnk[GermanyRegion,Copper demand,0,0,11] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,0] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,1] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,2] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,3] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,4] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,5] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,6] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,7] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,8] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,9] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,10] + 15*op_srcSnk[GermanyRegion,Copper demand,0,1,11] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,0] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,1] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,2] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,3] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,4] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,5] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,6] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,7] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,8] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,9] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,10] + 55*op_srcSnk[GermanyRegion,Copper demand,0,2,11] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,0] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,1] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,2] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,3] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,4] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,5] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,6] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,7] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,8] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,9] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,10] + 8*op_srcSnk[GermanyRegion,Copper demand,0,3,11] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,0] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,1] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,2] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,3] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,4] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,5] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,6] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,7] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,8] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,9] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,10] + 8*op_srcSnk[GermanyRegion,Copper demand,0,4,11] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,0] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,1] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,2] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,3] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,4] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,5] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,6] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,7] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,8] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,9] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,10] + 10*op_srcSnk[GermanyRegion,Copper demand,0,5,11] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,0] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,1] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,2] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,3] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,4] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,5] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,6] + 4*op_srcSnk[GermanyRegion,Copper demand,0,6,7] + 4*op_srcS ...
# RHS_demand 5.3*commis_srcSnk[GermanyRegion,'Wind (onshore)',0] + 5.3*commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',0] + 5.3*commis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_demand 23*op_srcSnk[GermanyRegion,Copper demand,1,0,0] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,1] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,2] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,3] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,4] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,5] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,6] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,7] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,8] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,9] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,10] + 23*op_srcSnk[GermanyRegion,Copper demand,1,0,11] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,0] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,1] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,2] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,3] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,4] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,5] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,6] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,7] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,8] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,9] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,10] + 15*op_srcSnk[GermanyRegion,Copper demand,1,1,11] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,0] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,1] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,2] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,3] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,4] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,5] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,6] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,7] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,8] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,9] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,10] + 55*op_srcSnk[GermanyRegion,Copper demand,1,2,11] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,0] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,1] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,2] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,3] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,4] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,5] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,6] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,7] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,8] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,9] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,10] + 8*op_srcSnk[GermanyRegion,Copper demand,1,3,11] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,0] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,1] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,2] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,3] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,4] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,5] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,6] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,7] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,8] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,9] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,10] + 8*op_srcSnk[GermanyRegion,Copper demand,1,4,11] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,0] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,1] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,2] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,3] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,4] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,5] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,6] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,7] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,8] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,9] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,10] + 10*op_srcSnk[GermanyRegion,Copper demand,1,5,11] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,0] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,1] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,2] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,3] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,4] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,5] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,6] + 4*op_srcSnk[GermanyRegion,Copper demand,1,6,7] + 4*op_srcS ...
# RHS_demand 5.2*commis_srcSnk[GermanyRegion,'Wind (onshore)',1] + 5.2*commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',1] + 5.2*commis_stor[GermanyRegion,Li-ion batteries,1]
# LHS_demand 23*op_srcSnk[GermanyRegion,Copper demand,2,0,0] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,1] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,2] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,3] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,4] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,5] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,6] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,7] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,8] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,9] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,10] + 23*op_srcSnk[GermanyRegion,Copper demand,2,0,11] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,0] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,1] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,2] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,3] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,4] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,5] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,6] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,7] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,8] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,9] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,10] + 15*op_srcSnk[GermanyRegion,Copper demand,2,1,11] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,0] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,1] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,2] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,3] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,4] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,5] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,6] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,7] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,8] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,9] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,10] + 55*op_srcSnk[GermanyRegion,Copper demand,2,2,11] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,0] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,1] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,2] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,3] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,4] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,5] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,6] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,7] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,8] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,9] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,10] + 8*op_srcSnk[GermanyRegion,Copper demand,2,3,11] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,0] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,1] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,2] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,3] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,4] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,5] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,6] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,7] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,8] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,9] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,10] + 8*op_srcSnk[GermanyRegion,Copper demand,2,4,11] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,0] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,1] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,2] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,3] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,4] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,5] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,6] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,7] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,8] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,9] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,10] + 10*op_srcSnk[GermanyRegion,Copper demand,2,5,11] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,0] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,1] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,2] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,3] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,4] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,5] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,6] + 4*op_srcSnk[GermanyRegion,Copper demand,2,6,7] + 4*op_srcS ...
# RHS_demand 5.1*commis_srcSnk[GermanyRegion,'Wind (onshore)',2] + 5.1*commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',2] + 5.1*commis_stor[GermanyRegion,Li-ion batteries,2]
# LHS_demand 23*op_srcSnk[GermanyRegion,Steel demand,0,0,0] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,1] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,2] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,3] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,4] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,5] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,6] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,7] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,8] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,9] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,10] + 23*op_srcSnk[GermanyRegion,Steel demand,0,0,11] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,0] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,1] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,2] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,3] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,4] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,5] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,6] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,7] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,8] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,9] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,10] + 15*op_srcSnk[GermanyRegion,Steel demand,0,1,11] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,0] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,1] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,2] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,3] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,4] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,5] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,6] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,7] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,8] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,9] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,10] + 55*op_srcSnk[GermanyRegion,Steel demand,0,2,11] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,0] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,1] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,2] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,3] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,4] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,5] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,6] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,7] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,8] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,9] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,10] + 8*op_srcSnk[GermanyRegion,Steel demand,0,3,11] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,0] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,1] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,2] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,3] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,4] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,5] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,6] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,7] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,8] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,9] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,10] + 8*op_srcSnk[GermanyRegion,Steel demand,0,4,11] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,0] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,1] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,2] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,3] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,4] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,5] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,6] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,7] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,8] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,9] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,10] + 10*op_srcSnk[GermanyRegion,Steel demand,0,5,11] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,0] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,1] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,2] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,3] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,4] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,5] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,6] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,7] + 4*op_srcSnk[GermanyRegion,Steel demand,0,6,8] + 4*op_srcSnk[GermanyRegion,Steel demand,0, ...
# RHS_demand 3.1*commis_srcSnk[GermanyRegion,'Wind (onshore)',0] + 3.1*commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',0] + 3.1*commis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_demand 23*op_srcSnk[GermanyRegion,Steel demand,1,0,0] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,1] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,2] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,3] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,4] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,5] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,6] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,7] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,8] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,9] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,10] + 23*op_srcSnk[GermanyRegion,Steel demand,1,0,11] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,0] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,1] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,2] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,3] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,4] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,5] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,6] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,7] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,8] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,9] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,10] + 15*op_srcSnk[GermanyRegion,Steel demand,1,1,11] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,0] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,1] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,2] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,3] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,4] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,5] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,6] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,7] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,8] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,9] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,10] + 55*op_srcSnk[GermanyRegion,Steel demand,1,2,11] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,0] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,1] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,2] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,3] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,4] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,5] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,6] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,7] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,8] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,9] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,10] + 8*op_srcSnk[GermanyRegion,Steel demand,1,3,11] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,0] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,1] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,2] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,3] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,4] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,5] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,6] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,7] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,8] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,9] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,10] + 8*op_srcSnk[GermanyRegion,Steel demand,1,4,11] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,0] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,1] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,2] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,3] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,4] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,5] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,6] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,7] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,8] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,9] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,10] + 10*op_srcSnk[GermanyRegion,Steel demand,1,5,11] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,0] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,1] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,2] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,3] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,4] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,5] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,6] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,7] + 4*op_srcSnk[GermanyRegion,Steel demand,1,6,8] + 4*op_srcSnk[GermanyRegion,Steel demand,1, ...
# RHS_demand 3.0*commis_srcSnk[GermanyRegion,'Wind (onshore)',1] + 3.0*commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',1] + 3.0*commis_stor[GermanyRegion,Li-ion batteries,1]
# LHS_demand 23*op_srcSnk[GermanyRegion,Steel demand,2,0,0] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,1] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,2] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,3] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,4] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,5] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,6] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,7] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,8] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,9] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,10] + 23*op_srcSnk[GermanyRegion,Steel demand,2,0,11] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,0] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,1] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,2] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,3] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,4] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,5] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,6] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,7] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,8] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,9] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,10] + 15*op_srcSnk[GermanyRegion,Steel demand,2,1,11] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,0] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,1] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,2] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,3] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,4] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,5] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,6] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,7] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,8] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,9] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,10] + 55*op_srcSnk[GermanyRegion,Steel demand,2,2,11] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,0] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,1] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,2] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,3] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,4] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,5] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,6] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,7] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,8] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,9] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,10] + 8*op_srcSnk[GermanyRegion,Steel demand,2,3,11] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,0] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,1] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,2] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,3] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,4] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,5] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,6] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,7] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,8] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,9] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,10] + 8*op_srcSnk[GermanyRegion,Steel demand,2,4,11] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,0] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,1] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,2] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,3] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,4] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,5] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,6] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,7] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,8] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,9] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,10] + 10*op_srcSnk[GermanyRegion,Steel demand,2,5,11] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,0] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,1] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,2] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,3] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,4] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,5] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,6] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,7] + 4*op_srcSnk[GermanyRegion,Steel demand,2,6,8] + 4*op_srcSnk[GermanyRegion,Steel demand,2, ...
# RHS_demand 2.9*commis_srcSnk[GermanyRegion,'Wind (onshore)',2] + 2.9*commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',2] + 2.9*commis_stor[GermanyRegion,Li-ion batteries,2]
# 		(0.0219 sec)
#
# Declaring material balances...
# ('GermanyRegion', 'Steel recovery', 'steel', 0)
# ('GermanyRegion', 'Steel recovery', 'steel', 1)
# ('GermanyRegion', 'Steel recovery', 'steel', 2)
# ('GermanyRegion', 'Copper recovery', 'copper', 0)
# ('GermanyRegion', 'Copper recovery', 'copper', 1)
# ('GermanyRegion', 'Copper recovery', 'copper', 2)
# LHS_recovery 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,0] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,1] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,2] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,3] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,4] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,5] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,6] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,7] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,8] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,9] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,10] + 23*op_srcSnk[GermanyRegion,Steel recovery,0,0,11] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,0] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,1] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,2] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,3] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,4] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,5] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,6] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,7] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,8] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,9] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,10] + 15*op_srcSnk[GermanyRegion,Steel recovery,0,1,11] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,0] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,1] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,2] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,3] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,4] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,5] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,6] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,7] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,8] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,9] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,10] + 55*op_srcSnk[GermanyRegion,Steel recovery,0,2,11] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,0] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,1] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,2] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,3] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,4] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,5] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,6] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,7] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,8] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,9] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,10] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,3,11] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,0] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,1] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,2] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,3] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,4] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,5] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,6] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,7] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,8] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,9] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,10] + 8*op_srcSnk[GermanyRegion,Steel recovery,0,4,11] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,0] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,1] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,2] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,3] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,4] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,5] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,6] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,7] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,8] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,9] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,10] + 10*op_srcSnk[GermanyRegion,Steel recovery,0,5,11] + 4*op_srcSnk[GermanyRegion,Steel recovery,0,6,0] + 4*op_srcSnk[GermanyRegion,Steel recovery,0,6,1] + 4*op_srcSnk[GermanyRegion,Steel recovery,0,6,2] + 4*op_srcSnk[GermanyRegion,Steel recovery,0,6,3] + 4*op_srcSnk[GermanyRegion,Steel recovery,0,6,4] + 4*op_srcSnk[GermanyRegion,Steel recovery,0,6,5] + 4*op_srcSnk[GermanyRegion,S ...
# RHS_recovery 0.9900000000000001*decommis_srcSnk[GermanyRegion,'Wind (onshore)',0] + 1.1*decommis_conv[GermanyRegion,'New CCGT plants (hydrogen)',0] + 1.1*decommis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_recovery 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,0] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,1] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,2] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,3] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,4] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,5] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,6] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,7] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,8] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,9] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,10] + 23*op_srcSnk[GermanyRegion,Steel recovery,1,0,11] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,0] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,1] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,2] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,3] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,4] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,5] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,6] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,7] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,8] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,9] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,10] + 15*op_srcSnk[GermanyRegion,Steel recovery,1,1,11] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,0] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,1] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,2] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,3] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,4] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,5] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,6] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,7] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,8] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,9] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,10] + 55*op_srcSnk[GermanyRegion,Steel recovery,1,2,11] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,0] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,1] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,2] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,3] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,4] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,5] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,6] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,7] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,8] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,9] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,10] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,3,11] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,0] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,1] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,2] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,3] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,4] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,5] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,6] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,7] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,8] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,9] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,10] + 8*op_srcSnk[GermanyRegion,Steel recovery,1,4,11] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,0] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,1] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,2] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,3] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,4] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,5] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,6] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,7] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,8] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,9] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,10] + 10*op_srcSnk[GermanyRegion,Steel recovery,1,5,11] + 4*op_srcSnk[GermanyRegion,Steel recovery,1,6,0] + 4*op_srcSnk[GermanyRegion,Steel recovery,1,6,1] + 4*op_srcSnk[GermanyRegion,Steel recovery,1,6,2] + 4*op_srcSnk[GermanyRegion,Steel recovery,1,6,3] + 4*op_srcSnk[GermanyRegion,Steel recovery,1,6,4] + 4*op_srcSnk[GermanyRegion,Steel recovery,1,6,5] + 4*op_srcSnk[GermanyRegion,S ...
# RHS_recovery 2.635*decommis_srcSnk[GermanyRegion,'Wind (onshore)',1] + 2.635*decommis_conv[GermanyRegion,'New CCGT plants (hydrogen)',1] + 0.935*decommis_stor[GermanyRegion,Li-ion batteries,1]
# LHS_recovery 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,0] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,1] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,2] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,3] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,4] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,5] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,6] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,7] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,8] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,9] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,10] + 23*op_srcSnk[GermanyRegion,Steel recovery,2,0,11] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,0] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,1] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,2] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,3] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,4] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,5] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,6] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,7] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,8] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,9] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,10] + 15*op_srcSnk[GermanyRegion,Steel recovery,2,1,11] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,0] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,1] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,2] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,3] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,4] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,5] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,6] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,7] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,8] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,9] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,10] + 55*op_srcSnk[GermanyRegion,Steel recovery,2,2,11] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,0] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,1] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,2] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,3] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,4] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,5] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,6] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,7] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,8] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,9] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,10] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,3,11] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,0] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,1] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,2] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,3] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,4] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,5] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,6] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,7] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,8] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,9] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,10] + 8*op_srcSnk[GermanyRegion,Steel recovery,2,4,11] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,0] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,1] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,2] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,3] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,4] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,5] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,6] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,7] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,8] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,9] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,10] + 10*op_srcSnk[GermanyRegion,Steel recovery,2,5,11] + 4*op_srcSnk[GermanyRegion,Steel recovery,2,6,0] + 4*op_srcSnk[GermanyRegion,Steel recovery,2,6,1] + 4*op_srcSnk[GermanyRegion,Steel recovery,2,6,2] + 4*op_srcSnk[GermanyRegion,Steel recovery,2,6,3] + 4*op_srcSnk[GermanyRegion,Steel recovery,2,6,4] + 4*op_srcSnk[GermanyRegion,Steel recovery,2,6,5] + 4*op_srcSnk[GermanyRegion,S ...
# RHS_recovery 2.7*decommis_srcSnk[GermanyRegion,'Wind (onshore)',2] + 2.7*decommis_conv[GermanyRegion,'New CCGT plants (hydrogen)',2] + 0.9900000000000001*decommis_stor[GermanyRegion,Li-ion batteries,2]
# LHS_recovery 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,0] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,1] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,2] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,3] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,4] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,5] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,6] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,7] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,8] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,9] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,10] + 23*op_srcSnk[GermanyRegion,Copper recovery,0,0,11] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,0] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,1] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,2] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,3] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,4] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,5] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,6] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,7] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,8] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,9] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,10] + 15*op_srcSnk[GermanyRegion,Copper recovery,0,1,11] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,0] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,1] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,2] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,3] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,4] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,5] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,6] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,7] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,8] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,9] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,10] + 55*op_srcSnk[GermanyRegion,Copper recovery,0,2,11] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,0] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,1] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,2] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,3] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,4] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,5] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,6] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,7] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,8] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,9] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,10] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,3,11] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,0] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,1] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,2] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,3] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,4] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,5] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,6] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,7] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,8] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,9] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,10] + 8*op_srcSnk[GermanyRegion,Copper recovery,0,4,11] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,0] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,1] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,2] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,3] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,4] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,5] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,6] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,7] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,8] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,9] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,10] + 10*op_srcSnk[GermanyRegion,Copper recovery,0,5,11] + 4*op_srcSnk[GermanyRegion,Copper recovery,0,6,0] + 4*op_srcSnk[GermanyRegion,Copper recovery,0,6,1] + 4*op_srcSnk[GermanyRegion,Copper recovery,0,6,2] + 4*op_srcSnk[GermanyRegion,Copper recovery,0,6,3] + 4*op_srcSnk[GermanyRegion,Copper recovery,0,6,4] +  ...
# RHS_recovery 0.8800000000000001*decommis_srcSnk[GermanyRegion,'Wind (onshore)',0] + 0.8800000000000001*decommis_conv[GermanyRegion,'New CCGT plants (hydrogen)',0] + 0.8800000000000001*decommis_stor[GermanyRegion,Li-ion batteries,0]
# LHS_recovery 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,0] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,1] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,2] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,3] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,4] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,5] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,6] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,7] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,8] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,9] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,10] + 23*op_srcSnk[GermanyRegion,Copper recovery,1,0,11] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,0] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,1] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,2] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,3] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,4] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,5] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,6] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,7] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,8] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,9] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,10] + 15*op_srcSnk[GermanyRegion,Copper recovery,1,1,11] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,0] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,1] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,2] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,3] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,4] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,5] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,6] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,7] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,8] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,9] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,10] + 55*op_srcSnk[GermanyRegion,Copper recovery,1,2,11] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,0] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,1] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,2] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,3] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,4] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,5] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,6] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,7] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,8] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,9] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,10] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,3,11] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,0] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,1] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,2] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,3] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,4] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,5] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,6] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,7] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,8] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,9] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,10] + 8*op_srcSnk[GermanyRegion,Copper recovery,1,4,11] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,0] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,1] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,2] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,3] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,4] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,5] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,6] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,7] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,8] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,9] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,10] + 10*op_srcSnk[GermanyRegion,Copper recovery,1,5,11] + 4*op_srcSnk[GermanyRegion,Copper recovery,1,6,0] + 4*op_srcSnk[GermanyRegion,Copper recovery,1,6,1] + 4*op_srcSnk[GermanyRegion,Copper recovery,1,6,2] + 4*op_srcSnk[GermanyRegion,Copper recovery,1,6,3] + 4*op_srcSnk[GermanyRegion,Copper recovery,1,6,4] +  ...
# RHS_recovery 4.505*decommis_srcSnk[GermanyRegion,'Wind (onshore)',1] + 4.505*decommis_conv[GermanyRegion,'New CCGT plants (hydrogen)',1] + 0.935*decommis_stor[GermanyRegion,Li-ion batteries,1]
# LHS_recovery 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,0] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,1] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,2] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,3] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,4] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,5] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,6] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,7] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,8] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,9] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,10] + 23*op_srcSnk[GermanyRegion,Copper recovery,2,0,11] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,0] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,1] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,2] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,3] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,4] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,5] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,6] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,7] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,8] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,9] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,10] + 15*op_srcSnk[GermanyRegion,Copper recovery,2,1,11] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,0] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,1] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,2] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,3] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,4] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,5] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,6] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,7] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,8] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,9] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,10] + 55*op_srcSnk[GermanyRegion,Copper recovery,2,2,11] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,0] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,1] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,2] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,3] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,4] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,5] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,6] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,7] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,8] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,9] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,10] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,3,11] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,0] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,1] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,2] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,3] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,4] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,5] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,6] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,7] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,8] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,9] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,10] + 8*op_srcSnk[GermanyRegion,Copper recovery,2,4,11] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,0] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,1] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,2] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,3] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,4] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,5] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,6] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,7] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,8] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,9] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,10] + 10*op_srcSnk[GermanyRegion,Copper recovery,2,5,11] + 4*op_srcSnk[GermanyRegion,Copper recovery,2,6,0] + 4*op_srcSnk[GermanyRegion,Copper recovery,2,6,1] + 4*op_srcSnk[GermanyRegion,Copper recovery,2,6,2] + 4*op_srcSnk[GermanyRegion,Copper recovery,2,6,3] + 4*op_srcSnk[GermanyRegion,Copper recovery,2,6,4] +  ...
# RHS_recovery 4.680000000000001*decommis_srcSnk[GermanyRegion,'Wind (onshore)',2] + 4.680000000000001*decommis_conv[GermanyRegion,'New CCGT plants (hydrogen)',2] + 0.9900000000000001*decommis_stor[GermanyRegion,Li-ion batteries,2]
# 		(0.0203 sec)
#
# 		(0.0154 sec)
#
# Declaring objective function...
# 		(1.5451 sec)
#
# Set parameter ServerPassword
# Set parameter TSPort to value 41955
# Set parameter TokenServer to value "iek3079"
# Read LP format model from file /tmp/tmp1rxobjaj.pyomo.lp
# Reading time = 0.05 seconds
# x1: 27192 rows, 21157 columns, 83636 nonzeros
# Set parameter QCPDual to value 1
# Set parameter Threads to value 3
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (linux64 - "Rocky Linux 8.8 (Green Obsidian)")
#
# CPU model: Intel(R) Xeon(R) Gold 6154 CPU @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 36 physical cores, 72 logical processors, using up to 3 threads
#
# Optimize a model with 27192 rows, 21157 columns and 83636 nonzeros
# Model fingerprint: 0xd3be50b2
# Coefficient statistics:
#   Matrix range     [7e-04, 7e+02]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [5e-02, 1e+03]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 8297 rows and 12390 columns
# Presolve time: 0.13s
# Presolved: 18895 rows, 8767 columns, 76653 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.34s
#
# Barrier statistics:
#  Dense cols : 63
#  Free vars  : 173
#  AA' NZ     : 3.467e+05
#  Factor NZ  : 2.590e+06 (roughly 30 MB of memory)
#  Factor Ops : 1.173e+09 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.97245578e+05 -6.89496489e+05  1.08e+07 6.34e-01  3.26e+04     1s
#    1   6.35178005e+05 -5.69419760e+05  8.80e+06 4.05e-01  2.35e+04     1s
#    2   3.73795140e+05 -4.84343914e+05  4.03e+06 2.16e-01  1.16e+04     1s
#    3   3.21045217e+05 -3.30387622e+05  2.58e+06 6.16e-02  5.98e+03     1s
#    4   1.62615862e+05 -3.39165649e+05  1.66e+06 8.30e-03  3.38e+03     1s
#    5   1.08140176e+05 -3.18187886e+05  2.95e+05 1.52e-03  6.18e+02     1s
#    6   4.14710403e+04 -2.33566670e+05  2.59e+04 4.86e-05  6.22e+01     1s
#    7   2.31015223e+04 -1.58511061e+05  1.42e+04 1.86e-05  3.41e+01     1s
#    8   1.37711483e+04 -1.13074453e+05  7.78e+03 2.26e-05  1.84e+01     2s
#    9   2.92171421e+03 -6.45158837e+04  1.23e+03 3.05e-05  4.19e+00     2s
#   10   1.56284831e+03 -3.71336174e+04  5.48e+02 1.55e-05  2.01e+00     2s
#   11   1.28470120e+03 -2.63441930e+04  4.12e+02 2.61e-05  1.39e+00     2s
#   12   9.47523050e+02 -1.33418086e+04  2.53e+02 2.26e-05  6.98e-01     2s
#   13   6.52516849e+02 -7.28458592e+03  1.25e+02 3.83e-05  3.55e-01     2s
#   14   4.70167780e+02 -3.79033588e+03  5.16e+01 3.69e-05  1.77e-01     2s
#   15   3.73241793e+02 -9.56905022e+02  1.89e+01 3.44e-05  5.39e-02     2s
#   16   2.68714089e+02 -4.85865699e+02  1.22e-01 1.97e-05  2.79e-02     2s
#   17   2.24108386e+02 -2.82483332e+02  3.24e-02 1.37e-05  1.84e-02     2s
#   18   2.07893585e+02  1.31965632e+00  1.63e-02 6.43e-06  7.48e-03     2s
#   19   1.94604279e+02  7.77474099e+01  9.53e-03 4.80e-06  4.22e-03     2s
#
# Barrier performed 19 iterations in 2.46 seconds (1.29 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 1
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    12003    1.6587255e+02   0.000000e+00   0.000000e+00      3s
#
# Solved in 12003 iterations and 2.52 seconds (3.01 work units)
# Optimal objective  1.658725476e+02
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 2.5212109088897705
# Error rc: 0
# Time: 2.968292236328125
#
#
# Name: x1
# Lower bound: 165.87254763851442
# Upper bound: 165.87254763851442
# Number of objectives: 1
# Number of constraints: 27192
# Number of variables: 21157
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 21157
# Number of nonzeros: 83636
# Sense: minimize
#
# Solve time: 3.5297772884368896 sec.
#
# Processing optimization output...
# for SourceSinkModel ...(2.0212sec)
# for ConversionModel ...(0.6118sec)
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2085: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2085: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2085: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/l-soeltzer/code/fine/fine/storage.py:2085: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(
# for StorageModel ...  (2.5023sec)
# 		(5.1815 sec)

# %% [markdown]
#  # 9. Selected results output

# %% [markdown]
#  ### Sources and Sink
#
#  Show optimization summary

# %%
for year in [2020,2025,2030]:
    print(f"\n Results of SourceSinkModel for year {year}")
    print(esM.getOptimizationSummary("SourceSinkModel", outputLevel=2, ip=year))
# Out:
#  Results of SourceSinkModel for year 2020
#                                                           GermanyRegion
# Component          Property        Unit
# Copper demand      operation       [tons/a]                  616.869704
# Copper recovery    operation       [tons/a]                         8.8
# Copper supply      operation       [tons/a]                  608.069704
# Electricity demand operation       [GW$_{el}$*h/a]         30957.888055
#                                    [GW$_{el}$*h]           30957.888055
# Hydrogen demand    operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                    [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand       operation       [tons/a]                  360.810582
# Steel recovery     operation       [tons/a]                         9.9
# Steel supply       operation       [tons/a]                  350.910582
# Wind (onshore)     NPVcontribution [1e9 Euro]                 51.389934
#                    TAC             [1e9 Euro/a]               11.917538
#                    capacity        [GW$_{el}$]                40.058668
#                    capexCap        [1e9 Euro/a]               11.036247
#                    commissioning   [GW$_{el}$]                40.058668
#                    decommissioning [GW$_{el}$]                     10.0
#                    invest          [1e9 Euro]                 44.064534
#                    operation       [GW$_{el}$*h/a]         44136.476727
#                                    [GW$_{el}$*h]           44136.476727
#                    opexCap         [1e9 Euro/a]                0.881291
#
#  Results of SourceSinkModel for year 2025
#                                                           GermanyRegion
# Component          Property        Unit
# Copper demand      operation       [tons/a]                  632.406047
# Copper recovery    operation       [tons/a]                  186.914908
# Copper supply      operation       [tons/a]                   445.49114
# Electricity demand operation       [GW$_{el}$*h/a]         40245.254471
#                                    [GW$_{el}$*h]           40245.254471
# Hydrogen demand    operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                    [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand       operation       [tons/a]                  364.849643
# Steel recovery     operation       [tons/a]                  109.327587
# Steel supply       operation       [tons/a]                  255.522055
# Wind (onshore)     NPVcontribution [1e9 Euro]                 41.688464
#                    TAC             [1e9 Euro/a]               14.205062
#                    capacity        [GW$_{el}$]                52.522549
#                    capexCap        [1e9 Euro/a]               13.154611
#                    commissioning   [GW$_{el}$]                52.522549
#                    decommissioning [GW$_{el}$]                40.058668
#                    invest          [1e9 Euro]                 52.522549
#                    operation       [GW$_{el}$*h/a]         53970.725051
#                                    [GW$_{el}$*h]           53970.725051
#                    opexCap         [1e9 Euro/a]                1.050451
#
#  Results of SourceSinkModel for year 2030
#                                                           GermanyRegion
# Component          Property        Unit
# Copper demand      operation       [tons/a]                 1255.458395
# Copper recovery    operation       [tons/a]                   252.50672
# Copper supply      operation       [tons/a]                 1002.951675
# Electricity demand operation       [GW$_{el}$*h/a]         49532.620887
#                                    [GW$_{el}$*h]           49532.620887
# Hydrogen demand    operation       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                    [GW$_{H_{2},LHV}$*h]     4765.074877
# Steel demand       operation       [tons/a]                  713.888107
# Steel recovery     operation       [tons/a]                  145.676954
# Steel supply       operation       [tons/a]                  568.211153
# Wind (onshore)     NPVcontribution [1e9 Euro]                 29.851679
#                    TAC             [1e9 Euro/a]                14.94565
#                    capacity        [GW$_{el}$]                  58.1693
#                    capexCap        [1e9 Euro/a]               13.840433
#                    commissioning   [GW$_{el}$]                  58.1693
#                    decommissioning [GW$_{el}$]                52.522549
#                    invest          [1e9 Euro]                 55.260835
#                    operation       [GW$_{el}$*h/a]         63797.896864
#                                    [GW$_{el}$*h]           63797.896864
#                    opexCap         [1e9 Euro/a]                1.105217

# %% [markdown]
#  Plot operation time series (either one or two dimensional) for different years

# %% [markdown]
#  Electricity demand operation for Investment Period 2020

# %%
fig, ax = fn.plotOperation(esM, "Electricity demand", "GermanyRegion", ip=2020)

# %% [markdown]
#  Electricity demand operation for Investment Period 2030

# %%
fig, ax = fn.plotOperation(esM, "Electricity demand", "GermanyRegion", ip=2030)

# %% [markdown]
#  Operation color map for Electricity demand in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(esM, "Electricity demand", "GermanyRegion",ip=2020)

# %% [markdown]
#  Operation color map for Electricity demand in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(esM, "Electricity demand", "GermanyRegion",ip=2030)

# %% [markdown]
#  ### Conversion
#
#  Show optimization summary

# %%
for year in [2020,2025,2030]:
    print(f"\n Results of ConversionMpdel for year {year}")
    print(esM.getOptimizationSummary("ConversionModel", outputLevel=2, ip=year))
# Out:
#  Results of ConversionMpdel for year 2020
#                                                            GermanyRegion
# Component                  Property        Unit
# Electroylzers              NPVcontribution [1e9 Euro]           2.888824
#                            TAC             [1e9 Euro/a]          0.66993
#                            capacity        [GW$_{el}$]          4.864146
#                            capexCap        [1e9 Euro/a]         0.609128
#                            commissioning   [GW$_{el}$]          4.864146
#                            invest          [1e9 Euro]           2.432073
#                            operation       [GW$_{el}$*h/a]  16701.949499
#                                            [GW$_{el}$*h]    16701.949499
#                            opexCap         [1e9 Euro/a]         0.060802
# New CCGT plants (hydrogen) NPVcontribution [1e9 Euro]           1.212163
#                            TAC             [1e9 Euro/a]         0.281106
#                            capacity        [GW$_{el}$]          1.431878
#                            capexCap        [1e9 Euro/a]         0.251036
#                            commissioning   [GW$_{el}$]          1.431878
#                            invest          [1e9 Euro]           1.002315
#                            operation       [GW$_{el}$*h/a]   4155.773864
#                                            [GW$_{el}$*h]     4155.773864
#                            opexCap         [1e9 Euro/a]         0.030069
#
#  Results of ConversionMpdel for year 2025
#                                                            GermanyRegion
# Component                  Property        Unit
# Electroylzers              NPVcontribution [1e9 Euro]           1.989497
#                            TAC             [1e9 Euro/a]         0.677908
#                            capacity        [GW$_{el}$]          4.922067
#                            capexCap        [1e9 Euro/a]         0.616382
#                            commissioning   [GW$_{el}$]          4.922067
#                            decommissioning [GW$_{el}$]          4.864146
#                            invest          [1e9 Euro]           2.461034
#                            operation       [GW$_{el}$*h/a]  16987.812895
#                                            [GW$_{el}$*h]    16987.812895
#                            opexCap         [1e9 Euro/a]         0.061526
# New CCGT plants (hydrogen) NPVcontribution [1e9 Euro]           0.812371
#                            TAC             [1e9 Euro/a]          0.27681
#                            capacity        [GW$_{el}$]          1.431878
#                            capexCap        [1e9 Euro/a]         0.251036
#                            commissioning   [GW$_{el}$]          1.431878
#                            decommissioning [GW$_{el}$]          1.431878
#                            invest          [1e9 Euro]           1.002315
#                            operation       [GW$_{el}$*h/a]    4275.83649
#                                            [GW$_{el}$*h]      4275.83649
#                            opexCap         [1e9 Euro/a]         0.025774
#
#  Results of ConversionMpdel for year 2030
#                                                            GermanyRegion
# Component                  Property        Unit
# Electroylzers              NPVcontribution [1e9 Euro]           1.366353
#                            TAC             [1e9 Euro/a]         0.684083
#                            capacity        [GW$_{el}$]          4.966908
#                            capexCap        [1e9 Euro/a]         0.621997
#                            commissioning   [GW$_{el}$]          4.966908
#                            decommissioning [GW$_{el}$]          4.922067
#                            invest          [1e9 Euro]           2.483454
#                            operation       [GW$_{el}$*h/a]  17089.434986
#                                            [GW$_{el}$*h]    17089.434986
#                            opexCap         [1e9 Euro/a]         0.062086
# New CCGT plants (hydrogen) NPVcontribution [1e9 Euro]           0.580617
#                            TAC             [1e9 Euro/a]         0.290694
#                            capacity        [GW$_{el}$]          1.451152
#                            capexCap        [1e9 Euro/a]         0.254415
#                            commissioning   [GW$_{el}$]          1.451152
#                            decommissioning [GW$_{el}$]          1.431878
#                            invest          [1e9 Euro]           1.015806
#                            operation       [GW$_{el}$*h/a]   4318.517768
#                                            [GW$_{el}$*h]     4318.517768
#                            opexCap         [1e9 Euro/a]         0.036279

# %% [markdown]
#  Operation color map for New CCGT plants (hydrogen) in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(esM, "New CCGT plants (hydrogen)", "GermanyRegion", ip=2020)

# %% [markdown]
#  Operation color map for New CCGT plants (hydrogen) in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(esM, "New CCGT plants (hydrogen)", "GermanyRegion", ip=2030)

# %% [markdown]
#  ### Storage
#
#  Show optimization summary

# %%
for year in [2020,2025,2030]:
    print(f"\n Results of StorageModel for year {year}")
    print(esM.getOptimizationSummary("StorageModel", outputLevel=2, ip=year))
# Out:
#  Results of StorageModel for year 2020
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                  6.343698
#                         TAC                [1e9 Euro/a]                 1.47113
#                         capacity           [GW$_{el}$*h]              74.899965
#                         capexCap           [1e9 Euro/a]                 1.32133
#                         commissioning      [GW$_{el}$*h]              74.899965
#                         invest             [1e9 Euro]                 11.309895
#                         operationCharge    [GW$_{el}$*h/a]          6355.287661
#                                            [GW$_{el}$*h]            6355.287661
#                         operationDischarge [GW$_{el}$*h/a]          5722.874625
#                                            [GW$_{el}$*h]            5722.874625
#                         opexCap            [1e9 Euro/a]                  0.1498
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  3.088097
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         commissioning      [GW$_{H_{2},LHV}$*h]     1235.216115
#                         invest             [1e9 Euro]                  0.135874
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   9502.733574
#                                            [GW$_{H_{2},LHV}$*h]     9502.733574
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   9502.733574
#                                            [GW$_{H_{2},LHV}$*h]     9502.733574
#                         opexCap            [1e9 Euro/a]                0.704073
#
#  Results of StorageModel for year 2025
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                  8.217622
#                         TAC                [1e9 Euro/a]                2.800099
#                         capacity           [GW$_{el}$*h]             142.562085
#                         capexCap           [1e9 Euro/a]                2.514975
#                         commissioning      [GW$_{el}$*h]               67.66212
#                         invest             [1e9 Euro]                  10.21698
#                         operationCharge    [GW$_{el}$*h/a]         10149.666661
#                                            [GW$_{el}$*h]           10149.666661
#                         operationDischarge [GW$_{el}$*h/a]          9136.172486
#                                            [GW$_{el}$*h]            9136.172486
#                         opexCap            [1e9 Euro/a]                0.285124
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  2.101707
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   9798.334025
#                                            [GW$_{H_{2},LHV}$*h]     9798.334025
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   9798.334025
#                                            [GW$_{H_{2},LHV}$*h]     9798.334025
#                         opexCap            [1e9 Euro/a]                0.704073
#
#  Results of StorageModel for year 2030
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                 12.911133
#                         TAC                [1e9 Euro/a]                6.464134
#                         capacity           [GW$_{el}$*h]             329.109946
#                         capexCap           [1e9 Euro/a]                5.805915
#                         commissioning      [GW$_{el}$*h]             186.547861
#                         invest             [1e9 Euro]                 28.168727
#                         operationCharge    [GW$_{el}$*h/a]         14749.188611
#                                            [GW$_{el}$*h]           14749.188611
#                         operationDischarge [GW$_{el}$*h/a]         13254.829852
#                                            [GW$_{el}$*h]           13254.829852
#                         opexCap            [1e9 Euro/a]                 0.65822
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  1.430387
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]  10168.882685
#                                            [GW$_{H_{2},LHV}$*h]    10168.882685
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]  10168.882685
#                                            [GW$_{H_{2},LHV}$*h]    10168.882685
#                         opexCap            [1e9 Euro/a]                0.704073

# %% [markdown]
#  Operation color map for Li-ion batteries in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Li-ion batteries",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2020
)

# %% [markdown]
#  Operation color map for Li-ion batteries in Investment Period 2025

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Li-ion batteries",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2025
)

# %% [markdown]
#  Operation color map for Li-ion batteries in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Li-ion batteries",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2030
)

# %% [markdown]
#  Operation color map for Salt caverns (hydrogen) in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (hydrogen)",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2020
)

# %% [markdown]
#  Operation color map for Salt caverns (hydrogen) in Investment Period 2025

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (hydrogen)",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2025
)

# %% [markdown]
#  Operation color map for Salt caverns (hydrogen) in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (hydrogen)",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2030
)
