# %% [markdown]
#  # Workflow for a transformation pathway of a single node energy system with perfect foresight
#
#  In this application of the ETHOS.FINE framework, a transformation pathway of a energy system is modeled and optimized.
#
#  All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
#  The workflow is structures as follows:
#  1. Required packages are imported and the input data path is set
#  2. An energy system model instance is created
#  3. Commodity sources are added to the energy system model
#  4. Commodity conversion components are added to the energy system model
#  5. Commodity storages are added to the energy system model
#  7. Commodity sinks are added to the energy system model
#  8. The energy system model is optimized
#  9. Selected optimization results are presented

# %% [markdown]
#  # 1. Import required packages and set input data path
#
#  The ETHOS.FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import fine as fn
from getData import getData

import os

cwd = os.getcwd()
data = getData()

# %% [markdown]
#  # 2. Create an energy system model instance
#
#  The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
#  The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {"GermanyRegion"}
onlycommodityUnitsDict = {"electricity": r"GW$_{el}$", "hydrogen": r"GW$_{H_{2},LHV}$"}
onlycommodities = {"electricity", "hydrogen"}
onlymaterials={"steel", "copper"}
onlymaterialUnitsDict={"steel": r"tons", "copper": r"tons"}
numberOfTimeSteps = 8760
hoursPerTimeStep = 1

# %% [markdown]
#  # 2.1 define Transformation Pathway parameters
#
#  Transformation Pathway Analyses can be run by setting a number of investment periods
#  larger than 1, which is the default value and results in a single year optimization.

# %%
numberOfInvestmentPeriods=3
startYear=2020
interval=5

# %%
esM = fn.EnergySystemModel(
    locations=locations,
    onlycommodities=onlycommodities,
    onlymaterials=onlymaterials,
    numberOfInvestmentPeriods=numberOfInvestmentPeriods,
    startYear=startYear, 
    investmentPeriodInterval=interval,
    numberOfTimeSteps=8760,
    onlycommodityUnitsDict=onlycommodityUnitsDict,
    onlymaterialUnitsDict=onlymaterialUnitsDict,
    hoursPerTimeStep=1,
    costUnit="1e9 Euro",
    lengthUnit="km",
    verboseLogLevel=0,
)

# %% [markdown]
#  # 3. Add commodity sources to the energy system model

# %% [markdown]
#  ## 3.1. Electricity sources

# %% [markdown]
#  ### Wind onshore

# %% [markdown]
#  change weather conditions for the different investment periods

# %%
operationRateMax={}
operationRateMax[2020]=1.2*data["Wind (onshore), operationRateMax"]
operationRateMax[2025]=0.7*data["Wind (onshore), operationRateMax"]
operationRateMax[2030]=1*data["Wind (onshore), operationRateMax"]

# %% [markdown]
#  define existing stock for wind onshore turbines

# %%
stockWindCommissioning={
    2015:10,
}

# %% [markdown]
#  define invest and opex per capacity for wind onshore turbines

# %%
investPerCapacityWind={
    2015:1.25, 
    2020:1.1, 
    2025:1, 
    2030:0.95
    }

opexPerCapacityWind={
    2015:1.25*0.02, 
    2020:1.1*0.02, 
    2025:1*0.02, 
    2030:0.95*0.02
    }

# %% [markdown]
#  add wind onshore source to esM

# %%
import pandas as pd
esM.add(
    fn.Source(
        esM=esM,
        name="Wind (onshore)",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=investPerCapacityWind,
        opexPerCapacity=opexPerCapacityWind,
        interestRate=0.08,
        economicLifetime=5,
        stockCommissioning=stockWindCommissioning,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({-1:1.1, 0: 3.1, 1: 3.0, 2: 2.9}, dtype='float64'),
                'copper': pd.Series({-1:1.1, 0: 5.3, 1: 5.2, 2: 5.1}, dtype='float64')  
            }
        }, 
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({-1:1.1, 0: 0.9, 1: 0.9, 2: 0.9}, dtype='float64'),
                'copper': pd.Series({-1:1.1, 0: 0.9, 1: 0.9, 2: 0.9}, dtype='float64')  
            }
        }
    )
)

# %% [markdown]
#  Full load hours:

# %%
data["Wind (onshore), operationRateMax"].sum()
# Out:
# 2300.4069071646272

# %% [markdown]
#  # 4. Add conversion components to the energy system model

# %% [markdown]
#  ### New combined cycly gas turbines for hydrogen

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="New CCGT plants (hydrogen)",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": 1, "hydrogen": -1 / 0.6},
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity={2020:0.021, 2025:0.018, 2030:0.025},
        interestRate=0.08,
        economicLifetime=30,
        
    )
)

# %% [markdown]
#  ### Electrolyzers

# %% [markdown]
#  add component with constant invest and opex per capacity

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Electroylzers",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.7},
        hasCapacityVariable=True,
        investPerCapacity=0.5,
        opexPerCapacity=0.5 * 0.025,
        interestRate=0.08,
        economicLifetime=10,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({-1:1.1, 0: 3.1, 1: 3.0, 2: 2.9}, dtype='float64'),
                'copper': pd.Series({-1:1.1, 0: 5.3, 1: 5.2, 2: 5.1}, dtype='float64')  
            }
        }, 
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({-1:1.1, 0: 0.9, 1: 0.9, 2: 0.9}, dtype='float64'),
                'copper': pd.Series({-1:1.1, 0: 0.9, 1: 0.9, 2: 0.9}, dtype='float64')  
            }
        }
    )
)

# %% [markdown]
#  # 5. Add commodity storages to the energy system model

# %% [markdown]
#  ## 5.1. Electricity storage

# %% [markdown]
#  ### Lithium ion batteries
#
#  The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Li-ion batteries",
        commodity="electricity",
        hasCapacityVariable=True,
        chargeEfficiency=0.95,
        cyclicLifetime=10000,
        dischargeEfficiency=0.95,
        selfDischarge=1 - (1 - 0.03) ** (1 / (30 * 24)),
        chargeRate=1,
        dischargeRate=1,
        doPreciseTsaModeling=False,
        investPerCapacity=0.151,
        opexPerCapacity=0.002,
        interestRate=0.08,
        economicLifetime=5,
        materialIntensity = {
            'GermanyRegion': {
                'steel': pd.Series({-1:1.1, 0: 3.1, 1: 3.0, 2: 2.9}, dtype='float64'),
                'copper': pd.Series({-1:1.1, 0: 5.3, 1: 5.2, 2: 5.1}, dtype='float64')  
            }
        }, 
        materialRecovery = {
            'GermanyRegion': {
                'steel': pd.Series({-1:1.1,  0: 0.9, 1: 0.9, 2: 0.9}, dtype='float64'),
                'copper': pd.Series({-1:1.1, 0: 0.9, 1: 0.9, 2: 0.9}, dtype='float64')  
            }
        }
    )
)

# %% [markdown]
#  ## 5.2. Hydrogen storage

# %% [markdown]
#  ### Hydrogen filled salt caverns
#  The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (hydrogen)",
        commodity="hydrogen",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=133,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (hydrogen), capacityMax"],
        investPerCapacity={2020:0.00011,2025: 0.00009,2030:0.00009},
        opexPerCapacity=0.00057,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
#  # 7. Add commodity sinks to the energy system model

# %% [markdown]
#  ## 7.1. Electricity sinks

# %% [markdown]
#  ### Electricity demand

# %% [markdown]
#  vary the demand with the years - increasing demand by 30% per year

# %%
electricityDemand={}
electricityDemand[2020]=(1+0*0.3)*data["Electricity demand, operationRateFix"]
electricityDemand[2025]=(1+1*0.3)*data["Electricity demand, operationRateFix"]
electricityDemand[2030]=(1+2*0.3)*data["Electricity demand, operationRateFix"]

esM.add(
    fn.Sink(
        esM=esM,
        name="Electricity demand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=electricityDemand,
    )
)

# %% [markdown]
#  ## 7.2. Hydrogen sinks

# %% [markdown]
#  ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration = 0.5

# vary the demand with the years - increasing demand by 25% per year
hydrogendDemand={}
hydrogendDemand[2020]=(1+0*0.25)*data["Hydrogen demand, operationRateFix"] * FCEV_penetration
hydrogendDemand[2025]=(1+0*0.25)*data["Hydrogen demand, operationRateFix"] * FCEV_penetration
hydrogendDemand[2030]=(1+0*0.25)*data["Hydrogen demand, operationRateFix"] * FCEV_penetration


esM.add(
    fn.Sink(
        esM=esM,
        name="Hydrogen demand",
        commodity="hydrogen",
        hasCapacityVariable=False,
        operationRateFix=hydrogendDemand,
    )
)

# %%
sink = esM.add(
    fn.Sink(
        esM=esM,
        name="Steel demand",
        hasCapacityVariable=False,
        commodity="steel",
        material=True,      
    )
)

sink = esM.add(
    fn.Sink(
        esM=esM,
        name="Copper demand",
        hasCapacityVariable=False,
        commodity="copper",
        material=True,      
    )
)

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Steel supply",
        hasCapacityVariable=False,
        commodity="steel",
        material=True,      
    )
)
 
esM.add(
    fn.Source(
        esM=esM,
        name="Copper supply",
        hasCapacityVariable=False,
        commodity="copper",
        material=True,      
    )
)

# %% [markdown]
#  # 8. Optimize energy system model

# %% [markdown]
#  All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
esM.aggregateTemporally(numberOfTypicalPeriods=20)
# Out:
# Clustering time series data with 20 typical periods and 24 time steps per period
# further clustered to 12 segments per period...
# 		(7.5805 sec)

# %%
print(dir(esM.pyM))
# Out:
# ['ConstSOCintraPeriodMax_stor', 'ConstSOCintraPeriodMin_stor', 'ConstrBigM_conv', 'ConstrBigM_srcSnk', 'ConstrBigM_stor', 'ConstrCapToNbInt_conv', 'ConstrCapToNbInt_srcSnk', 'ConstrCapToNbInt_stor', 'ConstrCapToNbReal_conv', 'ConstrCapToNbReal_srcSnk', 'ConstrCapToNbReal_stor', 'ConstrCapacityDevelopment_conv', 'ConstrCapacityDevelopment_srcSnk', 'ConstrCapacityDevelopment_stor', 'ConstrCapacityMinDec_conv', 'ConstrCapacityMinDec_srcSnk', 'ConstrCapacityMinDec_stor', 'ConstrCharge1_stor', 'ConstrCharge2_stor', 'ConstrCharge3_stor', 'ConstrConnectSOC_stor', 'ConstrCyclicLifetime_stor', 'ConstrCyclicState_stor', 'ConstrDesignBinFix_conv', 'ConstrDesignBinFix_srcSnk', 'ConstrDesignBinFix_stor', 'ConstrDischarge1_stor', 'ConstrDischarge2_stor', 'ConstrDischarge3_stor', 'ConstrEqualInterSOC_stor', 'ConstrInterSOC_stor', 'ConstrLinkedCapacity_conv', 'ConstrOperation1_conv', 'ConstrOperation1_srcSnk', 'ConstrOperation2_conv', 'ConstrOperation2_srcSnk', 'ConstrOperation3_conv', 'ConstrOperation3_srcSnk', 'ConstrOperation4_conv', 'ConstrOperation4_srcSnk', 'ConstrOperation5_srcSnk', 'ConstrOperation6_srcSnk', 'ConstrOperationCommis1_conv', 'ConstrOperationCommis2_conv', 'ConstrOperationCommis3_conv', 'ConstrOperationCommis4_conv', 'ConstrSOCMaxPrecise_stor', 'ConstrSOCMaxSimple_stor', 'ConstrSOCMinPrecise_stor', 'ConstrSOCMinSimple_stor', 'ConstrYearlyFullLoadHoursMaxCommis_conv', 'ConstrYearlyFullLoadHoursMax_conv', 'ConstrYearlyFullLoadHoursMax_srcSnk', 'ConstrYearlyFullLoadHoursMinCommis_conv', 'ConstrYearlyFullLoadHoursMin_conv', 'ConstrYearlyFullLoadHoursMin_srcSnk', 'ConstrYearlyLimitation_srcSnk', 'ConstraintSharedPotentials', 'DecommConstrCapacityDevelopment_conv', 'DecommConstrCapacityDevelopment_srcSnk', 'DecommConstrCapacityDevelopment_stor', 'DesignLocationComponentVarSet_conv', 'DesignLocationComponentVarSet_srcSnk', 'DesignLocationComponentVarSet_stor', 'InitialYear_conv', 'InitialYear_srcSnk', 'InitialYear_stor', 'IntSinkSet', 'IntSourceSet', 'Obj', 'SinkSet', 'Skip', 'SourceSet', 'StockCommissioning_conv', 'StockCommissioning_srcSnk', 'StockCommissioning_stor', '_BlockData__autoslot_mappers', '_Block_reserved_words', '_ComponentDataClass', '_DEFAULT_INDEX_CHECKING_ENABLED', '_PPRINT_INDENT', '__auto_slots__', '__autoslot_mappers__', '__class__', '__contains__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_active', '_anonymous_sets', '_bfs_iterator', '_compact_decl_storage', '_component', '_component_data_iteritems', '_component_data_itervalues', '_component_typemap', '_construct_from_rule_using_setitem', '_constructed', '_create_objects_for_deepcopy', '_ctype', '_ctypes', '_data', '_decl', '_decl_order', '_declare_reserved_components', '_deepcopy_field', '_dense', '_getitem_when_not_present', '_index', '_index_set', '_initialize_component', '_load_model_data', '_name', '_not_constructed_error', '_parent', '_pop_from_kwargs', '_postfix_dfs_iterator', '_pprint', '_pprint_base_impl', '_pprint_blockdata_components', '_pprint_callback', '_prefix_dfs_iterator', '_private_data', '_private_data_initializers', '_processUnhashableIndex', '_rule', '_setitem_impl', '_setitem_when_not_present', '_validate_index', 'activate', 'active', 'active_blocks', 'active_component_data', 'active_components', 'add_component', 'all_blocks', 'all_component_data', 'all_components', 'block_data_objects', 'cap_conv', 'cap_srcSnk', 'cap_stor', 'chargeOpConstrSet1_stor', 'chargeOpConstrSet2_stor', 'chargeOpConstrSet3_stor', 'chargeOpConstrSet5_int_sink_stor', 'chargeOpConstrSet5_sinks_stor', 'chargeOpConstrSet6_int_source_stor', ...

# %%
esM.optimize(timeSeriesAggregation=True, solver="glpk")
# Out:
# Time series aggregation specifications:
# Number of typical periods:20, number of time steps per period:24, number of segments per period:12
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# SinkSet: [('GermanyRegion', 'Steel demand', 'steel', 0), ('GermanyRegion', 'Steel demand', 'steel', 1), ('GermanyRegion', 'Steel demand', 'steel', 2), ('GermanyRegion', 'Copper demand', 'copper', 0), ('GermanyRegion', 'Copper demand', 'copper', 1), ('GermanyRegion', 'Copper demand', 'copper', 2)]
# IntSinkSet: [('GermanyRegion', 'Wind (onshore)', 'steel', 0), ('GermanyRegion', 'Wind (onshore)', 'copper', 0), ('GermanyRegion', 'Wind (onshore)', 'steel', 1), ('GermanyRegion', 'Wind (onshore)', 'copper', 1), ('GermanyRegion', 'Wind (onshore)', 'steel', 2), ('GermanyRegion', 'Wind (onshore)', 'copper', 2)]
# LHS_sinks op_srcSnk[GermanyRegion,Steel demand,0,0,0] + op_srcSnk[GermanyRegion,Steel demand,0,0,1] + op_srcSnk[GermanyRegion,Steel demand,0,0,2] + op_srcSnk[GermanyRegion,Steel demand,0,0,3] + op_srcSnk[GermanyRegion,Steel demand,0,0,4] + op_srcSnk[GermanyRegion,Steel demand,0,0,5] + op_srcSnk[GermanyRegion,Steel demand,0,0,6] + op_srcSnk[GermanyRegion,Steel demand,0,0,7] + op_srcSnk[GermanyRegion,Steel demand,0,0,8] + op_srcSnk[GermanyRegion,Steel demand,0,0,9] + op_srcSnk[GermanyRegion,Steel demand,0,0,10] + op_srcSnk[GermanyRegion,Steel demand,0,0,11] + op_srcSnk[GermanyRegion,Steel demand,0,1,0] + op_srcSnk[GermanyRegion,Steel demand,0,1,1] + op_srcSnk[GermanyRegion,Steel demand,0,1,2] + op_srcSnk[GermanyRegion,Steel demand,0,1,3] + op_srcSnk[GermanyRegion,Steel demand,0,1,4] + op_srcSnk[GermanyRegion,Steel demand,0,1,5] + op_srcSnk[GermanyRegion,Steel demand,0,1,6] + op_srcSnk[GermanyRegion,Steel demand,0,1,7] + op_srcSnk[GermanyRegion,Steel demand,0,1,8] + op_srcSnk[GermanyRegion,Steel demand,0,1,9] + op_srcSnk[GermanyRegion,Steel demand,0,1,10] + op_srcSnk[GermanyRegion,Steel demand,0,1,11] + op_srcSnk[GermanyRegion,Steel demand,0,2,0] + op_srcSnk[GermanyRegion,Steel demand,0,2,1] + op_srcSnk[GermanyRegion,Steel demand,0,2,2] + op_srcSnk[GermanyRegion,Steel demand,0,2,3] + op_srcSnk[GermanyRegion,Steel demand,0,2,4] + op_srcSnk[GermanyRegion,Steel demand,0,2,5] + op_srcSnk[GermanyRegion,Steel demand,0,2,6] + op_srcSnk[GermanyRegion,Steel demand,0,2,7] + op_srcSnk[GermanyRegion,Steel demand,0,2,8] + op_srcSnk[GermanyRegion,Steel demand,0,2,9] + op_srcSnk[GermanyRegion,Steel demand,0,2,10] + op_srcSnk[GermanyRegion,Steel demand,0,2,11] + op_srcSnk[GermanyRegion,Steel demand,0,3,0] + op_srcSnk[GermanyRegion,Steel demand,0,3,1] + op_srcSnk[GermanyRegion,Steel demand,0,3,2] + op_srcSnk[GermanyRegion,Steel demand,0,3,3] + op_srcSnk[GermanyRegion,Steel demand,0,3,4] + op_srcSnk[GermanyRegion,Steel demand,0,3,5] + op_srcSnk[GermanyRegion,Steel demand,0,3,6] + op_srcSnk[GermanyRegion,Steel demand,0,3,7] + op_srcSnk[GermanyRegion,Steel demand,0,3,8] + op_srcSnk[GermanyRegion,Steel demand,0,3,9] + op_srcSnk[GermanyRegion,Steel demand,0,3,10] + op_srcSnk[GermanyRegion,Steel demand,0,3,11] + op_srcSnk[GermanyRegion,Steel demand,0,4,0] + op_srcSnk[GermanyRegion,Steel demand,0,4,1] + op_srcSnk[GermanyRegion,Steel demand,0,4,2] + op_srcSnk[GermanyRegion,Steel demand,0,4,3] + op_srcSnk[GermanyRegion,Steel demand,0,4,4] + op_srcSnk[GermanyRegion,Steel demand,0,4,5] + op_srcSnk[GermanyRegion,Steel demand,0,4,6] + op_srcSnk[GermanyRegion,Steel demand,0,4,7] + op_srcSnk[GermanyRegion,Steel demand,0,4,8] + op_srcSnk[GermanyRegion,Steel demand,0,4,9] + op_srcSnk[GermanyRegion,Steel demand,0,4,10] + op_srcSnk[GermanyRegion,Steel demand,0,4,11] + op_srcSnk[GermanyRegion,Steel demand,0,5,0] + op_srcSnk[GermanyRegion,Steel demand,0,5,1] + op_srcSnk[GermanyRegion,Steel demand,0,5,2] + op_srcSnk[GermanyRegion,Steel demand,0,5,3] + op_srcSnk[GermanyRegion,Steel demand,0,5,4] + op_srcSnk[GermanyRegion,Steel demand,0,5,5] + op_srcSnk[GermanyRegion,Steel demand,0,5,6] + op_srcSnk[GermanyRegion,Steel demand,0,5,7] + op_srcSnk[GermanyRegion,Steel demand,0,5,8] + op_srcSnk[GermanyRegion,Steel demand,0,5,9] + op_srcSnk[GermanyRegion,Steel demand,0,5,10] + op_srcSnk[GermanyRegion,Steel demand,0,5,11] + op_srcSnk[GermanyRegion,Steel demand,0,6,0] + op_srcSnk[GermanyRegion,Steel demand,0,6,1] + op_srcSnk[GermanyRegion,Steel demand,0,6,2] + op_srcSnk[GermanyRegion,Steel demand,0,6,3] + op_srcSnk[GermanyRegion,Steel demand,0,6,4] + op_srcSnk[GermanyRegion,Steel demand,0,6,5] + op_srcSnk[GermanyRegion,Steel demand,0,6,6] + op_srcSnk[GermanyRegion,Steel demand,0,6,7] + op_srcSnk[GermanyRegion,Steel demand,0,6,8] + op_srcSnk[GermanyRegion,Steel demand,0,6,9] + op_srcSnk[GermanyRegion,Steel demand,0,6,10] + op_srcSnk[GermanyRegion,Steel demand,0,6,11] + op_srcSnk[GermanyRegion,Steel demand,0,7,0] + op_srcSnk[GermanyRegion,Steel demand,0,7,1] + op_srcSnk[GermanyReg ...
# RHS_sinks 3.1*commis_srcSnk[GermanyRegion,'Wind (onshore)',0]
# LHS_sinks op_srcSnk[GermanyRegion,Steel demand,1,0,0] + op_srcSnk[GermanyRegion,Steel demand,1,0,1] + op_srcSnk[GermanyRegion,Steel demand,1,0,2] + op_srcSnk[GermanyRegion,Steel demand,1,0,3] + op_srcSnk[GermanyRegion,Steel demand,1,0,4] + op_srcSnk[GermanyRegion,Steel demand,1,0,5] + op_srcSnk[GermanyRegion,Steel demand,1,0,6] + op_srcSnk[GermanyRegion,Steel demand,1,0,7] + op_srcSnk[GermanyRegion,Steel demand,1,0,8] + op_srcSnk[GermanyRegion,Steel demand,1,0,9] + op_srcSnk[GermanyRegion,Steel demand,1,0,10] + op_srcSnk[GermanyRegion,Steel demand,1,0,11] + op_srcSnk[GermanyRegion,Steel demand,1,1,0] + op_srcSnk[GermanyRegion,Steel demand,1,1,1] + op_srcSnk[GermanyRegion,Steel demand,1,1,2] + op_srcSnk[GermanyRegion,Steel demand,1,1,3] + op_srcSnk[GermanyRegion,Steel demand,1,1,4] + op_srcSnk[GermanyRegion,Steel demand,1,1,5] + op_srcSnk[GermanyRegion,Steel demand,1,1,6] + op_srcSnk[GermanyRegion,Steel demand,1,1,7] + op_srcSnk[GermanyRegion,Steel demand,1,1,8] + op_srcSnk[GermanyRegion,Steel demand,1,1,9] + op_srcSnk[GermanyRegion,Steel demand,1,1,10] + op_srcSnk[GermanyRegion,Steel demand,1,1,11] + op_srcSnk[GermanyRegion,Steel demand,1,2,0] + op_srcSnk[GermanyRegion,Steel demand,1,2,1] + op_srcSnk[GermanyRegion,Steel demand,1,2,2] + op_srcSnk[GermanyRegion,Steel demand,1,2,3] + op_srcSnk[GermanyRegion,Steel demand,1,2,4] + op_srcSnk[GermanyRegion,Steel demand,1,2,5] + op_srcSnk[GermanyRegion,Steel demand,1,2,6] + op_srcSnk[GermanyRegion,Steel demand,1,2,7] + op_srcSnk[GermanyRegion,Steel demand,1,2,8] + op_srcSnk[GermanyRegion,Steel demand,1,2,9] + op_srcSnk[GermanyRegion,Steel demand,1,2,10] + op_srcSnk[GermanyRegion,Steel demand,1,2,11] + op_srcSnk[GermanyRegion,Steel demand,1,3,0] + op_srcSnk[GermanyRegion,Steel demand,1,3,1] + op_srcSnk[GermanyRegion,Steel demand,1,3,2] + op_srcSnk[GermanyRegion,Steel demand,1,3,3] + op_srcSnk[GermanyRegion,Steel demand,1,3,4] + op_srcSnk[GermanyRegion,Steel demand,1,3,5] + op_srcSnk[GermanyRegion,Steel demand,1,3,6] + op_srcSnk[GermanyRegion,Steel demand,1,3,7] + op_srcSnk[GermanyRegion,Steel demand,1,3,8] + op_srcSnk[GermanyRegion,Steel demand,1,3,9] + op_srcSnk[GermanyRegion,Steel demand,1,3,10] + op_srcSnk[GermanyRegion,Steel demand,1,3,11] + op_srcSnk[GermanyRegion,Steel demand,1,4,0] + op_srcSnk[GermanyRegion,Steel demand,1,4,1] + op_srcSnk[GermanyRegion,Steel demand,1,4,2] + op_srcSnk[GermanyRegion,Steel demand,1,4,3] + op_srcSnk[GermanyRegion,Steel demand,1,4,4] + op_srcSnk[GermanyRegion,Steel demand,1,4,5] + op_srcSnk[GermanyRegion,Steel demand,1,4,6] + op_srcSnk[GermanyRegion,Steel demand,1,4,7] + op_srcSnk[GermanyRegion,Steel demand,1,4,8] + op_srcSnk[GermanyRegion,Steel demand,1,4,9] + op_srcSnk[GermanyRegion,Steel demand,1,4,10] + op_srcSnk[GermanyRegion,Steel demand,1,4,11] + op_srcSnk[GermanyRegion,Steel demand,1,5,0] + op_srcSnk[GermanyRegion,Steel demand,1,5,1] + op_srcSnk[GermanyRegion,Steel demand,1,5,2] + op_srcSnk[GermanyRegion,Steel demand,1,5,3] + op_srcSnk[GermanyRegion,Steel demand,1,5,4] + op_srcSnk[GermanyRegion,Steel demand,1,5,5] + op_srcSnk[GermanyRegion,Steel demand,1,5,6] + op_srcSnk[GermanyRegion,Steel demand,1,5,7] + op_srcSnk[GermanyRegion,Steel demand,1,5,8] + op_srcSnk[GermanyRegion,Steel demand,1,5,9] + op_srcSnk[GermanyRegion,Steel demand,1,5,10] + op_srcSnk[GermanyRegion,Steel demand,1,5,11] + op_srcSnk[GermanyRegion,Steel demand,1,6,0] + op_srcSnk[GermanyRegion,Steel demand,1,6,1] + op_srcSnk[GermanyRegion,Steel demand,1,6,2] + op_srcSnk[GermanyRegion,Steel demand,1,6,3] + op_srcSnk[GermanyRegion,Steel demand,1,6,4] + op_srcSnk[GermanyRegion,Steel demand,1,6,5] + op_srcSnk[GermanyRegion,Steel demand,1,6,6] + op_srcSnk[GermanyRegion,Steel demand,1,6,7] + op_srcSnk[GermanyRegion,Steel demand,1,6,8] + op_srcSnk[GermanyRegion,Steel demand,1,6,9] + op_srcSnk[GermanyRegion,Steel demand,1,6,10] + op_srcSnk[GermanyRegion,Steel demand,1,6,11] + op_srcSnk[GermanyRegion,Steel demand,1,7,0] + op_srcSnk[GermanyRegion,Steel demand,1,7,1] + op_srcSnk[GermanyReg ...
# RHS_sinks 3.0*commis_srcSnk[GermanyRegion,'Wind (onshore)',1]
# LHS_sinks op_srcSnk[GermanyRegion,Steel demand,2,0,0] + op_srcSnk[GermanyRegion,Steel demand,2,0,1] + op_srcSnk[GermanyRegion,Steel demand,2,0,2] + op_srcSnk[GermanyRegion,Steel demand,2,0,3] + op_srcSnk[GermanyRegion,Steel demand,2,0,4] + op_srcSnk[GermanyRegion,Steel demand,2,0,5] + op_srcSnk[GermanyRegion,Steel demand,2,0,6] + op_srcSnk[GermanyRegion,Steel demand,2,0,7] + op_srcSnk[GermanyRegion,Steel demand,2,0,8] + op_srcSnk[GermanyRegion,Steel demand,2,0,9] + op_srcSnk[GermanyRegion,Steel demand,2,0,10] + op_srcSnk[GermanyRegion,Steel demand,2,0,11] + op_srcSnk[GermanyRegion,Steel demand,2,1,0] + op_srcSnk[GermanyRegion,Steel demand,2,1,1] + op_srcSnk[GermanyRegion,Steel demand,2,1,2] + op_srcSnk[GermanyRegion,Steel demand,2,1,3] + op_srcSnk[GermanyRegion,Steel demand,2,1,4] + op_srcSnk[GermanyRegion,Steel demand,2,1,5] + op_srcSnk[GermanyRegion,Steel demand,2,1,6] + op_srcSnk[GermanyRegion,Steel demand,2,1,7] + op_srcSnk[GermanyRegion,Steel demand,2,1,8] + op_srcSnk[GermanyRegion,Steel demand,2,1,9] + op_srcSnk[GermanyRegion,Steel demand,2,1,10] + op_srcSnk[GermanyRegion,Steel demand,2,1,11] + op_srcSnk[GermanyRegion,Steel demand,2,2,0] + op_srcSnk[GermanyRegion,Steel demand,2,2,1] + op_srcSnk[GermanyRegion,Steel demand,2,2,2] + op_srcSnk[GermanyRegion,Steel demand,2,2,3] + op_srcSnk[GermanyRegion,Steel demand,2,2,4] + op_srcSnk[GermanyRegion,Steel demand,2,2,5] + op_srcSnk[GermanyRegion,Steel demand,2,2,6] + op_srcSnk[GermanyRegion,Steel demand,2,2,7] + op_srcSnk[GermanyRegion,Steel demand,2,2,8] + op_srcSnk[GermanyRegion,Steel demand,2,2,9] + op_srcSnk[GermanyRegion,Steel demand,2,2,10] + op_srcSnk[GermanyRegion,Steel demand,2,2,11] + op_srcSnk[GermanyRegion,Steel demand,2,3,0] + op_srcSnk[GermanyRegion,Steel demand,2,3,1] + op_srcSnk[GermanyRegion,Steel demand,2,3,2] + op_srcSnk[GermanyRegion,Steel demand,2,3,3] + op_srcSnk[GermanyRegion,Steel demand,2,3,4] + op_srcSnk[GermanyRegion,Steel demand,2,3,5] + op_srcSnk[GermanyRegion,Steel demand,2,3,6] + op_srcSnk[GermanyRegion,Steel demand,2,3,7] + op_srcSnk[GermanyRegion,Steel demand,2,3,8] + op_srcSnk[GermanyRegion,Steel demand,2,3,9] + op_srcSnk[GermanyRegion,Steel demand,2,3,10] + op_srcSnk[GermanyRegion,Steel demand,2,3,11] + op_srcSnk[GermanyRegion,Steel demand,2,4,0] + op_srcSnk[GermanyRegion,Steel demand,2,4,1] + op_srcSnk[GermanyRegion,Steel demand,2,4,2] + op_srcSnk[GermanyRegion,Steel demand,2,4,3] + op_srcSnk[GermanyRegion,Steel demand,2,4,4] + op_srcSnk[GermanyRegion,Steel demand,2,4,5] + op_srcSnk[GermanyRegion,Steel demand,2,4,6] + op_srcSnk[GermanyRegion,Steel demand,2,4,7] + op_srcSnk[GermanyRegion,Steel demand,2,4,8] + op_srcSnk[GermanyRegion,Steel demand,2,4,9] + op_srcSnk[GermanyRegion,Steel demand,2,4,10] + op_srcSnk[GermanyRegion,Steel demand,2,4,11] + op_srcSnk[GermanyRegion,Steel demand,2,5,0] + op_srcSnk[GermanyRegion,Steel demand,2,5,1] + op_srcSnk[GermanyRegion,Steel demand,2,5,2] + op_srcSnk[GermanyRegion,Steel demand,2,5,3] + op_srcSnk[GermanyRegion,Steel demand,2,5,4] + op_srcSnk[GermanyRegion,Steel demand,2,5,5] + op_srcSnk[GermanyRegion,Steel demand,2,5,6] + op_srcSnk[GermanyRegion,Steel demand,2,5,7] + op_srcSnk[GermanyRegion,Steel demand,2,5,8] + op_srcSnk[GermanyRegion,Steel demand,2,5,9] + op_srcSnk[GermanyRegion,Steel demand,2,5,10] + op_srcSnk[GermanyRegion,Steel demand,2,5,11] + op_srcSnk[GermanyRegion,Steel demand,2,6,0] + op_srcSnk[GermanyRegion,Steel demand,2,6,1] + op_srcSnk[GermanyRegion,Steel demand,2,6,2] + op_srcSnk[GermanyRegion,Steel demand,2,6,3] + op_srcSnk[GermanyRegion,Steel demand,2,6,4] + op_srcSnk[GermanyRegion,Steel demand,2,6,5] + op_srcSnk[GermanyRegion,Steel demand,2,6,6] + op_srcSnk[GermanyRegion,Steel demand,2,6,7] + op_srcSnk[GermanyRegion,Steel demand,2,6,8] + op_srcSnk[GermanyRegion,Steel demand,2,6,9] + op_srcSnk[GermanyRegion,Steel demand,2,6,10] + op_srcSnk[GermanyRegion,Steel demand,2,6,11] + op_srcSnk[GermanyRegion,Steel demand,2,7,0] + op_srcSnk[GermanyRegion,Steel demand,2,7,1] + op_srcSnk[GermanyReg ...
# RHS_sinks 2.9*commis_srcSnk[GermanyRegion,'Wind (onshore)',2]
# LHS_sinks op_srcSnk[GermanyRegion,Copper demand,0,0,0] + op_srcSnk[GermanyRegion,Copper demand,0,0,1] + op_srcSnk[GermanyRegion,Copper demand,0,0,2] + op_srcSnk[GermanyRegion,Copper demand,0,0,3] + op_srcSnk[GermanyRegion,Copper demand,0,0,4] + op_srcSnk[GermanyRegion,Copper demand,0,0,5] + op_srcSnk[GermanyRegion,Copper demand,0,0,6] + op_srcSnk[GermanyRegion,Copper demand,0,0,7] + op_srcSnk[GermanyRegion,Copper demand,0,0,8] + op_srcSnk[GermanyRegion,Copper demand,0,0,9] + op_srcSnk[GermanyRegion,Copper demand,0,0,10] + op_srcSnk[GermanyRegion,Copper demand,0,0,11] + op_srcSnk[GermanyRegion,Copper demand,0,1,0] + op_srcSnk[GermanyRegion,Copper demand,0,1,1] + op_srcSnk[GermanyRegion,Copper demand,0,1,2] + op_srcSnk[GermanyRegion,Copper demand,0,1,3] + op_srcSnk[GermanyRegion,Copper demand,0,1,4] + op_srcSnk[GermanyRegion,Copper demand,0,1,5] + op_srcSnk[GermanyRegion,Copper demand,0,1,6] + op_srcSnk[GermanyRegion,Copper demand,0,1,7] + op_srcSnk[GermanyRegion,Copper demand,0,1,8] + op_srcSnk[GermanyRegion,Copper demand,0,1,9] + op_srcSnk[GermanyRegion,Copper demand,0,1,10] + op_srcSnk[GermanyRegion,Copper demand,0,1,11] + op_srcSnk[GermanyRegion,Copper demand,0,2,0] + op_srcSnk[GermanyRegion,Copper demand,0,2,1] + op_srcSnk[GermanyRegion,Copper demand,0,2,2] + op_srcSnk[GermanyRegion,Copper demand,0,2,3] + op_srcSnk[GermanyRegion,Copper demand,0,2,4] + op_srcSnk[GermanyRegion,Copper demand,0,2,5] + op_srcSnk[GermanyRegion,Copper demand,0,2,6] + op_srcSnk[GermanyRegion,Copper demand,0,2,7] + op_srcSnk[GermanyRegion,Copper demand,0,2,8] + op_srcSnk[GermanyRegion,Copper demand,0,2,9] + op_srcSnk[GermanyRegion,Copper demand,0,2,10] + op_srcSnk[GermanyRegion,Copper demand,0,2,11] + op_srcSnk[GermanyRegion,Copper demand,0,3,0] + op_srcSnk[GermanyRegion,Copper demand,0,3,1] + op_srcSnk[GermanyRegion,Copper demand,0,3,2] + op_srcSnk[GermanyRegion,Copper demand,0,3,3] + op_srcSnk[GermanyRegion,Copper demand,0,3,4] + op_srcSnk[GermanyRegion,Copper demand,0,3,5] + op_srcSnk[GermanyRegion,Copper demand,0,3,6] + op_srcSnk[GermanyRegion,Copper demand,0,3,7] + op_srcSnk[GermanyRegion,Copper demand,0,3,8] + op_srcSnk[GermanyRegion,Copper demand,0,3,9] + op_srcSnk[GermanyRegion,Copper demand,0,3,10] + op_srcSnk[GermanyRegion,Copper demand,0,3,11] + op_srcSnk[GermanyRegion,Copper demand,0,4,0] + op_srcSnk[GermanyRegion,Copper demand,0,4,1] + op_srcSnk[GermanyRegion,Copper demand,0,4,2] + op_srcSnk[GermanyRegion,Copper demand,0,4,3] + op_srcSnk[GermanyRegion,Copper demand,0,4,4] + op_srcSnk[GermanyRegion,Copper demand,0,4,5] + op_srcSnk[GermanyRegion,Copper demand,0,4,6] + op_srcSnk[GermanyRegion,Copper demand,0,4,7] + op_srcSnk[GermanyRegion,Copper demand,0,4,8] + op_srcSnk[GermanyRegion,Copper demand,0,4,9] + op_srcSnk[GermanyRegion,Copper demand,0,4,10] + op_srcSnk[GermanyRegion,Copper demand,0,4,11] + op_srcSnk[GermanyRegion,Copper demand,0,5,0] + op_srcSnk[GermanyRegion,Copper demand,0,5,1] + op_srcSnk[GermanyRegion,Copper demand,0,5,2] + op_srcSnk[GermanyRegion,Copper demand,0,5,3] + op_srcSnk[GermanyRegion,Copper demand,0,5,4] + op_srcSnk[GermanyRegion,Copper demand,0,5,5] + op_srcSnk[GermanyRegion,Copper demand,0,5,6] + op_srcSnk[GermanyRegion,Copper demand,0,5,7] + op_srcSnk[GermanyRegion,Copper demand,0,5,8] + op_srcSnk[GermanyRegion,Copper demand,0,5,9] + op_srcSnk[GermanyRegion,Copper demand,0,5,10] + op_srcSnk[GermanyRegion,Copper demand,0,5,11] + op_srcSnk[GermanyRegion,Copper demand,0,6,0] + op_srcSnk[GermanyRegion,Copper demand,0,6,1] + op_srcSnk[GermanyRegion,Copper demand,0,6,2] + op_srcSnk[GermanyRegion,Copper demand,0,6,3] + op_srcSnk[GermanyRegion,Copper demand,0,6,4] + op_srcSnk[GermanyRegion,Copper demand,0,6,5] + op_srcSnk[GermanyRegion,Copper demand,0,6,6] + op_srcSnk[GermanyRegion,Copper demand,0,6,7] + op_srcSnk[GermanyRegion,Copper demand,0,6,8] + op_srcSnk[GermanyRegion,Copper demand,0,6,9] + op_srcSnk[GermanyRegion,Copper demand,0,6,10] + op_srcSnk[GermanyRegion,Copper demand,0,6,11] + op_srcSnk[GermanyRegion,Copp ...
# RHS_sinks 5.3*commis_srcSnk[GermanyRegion,'Wind (onshore)',0]
# LHS_sinks op_srcSnk[GermanyRegion,Copper demand,1,0,0] + op_srcSnk[GermanyRegion,Copper demand,1,0,1] + op_srcSnk[GermanyRegion,Copper demand,1,0,2] + op_srcSnk[GermanyRegion,Copper demand,1,0,3] + op_srcSnk[GermanyRegion,Copper demand,1,0,4] + op_srcSnk[GermanyRegion,Copper demand,1,0,5] + op_srcSnk[GermanyRegion,Copper demand,1,0,6] + op_srcSnk[GermanyRegion,Copper demand,1,0,7] + op_srcSnk[GermanyRegion,Copper demand,1,0,8] + op_srcSnk[GermanyRegion,Copper demand,1,0,9] + op_srcSnk[GermanyRegion,Copper demand,1,0,10] + op_srcSnk[GermanyRegion,Copper demand,1,0,11] + op_srcSnk[GermanyRegion,Copper demand,1,1,0] + op_srcSnk[GermanyRegion,Copper demand,1,1,1] + op_srcSnk[GermanyRegion,Copper demand,1,1,2] + op_srcSnk[GermanyRegion,Copper demand,1,1,3] + op_srcSnk[GermanyRegion,Copper demand,1,1,4] + op_srcSnk[GermanyRegion,Copper demand,1,1,5] + op_srcSnk[GermanyRegion,Copper demand,1,1,6] + op_srcSnk[GermanyRegion,Copper demand,1,1,7] + op_srcSnk[GermanyRegion,Copper demand,1,1,8] + op_srcSnk[GermanyRegion,Copper demand,1,1,9] + op_srcSnk[GermanyRegion,Copper demand,1,1,10] + op_srcSnk[GermanyRegion,Copper demand,1,1,11] + op_srcSnk[GermanyRegion,Copper demand,1,2,0] + op_srcSnk[GermanyRegion,Copper demand,1,2,1] + op_srcSnk[GermanyRegion,Copper demand,1,2,2] + op_srcSnk[GermanyRegion,Copper demand,1,2,3] + op_srcSnk[GermanyRegion,Copper demand,1,2,4] + op_srcSnk[GermanyRegion,Copper demand,1,2,5] + op_srcSnk[GermanyRegion,Copper demand,1,2,6] + op_srcSnk[GermanyRegion,Copper demand,1,2,7] + op_srcSnk[GermanyRegion,Copper demand,1,2,8] + op_srcSnk[GermanyRegion,Copper demand,1,2,9] + op_srcSnk[GermanyRegion,Copper demand,1,2,10] + op_srcSnk[GermanyRegion,Copper demand,1,2,11] + op_srcSnk[GermanyRegion,Copper demand,1,3,0] + op_srcSnk[GermanyRegion,Copper demand,1,3,1] + op_srcSnk[GermanyRegion,Copper demand,1,3,2] + op_srcSnk[GermanyRegion,Copper demand,1,3,3] + op_srcSnk[GermanyRegion,Copper demand,1,3,4] + op_srcSnk[GermanyRegion,Copper demand,1,3,5] + op_srcSnk[GermanyRegion,Copper demand,1,3,6] + op_srcSnk[GermanyRegion,Copper demand,1,3,7] + op_srcSnk[GermanyRegion,Copper demand,1,3,8] + op_srcSnk[GermanyRegion,Copper demand,1,3,9] + op_srcSnk[GermanyRegion,Copper demand,1,3,10] + op_srcSnk[GermanyRegion,Copper demand,1,3,11] + op_srcSnk[GermanyRegion,Copper demand,1,4,0] + op_srcSnk[GermanyRegion,Copper demand,1,4,1] + op_srcSnk[GermanyRegion,Copper demand,1,4,2] + op_srcSnk[GermanyRegion,Copper demand,1,4,3] + op_srcSnk[GermanyRegion,Copper demand,1,4,4] + op_srcSnk[GermanyRegion,Copper demand,1,4,5] + op_srcSnk[GermanyRegion,Copper demand,1,4,6] + op_srcSnk[GermanyRegion,Copper demand,1,4,7] + op_srcSnk[GermanyRegion,Copper demand,1,4,8] + op_srcSnk[GermanyRegion,Copper demand,1,4,9] + op_srcSnk[GermanyRegion,Copper demand,1,4,10] + op_srcSnk[GermanyRegion,Copper demand,1,4,11] + op_srcSnk[GermanyRegion,Copper demand,1,5,0] + op_srcSnk[GermanyRegion,Copper demand,1,5,1] + op_srcSnk[GermanyRegion,Copper demand,1,5,2] + op_srcSnk[GermanyRegion,Copper demand,1,5,3] + op_srcSnk[GermanyRegion,Copper demand,1,5,4] + op_srcSnk[GermanyRegion,Copper demand,1,5,5] + op_srcSnk[GermanyRegion,Copper demand,1,5,6] + op_srcSnk[GermanyRegion,Copper demand,1,5,7] + op_srcSnk[GermanyRegion,Copper demand,1,5,8] + op_srcSnk[GermanyRegion,Copper demand,1,5,9] + op_srcSnk[GermanyRegion,Copper demand,1,5,10] + op_srcSnk[GermanyRegion,Copper demand,1,5,11] + op_srcSnk[GermanyRegion,Copper demand,1,6,0] + op_srcSnk[GermanyRegion,Copper demand,1,6,1] + op_srcSnk[GermanyRegion,Copper demand,1,6,2] + op_srcSnk[GermanyRegion,Copper demand,1,6,3] + op_srcSnk[GermanyRegion,Copper demand,1,6,4] + op_srcSnk[GermanyRegion,Copper demand,1,6,5] + op_srcSnk[GermanyRegion,Copper demand,1,6,6] + op_srcSnk[GermanyRegion,Copper demand,1,6,7] + op_srcSnk[GermanyRegion,Copper demand,1,6,8] + op_srcSnk[GermanyRegion,Copper demand,1,6,9] + op_srcSnk[GermanyRegion,Copper demand,1,6,10] + op_srcSnk[GermanyRegion,Copper demand,1,6,11] + op_srcSnk[GermanyRegion,Copp ...
# RHS_sinks 5.2*commis_srcSnk[GermanyRegion,'Wind (onshore)',1]
# LHS_sinks op_srcSnk[GermanyRegion,Copper demand,2,0,0] + op_srcSnk[GermanyRegion,Copper demand,2,0,1] + op_srcSnk[GermanyRegion,Copper demand,2,0,2] + op_srcSnk[GermanyRegion,Copper demand,2,0,3] + op_srcSnk[GermanyRegion,Copper demand,2,0,4] + op_srcSnk[GermanyRegion,Copper demand,2,0,5] + op_srcSnk[GermanyRegion,Copper demand,2,0,6] + op_srcSnk[GermanyRegion,Copper demand,2,0,7] + op_srcSnk[GermanyRegion,Copper demand,2,0,8] + op_srcSnk[GermanyRegion,Copper demand,2,0,9] + op_srcSnk[GermanyRegion,Copper demand,2,0,10] + op_srcSnk[GermanyRegion,Copper demand,2,0,11] + op_srcSnk[GermanyRegion,Copper demand,2,1,0] + op_srcSnk[GermanyRegion,Copper demand,2,1,1] + op_srcSnk[GermanyRegion,Copper demand,2,1,2] + op_srcSnk[GermanyRegion,Copper demand,2,1,3] + op_srcSnk[GermanyRegion,Copper demand,2,1,4] + op_srcSnk[GermanyRegion,Copper demand,2,1,5] + op_srcSnk[GermanyRegion,Copper demand,2,1,6] + op_srcSnk[GermanyRegion,Copper demand,2,1,7] + op_srcSnk[GermanyRegion,Copper demand,2,1,8] + op_srcSnk[GermanyRegion,Copper demand,2,1,9] + op_srcSnk[GermanyRegion,Copper demand,2,1,10] + op_srcSnk[GermanyRegion,Copper demand,2,1,11] + op_srcSnk[GermanyRegion,Copper demand,2,2,0] + op_srcSnk[GermanyRegion,Copper demand,2,2,1] + op_srcSnk[GermanyRegion,Copper demand,2,2,2] + op_srcSnk[GermanyRegion,Copper demand,2,2,3] + op_srcSnk[GermanyRegion,Copper demand,2,2,4] + op_srcSnk[GermanyRegion,Copper demand,2,2,5] + op_srcSnk[GermanyRegion,Copper demand,2,2,6] + op_srcSnk[GermanyRegion,Copper demand,2,2,7] + op_srcSnk[GermanyRegion,Copper demand,2,2,8] + op_srcSnk[GermanyRegion,Copper demand,2,2,9] + op_srcSnk[GermanyRegion,Copper demand,2,2,10] + op_srcSnk[GermanyRegion,Copper demand,2,2,11] + op_srcSnk[GermanyRegion,Copper demand,2,3,0] + op_srcSnk[GermanyRegion,Copper demand,2,3,1] + op_srcSnk[GermanyRegion,Copper demand,2,3,2] + op_srcSnk[GermanyRegion,Copper demand,2,3,3] + op_srcSnk[GermanyRegion,Copper demand,2,3,4] + op_srcSnk[GermanyRegion,Copper demand,2,3,5] + op_srcSnk[GermanyRegion,Copper demand,2,3,6] + op_srcSnk[GermanyRegion,Copper demand,2,3,7] + op_srcSnk[GermanyRegion,Copper demand,2,3,8] + op_srcSnk[GermanyRegion,Copper demand,2,3,9] + op_srcSnk[GermanyRegion,Copper demand,2,3,10] + op_srcSnk[GermanyRegion,Copper demand,2,3,11] + op_srcSnk[GermanyRegion,Copper demand,2,4,0] + op_srcSnk[GermanyRegion,Copper demand,2,4,1] + op_srcSnk[GermanyRegion,Copper demand,2,4,2] + op_srcSnk[GermanyRegion,Copper demand,2,4,3] + op_srcSnk[GermanyRegion,Copper demand,2,4,4] + op_srcSnk[GermanyRegion,Copper demand,2,4,5] + op_srcSnk[GermanyRegion,Copper demand,2,4,6] + op_srcSnk[GermanyRegion,Copper demand,2,4,7] + op_srcSnk[GermanyRegion,Copper demand,2,4,8] + op_srcSnk[GermanyRegion,Copper demand,2,4,9] + op_srcSnk[GermanyRegion,Copper demand,2,4,10] + op_srcSnk[GermanyRegion,Copper demand,2,4,11] + op_srcSnk[GermanyRegion,Copper demand,2,5,0] + op_srcSnk[GermanyRegion,Copper demand,2,5,1] + op_srcSnk[GermanyRegion,Copper demand,2,5,2] + op_srcSnk[GermanyRegion,Copper demand,2,5,3] + op_srcSnk[GermanyRegion,Copper demand,2,5,4] + op_srcSnk[GermanyRegion,Copper demand,2,5,5] + op_srcSnk[GermanyRegion,Copper demand,2,5,6] + op_srcSnk[GermanyRegion,Copper demand,2,5,7] + op_srcSnk[GermanyRegion,Copper demand,2,5,8] + op_srcSnk[GermanyRegion,Copper demand,2,5,9] + op_srcSnk[GermanyRegion,Copper demand,2,5,10] + op_srcSnk[GermanyRegion,Copper demand,2,5,11] + op_srcSnk[GermanyRegion,Copper demand,2,6,0] + op_srcSnk[GermanyRegion,Copper demand,2,6,1] + op_srcSnk[GermanyRegion,Copper demand,2,6,2] + op_srcSnk[GermanyRegion,Copper demand,2,6,3] + op_srcSnk[GermanyRegion,Copper demand,2,6,4] + op_srcSnk[GermanyRegion,Copper demand,2,6,5] + op_srcSnk[GermanyRegion,Copper demand,2,6,6] + op_srcSnk[GermanyRegion,Copper demand,2,6,7] + op_srcSnk[GermanyRegion,Copper demand,2,6,8] + op_srcSnk[GermanyRegion,Copper demand,2,6,9] + op_srcSnk[GermanyRegion,Copper demand,2,6,10] + op_srcSnk[GermanyRegion,Copper demand,2,6,11] + op_srcSnk[GermanyRegion,Copp ...
# RHS_sinks 5.1*commis_srcSnk[GermanyRegion,'Wind (onshore)',2]
# SourceSet: [('GermanyRegion', 'Steel supply', 'steel', 0), ('GermanyRegion', 'Steel supply', 'steel', 1), ('GermanyRegion', 'Steel supply', 'steel', 2), ('GermanyRegion', 'Copper supply', 'copper', 0), ('GermanyRegion', 'Copper supply', 'copper', 1), ('GermanyRegion', 'Copper supply', 'copper', 2)]
# IntSourceSet: [('GermanyRegion', 'Wind (onshore)', 'steel', 0), ('GermanyRegion', 'Wind (onshore)', 'copper', 0), ('GermanyRegion', 'Wind (onshore)', 'steel', 1), ('GermanyRegion', 'Wind (onshore)', 'copper', 1), ('GermanyRegion', 'Wind (onshore)', 'steel', 2), ('GermanyRegion', 'Wind (onshore)', 'copper', 2)]
# LHS_sources op_srcSnk[GermanyRegion,Steel supply,0,0,0] + op_srcSnk[GermanyRegion,Steel supply,0,0,1] + op_srcSnk[GermanyRegion,Steel supply,0,0,2] + op_srcSnk[GermanyRegion,Steel supply,0,0,3] + op_srcSnk[GermanyRegion,Steel supply,0,0,4] + op_srcSnk[GermanyRegion,Steel supply,0,0,5] + op_srcSnk[GermanyRegion,Steel supply,0,0,6] + op_srcSnk[GermanyRegion,Steel supply,0,0,7] + op_srcSnk[GermanyRegion,Steel supply,0,0,8] + op_srcSnk[GermanyRegion,Steel supply,0,0,9] + op_srcSnk[GermanyRegion,Steel supply,0,0,10] + op_srcSnk[GermanyRegion,Steel supply,0,0,11] + op_srcSnk[GermanyRegion,Steel supply,0,1,0] + op_srcSnk[GermanyRegion,Steel supply,0,1,1] + op_srcSnk[GermanyRegion,Steel supply,0,1,2] + op_srcSnk[GermanyRegion,Steel supply,0,1,3] + op_srcSnk[GermanyRegion,Steel supply,0,1,4] + op_srcSnk[GermanyRegion,Steel supply,0,1,5] + op_srcSnk[GermanyRegion,Steel supply,0,1,6] + op_srcSnk[GermanyRegion,Steel supply,0,1,7] + op_srcSnk[GermanyRegion,Steel supply,0,1,8] + op_srcSnk[GermanyRegion,Steel supply,0,1,9] + op_srcSnk[GermanyRegion,Steel supply,0,1,10] + op_srcSnk[GermanyRegion,Steel supply,0,1,11] + op_srcSnk[GermanyRegion,Steel supply,0,2,0] + op_srcSnk[GermanyRegion,Steel supply,0,2,1] + op_srcSnk[GermanyRegion,Steel supply,0,2,2] + op_srcSnk[GermanyRegion,Steel supply,0,2,3] + op_srcSnk[GermanyRegion,Steel supply,0,2,4] + op_srcSnk[GermanyRegion,Steel supply,0,2,5] + op_srcSnk[GermanyRegion,Steel supply,0,2,6] + op_srcSnk[GermanyRegion,Steel supply,0,2,7] + op_srcSnk[GermanyRegion,Steel supply,0,2,8] + op_srcSnk[GermanyRegion,Steel supply,0,2,9] + op_srcSnk[GermanyRegion,Steel supply,0,2,10] + op_srcSnk[GermanyRegion,Steel supply,0,2,11] + op_srcSnk[GermanyRegion,Steel supply,0,3,0] + op_srcSnk[GermanyRegion,Steel supply,0,3,1] + op_srcSnk[GermanyRegion,Steel supply,0,3,2] + op_srcSnk[GermanyRegion,Steel supply,0,3,3] + op_srcSnk[GermanyRegion,Steel supply,0,3,4] + op_srcSnk[GermanyRegion,Steel supply,0,3,5] + op_srcSnk[GermanyRegion,Steel supply,0,3,6] + op_srcSnk[GermanyRegion,Steel supply,0,3,7] + op_srcSnk[GermanyRegion,Steel supply,0,3,8] + op_srcSnk[GermanyRegion,Steel supply,0,3,9] + op_srcSnk[GermanyRegion,Steel supply,0,3,10] + op_srcSnk[GermanyRegion,Steel supply,0,3,11] + op_srcSnk[GermanyRegion,Steel supply,0,4,0] + op_srcSnk[GermanyRegion,Steel supply,0,4,1] + op_srcSnk[GermanyRegion,Steel supply,0,4,2] + op_srcSnk[GermanyRegion,Steel supply,0,4,3] + op_srcSnk[GermanyRegion,Steel supply,0,4,4] + op_srcSnk[GermanyRegion,Steel supply,0,4,5] + op_srcSnk[GermanyRegion,Steel supply,0,4,6] + op_srcSnk[GermanyRegion,Steel supply,0,4,7] + op_srcSnk[GermanyRegion,Steel supply,0,4,8] + op_srcSnk[GermanyRegion,Steel supply,0,4,9] + op_srcSnk[GermanyRegion,Steel supply,0,4,10] + op_srcSnk[GermanyRegion,Steel supply,0,4,11] + op_srcSnk[GermanyRegion,Steel supply,0,5,0] + op_srcSnk[GermanyRegion,Steel supply,0,5,1] + op_srcSnk[GermanyRegion,Steel supply,0,5,2] + op_srcSnk[GermanyRegion,Steel supply,0,5,3] + op_srcSnk[GermanyRegion,Steel supply,0,5,4] + op_srcSnk[GermanyRegion,Steel supply,0,5,5] + op_srcSnk[GermanyRegion,Steel supply,0,5,6] + op_srcSnk[GermanyRegion,Steel supply,0,5,7] + op_srcSnk[GermanyRegion,Steel supply,0,5,8] + op_srcSnk[GermanyRegion,Steel supply,0,5,9] + op_srcSnk[GermanyRegion,Steel supply,0,5,10] + op_srcSnk[GermanyRegion,Steel supply,0,5,11] + op_srcSnk[GermanyRegion,Steel supply,0,6,0] + op_srcSnk[GermanyRegion,Steel supply,0,6,1] + op_srcSnk[GermanyRegion,Steel supply,0,6,2] + op_srcSnk[GermanyRegion,Steel supply,0,6,3] + op_srcSnk[GermanyRegion,Steel supply,0,6,4] + op_srcSnk[GermanyRegion,Steel supply,0,6,5] + op_srcSnk[GermanyRegion,Steel supply,0,6,6] + op_srcSnk[GermanyRegion,Steel supply,0,6,7] + op_srcSnk[GermanyRegion,Steel supply,0,6,8] + op_srcSnk[GermanyRegion,Steel supply,0,6,9] + op_srcSnk[GermanyRegion,Steel supply,0,6,10] + op_srcSnk[GermanyRegion,Steel supply,0,6,11] + op_srcSnk[GermanyRegion,Steel supply,0,7,0] + op_srcSnk[GermanyRegion,Steel supply,0,7,1] + op_srcSnk[GermanyR ...
# RHS_sources 0.9900000000000001*decommis_srcSnk[GermanyRegion,'Wind (onshore)',0]
# LHS_sources op_srcSnk[GermanyRegion,Steel supply,1,0,0] + op_srcSnk[GermanyRegion,Steel supply,1,0,1] + op_srcSnk[GermanyRegion,Steel supply,1,0,2] + op_srcSnk[GermanyRegion,Steel supply,1,0,3] + op_srcSnk[GermanyRegion,Steel supply,1,0,4] + op_srcSnk[GermanyRegion,Steel supply,1,0,5] + op_srcSnk[GermanyRegion,Steel supply,1,0,6] + op_srcSnk[GermanyRegion,Steel supply,1,0,7] + op_srcSnk[GermanyRegion,Steel supply,1,0,8] + op_srcSnk[GermanyRegion,Steel supply,1,0,9] + op_srcSnk[GermanyRegion,Steel supply,1,0,10] + op_srcSnk[GermanyRegion,Steel supply,1,0,11] + op_srcSnk[GermanyRegion,Steel supply,1,1,0] + op_srcSnk[GermanyRegion,Steel supply,1,1,1] + op_srcSnk[GermanyRegion,Steel supply,1,1,2] + op_srcSnk[GermanyRegion,Steel supply,1,1,3] + op_srcSnk[GermanyRegion,Steel supply,1,1,4] + op_srcSnk[GermanyRegion,Steel supply,1,1,5] + op_srcSnk[GermanyRegion,Steel supply,1,1,6] + op_srcSnk[GermanyRegion,Steel supply,1,1,7] + op_srcSnk[GermanyRegion,Steel supply,1,1,8] + op_srcSnk[GermanyRegion,Steel supply,1,1,9] + op_srcSnk[GermanyRegion,Steel supply,1,1,10] + op_srcSnk[GermanyRegion,Steel supply,1,1,11] + op_srcSnk[GermanyRegion,Steel supply,1,2,0] + op_srcSnk[GermanyRegion,Steel supply,1,2,1] + op_srcSnk[GermanyRegion,Steel supply,1,2,2] + op_srcSnk[GermanyRegion,Steel supply,1,2,3] + op_srcSnk[GermanyRegion,Steel supply,1,2,4] + op_srcSnk[GermanyRegion,Steel supply,1,2,5] + op_srcSnk[GermanyRegion,Steel supply,1,2,6] + op_srcSnk[GermanyRegion,Steel supply,1,2,7] + op_srcSnk[GermanyRegion,Steel supply,1,2,8] + op_srcSnk[GermanyRegion,Steel supply,1,2,9] + op_srcSnk[GermanyRegion,Steel supply,1,2,10] + op_srcSnk[GermanyRegion,Steel supply,1,2,11] + op_srcSnk[GermanyRegion,Steel supply,1,3,0] + op_srcSnk[GermanyRegion,Steel supply,1,3,1] + op_srcSnk[GermanyRegion,Steel supply,1,3,2] + op_srcSnk[GermanyRegion,Steel supply,1,3,3] + op_srcSnk[GermanyRegion,Steel supply,1,3,4] + op_srcSnk[GermanyRegion,Steel supply,1,3,5] + op_srcSnk[GermanyRegion,Steel supply,1,3,6] + op_srcSnk[GermanyRegion,Steel supply,1,3,7] + op_srcSnk[GermanyRegion,Steel supply,1,3,8] + op_srcSnk[GermanyRegion,Steel supply,1,3,9] + op_srcSnk[GermanyRegion,Steel supply,1,3,10] + op_srcSnk[GermanyRegion,Steel supply,1,3,11] + op_srcSnk[GermanyRegion,Steel supply,1,4,0] + op_srcSnk[GermanyRegion,Steel supply,1,4,1] + op_srcSnk[GermanyRegion,Steel supply,1,4,2] + op_srcSnk[GermanyRegion,Steel supply,1,4,3] + op_srcSnk[GermanyRegion,Steel supply,1,4,4] + op_srcSnk[GermanyRegion,Steel supply,1,4,5] + op_srcSnk[GermanyRegion,Steel supply,1,4,6] + op_srcSnk[GermanyRegion,Steel supply,1,4,7] + op_srcSnk[GermanyRegion,Steel supply,1,4,8] + op_srcSnk[GermanyRegion,Steel supply,1,4,9] + op_srcSnk[GermanyRegion,Steel supply,1,4,10] + op_srcSnk[GermanyRegion,Steel supply,1,4,11] + op_srcSnk[GermanyRegion,Steel supply,1,5,0] + op_srcSnk[GermanyRegion,Steel supply,1,5,1] + op_srcSnk[GermanyRegion,Steel supply,1,5,2] + op_srcSnk[GermanyRegion,Steel supply,1,5,3] + op_srcSnk[GermanyRegion,Steel supply,1,5,4] + op_srcSnk[GermanyRegion,Steel supply,1,5,5] + op_srcSnk[GermanyRegion,Steel supply,1,5,6] + op_srcSnk[GermanyRegion,Steel supply,1,5,7] + op_srcSnk[GermanyRegion,Steel supply,1,5,8] + op_srcSnk[GermanyRegion,Steel supply,1,5,9] + op_srcSnk[GermanyRegion,Steel supply,1,5,10] + op_srcSnk[GermanyRegion,Steel supply,1,5,11] + op_srcSnk[GermanyRegion,Steel supply,1,6,0] + op_srcSnk[GermanyRegion,Steel supply,1,6,1] + op_srcSnk[GermanyRegion,Steel supply,1,6,2] + op_srcSnk[GermanyRegion,Steel supply,1,6,3] + op_srcSnk[GermanyRegion,Steel supply,1,6,4] + op_srcSnk[GermanyRegion,Steel supply,1,6,5] + op_srcSnk[GermanyRegion,Steel supply,1,6,6] + op_srcSnk[GermanyRegion,Steel supply,1,6,7] + op_srcSnk[GermanyRegion,Steel supply,1,6,8] + op_srcSnk[GermanyRegion,Steel supply,1,6,9] + op_srcSnk[GermanyRegion,Steel supply,1,6,10] + op_srcSnk[GermanyRegion,Steel supply,1,6,11] + op_srcSnk[GermanyRegion,Steel supply,1,7,0] + op_srcSnk[GermanyRegion,Steel supply,1,7,1] + op_srcSnk[GermanyR ...
# RHS_sources 2.79*decommis_srcSnk[GermanyRegion,'Wind (onshore)',1]
# LHS_sources op_srcSnk[GermanyRegion,Steel supply,2,0,0] + op_srcSnk[GermanyRegion,Steel supply,2,0,1] + op_srcSnk[GermanyRegion,Steel supply,2,0,2] + op_srcSnk[GermanyRegion,Steel supply,2,0,3] + op_srcSnk[GermanyRegion,Steel supply,2,0,4] + op_srcSnk[GermanyRegion,Steel supply,2,0,5] + op_srcSnk[GermanyRegion,Steel supply,2,0,6] + op_srcSnk[GermanyRegion,Steel supply,2,0,7] + op_srcSnk[GermanyRegion,Steel supply,2,0,8] + op_srcSnk[GermanyRegion,Steel supply,2,0,9] + op_srcSnk[GermanyRegion,Steel supply,2,0,10] + op_srcSnk[GermanyRegion,Steel supply,2,0,11] + op_srcSnk[GermanyRegion,Steel supply,2,1,0] + op_srcSnk[GermanyRegion,Steel supply,2,1,1] + op_srcSnk[GermanyRegion,Steel supply,2,1,2] + op_srcSnk[GermanyRegion,Steel supply,2,1,3] + op_srcSnk[GermanyRegion,Steel supply,2,1,4] + op_srcSnk[GermanyRegion,Steel supply,2,1,5] + op_srcSnk[GermanyRegion,Steel supply,2,1,6] + op_srcSnk[GermanyRegion,Steel supply,2,1,7] + op_srcSnk[GermanyRegion,Steel supply,2,1,8] + op_srcSnk[GermanyRegion,Steel supply,2,1,9] + op_srcSnk[GermanyRegion,Steel supply,2,1,10] + op_srcSnk[GermanyRegion,Steel supply,2,1,11] + op_srcSnk[GermanyRegion,Steel supply,2,2,0] + op_srcSnk[GermanyRegion,Steel supply,2,2,1] + op_srcSnk[GermanyRegion,Steel supply,2,2,2] + op_srcSnk[GermanyRegion,Steel supply,2,2,3] + op_srcSnk[GermanyRegion,Steel supply,2,2,4] + op_srcSnk[GermanyRegion,Steel supply,2,2,5] + op_srcSnk[GermanyRegion,Steel supply,2,2,6] + op_srcSnk[GermanyRegion,Steel supply,2,2,7] + op_srcSnk[GermanyRegion,Steel supply,2,2,8] + op_srcSnk[GermanyRegion,Steel supply,2,2,9] + op_srcSnk[GermanyRegion,Steel supply,2,2,10] + op_srcSnk[GermanyRegion,Steel supply,2,2,11] + op_srcSnk[GermanyRegion,Steel supply,2,3,0] + op_srcSnk[GermanyRegion,Steel supply,2,3,1] + op_srcSnk[GermanyRegion,Steel supply,2,3,2] + op_srcSnk[GermanyRegion,Steel supply,2,3,3] + op_srcSnk[GermanyRegion,Steel supply,2,3,4] + op_srcSnk[GermanyRegion,Steel supply,2,3,5] + op_srcSnk[GermanyRegion,Steel supply,2,3,6] + op_srcSnk[GermanyRegion,Steel supply,2,3,7] + op_srcSnk[GermanyRegion,Steel supply,2,3,8] + op_srcSnk[GermanyRegion,Steel supply,2,3,9] + op_srcSnk[GermanyRegion,Steel supply,2,3,10] + op_srcSnk[GermanyRegion,Steel supply,2,3,11] + op_srcSnk[GermanyRegion,Steel supply,2,4,0] + op_srcSnk[GermanyRegion,Steel supply,2,4,1] + op_srcSnk[GermanyRegion,Steel supply,2,4,2] + op_srcSnk[GermanyRegion,Steel supply,2,4,3] + op_srcSnk[GermanyRegion,Steel supply,2,4,4] + op_srcSnk[GermanyRegion,Steel supply,2,4,5] + op_srcSnk[GermanyRegion,Steel supply,2,4,6] + op_srcSnk[GermanyRegion,Steel supply,2,4,7] + op_srcSnk[GermanyRegion,Steel supply,2,4,8] + op_srcSnk[GermanyRegion,Steel supply,2,4,9] + op_srcSnk[GermanyRegion,Steel supply,2,4,10] + op_srcSnk[GermanyRegion,Steel supply,2,4,11] + op_srcSnk[GermanyRegion,Steel supply,2,5,0] + op_srcSnk[GermanyRegion,Steel supply,2,5,1] + op_srcSnk[GermanyRegion,Steel supply,2,5,2] + op_srcSnk[GermanyRegion,Steel supply,2,5,3] + op_srcSnk[GermanyRegion,Steel supply,2,5,4] + op_srcSnk[GermanyRegion,Steel supply,2,5,5] + op_srcSnk[GermanyRegion,Steel supply,2,5,6] + op_srcSnk[GermanyRegion,Steel supply,2,5,7] + op_srcSnk[GermanyRegion,Steel supply,2,5,8] + op_srcSnk[GermanyRegion,Steel supply,2,5,9] + op_srcSnk[GermanyRegion,Steel supply,2,5,10] + op_srcSnk[GermanyRegion,Steel supply,2,5,11] + op_srcSnk[GermanyRegion,Steel supply,2,6,0] + op_srcSnk[GermanyRegion,Steel supply,2,6,1] + op_srcSnk[GermanyRegion,Steel supply,2,6,2] + op_srcSnk[GermanyRegion,Steel supply,2,6,3] + op_srcSnk[GermanyRegion,Steel supply,2,6,4] + op_srcSnk[GermanyRegion,Steel supply,2,6,5] + op_srcSnk[GermanyRegion,Steel supply,2,6,6] + op_srcSnk[GermanyRegion,Steel supply,2,6,7] + op_srcSnk[GermanyRegion,Steel supply,2,6,8] + op_srcSnk[GermanyRegion,Steel supply,2,6,9] + op_srcSnk[GermanyRegion,Steel supply,2,6,10] + op_srcSnk[GermanyRegion,Steel supply,2,6,11] + op_srcSnk[GermanyRegion,Steel supply,2,7,0] + op_srcSnk[GermanyRegion,Steel supply,2,7,1] + op_srcSnk[GermanyR ...
# RHS_sources 2.7*decommis_srcSnk[GermanyRegion,'Wind (onshore)',2]
# LHS_sources op_srcSnk[GermanyRegion,Copper supply,0,0,0] + op_srcSnk[GermanyRegion,Copper supply,0,0,1] + op_srcSnk[GermanyRegion,Copper supply,0,0,2] + op_srcSnk[GermanyRegion,Copper supply,0,0,3] + op_srcSnk[GermanyRegion,Copper supply,0,0,4] + op_srcSnk[GermanyRegion,Copper supply,0,0,5] + op_srcSnk[GermanyRegion,Copper supply,0,0,6] + op_srcSnk[GermanyRegion,Copper supply,0,0,7] + op_srcSnk[GermanyRegion,Copper supply,0,0,8] + op_srcSnk[GermanyRegion,Copper supply,0,0,9] + op_srcSnk[GermanyRegion,Copper supply,0,0,10] + op_srcSnk[GermanyRegion,Copper supply,0,0,11] + op_srcSnk[GermanyRegion,Copper supply,0,1,0] + op_srcSnk[GermanyRegion,Copper supply,0,1,1] + op_srcSnk[GermanyRegion,Copper supply,0,1,2] + op_srcSnk[GermanyRegion,Copper supply,0,1,3] + op_srcSnk[GermanyRegion,Copper supply,0,1,4] + op_srcSnk[GermanyRegion,Copper supply,0,1,5] + op_srcSnk[GermanyRegion,Copper supply,0,1,6] + op_srcSnk[GermanyRegion,Copper supply,0,1,7] + op_srcSnk[GermanyRegion,Copper supply,0,1,8] + op_srcSnk[GermanyRegion,Copper supply,0,1,9] + op_srcSnk[GermanyRegion,Copper supply,0,1,10] + op_srcSnk[GermanyRegion,Copper supply,0,1,11] + op_srcSnk[GermanyRegion,Copper supply,0,2,0] + op_srcSnk[GermanyRegion,Copper supply,0,2,1] + op_srcSnk[GermanyRegion,Copper supply,0,2,2] + op_srcSnk[GermanyRegion,Copper supply,0,2,3] + op_srcSnk[GermanyRegion,Copper supply,0,2,4] + op_srcSnk[GermanyRegion,Copper supply,0,2,5] + op_srcSnk[GermanyRegion,Copper supply,0,2,6] + op_srcSnk[GermanyRegion,Copper supply,0,2,7] + op_srcSnk[GermanyRegion,Copper supply,0,2,8] + op_srcSnk[GermanyRegion,Copper supply,0,2,9] + op_srcSnk[GermanyRegion,Copper supply,0,2,10] + op_srcSnk[GermanyRegion,Copper supply,0,2,11] + op_srcSnk[GermanyRegion,Copper supply,0,3,0] + op_srcSnk[GermanyRegion,Copper supply,0,3,1] + op_srcSnk[GermanyRegion,Copper supply,0,3,2] + op_srcSnk[GermanyRegion,Copper supply,0,3,3] + op_srcSnk[GermanyRegion,Copper supply,0,3,4] + op_srcSnk[GermanyRegion,Copper supply,0,3,5] + op_srcSnk[GermanyRegion,Copper supply,0,3,6] + op_srcSnk[GermanyRegion,Copper supply,0,3,7] + op_srcSnk[GermanyRegion,Copper supply,0,3,8] + op_srcSnk[GermanyRegion,Copper supply,0,3,9] + op_srcSnk[GermanyRegion,Copper supply,0,3,10] + op_srcSnk[GermanyRegion,Copper supply,0,3,11] + op_srcSnk[GermanyRegion,Copper supply,0,4,0] + op_srcSnk[GermanyRegion,Copper supply,0,4,1] + op_srcSnk[GermanyRegion,Copper supply,0,4,2] + op_srcSnk[GermanyRegion,Copper supply,0,4,3] + op_srcSnk[GermanyRegion,Copper supply,0,4,4] + op_srcSnk[GermanyRegion,Copper supply,0,4,5] + op_srcSnk[GermanyRegion,Copper supply,0,4,6] + op_srcSnk[GermanyRegion,Copper supply,0,4,7] + op_srcSnk[GermanyRegion,Copper supply,0,4,8] + op_srcSnk[GermanyRegion,Copper supply,0,4,9] + op_srcSnk[GermanyRegion,Copper supply,0,4,10] + op_srcSnk[GermanyRegion,Copper supply,0,4,11] + op_srcSnk[GermanyRegion,Copper supply,0,5,0] + op_srcSnk[GermanyRegion,Copper supply,0,5,1] + op_srcSnk[GermanyRegion,Copper supply,0,5,2] + op_srcSnk[GermanyRegion,Copper supply,0,5,3] + op_srcSnk[GermanyRegion,Copper supply,0,5,4] + op_srcSnk[GermanyRegion,Copper supply,0,5,5] + op_srcSnk[GermanyRegion,Copper supply,0,5,6] + op_srcSnk[GermanyRegion,Copper supply,0,5,7] + op_srcSnk[GermanyRegion,Copper supply,0,5,8] + op_srcSnk[GermanyRegion,Copper supply,0,5,9] + op_srcSnk[GermanyRegion,Copper supply,0,5,10] + op_srcSnk[GermanyRegion,Copper supply,0,5,11] + op_srcSnk[GermanyRegion,Copper supply,0,6,0] + op_srcSnk[GermanyRegion,Copper supply,0,6,1] + op_srcSnk[GermanyRegion,Copper supply,0,6,2] + op_srcSnk[GermanyRegion,Copper supply,0,6,3] + op_srcSnk[GermanyRegion,Copper supply,0,6,4] + op_srcSnk[GermanyRegion,Copper supply,0,6,5] + op_srcSnk[GermanyRegion,Copper supply,0,6,6] + op_srcSnk[GermanyRegion,Copper supply,0,6,7] + op_srcSnk[GermanyRegion,Copper supply,0,6,8] + op_srcSnk[GermanyRegion,Copper supply,0,6,9] + op_srcSnk[GermanyRegion,Copper supply,0,6,10] + op_srcSnk[GermanyRegion,Copper supply,0,6,11] + op_srcSnk[GermanyRegion,Co ...
# RHS_sources 0.9900000000000001*decommis_srcSnk[GermanyRegion,'Wind (onshore)',0]
# LHS_sources op_srcSnk[GermanyRegion,Copper supply,1,0,0] + op_srcSnk[GermanyRegion,Copper supply,1,0,1] + op_srcSnk[GermanyRegion,Copper supply,1,0,2] + op_srcSnk[GermanyRegion,Copper supply,1,0,3] + op_srcSnk[GermanyRegion,Copper supply,1,0,4] + op_srcSnk[GermanyRegion,Copper supply,1,0,5] + op_srcSnk[GermanyRegion,Copper supply,1,0,6] + op_srcSnk[GermanyRegion,Copper supply,1,0,7] + op_srcSnk[GermanyRegion,Copper supply,1,0,8] + op_srcSnk[GermanyRegion,Copper supply,1,0,9] + op_srcSnk[GermanyRegion,Copper supply,1,0,10] + op_srcSnk[GermanyRegion,Copper supply,1,0,11] + op_srcSnk[GermanyRegion,Copper supply,1,1,0] + op_srcSnk[GermanyRegion,Copper supply,1,1,1] + op_srcSnk[GermanyRegion,Copper supply,1,1,2] + op_srcSnk[GermanyRegion,Copper supply,1,1,3] + op_srcSnk[GermanyRegion,Copper supply,1,1,4] + op_srcSnk[GermanyRegion,Copper supply,1,1,5] + op_srcSnk[GermanyRegion,Copper supply,1,1,6] + op_srcSnk[GermanyRegion,Copper supply,1,1,7] + op_srcSnk[GermanyRegion,Copper supply,1,1,8] + op_srcSnk[GermanyRegion,Copper supply,1,1,9] + op_srcSnk[GermanyRegion,Copper supply,1,1,10] + op_srcSnk[GermanyRegion,Copper supply,1,1,11] + op_srcSnk[GermanyRegion,Copper supply,1,2,0] + op_srcSnk[GermanyRegion,Copper supply,1,2,1] + op_srcSnk[GermanyRegion,Copper supply,1,2,2] + op_srcSnk[GermanyRegion,Copper supply,1,2,3] + op_srcSnk[GermanyRegion,Copper supply,1,2,4] + op_srcSnk[GermanyRegion,Copper supply,1,2,5] + op_srcSnk[GermanyRegion,Copper supply,1,2,6] + op_srcSnk[GermanyRegion,Copper supply,1,2,7] + op_srcSnk[GermanyRegion,Copper supply,1,2,8] + op_srcSnk[GermanyRegion,Copper supply,1,2,9] + op_srcSnk[GermanyRegion,Copper supply,1,2,10] + op_srcSnk[GermanyRegion,Copper supply,1,2,11] + op_srcSnk[GermanyRegion,Copper supply,1,3,0] + op_srcSnk[GermanyRegion,Copper supply,1,3,1] + op_srcSnk[GermanyRegion,Copper supply,1,3,2] + op_srcSnk[GermanyRegion,Copper supply,1,3,3] + op_srcSnk[GermanyRegion,Copper supply,1,3,4] + op_srcSnk[GermanyRegion,Copper supply,1,3,5] + op_srcSnk[GermanyRegion,Copper supply,1,3,6] + op_srcSnk[GermanyRegion,Copper supply,1,3,7] + op_srcSnk[GermanyRegion,Copper supply,1,3,8] + op_srcSnk[GermanyRegion,Copper supply,1,3,9] + op_srcSnk[GermanyRegion,Copper supply,1,3,10] + op_srcSnk[GermanyRegion,Copper supply,1,3,11] + op_srcSnk[GermanyRegion,Copper supply,1,4,0] + op_srcSnk[GermanyRegion,Copper supply,1,4,1] + op_srcSnk[GermanyRegion,Copper supply,1,4,2] + op_srcSnk[GermanyRegion,Copper supply,1,4,3] + op_srcSnk[GermanyRegion,Copper supply,1,4,4] + op_srcSnk[GermanyRegion,Copper supply,1,4,5] + op_srcSnk[GermanyRegion,Copper supply,1,4,6] + op_srcSnk[GermanyRegion,Copper supply,1,4,7] + op_srcSnk[GermanyRegion,Copper supply,1,4,8] + op_srcSnk[GermanyRegion,Copper supply,1,4,9] + op_srcSnk[GermanyRegion,Copper supply,1,4,10] + op_srcSnk[GermanyRegion,Copper supply,1,4,11] + op_srcSnk[GermanyRegion,Copper supply,1,5,0] + op_srcSnk[GermanyRegion,Copper supply,1,5,1] + op_srcSnk[GermanyRegion,Copper supply,1,5,2] + op_srcSnk[GermanyRegion,Copper supply,1,5,3] + op_srcSnk[GermanyRegion,Copper supply,1,5,4] + op_srcSnk[GermanyRegion,Copper supply,1,5,5] + op_srcSnk[GermanyRegion,Copper supply,1,5,6] + op_srcSnk[GermanyRegion,Copper supply,1,5,7] + op_srcSnk[GermanyRegion,Copper supply,1,5,8] + op_srcSnk[GermanyRegion,Copper supply,1,5,9] + op_srcSnk[GermanyRegion,Copper supply,1,5,10] + op_srcSnk[GermanyRegion,Copper supply,1,5,11] + op_srcSnk[GermanyRegion,Copper supply,1,6,0] + op_srcSnk[GermanyRegion,Copper supply,1,6,1] + op_srcSnk[GermanyRegion,Copper supply,1,6,2] + op_srcSnk[GermanyRegion,Copper supply,1,6,3] + op_srcSnk[GermanyRegion,Copper supply,1,6,4] + op_srcSnk[GermanyRegion,Copper supply,1,6,5] + op_srcSnk[GermanyRegion,Copper supply,1,6,6] + op_srcSnk[GermanyRegion,Copper supply,1,6,7] + op_srcSnk[GermanyRegion,Copper supply,1,6,8] + op_srcSnk[GermanyRegion,Copper supply,1,6,9] + op_srcSnk[GermanyRegion,Copper supply,1,6,10] + op_srcSnk[GermanyRegion,Copper supply,1,6,11] + op_srcSnk[GermanyRegion,Co ...
# RHS_sources 4.77*decommis_srcSnk[GermanyRegion,'Wind (onshore)',1]
# LHS_sources op_srcSnk[GermanyRegion,Copper supply,2,0,0] + op_srcSnk[GermanyRegion,Copper supply,2,0,1] + op_srcSnk[GermanyRegion,Copper supply,2,0,2] + op_srcSnk[GermanyRegion,Copper supply,2,0,3] + op_srcSnk[GermanyRegion,Copper supply,2,0,4] + op_srcSnk[GermanyRegion,Copper supply,2,0,5] + op_srcSnk[GermanyRegion,Copper supply,2,0,6] + op_srcSnk[GermanyRegion,Copper supply,2,0,7] + op_srcSnk[GermanyRegion,Copper supply,2,0,8] + op_srcSnk[GermanyRegion,Copper supply,2,0,9] + op_srcSnk[GermanyRegion,Copper supply,2,0,10] + op_srcSnk[GermanyRegion,Copper supply,2,0,11] + op_srcSnk[GermanyRegion,Copper supply,2,1,0] + op_srcSnk[GermanyRegion,Copper supply,2,1,1] + op_srcSnk[GermanyRegion,Copper supply,2,1,2] + op_srcSnk[GermanyRegion,Copper supply,2,1,3] + op_srcSnk[GermanyRegion,Copper supply,2,1,4] + op_srcSnk[GermanyRegion,Copper supply,2,1,5] + op_srcSnk[GermanyRegion,Copper supply,2,1,6] + op_srcSnk[GermanyRegion,Copper supply,2,1,7] + op_srcSnk[GermanyRegion,Copper supply,2,1,8] + op_srcSnk[GermanyRegion,Copper supply,2,1,9] + op_srcSnk[GermanyRegion,Copper supply,2,1,10] + op_srcSnk[GermanyRegion,Copper supply,2,1,11] + op_srcSnk[GermanyRegion,Copper supply,2,2,0] + op_srcSnk[GermanyRegion,Copper supply,2,2,1] + op_srcSnk[GermanyRegion,Copper supply,2,2,2] + op_srcSnk[GermanyRegion,Copper supply,2,2,3] + op_srcSnk[GermanyRegion,Copper supply,2,2,4] + op_srcSnk[GermanyRegion,Copper supply,2,2,5] + op_srcSnk[GermanyRegion,Copper supply,2,2,6] + op_srcSnk[GermanyRegion,Copper supply,2,2,7] + op_srcSnk[GermanyRegion,Copper supply,2,2,8] + op_srcSnk[GermanyRegion,Copper supply,2,2,9] + op_srcSnk[GermanyRegion,Copper supply,2,2,10] + op_srcSnk[GermanyRegion,Copper supply,2,2,11] + op_srcSnk[GermanyRegion,Copper supply,2,3,0] + op_srcSnk[GermanyRegion,Copper supply,2,3,1] + op_srcSnk[GermanyRegion,Copper supply,2,3,2] + op_srcSnk[GermanyRegion,Copper supply,2,3,3] + op_srcSnk[GermanyRegion,Copper supply,2,3,4] + op_srcSnk[GermanyRegion,Copper supply,2,3,5] + op_srcSnk[GermanyRegion,Copper supply,2,3,6] + op_srcSnk[GermanyRegion,Copper supply,2,3,7] + op_srcSnk[GermanyRegion,Copper supply,2,3,8] + op_srcSnk[GermanyRegion,Copper supply,2,3,9] + op_srcSnk[GermanyRegion,Copper supply,2,3,10] + op_srcSnk[GermanyRegion,Copper supply,2,3,11] + op_srcSnk[GermanyRegion,Copper supply,2,4,0] + op_srcSnk[GermanyRegion,Copper supply,2,4,1] + op_srcSnk[GermanyRegion,Copper supply,2,4,2] + op_srcSnk[GermanyRegion,Copper supply,2,4,3] + op_srcSnk[GermanyRegion,Copper supply,2,4,4] + op_srcSnk[GermanyRegion,Copper supply,2,4,5] + op_srcSnk[GermanyRegion,Copper supply,2,4,6] + op_srcSnk[GermanyRegion,Copper supply,2,4,7] + op_srcSnk[GermanyRegion,Copper supply,2,4,8] + op_srcSnk[GermanyRegion,Copper supply,2,4,9] + op_srcSnk[GermanyRegion,Copper supply,2,4,10] + op_srcSnk[GermanyRegion,Copper supply,2,4,11] + op_srcSnk[GermanyRegion,Copper supply,2,5,0] + op_srcSnk[GermanyRegion,Copper supply,2,5,1] + op_srcSnk[GermanyRegion,Copper supply,2,5,2] + op_srcSnk[GermanyRegion,Copper supply,2,5,3] + op_srcSnk[GermanyRegion,Copper supply,2,5,4] + op_srcSnk[GermanyRegion,Copper supply,2,5,5] + op_srcSnk[GermanyRegion,Copper supply,2,5,6] + op_srcSnk[GermanyRegion,Copper supply,2,5,7] + op_srcSnk[GermanyRegion,Copper supply,2,5,8] + op_srcSnk[GermanyRegion,Copper supply,2,5,9] + op_srcSnk[GermanyRegion,Copper supply,2,5,10] + op_srcSnk[GermanyRegion,Copper supply,2,5,11] + op_srcSnk[GermanyRegion,Copper supply,2,6,0] + op_srcSnk[GermanyRegion,Copper supply,2,6,1] + op_srcSnk[GermanyRegion,Copper supply,2,6,2] + op_srcSnk[GermanyRegion,Copper supply,2,6,3] + op_srcSnk[GermanyRegion,Copper supply,2,6,4] + op_srcSnk[GermanyRegion,Copper supply,2,6,5] + op_srcSnk[GermanyRegion,Copper supply,2,6,6] + op_srcSnk[GermanyRegion,Copper supply,2,6,7] + op_srcSnk[GermanyRegion,Copper supply,2,6,8] + op_srcSnk[GermanyRegion,Copper supply,2,6,9] + op_srcSnk[GermanyRegion,Copper supply,2,6,10] + op_srcSnk[GermanyRegion,Copper supply,2,6,11] + op_srcSnk[GermanyRegion,Co ...
# RHS_sources 4.680000000000001*decommis_srcSnk[GermanyRegion,'Wind (onshore)',2]
# 		(0.2878 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.0688 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.2885 sec)
#
# Declaring shared potential constraint...
# 		(0.0003 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0000 sec)
#
# Declaring commodity balances...
# 		(0.1985 sec)
#
# 		(0.0000 sec)
#
# Declaring objective function...
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',-1]
#
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',0]
#
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',1]
#
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',2]
#
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',-1]
#
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',0]
#
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',1]
#
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',2]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',0]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',1]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',2]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,Electroylzers,0]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,Electroylzers,1]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,Electroylzers,2]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',0]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',1]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,'New CCGT plants (hydrogen)',2]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,Electroylzers,0]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,Electroylzers,1]
#
# var name commis
# var value None
# var commis_conv[GermanyRegion,Electroylzers,2]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,Li-ion batteries,0]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,Li-ion batteries,1]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,Li-ion batteries,2]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,'Salt caverns (hydrogen)',0]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,'Salt caverns (hydrogen)',1]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,'Salt caverns (hydrogen)',2]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,Li-ion batteries,0]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,Li-ion batteries,1]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,Li-ion batteries,2]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,'Salt caverns (hydrogen)',0]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,'Salt caverns (hydrogen)',1]
#
# var name commis
# var value None
# var commis_stor[GermanyRegion,'Salt caverns (hydrogen)',2]
#
# 		(0.7658 sec)
#
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write /tmp/tmpf3z1gqau.glpk.raw --wglp /tmp/tmpbpgyhvtb.glpk.glp --cpxlp
#  /tmp/tmpm9wi0ldn.pyomo.lp
# Reading problem data from '/tmp/tmpm9wi0ldn.pyomo.lp'...
# 21070 rows, 13417 columns, 60571 non-zeros
# 137222 lines were read
# Writing problem data to '/tmp/tmpbpgyhvtb.glpk.glp'...
# 110631 lines were written
# GLPK Simplex Optimizer 5.0
# 21070 rows, 13417 columns, 60571 non-zeros
# Preprocessing...
# 20799 rows, 11822 columns, 58464 non-zeros
# Scaling...
#  A: min|aij| =  6.230e-04  max|aij| =  2.000e+03  ratio =  3.210e+06
# GM: min|aij| =  2.236e-01  max|aij| =  4.472e+00  ratio =  2.000e+01
# EQ: min|aij| =  5.000e-02  max|aij| =  1.000e+00  ratio =  2.000e+01
# Constructing initial basis...
# Size of triangular part is 17877
#       0: obj =   0.000000000e+00 inf =   3.367e+03 (1457)
# Perturbing LP to avoid stalling [203]...
#    8201: obj =   1.738224691e+03 inf =   4.319e+02 (14) 66
#   10484: obj =   3.986765518e+03 inf =   4.053e+02 (9) 19
# LP HAS NO PRIMAL FEASIBLE SOLUTION
# glp_simplex: unable to recover undefined or non-optimal solution
# If you need actual output for non-optimal solution, use --nopresol
# Time used:   6.4 secs
# Memory used: 26.0 Mb (27252583 bytes)
# Writing basic solution to '/tmp/tmpf3z1gqau.glpk.raw'...
# 34496 lines were written
#
# Status: ok
# Termination condition: other
# Statistics:
#   Branch and bound:
#     Number of bounded subproblems: 0
#     Number of created subproblems: 0
# Error rc: 0
# Time: 6.482060194015503
#
#
# Name: unknown
# Lower bound: -inf
# Upper bound: inf
# Number of objectives: 1
# Number of constraints: 21070
# Number of variables: 13417
# Number of nonzeros: 60571
# Sense: minimize
#
# Solve time: 7.05000901222229 sec.
#
# Processing optimization output...
# var name commis
# var value None
# var commis_srcSnk[GermanyRegion,'Wind (onshore)',-1]
# /fast/home/l-soeltzer/code/fine/fine/energySystemModel.py:2164: UserWarning: Output is generated for a non-optimal solution.
#   warnings.warn("Output is generated for a non-optimal solution.")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 esM.optimize(timeSeriesAggregation=True, solver="glpk")
#
# File ~/code/fine/fine/energySystemModel.py:2177, in EnergySystemModel.optimize(self, declaresOptimizationProblem, relaxIsBuiltBinary, timeSeriesAggregation, logFileName, threads, solver, timeLimit, optimizationSpecs, warmstart, relevanceThreshold, includePerformanceSummary)
#    2173 __t = time.time()
#    2174 # if _capacityVariablesOptimum is not a dict, convert to dict
#    2175 # (if single year system is optimized several times)
# -> 2177 mdl.setOptimalValues(self, self.pyM)
#    2178 outputString = (
#    2179     ("for {:" + w + "}").format(key + " ...")
#    2180     + "(%.4f" % (time.time() - __t)
#    2181     + "sec)"
#    2182 )
#    2183 utils.output(outputString, self.verbose, 0)
#
# File ~/code/fine/fine/sourceSink.py:1181, in SourceSinkModel.setOptimalValues(self, esM, pyM, unitType)
#    1168 """
#    1169 Set the optimal values of the components.
#    1170
#    (...)
#    1178 :type ip: int
#    1179 """
#    1180 # Set optimal design dimension variables and get basic optimization summary
# -> 1181 optSummaryBasic = super().setOptimalValues(
#    1182     esM, pyM, esM.locations, "commodityUnit"
#    1183 )
#    1185 # get class related results
#    1186 resultsTAC_opexOp = self.getEconomicsOperation(
#    1187     pyM,
#    1188     esM,
#    (...)
#    1194     getOptValueCostType="TAC",
#    1195 )
#
# File ~/code/fine/fine/component.py:4096, in ComponentModel.setOptimalValues(self, esM, pyM, indexColumns, plantUnit, unitApp)
#    4091 mIndex = pd.MultiIndex.from_tuples(
#    4092     tuples, names=["Component", "Property", "Unit"]
#    4093 )
#    4095 # get the results for all components
# -> 4096 resultsNPV_cx = self.getEconomicsDesign(
#    4097     pyM,
#    4098     esM,
#    4099     factorNames=["processedInvestPerCapacity", "QPcostDev"],
#    4100     QPfactorNames=["processedQPcostScale", "processedInvestPerCapacity"],
#    4101     lifetimeAttr="ipEconomicLifetime",
#    4102     varName="commis",
#    4103     divisorName="CCF",
#    4104     QPdivisorNames=["QPbound", "CCF"],
#    4105     getOptValue=True,
#    4106     getOptValueCostType="NPV",
#    4107 )
#    4109 resultsTAC_cx = self.getEconomicsDesign(
#    4110     pyM,
#    4111     esM,
#    (...)
#    4119     getOptValueCostType="TAC",
#    4120 )
#    4122 resultsNPV_ox = self.getEconomicsDesign(
#    4123     pyM,
#    4124     esM,
#    (...)
#    4131     getOptValueCostType="NPV",
#    4132 )
#
# File ~/code/fine/fine/component.py:3412, in ComponentModel.getEconomicsDesign(self, pyM, esM, factorNames, lifetimeAttr, varName, divisorName, QPfactorNames, QPdivisorNames, getOptValue, getOptValueCostType)
#    3405 (fullCostIntervals, costInLastEconInterval,
#    3406  costInLastTechInterval) = utils.getParametersForUnevenLifetimes(
#    3407     compName, loc, lifetimeAttr, esM
#    3408 )
#    3411 # calculation of the annuity
# -> 3412 annuity = self.getLocEconomicsDesign(
#    3413     pyM,
#    3414     esM,
#    3415     factorNames,
#    3416     varName,
#    3417     loc,
#    3418     compName,
#    3419     commisYear,
#    3420     divisorName,
#    3421     QPfactorNames,
#    3422     QPdivisorNames,
#    3423     getOptValue,
#    3424 )
#    3426 # write costs into dataframe
#    3427 # a) costs for complete intervals
#    3428 for i in range(commisYear, commisYear + fullCostIntervals):
#
# File ~/code/fine/fine/component.py:3651, in ComponentModel.getLocEconomicsDesign(self, pyM, esM, factorNames, varName, loc, compName, ip, divisorName, QPfactorNames, QPdivisorNames, getOptValue)
#    3649         return factor * _var
#    3650     else:
# -> 3651         return factor * _var.value
#    3652 else:
#    3653     QPfactors = [
#    3654         getattr(self.componentsDict[compName], QPfactorName)[ip][loc]
#    3655         for QPfactorName in QPfactorNames
#    3656     ]
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
print("Investment periods (relative):", esM.investmentPeriods)
# Out:
# Investment periods (relative): [0, 1, 2]

# %% [markdown]
#  # 9. Selected results output

# %% [markdown]
#  ### Sources and Sink
#
#  Show optimization summary

# %%
for year in [2020,2025,2030]:
    print(f"\n Results of SourceSinkModel for year {year}")
    print(esM.getOptimizationSummary("SourceSinkModel", outputLevel=1, ip=year))
# Out:
#  Results of SourceSinkModel for year 2020
#                                                                           GermanyRegion
# Component          Property                        Unit
# Copper demand      NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]                     158.4
#                                                    [tons*h]                       158.4
#                    opexOp                          [1e9 Euro/a]                     0.0
# Copper supply      NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]                     158.4
#                                                    [tons*h]                       158.4
#                    opexOp                          [1e9 Euro/a]                     0.0
# Electricity demand NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [GW$_{el}$*h/a]         30957.888055
#                                                    [GW$_{el}$*h]           30957.888055
#                    opexOp                          [1e9 Euro/a]                     0.0
# Hydrogen demand    NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                                    [GW$_{H_{2},LHV}$*h]     4765.074877
#                    opexOp                          [1e9 Euro/a]                     0.0
# Steel demand       NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]                     158.4
#                                                    [tons*h]                       158.4
#                    opexOp                          [1e9 Euro/a]                     0.0
# Steel supply       NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]                     158.4
#                                                    [tons*h]                       158.4
#                    opexOp                          [1e9 Euro/a]                     0.0
# Wind (onshore)     NPVcontribution                 [1e9 Euro]                 56.996797
#                    TAC                             [1e9 Euro/a]               13.217792
#                    capacity                        [GW$_{el}$]                44.429241
#                    capexCap                        [1e9 Euro/a]               12.240349
#                    commissioning                   [GW$_{el}$]                44.429241
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    decommissioning                 [GW$_{el}$]                     10.0
#                    invest                          [1e9 Euro]                 48.872165
#                    investLifetimeExtension         [1e9 Euro]                         0
#                    operation                       [GW$_{el}$*h/a]         43484.921988
#                                                    [GW$_{el}$*h]           43484.921988
#                    opexCap                         [1e9 Euro/a]                0.977443
#                    opexOp                          [1e9 Euro/a]                     0.0
#                    revenueLifetimeShorteningResale [1e9 Euro]                         0
#
#  Results of SourceSinkModel for year 2025
#                                                                           GermanyRegion
# Component          Property                        Unit
# Copper demand      NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]               3390.839653
#                                                    [tons*h]                 3390.839653
#                    opexOp                          [1e9 Euro/a]                     0.0
# Copper supply      NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]               3390.839653
#                                                    [tons*h]                 3390.839653
#                    opexOp                          [1e9 Euro/a]                     0.0
# Electricity demand NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [GW$_{el}$*h/a]         40245.254471
#                                                    [GW$_{el}$*h]           40245.254471
#                    opexOp                          [1e9 Euro/a]                     0.0
# Hydrogen demand    NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                                    [GW$_{H_{2},LHV}$*h]     4765.074877
#                    opexOp                          [1e9 Euro/a]                     0.0
# Steel demand       NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]               1983.321306
#                                                    [tons*h]                 1983.321306
#                    opexOp                          [1e9 Euro/a]                     0.0
# Steel supply       NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]               1983.321306
#                                                    [tons*h]                 1983.321306
#                    opexOp                          [1e9 Euro/a]                     0.0
# Wind (onshore)     NPVcontribution                 [1e9 Euro]                 46.170432
#                    TAC                             [1e9 Euro/a]               15.732263
#                    capacity                        [GW$_{el}$]                  58.1693
#                    capexCap                        [1e9 Euro/a]               14.568877
#                    commissioning                   [GW$_{el}$]                  58.1693
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    decommissioning                 [GW$_{el}$]                44.429241
#                    invest                          [1e9 Euro]                   58.1693
#                    investLifetimeExtension         [1e9 Euro]                         0
#                    operation                       [GW$_{el}$*h/a]         53439.459823
#                                                    [GW$_{el}$*h]           53439.459823
#                    opexCap                         [1e9 Euro/a]                1.163386
#                    opexOp                          [1e9 Euro/a]                     0.0
#                    revenueLifetimeShorteningResale [1e9 Euro]                         0
#
#  Results of SourceSinkModel for year 2030
#                                                                           GermanyRegion
# Component          Property                        Unit
# Copper demand      NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]               4355.717184
#                                                    [tons*h]                 4355.717184
#                    opexOp                          [1e9 Euro/a]                     0.0
# Copper supply      NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]               4355.717184
#                                                    [tons*h]                 4355.717184
#                    opexOp                          [1e9 Euro/a]                     0.0
# Electricity demand NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [GW$_{el}$*h/a]         49532.620887
#                                                    [GW$_{el}$*h]           49532.620887
#                    opexOp                          [1e9 Euro/a]                     0.0
# Hydrogen demand    NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [GW$_{H_{2},LHV}$*h/a]   4765.074877
#                                                    [GW$_{H_{2},LHV}$*h]     4765.074877
#                    opexOp                          [1e9 Euro/a]                     0.0
# Steel demand       NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]                2512.91376
#                                                    [tons*h]                  2512.91376
#                    opexOp                          [1e9 Euro/a]                     0.0
# Steel supply       NPVcontribution                 [1e9 Euro]                       0.0
#                    TAC                             [1e9 Euro/a]                     0.0
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    operation                       [tons*h/a]                2512.91376
#                                                    [tons*h]                  2512.91376
#                    opexOp                          [1e9 Euro/a]                     0.0
# Wind (onshore)     NPVcontribution                 [1e9 Euro]                 29.851679
#                    TAC                             [1e9 Euro/a]                14.94565
#                    capacity                        [GW$_{el}$]                  58.1693
#                    capexCap                        [1e9 Euro/a]               13.840433
#                    commissioning                   [GW$_{el}$]                  58.1693
#                    commodCosts                     [1e9 Euro/a]                     0.0
#                    commodRevenues                  [1e9 Euro/a]                     0.0
#                    decommissioning                 [GW$_{el}$]                  58.1693
#                    invest                          [1e9 Euro]                 55.260835
#                    investLifetimeExtension         [1e9 Euro]                         0
#                    operation                       [GW$_{el}$*h/a]         62729.893728
#                                                    [GW$_{el}$*h]           62729.893728
#                    opexCap                         [1e9 Euro/a]                1.105217
#                    opexOp                          [1e9 Euro/a]                     0.0
#                    revenueLifetimeShorteningResale [1e9 Euro]                         0

# %% [markdown]
#  Plot operation time series (either one or two dimensional) for different years

# %% [markdown]
#  Electricity demand operation for Investment Period 2020

# %%
fig, ax = fn.plotOperation(esM, "Electricity demand", "GermanyRegion", ip=2020)

# %% [markdown]
#  Electricity demand operation for Investment Period 2030

# %%
fig, ax = fn.plotOperation(esM, "Electricity demand", "GermanyRegion", ip=2030)

# %% [markdown]
#  Operation color map for Electricity demand in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(esM, "Electricity demand", "GermanyRegion",ip=2020)

# %% [markdown]
#  Operation color map for Electricity demand in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(esM, "Electricity demand", "GermanyRegion",ip=2030)

# %% [markdown]
#  ### Conversion
#
#  Show optimization summary

# %%
for year in [2020,2025,2030]:
    print(f"\n Results of ConversionMpdel for year {year}")
    esM.getOptimizationSummary("ConversionModel", outputLevel=2, ip=year)
# Out:
#  Results of ConversionMpdel for year 2020
#
#  Results of ConversionMpdel for year 2025
#
#  Results of ConversionMpdel for year 2030

# %% [markdown]
#  Operation color map for New CCGT plants (hydrogen) in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(esM, "New CCGT plants (hydrogen)", "GermanyRegion", ip=2020)

# %% [markdown]
#  Operation color map for New CCGT plants (hydrogen) in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(esM, "New CCGT plants (hydrogen)", "GermanyRegion", ip=2030)

# %% [markdown]
#  ### Storage
#
#  Show optimization summary

# %%
for year in [2020,2025,2030]:
    print(f"\n Results of StorageModel for year {year}")
    print(esM.getOptimizationSummary("StorageModel", outputLevel=2, ip=year))
# Out:
#  Results of StorageModel for year 2020
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                   4.82173
#                         TAC                [1e9 Euro/a]                1.118179
#                         capacity           [GW$_{el}$*h]                28.0816
#                         capexCap           [1e9 Euro/a]                1.062016
#                         commissioning      [GW$_{el}$*h]                28.0816
#                         invest             [1e9 Euro]                  4.240322
#                         operationCharge    [GW$_{el}$*h/a]          5637.590143
#                                            [GW$_{el}$*h]            5637.590143
#                         operationDischarge [GW$_{el}$*h/a]          5082.400519
#                                            [GW$_{el}$*h]            5082.400519
#                         opexCap            [1e9 Euro/a]                0.056163
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  3.088097
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         commissioning      [GW$_{H_{2},LHV}$*h]     1235.216115
#                         invest             [1e9 Euro]                  0.135874
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]    9781.14563
#                                            [GW$_{H_{2},LHV}$*h]      9781.14563
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]    9781.14563
#                                            [GW$_{H_{2},LHV}$*h]      9781.14563
#                         opexCap            [1e9 Euro/a]                0.704073
#
#  Results of StorageModel for year 2025
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                  9.416271
#                         TAC                [1e9 Euro/a]                3.208531
#                         capacity           [GW$_{el}$*h]              80.578032
#                         capexCap           [1e9 Euro/a]                3.047375
#                         commissioning      [GW$_{el}$*h]              80.578032
#                         decommissioning    [GW$_{el}$*h]                28.0816
#                         invest             [1e9 Euro]                 12.167283
#                         operationCharge    [GW$_{el}$*h/a]          8023.397543
#                                            [GW$_{el}$*h]            8023.397543
#                         operationDischarge [GW$_{el}$*h/a]          7225.917054
#                                            [GW$_{el}$*h]            7225.917054
#                         opexCap            [1e9 Euro/a]                0.161156
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  2.101707
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]  10047.793771
#                                            [GW$_{H_{2},LHV}$*h]    10047.793771
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]  10047.793771
#                                            [GW$_{H_{2},LHV}$*h]    10047.793771
#                         opexCap            [1e9 Euro/a]                0.704073
#
#  Results of StorageModel for year 2030
#                                                                   GermanyRegion
# Component               Property           Unit
# Li-ion batteries        NPVcontribution    [1e9 Euro]                 33.724946
#                         TAC                [1e9 Euro/a]               16.884853
#                         capacity           [GW$_{el}$*h]             424.040913
#                         capexCap           [1e9 Euro/a]               16.036771
#                         commissioning      [GW$_{el}$*h]             424.040913
#                         decommissioning    [GW$_{el}$*h]              80.578032
#                         invest             [1e9 Euro]                 64.030178
#                         operationCharge    [GW$_{el}$*h/a]         12055.503782
#                                            [GW$_{el}$*h]           12055.503782
#                         operationDischarge [GW$_{el}$*h/a]         10813.092579
#                                            [GW$_{el}$*h]           10813.092579
#                         opexCap            [1e9 Euro/a]                0.848082
# Salt caverns (hydrogen) NPVcontribution    [1e9 Euro]                  1.430387
#                         TAC                [1e9 Euro/a]                0.716143
#                         capacity           [GW$_{H_{2},LHV}$*h]     1235.216115
#                         capexCap           [1e9 Euro/a]                0.012069
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]  10093.043755
#                                            [GW$_{H_{2},LHV}$*h]    10093.043755
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]  10093.043755
#                                            [GW$_{H_{2},LHV}$*h]    10093.043755
#                         opexCap            [1e9 Euro/a]                0.704073

# %% [markdown]
#  Operation color map for Li-ion batteries in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Li-ion batteries",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2020
)

# %% [markdown]
#  Operation color map for Li-ion batteries in Investment Period 2025

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Li-ion batteries",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2025
)

# %% [markdown]
#  Operation color map for Li-ion batteries in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Li-ion batteries",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2030
)

# %% [markdown]
#  Operation color map for Salt caverns (hydrogen) in Investment Period 2020

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (hydrogen)",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2020
)

# %% [markdown]
#  Operation color map for Salt caverns (hydrogen) in Investment Period 2025

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (hydrogen)",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2025
)

# %% [markdown]
#  Operation color map for Salt caverns (hydrogen) in Investment Period 2030

# %%
fig, ax = fn.plotOperationColorMap(
    esM,
    "Salt caverns (hydrogen)",
    "GermanyRegion",
    variableName="stateOfChargeOperationVariablesOptimum",
    ip=2030
)
