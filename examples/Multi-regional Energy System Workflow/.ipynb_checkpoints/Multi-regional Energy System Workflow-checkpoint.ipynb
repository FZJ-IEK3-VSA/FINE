# %% [markdown]
# # Workflow for a multi-regional energy system
#
# In this application of the FINE framework, a multi-regional energy system is modeled and optimized.
#
# All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
# The workflow is structures as follows:
# 1. Required packages are imported and the input data path is set
# 2. An energy system model instance is created
# 3. Commodity sources are added to the energy system model
# 4. Commodity conversion components are added to the energy system model
# 5. Commodity storages are added to the energy system model
# 6. Commodity transmission components are added to the energy system model
# 7. Commodity sinks are added to the energy system model
# 8. The energy system model is optimized
# 9. Selected optimization results are presented

# %% [markdown]
# # 1. Import required packages and set input data path
#
# The FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import FINE as fn
from getData import getData
import pandas as pd
data = getData()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 2. Create an energy system model instance
#
# The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
# The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {'cluster_0', 'cluster_1', 'cluster_2', 'cluster_3', 'cluster_4', 'cluster_5', 'cluster_6', 'cluster_7'}
commodityUnitDict = {'electricity': 'GW_el', 'methane': 'GW_CH4_LHV', 'biogas': 'GW_biogas_LHV',
                     'CO2': 'Mio. t CO2/h', 'hydrogen': 'GW_H2_LHV'}
commodities = {'electricity', 'hydrogen', 'methane', 'biogas', 'CO2'}
numberOfTimeSteps=8760
hoursPerTimeStep=1

# %%
esM = fn.EnergySystemModel(locations=locations, commodities=commodities, numberOfTimeSteps=8760,
                           commodityUnitsDict=commodityUnitDict,
                           hoursPerTimeStep=1, costUnit='1e9 Euro', lengthUnit='km', verboseLogLevel=0)

# %%
CO2_reductionTarget = 1

# %% [markdown]
# # 3. Add commodity sources to the energy system model

# %% [markdown]
# ## 3.1. Electricity sources

# %% [markdown]
# ### Wind onshore

# %%
esM.add(fn.Source(esM=esM, name='Wind (onshore)', commodity='electricity', hasCapacityVariable=True,
                  operationRateMax=data['Wind (onshore), operationRateMax'],
                  capacityMax=data['Wind (onshore), capacityMax'],
                  investPerCapacity=1.1, opexPerCapacity=1.1*0.02, interestRate=0.08,
                  economicLifetime=20))

# %% [markdown]
# Full load hours:

# %%
data['Wind (onshore), operationRateMax'].sum()
# Out:
# cluster_0    2300.406907
# cluster_1    1082.032187
# cluster_2    1447.812026
# cluster_3    1448.827987
# cluster_4    1935.618218
# cluster_5    1757.696047
# cluster_6    1286.944636
# cluster_7    1199.380071
# dtype: float64

# %% [markdown]
# ### Wind offshore

# %%
esM.add(fn.Source(esM=esM, name='Wind (offshore)', commodity='electricity', hasCapacityVariable=True,
                  operationRateMax=data['Wind (offshore), operationRateMax'],
                  capacityMax=data['Wind (offshore), capacityMax'],
                  investPerCapacity=2.3, opexPerCapacity=2.3*0.02, interestRate=0.08,
                  economicLifetime=20))

# %% [markdown]
# Full load hours:

# %%
data['Wind (offshore), operationRateMax'].sum()
# Out:
# cluster_0    4332.977326
# cluster_1       0.000000
# cluster_2       0.000000
# cluster_3       0.000000
# cluster_4    3963.044612
# cluster_5    3459.283279
# cluster_6       0.000000
# cluster_7       0.000000
# dtype: float64

# %% [markdown]
# ### PV

# %%
esM.add(fn.Source(esM=esM, name='PV', commodity='electricity', hasCapacityVariable=True,
                  operationRateMax=data['PV, operationRateMax'], capacityMax=data['PV, capacityMax'],
                  investPerCapacity=0.65, opexPerCapacity=0.65*0.02, interestRate=0.08,
                  economicLifetime=25))

# %% [markdown]
# Full load hours:

# %%
data['PV, operationRateMax'].sum()
# Out:
# cluster_0    859.175855
# cluster_1    970.535848
# cluster_2    913.049274
# cluster_3    917.880212
# cluster_4    875.448945
# cluster_5    904.590003
# cluster_6    984.223517
# cluster_7    992.311727
# dtype: float64

# %% [markdown]
# ### Exisisting run-of-river hydroelectricity plants

# %%
esM.add(fn.Source(esM=esM, name='Existing run-of-river plants', commodity='electricity',
                  hasCapacityVariable=True,
                  operationRateFix=data['Existing run-of-river plants, operationRateFix'],
                  capacityFix=data['Existing run-of-river plants, capacityFix'],
                  investPerCapacity=0, opexPerCapacity=0.208))

# %% [markdown]
# ## 3.2. Methane (natural gas and biogas)

# %% [markdown]
# ### Natural gas

# %%
esM.add(fn.Source(esM=esM, name='Natural gas purchase', commodity='methane',
                  hasCapacityVariable=False, commodityCost=0.0331*1e-3))

# %% [markdown]
# ### Biogas

# %%
esM.add(fn.Source(esM=esM, name='Biogas purchase', commodity='biogas',
                  operationRateMax=data['Biogas, operationRateMax'], hasCapacityVariable=False,
                  commodityCost=0.05409*1e-3))

# %% [markdown]
# ## 3.3 CO2

# %% [markdown]
# ### CO2
#
# The CO2 source is required for the case in which it can be mixed with conventional natural gas.

# %%
esM.add(fn.Source(esM=esM, name='CO2 from enviroment', commodity='CO2',
                  hasCapacityVariable=False, commodityLimitID='CO2 limit', yearlyLimit=366*(1-CO2_reductionTarget)))

# %% [markdown]
# # 4. Add conversion components to the energy system model

# %% [markdown]
# ### Combined cycle gas turbine plants

# %%
esM.add(fn.Conversion(esM=esM, name='CCGT plants (methane)', physicalUnit='GW_el',
                      commodityConversionFactors={'electricity':1, 'methane':-1/0.625, 'CO2':201*1e-6/0.625},
                      hasCapacityVariable=True,
                      investPerCapacity=0.65, opexPerCapacity=0.021, interestRate=0.08,
                      economicLifetime=33))

# %% [markdown]
# ### New combined cycle gas turbine plants for biogas

# %%
esM.add(fn.Conversion(esM=esM, name='New CCGT plants (biogas)', physicalUnit='GW_el',
                      commodityConversionFactors={'electricity':1, 'biogas':-1/0.635},
                      hasCapacityVariable=True, 
                      investPerCapacity=0.7, opexPerCapacity=0.021, interestRate=0.08,
                      economicLifetime=33))

# %% [markdown]
# ### New combined cycly gas turbines for hydrogen

# %%
esM.add(fn.Conversion(esM=esM, name='New CCGT plants (hydrogen)', physicalUnit='GW_el',
                      commodityConversionFactors={'electricity':1, 'hydrogen':-1/0.6},
                      hasCapacityVariable=True, 
                      investPerCapacity=0.7, opexPerCapacity=0.021, interestRate=0.08,
                      economicLifetime=33))

# %% [markdown]
# ### Electrolyzers

# %%
esM.add(fn.Conversion(esM=esM, name='Electroylzers', physicalUnit='GW_el',
                      commodityConversionFactors={'electricity':-1, 'hydrogen':0.7},
                      hasCapacityVariable=True, 
                      investPerCapacity=0.5, opexPerCapacity=0.5*0.025, interestRate=0.08,
                      economicLifetime=10))

# %% [markdown]
# ### rSOC

# %%
capexRSOC=1.5

esM.add(fn.Conversion(esM=esM, name='rSOEC', physicalUnit='GW_el', linkedConversionCapacityID='rSOC',
                      commodityConversionFactors={'electricity':-1, 'hydrogen':0.6},
                      hasCapacityVariable=True, 
                      investPerCapacity=capexRSOC/2, opexPerCapacity=capexRSOC*0.02/2, interestRate=0.08,
                      economicLifetime=10))

esM.add(fn.Conversion(esM=esM, name='rSOFC', physicalUnit='GW_el', linkedConversionCapacityID='rSOC',
                      commodityConversionFactors={'electricity':1, 'hydrogen':-1/0.6},
                      hasCapacityVariable=True, 
                      investPerCapacity=capexRSOC/2, opexPerCapacity=capexRSOC*0.02/2, interestRate=0.08,
                      economicLifetime=10))

# %% [markdown]
# # 5. Add commodity storages to the energy system model

# %% [markdown]
# ## 5.1. Electricity storage

# %% [markdown]
# ### Lithium ion batteries
#
# The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(fn.Storage(esM=esM, name='Li-ion batteries', commodity='electricity',
                   hasCapacityVariable=True, chargeEfficiency=0.95,
                   cyclicLifetime=10000, dischargeEfficiency=0.95, selfDischarge=1-(1-0.03)**(1/(30*24)),
                   chargeRate=1, dischargeRate=1, doPreciseTsaModeling=False,
                   investPerCapacity=0.151, opexPerCapacity=0.002, interestRate=0.08,
                   economicLifetime=22))

# %% [markdown]
# ## 5.2. Hydrogen storage

# %% [markdown]
# ### Hydrogen filled salt caverns
# The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(fn.Storage(esM=esM, name='Salt caverns (hydrogen)', commodity='hydrogen',
                   hasCapacityVariable=True, capacityVariableDomain='continuous',
                   capacityPerPlantUnit=133,
                   chargeRate=1/470.37, dischargeRate=1/470.37, sharedPotentialID='Existing salt caverns',
                   stateOfChargeMin=0.33, stateOfChargeMax=1, capacityMax=data['Salt caverns (hydrogen), capacityMax'],
                   investPerCapacity=0.00011, opexPerCapacity=0.00057, interestRate=0.08,
                   economicLifetime=30))

# %% [markdown]
# ## 5.3. Methane storage

# %% [markdown]
# ### Methane filled salt caverns

# %%
esM.add(fn.Storage(esM=esM, name='Salt caverns (biogas)', commodity='biogas',
                   hasCapacityVariable=True, capacityVariableDomain='continuous',
                   capacityPerPlantUnit=443,
                   chargeRate=1/470.37, dischargeRate=1/470.37, sharedPotentialID='Existing salt caverns',
                   stateOfChargeMin=0.33, stateOfChargeMax=1, capacityMax=data['Salt caverns (methane), capacityMax'],
                   investPerCapacity=0.00004, opexPerCapacity=0.00001, interestRate=0.08,
                   economicLifetime=30))

# %% [markdown]
# ## 5.4 Pumped hydro storage

# %% [markdown]
# ### Pumped hydro storage

# %%
esM.add(fn.Storage(esM=esM, name='Pumped hydro storage', commodity='electricity',
                   chargeEfficiency=0.88, dischargeEfficiency=0.88,
                   hasCapacityVariable=True, selfDischarge=1-(1-0.00375)**(1/(30*24)),
                   chargeRate=0.16, dischargeRate=0.12, capacityFix=data['Pumped hydro storage, capacityFix'],
                   investPerCapacity=0, opexPerCapacity=0.000153))

# %% [markdown]
# # 6. Add commodity transmission components to the energy system model

# %% [markdown]
# ## 6.1. Electricity transmission

# %% [markdown]
# ### AC cables

# %% [markdown]
# esM.add(fn.LinearOptimalPowerFlow(esM=esM, name='AC cables', commodity='electricity',
#                                   hasCapacityVariable=True, capacityFix=data['AC cables, capacityFix'],
#                                   reactances=data['AC cables, reactances']))

# %%
esM.add(fn.Transmission(esM=esM, name='AC cables', commodity='electricity',
                                  hasCapacityVariable=True, capacityFix=data['AC cables, capacityFix']))
# Out:
# The distances of a component are set to a normalized values of 1.

# %% [markdown]
# ### DC cables

# %%
esM.add(fn.Transmission(esM=esM, name='DC cables', commodity='electricity', losses=data['DC cables, losses'],
                        distances=data['DC cables, distances'],
                        hasCapacityVariable=True, capacityFix=data['DC cables, capacityFix']))

# %% [markdown]
# ## 6.2 Methane transmission

# %% [markdown]
# ### Methane pipeline

# %%
esM.add(fn.Transmission(esM=esM, name='Pipelines (biogas)', commodity='biogas', 
                        distances=data['Pipelines, distances'],
                        hasCapacityVariable=True, hasIsBuiltBinaryVariable=False, bigM=300,
                        locationalEligibility=data['Pipelines, eligibility'],
                        capacityMax=data['Pipelines, eligibility']*15, sharedPotentialID='pipelines',
                        investPerCapacity=0.000037, investIfBuilt=0.000314,
                        interestRate=0.08, economicLifetime=40))

# %% [markdown]
# esM.getComponent('Pipelines (methane)')._mapC['cluster_0_cluster_4'][1]

# %% [markdown]
# ## 6.3 Hydrogen transmission

# %% [markdown]
# ### Hydrogen pipelines

# %%
esM.add(fn.Transmission(esM=esM, name='Pipelines (hydrogen)', commodity='hydrogen',
                        distances=data['Pipelines, distances'],
                        hasCapacityVariable=True, hasIsBuiltBinaryVariable=False, bigM=300,
                        locationalEligibility=data['Pipelines, eligibility'],
                        capacityMax=data['Pipelines, eligibility']*15, sharedPotentialID='pipelines',
                        investPerCapacity=0.000177, investIfBuilt=0.00033,
                        interestRate=0.08, economicLifetime=40))

# %% [markdown]
# esM.getComponent('Pipeline (hydrogen)')._mapC

# %% [markdown]
# # 7. Add commodity sinks to the energy system model

# %% [markdown]
# ## 7.1. Electricity sinks

# %% [markdown]
# ### Electricity demand

# %%
esM.add(fn.Sink(esM=esM, name='Electricity demand', commodity='electricity',
                hasCapacityVariable=False, operationRateFix=data['Electricity demand, operationRateFix']))

# %% [markdown]
# ## 7.2. Hydrogen sinks

# %% [markdown]
# ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration=0.5
esM.add(fn.Sink(esM=esM, name='Hydrogen demand', commodity='hydrogen', hasCapacityVariable=False,
                operationRateFix=data['Hydrogen demand, operationRateFix']*FCEV_penetration))

# %% [markdown]
# ## 7.3. CO2 sinks

# %% [markdown]
# ### CO2 exiting the system's boundary

# %%
esM.add(fn.Sink(esM=esM, name='CO2 to enviroment', commodity='CO2',
                hasCapacityVariable=False, commodityLimitID='CO2 limit', yearlyLimit=366*(1-CO2_reductionTarget)))

# %% [markdown]
# # 8. Optimize energy system model

# %% [markdown]
# All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
esM.cluster(numberOfTypicalPeriods=7)
# Out:
# Clustering time series data with 7 typical periods and 24 time steps per period...
# 		(3.2760 sec)

# %%
esM.optimize(timeSeriesAggregation=True, optimizationSpecs='OptimalityTol=1e-3 cuts=0 method=2')
# Out:
# Time series aggregation specifications:
# Number of typical periods:7, number of time steps per periods:24
#
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.3190 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.2420 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.9510 sec)
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.4520 sec)
#
# Declaring shared potential constraint...
# 		(0.0020 sec)
#
# Declaring commodity balances...
# 		(0.7850 sec)
#
# Declaring objective function...
# 		(0.5680 sec)
#
# Academic license - for non-commercial use only
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Changed value of parameter logfile to job
#    Prev: gurobi.log  Default:
# Changed value of parameter Threads to 3
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Changed value of parameter method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Changed value of parameter OptimalityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Changed value of parameter cuts to 0
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Optimize a model with 82655 rows, 53680 columns and 251636 nonzeros
# Coefficient statistics:
#   Matrix range     [1e-06, 5e+02]
#   Objective range  [2e-06, 3e-01]
#   Bounds range     [2e+01, 6e+04]
#   RHS range        [4e-02, 2e+01]
# Presolve removed 29633 rows and 21505 columns
# Presolve time: 0.11s
# Presolved: 53022 rows, 32175 columns, 220377 nonzeros
#
# Ordering time: 0.80s
#
# Barrier statistics:
#  Dense cols : 200
#  Free vars  : 560
#  AA' NZ     : 1.551e+06
#  Factor NZ  : 7.229e+06 (roughly 100 MBytes of memory)
#  Factor Ops : 2.719e+09 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.39877067e+03 -5.31643890e+02  4.22e+04 1.24e-02  6.59e+01     1s
#    1   7.03057144e+03 -2.82965649e+03  3.45e+04 4.41e-02  4.39e+01     1s
#    2   5.33859515e+03 -4.96717975e+03  2.38e+04 2.59e-02  2.99e+01     1s
#    3   4.19255813e+03 -9.36340657e+03  8.28e+03 7.19e-03  1.04e+01     1s
#    4   3.04538925e+03 -1.51233681e+04  1.26e+03 1.27e-03  2.05e+00     2s
#    5   2.03323592e+03 -9.69814343e+03  1.27e+01 3.89e-04  3.52e-01     2s
#    6   1.16640710e+03 -6.69036348e+03  4.68e+00 1.26e-04  1.73e-01     2s
#    7   7.89003440e+02 -2.97498297e+03  2.55e+00 3.34e-04  7.12e-02     2s
#    8   3.33010100e+02 -1.04055321e+03  3.34e-01 1.84e-04  1.97e-02     2s
#    9   2.18017977e+02 -5.17618240e+02  5.21e-02 1.15e-04  9.77e-03     2s
#   10   1.52066136e+02 -1.67876740e+02  1.38e-02 1.21e-04  4.12e-03     2s
#   11   1.29228224e+02 -6.42826403e+01  9.97e-03 9.02e-05  2.46e-03     2s
#   12   1.03673556e+02 -1.30282441e+01  4.92e-03 6.54e-05  1.48e-03     2s
#   13   9.47151916e+01  1.06850360e+00  3.62e-03 5.42e-05  1.19e-03     2s
#   14   8.55395809e+01  3.80786583e+01  2.33e-03 3.13e-05  5.96e-04     2s
#   15   7.65501464e+01  5.12104046e+01  1.20e-03 1.89e-05  3.15e-04     3s
#   16   7.18092886e+01  6.05885714e+01  5.79e-04 7.76e-06  1.39e-04     3s
#   17   6.98875873e+01  6.32981044e+01  3.53e-04 4.12e-06  8.11e-05     3s
#   18   6.89549345e+01  6.45213857e+01  2.34e-04 2.63e-06  5.45e-05     3s
#   19   6.87139031e+01  6.51500418e+01  2.01e-04 1.93e-06  4.37e-05     3s
#   20   6.81802134e+01  6.60597238e+01  1.28e-04 1.09e-06  2.60e-05     3s
#   21   6.79339539e+01  6.66095894e+01  9.47e-05 6.28e-07  1.62e-05     3s
#   22   6.76743253e+01  6.68511686e+01  5.86e-05 4.12e-07  1.01e-05     3s
#   23   6.74848977e+01  6.70383499e+01  3.15e-05 2.35e-07  5.46e-06     3s
#   24   6.74224527e+01  6.71630832e+01  2.14e-05 1.16e-07  3.17e-06     4s
#   25   6.73701071e+01  6.72006036e+01  1.26e-05 8.14e-08  2.07e-06     4s
#   26   6.73510204e+01  6.72291857e+01  9.59e-06 5.45e-08  1.49e-06     4s
#   27   6.73404805e+01  6.72440571e+01  7.94e-06 4.17e-08  1.18e-06     4s
#   28   6.73267416e+01  6.72635544e+01  5.96e-06 2.22e-08  7.72e-07     4s
#   29   6.73050507e+01  6.72800992e+01  2.37e-06 1.69e-08  3.05e-07     4s
#   30   6.72993338e+01  6.72819646e+01  1.51e-06 1.50e-08  2.12e-07     4s
#   31   6.72968293e+01  6.72854109e+01  1.10e-06 9.71e-09  1.39e-07     4s
#   32   6.72936596e+01  6.72878597e+01  5.97e-07 4.55e-09  7.08e-08     4s
#   33   6.72913319e+01  6.72889635e+01  2.28e-07 1.80e-09  2.91e-08     5s
#   34   6.72905054e+01  6.72895656e+01  9.71e-08 7.39e-10  1.17e-08     5s
#   35   6.72901277e+01  6.72897424e+01  5.01e-08 3.40e-10  5.23e-09     5s
#   36   6.72899938e+01  6.72897999e+01  3.48e-08 2.11e-10  2.96e-09     5s
#   37   6.72899265e+01  6.72898204e+01  2.18e-08 1.69e-10  1.92e-09     5s
#   38   6.72898657e+01  6.72898288e+01  1.20e-08 1.74e-10  1.01e-09     5s
#   39   6.72898542e+01  6.72898387e+01  9.07e-09 1.75e-10  5.29e-10     5s
#   40   6.72898452e+01  6.72898369e+01  5.76e-09 1.38e-10  3.64e-10     5s
#   41   6.72898336e+01  6.72898314e+01  3.33e-09 1.42e-09  2.40e-10     5s
#   42   6.72898321e+01  6.72898330e+01  3.04e-09 1.37e-09  2.10e-10     5s
#   43   6.72898233e+01  6.72898332e+01  2.56e-09 6.82e-10  9.90e-11     6s
#   44   6.72898224e+01  6.72898313e+01  4.19e-08 5.56e-10  8.07e-11     6s
#   45   6.72898202e+01  6.72897884e+01  2.89e-08 2.76e-08  5.85e-11     6s
#   46   6.72898196e+01  6.72897780e+01  2.28e-08 6.67e-08  5.08e-11     6s
#   47   6.72898194e+01  6.72897953e+01  2.68e-08 4.72e-08  4.20e-11     6s
#   48   6.72898181e+01  6.72898087e+01  5.07e-08 2.48e-08  2.16e-11     6s
#   49   6.72898175e+01  6.72891864e+01  3.85e-08 5.00e-08  1.72e-11     6s
#   50   6.72898174e+01  6.72893675e+01  4.59e-08 3.57e-08  1.44e-11     6s
#   51   6.72898171e+01  6.72896647e+01  3.14e-08 1.23e-08  8.33e-12     7s
#   52   6.72898169e+01  6.72896812e+01  1.23e-07 1.50e-08  6.95e-12     7s
#
# Barrier solved model in 52 iterations and 6.61 seconds
# Optimal objective 6.72898169e+01
#
# Crossover log...
#
#     1129 DPushes remaining with DInf 9.0309406e+00                 7s
#        0 DPushes remaining with DInf 1.1909456e+02                 7s
#
#    12773 PPushes remaining with PInf 6.2441197e-03                 7s
#        0 PPushes remaining with PInf 0.0000000e+00                 7s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.6709476e+00      7s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    13436    6.7289818e+01   0.000000e+00   3.635302e+00      7s
#    13872    6.7289818e+01   0.000000e+00   0.000000e+00      8s
#
# Solved in 13872 iterations and 7.64 seconds
# Optimal objective  6.728981767e+01
# Freed default Gurobi environment
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 7.64100074768
# Error rc: 0
# Time: 8.3510000705719
#
#
# Name: x53680
# Lower bound: 67.2898176733
# Upper bound: 67.2898176733
# Number of objectives: 1
# Number of constraints: 82655
# Number of variables: 53680
# Number of binary variables: 0
# Number of integer variables: 0
# Number of continuous variables: 53680
# Number of nonzeros: 251636
# Sense: minimize
#
# Solve time: 13.77299976348877 sec.
#
# Processing optimization output...
# for TransmissionModel ...  (1.9630sec)
# for ConversionModel ...    (0.7220sec)
# for StorageModel ...       (2.1780sec)
# for SourceSinkModel ...    (0.9060sec)
# 		(5.7690 sec)

# %% [markdown]
# # 9. Selected results output

# %% [markdown]
# ### Sources and Sink

# %%
esM.getOptimizationSummary("SourceSinkModel", outputLevel=2).sum(axis=1)
# Out:
# Component                     Property     Unit
# Biogas purchase               TAC          [1e9 Euro/a]                3.907083
#                               commodCosts  [1e9 Euro/a]                3.907083
#                               operation    [GW_biogas_LHV*h/a]     72233.000000
# Electricity demand            operation    [GW_el*h/a]            512651.650200
# Existing run-of-river plants  TAC          [1e9 Euro/a]                0.792688
#                               capacity     [GW_el]                     3.811000
#                               operation    [GW_el*h/a]             18683.000000
#                               opexCap      [1e9 Euro/a]                0.792688
# Hydrogen demand               operation    [GW_H2_LHV*h/a]         66726.660000
# PV                            TAC          [1e9 Euro/a]               14.778241
#                               capacity     [GW_el]                   199.999992
#                               capexCap     [1e9 Euro/a]               12.178241
#                               invest       [1e9 Euro]                129.999995
#                               operation    [GW_el*h/a]            168097.369437
#                               opexCap      [1e9 Euro/a]                2.600000
# Wind (offshore)               TAC          [1e9 Euro/a]               16.815605
#                               capacity     [GW_el]                    60.000000
#                               capexCap     [1e9 Euro/a]               14.055605
#                               invest       [1e9 Euro]                138.000000
#                               operation    [GW_el*h/a]            202648.332413
#                               opexCap      [1e9 Euro/a]                2.760000
# Wind (onshore)                TAC          [1e9 Euro/a]               17.807225
#                               capacity     [GW_el]                   132.852629
#                               capexCap     [1e9 Euro/a]               14.884467
#                               invest       [1e9 Euro]                146.137892
#                               operation    [GW_el*h/a]            188259.123521
#                               opexCap      [1e9 Euro/a]                2.922758
# dtype: float64

# %% [markdown]
# ### Conversion

# %%
esM.getOptimizationSummary("ConversionModel", outputLevel=2)
# Out:
#                                                   cluster_0   cluster_1  \
# Component                  Property  Unit
# Electroylzers              TAC       [1e9 Euro/a]   1.91398           0
#                            capacity  [GW_el]         21.996           0
#                            capexCap  [1e9 Euro/a]   1.63903           0
#                            invest    [1e9 Euro]      10.998           0
#                            operation [GW_el*h/a]    74457.3           0
#                            opexCap   [1e9 Euro/a]   0.27495           0
# New CCGT plants (biogas)   TAC       [1e9 Euro/a]         0   0.0446187
#                            capacity  [GW_el]              0    0.545487
#                            capexCap  [1e9 Euro/a]         0   0.0331635
#                            invest    [1e9 Euro]           0    0.381841
#                            operation [GW_el*h/a]          0     1207.71
#                            opexCap   [1e9 Euro/a]         0   0.0114552
# New CCGT plants (hydrogen) TAC       [1e9 Euro/a]         0  0.00983975
#                            capacity  [GW_el]              0    0.120296
#                            capexCap  [1e9 Euro/a]         0  0.00731353
#                            invest    [1e9 Euro]           0   0.0842072
#                            operation [GW_el*h/a]          0     420.434
#                            opexCap   [1e9 Euro/a]         0  0.00252622
#
#                                                     cluster_2 cluster_3  \
# Component                  Property  Unit
# Electroylzers              TAC       [1e9 Euro/a]           0         0
#                            capacity  [GW_el]                0         0
#                            capexCap  [1e9 Euro/a]           0         0
#                            invest    [1e9 Euro]             0         0
#                            operation [GW_el*h/a]            0         0
#                            opexCap   [1e9 Euro/a]           0         0
# New CCGT plants (biogas)   TAC       [1e9 Euro/a]    0.735489  0.491667
#                            capacity  [GW_el]          8.99173   6.01088
#                            capexCap  [1e9 Euro/a]    0.546663  0.365438
#                            invest    [1e9 Euro]       6.29421   4.20761
#                            operation [GW_el*h/a]      19057.9   12809.3
#                            opexCap   [1e9 Euro/a]    0.188826  0.126228
# New CCGT plants (hydrogen) TAC       [1e9 Euro/a]   0.0294166         0
#                            capacity  [GW_el]         0.359633         0
#                            capexCap  [1e9 Euro/a]   0.0218643         0
#                            invest    [1e9 Euro]      0.251743         0
#                            operation [GW_el*h/a]       1236.9         0
#                            opexCap   [1e9 Euro/a]  0.00755228         0
#
#                                                    cluster_4  cluster_5  \
# Component                  Property  Unit
# Electroylzers              TAC       [1e9 Euro/a]   0.674155          0
#                            capacity  [GW_el]         7.74759          0
#                            capexCap  [1e9 Euro/a]    0.57731          0
#                            invest    [1e9 Euro]      3.87379          0
#                            operation [GW_el*h/a]     25730.5          0
#                            opexCap   [1e9 Euro/a]  0.0968449          0
# New CCGT plants (biogas)   TAC       [1e9 Euro/a]   0.215196   0.119498
#                            capacity  [GW_el]         2.63088    1.46092
#                            capexCap  [1e9 Euro/a]   0.159948  0.0888184
#                            invest    [1e9 Euro]      1.84162    1.02265
#                            operation [GW_el*h/a]     6056.86    3163.13
#                            opexCap   [1e9 Euro/a]  0.0552486  0.0306794
# New CCGT plants (hydrogen) TAC       [1e9 Euro/a]          0          0
#                            capacity  [GW_el]               0          0
#                            capexCap  [1e9 Euro/a]          0          0
#                            invest    [1e9 Euro]            0          0
#                            operation [GW_el*h/a]           0          0
#                            opexCap   [1e9 Euro/a]          0          0
#
#                                                    cluster_6   cluster_7
# Component                  Property  Unit
# Electroylzers              TAC       [1e9 Euro/a]          0           0
#                            capacity  [GW_el]               0           0
#                            capexCap  [1e9 Euro/a]          0           0
#                            invest    [1e9 Euro]            0           0
#                            operation [GW_el*h/a]           0           0
#                            opexCap   [1e9 Euro/a]          0           0
# New CCGT plants (biogas)   TAC       [1e9 Euro/a]  0.0513822   0.0796087
#                            capacity  [GW_el]        0.628174    0.973258
#                            capexCap  [1e9 Euro/a]  0.0381905   0.0591703
#                            invest    [1e9 Euro]     0.439722    0.681281
#                            operation [GW_el*h/a]     1437.89     2135.25
#                            opexCap   [1e9 Euro/a]  0.0131916   0.0204384
# New CCGT plants (hydrogen) TAC       [1e9 Euro/a]          0  0.00964341
#                            capacity  [GW_el]               0    0.117896
#                            capexCap  [1e9 Euro/a]          0   0.0071676
#                            invest    [1e9 Euro]            0   0.0825269
#                            operation [GW_el*h/a]           0     385.528
#                            opexCap   [1e9 Euro/a]          0  0.00247581

# %% [markdown]
# ### Storage

# %%
esM.getOptimizationSummary("StorageModel", outputLevel=2).sum(axis=1)
# Out:
# Component                Property            Unit
# Li-ion batteries         TAC                 [1e9 Euro/a]               3.756834
#                          capacity            [GW_el*h]                223.583248
#                          capexCap            [1e9 Euro/a]               3.309668
#                          invest              [1e9 Euro]                33.761070
#                          operationCharge     [GW_el*h/a]            76409.498829
#                          operationDischarge  [GW_el*h/a]            68920.251035
#                          opexCap             [1e9 Euro/a]               0.447166
# Pumped hydro storage     TAC                 [1e9 Euro/a]               0.009971
#                          capacity            [GW_el*h]                 65.173000
#                          operationCharge     [GW_el*h/a]            22583.583677
#                          operationDischarge  [GW_el*h/a]            17487.402211
#                          opexCap             [1e9 Euro/a]               0.009971
# Salt caverns (biogas)    TAC                 [1e9 Euro/a]               0.361272
#                          capacity            [GW_biogas_LHV*h]      26656.016674
#                          capexCap            [1e9 Euro/a]               0.094711
#                          invest              [1e9 Euro]                 1.066241
#                          operationCharge     [GW_biogas_LHV*h/a]    54309.090665
#                          operationDischarge  [GW_biogas_LHV*h/a]    54309.090665
#                          opexCap             [1e9 Euro/a]               0.266560
# Salt caverns (hydrogen)  TAC                 [1e9 Euro/a]               4.685803
#                          capacity            [GW_H2_LHV*h]           8082.161061
#                          capexCap            [1e9 Euro/a]               0.078971
#                          invest              [1e9 Euro]                 0.889038
#                          operationCharge     [GW_H2_LHV*h/a]        43489.449951
#                          operationDischarge  [GW_H2_LHV*h/a]        43489.449951
#                          opexCap             [1e9 Euro/a]               4.606832
# dtype: float64

# %% [markdown]
# ## Transmission

# %%
esM.getOptimizationSummary("TransmissionModel", outputLevel=2)
# Out:
#                                                             cluster_0  \
# AC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3      2.39577
#                                                cluster_4      3.26266
#                                                cluster_5      2.39577
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3      1797.06
#                                                cluster_4      2927.36
#                                                cluster_5      1142.78
#                                                cluster_6         None
#                                                cluster_7         None
# DC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1            2
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7            2
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1       1589.8
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7          770
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      12.7305
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      capexCap  [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4  9.44811e-05
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      invest    [1e9 Euro]      cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4   0.00112665
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_H2_LHV*h/a] cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      767.817
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#
#                                                             cluster_1  \
# AC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1         None
#                                                cluster_2      8.90534
#                                                cluster_3      4.79155
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7       9.8668
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1         None
#                                                cluster_2      19075.8
#                                                cluster_3      31491.6
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7      33749.8
# DC cables            capacity  [GW_el]         cluster_0            2
#                                                cluster_1         None
#                                                cluster_2            2
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0      7865.74
#                                                cluster_1         None
#                                                cluster_2         1056
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2      7.14318
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7       3.5356
#                      capexCap  [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
#                                                cluster_2   5.3014e-05
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7  2.62399e-05
#                      invest    [1e9 Euro]      cluster_0         None
#                                                cluster_1         None
#                                                cluster_2  0.000632172
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7  0.000312901
#                      operation [GW_H2_LHV*h/a] cluster_0         None
#                                                cluster_1         None
#                                                cluster_2      28036.9
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7      2.23611
#
#                                                             cluster_2  \
# AC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1      8.90534
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      8.73196
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1      6162.48
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      63844.5
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
# DC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1            2
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4            2
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1            0
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      3805.82
#                                                cluster_7         None
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0         None
#                                                cluster_1  4.24045e-06
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      8.69004
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      capexCap  [1e9 Euro/a]    cluster_0         None
#                                                cluster_1   5.3014e-05
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4  6.44942e-05
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      invest    [1e9 Euro]      cluster_0         None
#                                                cluster_1  0.000632172
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4  0.000769068
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_H2_LHV*h/a] cluster_0         None
#                                                cluster_1            0
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      44563.7
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#
#                                                             cluster_3  \
# AC cables            capacity  [GW_el]         cluster_0      2.39577
#                                                cluster_1      4.79155
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      5.73725
#                                                cluster_5      13.3817
#                                                cluster_6       0.9457
#                                                cluster_7      3.59366
#                      operation [GW_el*h/a]     cluster_0      14576.6
#                                                cluster_1      1538.88
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      27512.2
#                                                cluster_5        49074
#                                                cluster_6      13.2398
#                                                cluster_7      178.896
# DC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7            4
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7            0
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      3.05709
#                                                cluster_5      1.53329
#                                                cluster_6         None
#                                                cluster_7         None
#                      capexCap  [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4  2.26886e-05
#                                                cluster_5  1.13795e-05
#                                                cluster_6         None
#                                                cluster_7         None
#                      invest    [1e9 Euro]      cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4  0.000270552
#                                                cluster_5  0.000135696
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_H2_LHV*h/a] cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4      15850.1
#                                                cluster_5      142.394
#                                                cluster_6         None
#                                                cluster_7         None
#
#                                                             cluster_4  \
# AC cables            capacity  [GW_el]         cluster_0      3.26266
#                                                cluster_1         None
#                                                cluster_2      8.73196
#                                                cluster_3      5.73725
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0        13380
#                                                cluster_1         None
#                                                cluster_2      1494.77
#                                                cluster_3      5874.32
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
# DC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1         None
#                                                cluster_2            2
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1         None
#                                                cluster_2      64.8787
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0  1.47535e-06
#                                                cluster_1         None
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2      8.69004
#                                                cluster_3      3.05709
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      capexCap  [1e9 Euro/a]    cluster_0  9.44811e-05
#                                                cluster_1         None
#                                                cluster_2  6.44942e-05
#                                                cluster_3  2.26886e-05
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      invest    [1e9 Euro]      cluster_0   0.00112665
#                                                cluster_1         None
#                                                cluster_2  0.000769068
#                                                cluster_3  0.000270552
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_H2_LHV*h/a] cluster_0      48122.9
#                                                cluster_1         None
#                                                cluster_2      1578.52
#                                                cluster_3      187.341
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#
#                                                             cluster_5  \
# AC cables            capacity  [GW_el]         cluster_0      2.39577
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3      13.3817
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6      1.79683
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0      14582.7
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3      948.259
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6      595.227
#                                                cluster_7         None
# DC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2         None
#                                                cluster_3      1.53329
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      capexCap  [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3  1.13795e-05
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      invest    [1e9 Euro]      cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3  0.000135696
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#                      operation [GW_H2_LHV*h/a] cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3      8030.46
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7         None
#
#                                                             cluster_6  \
# AC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3       0.9457
#                                                cluster_4         None
#                                                cluster_5      1.79683
#                                                cluster_6         None
#                                                cluster_7      6.17857
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3      5396.16
#                                                cluster_4         None
#                                                cluster_5      10663.6
#                                                cluster_6         None
#                                                cluster_7      979.387
# DC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_7         None
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7      1.69778
#                      capexCap  [1e9 Euro/a]    cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7  1.26003e-05
#                      invest    [1e9 Euro]      cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7  0.000150254
#                      operation [GW_H2_LHV*h/a] cluster_0         None
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6         None
#                                                cluster_7       6348.3
#
#                                                             cluster_7
# AC cables            capacity  [GW_el]         cluster_0         None
#                                                cluster_1       9.8668
#                                                cluster_2         None
#                                                cluster_3      3.59366
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6      6.17857
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0         None
#                                                cluster_1      152.741
#                                                cluster_2         None
#                                                cluster_3      27486.6
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6      18338.1
#                                                cluster_7         None
# DC cables            capacity  [GW_el]         cluster_0            2
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3            4
#                                                cluster_4         None
#                                                cluster_7         None
#                      operation [GW_el*h/a]     cluster_0      7045.36
#                                                cluster_1         None
#                                                cluster_2         None
#                                                cluster_3      7733.89
#                                                cluster_4         None
#                                                cluster_7         None
# Pipelines (biogas)   TAC       [1e9 Euro/a]    cluster_0         None
#                                                cluster_1  2.90774e-06
# ...                                                               ...
# Pipelines (hydrogen) capacity  [GW_H2_LHV]     cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6      1.69778
#                                                cluster_7         None
#                      capexCap  [1e9 Euro/a]    cluster_0         None
#                                                cluster_1  2.62399e-05
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6  1.26003e-05
#                                                cluster_7         None
#                      invest    [1e9 Euro]      cluster_0         None
#                                                cluster_1  0.000312901
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6  0.000150254
#                                                cluster_7         None
#                      operation [GW_H2_LHV*h/a] cluster_0         None
#                                                cluster_1      13857.1
#                                                cluster_2         None
#                                                cluster_3         None
#                                                cluster_4         None
#                                                cluster_5         None
#                                                cluster_6      3.81007
#                                                cluster_7         None
#
# [108 rows x 8 columns]

# %%
df=esM.componentModelingDict["TransmissionModel"].capacityVariablesOptimum
df.loc['Pipelines (biogas)']+df.loc['Pipelines (hydrogen)']
# Out:
#            cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  \
# cluster_0        NaN        NaN        NaN        NaN  13.681481        NaN
# cluster_1        NaN        NaN   9.876467        NaN        NaN        NaN
# cluster_2        NaN   9.876467        NaN        NaN  10.935732        NaN
# cluster_3        NaN        NaN        NaN        NaN   3.787620   2.787022
# cluster_4  13.681481        NaN  10.935732   3.787620        NaN        NaN
# cluster_5        NaN        NaN        NaN   2.787022        NaN        NaN
# cluster_6        NaN        NaN        NaN        NaN        NaN        NaN
# cluster_7        NaN   5.409849        NaN        NaN        NaN        NaN
#
#            cluster_6  cluster_7
# cluster_0        NaN        NaN
# cluster_1        NaN   5.409849
# cluster_2        NaN        NaN
# cluster_3        NaN        NaN
# cluster_4        NaN        NaN
# cluster_5        NaN        NaN
# cluster_6        NaN   2.687030
# cluster_7    2.68703        NaN
