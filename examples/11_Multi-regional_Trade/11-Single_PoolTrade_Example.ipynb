# %% [markdown]
# # Workflow for a multi-regional energy system with pooledCommodities for trading via a trading pool
#
# In this application of the ETHOS.FINE framework, a multi-regional energy system is modeled and optimized, which uses pooledCommodities for trading within a trading pool.
#
# All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
# The workflow is structures as follows:
# 1. Required packages are imported and the input data path is set
# 2. An energy system model instance is created and pooledCommodities are defined
# 3. Commodity sources are added to the energy system model
# 4. Commodity conversion components are added to the energy system model
# 5. Commodity storages are added to the energy system model
# 6. Commodity Import and Export via Pooled Trade components are added to the energy system model
# 7. Commodity sinks are added to the energy system model
# 8. The energy system model is optimized
# 9. Selected optimization results are presented

# %% [markdown]
# # 1. Import required packages and set input data path
#
# The ETHOS.FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import fine as fn
from getData import getData, INPUT_DATA_PATH
import pandas as pd
from pathlib import Path

import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import TwoSlopeNorm

cwd = Path.cwd()
data = getData()

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 2. Create an energy system model instance
#
# The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
# The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {
    "cluster_0",
    "cluster_1",
    "cluster_2",
    "cluster_3",
    "cluster_4",
    "cluster_5",
    "cluster_6",
    "cluster_7",
}
commodityUnitDict = {
    "electricity": r"GW$_{el}$",
    "methane": r"GW$_{CH_{4},LHV}$",
    "biogas": r"GW$_{biogas,LHV}$",
    "CO2": r"Mio. t$_{CO_2}$/h",
    "hydrogen": r"GW$_{H_{2},LHV}$",
    "hydrogen_trade": r"GW$_{H_{2},LHV}$",
}

commodities = {"electricity", "hydrogen", "methane", "biogas", "CO2", "hydrogen_trade"}
numberOfTimeSteps = 8760
hoursPerTimeStep = 1

# %%
esM = fn.EnergySystemModel(
    locations=locations,
    commodities=commodities,
    numberOfTimeSteps=8760,
    commodityUnitsDict=commodityUnitDict,
    hoursPerTimeStep=1,
    costUnit="1e9 Euro",
    lengthUnit="km",
    verboseLogLevel=0,
    pooledCommodities={
        "hydrogen_trade": {
            "hydrogen_pool": [
                "cluster_0",
                "cluster_1",
                "cluster_2",
                "cluster_3",
                "cluster_4",
                "cluster_5",
                "cluster_6",
                "cluster_7",
            ]
        }
    },
)

# %% [markdown]
# # 3. Add commodity sources to the energy system model

# %% [markdown]
# ## 3.1. Electricity sources

# %% [markdown]
# ### Wind onshore

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Wind (onshore)",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (onshore), operationRateMax"],
        capacityMax=data["Wind (onshore), capacityMax"],
        investPerCapacity=1.1,
        opexPerCapacity=1.1 * 0.02,
        interestRate=0.08,
        economicLifetime=20,
    )
)

# %% [markdown]
# ### Wind offshore

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="Wind (offshore)",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["Wind (offshore), operationRateMax"],
        capacityMax=data["Wind (offshore), capacityMax"],
        investPerCapacity=2.3,
        opexPerCapacity=2.3 * 0.02,
        interestRate=0.08,
        economicLifetime=20,
    )
)

# %% [markdown]
# ### PV

# %%
esM.add(
    fn.Source(
        esM=esM,
        name="PV",
        commodity="electricity",
        hasCapacityVariable=True,
        operationRateMax=data["PV, operationRateMax"],
        capacityMax=data["PV, capacityMax"],
        investPerCapacity=0.65,
        opexPerCapacity=0.65 * 0.02,
        interestRate=0.08,
        economicLifetime=25,
    )
)

# %% [markdown]
# # 4. Add conversion components to the energy system model

# %% [markdown]
# ### New combined cycly gas turbines for hydrogen

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="New CCGT plants (hydrogen)",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": 1, "hydrogen": -1 / 0.63},
        hasCapacityVariable=True,
        investPerCapacity=0.7,
        opexPerCapacity=0.021,
        interestRate=0.08,
        economicLifetime=33,
    )
)

# %% [markdown]
# ### Electrolyzers

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="Electrolyzer",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"electricity": -1, "hydrogen": 0.7},
        hasCapacityVariable=True,
        investPerCapacity=0.5,
        opexPerCapacity=0.5 * 0.025,
        interestRate=0.08,
        economicLifetime=10,
    )
)

# %% [markdown]
# # 5. Add commodity storages to the energy system model

# %% [markdown]
# ## 5.1. Electricity storage

# %% [markdown]
# ### Lithium ion batteries
#
# The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Li-ion batteries",
        commodity="electricity",
        hasCapacityVariable=True,
        chargeEfficiency=0.95,
        cyclicLifetime=10000,
        dischargeEfficiency=0.95,
        selfDischarge=1 - (1 - 0.03) ** (1 / (30 * 24)),
        chargeRate=1,
        dischargeRate=1,
        doPreciseTsaModeling=False,
        investPerCapacity=0.151,
        opexPerCapacity=0.002,
        interestRate=0.08,
        economicLifetime=22,
    )
)

# %% [markdown]
# ## 5.2. Hydrogen storage

# %% [markdown]
# ### Hydrogen filled salt caverns
# The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(
    fn.Storage(
        esM=esM,
        name="Salt caverns (hydrogen)",
        commodity="hydrogen",
        hasCapacityVariable=True,
        capacityVariableDomain="continuous",
        capacityPerPlantUnit=133,
        chargeRate=1 / 470.37,
        dischargeRate=1 / 470.37,
        sharedPotentialID="Existing salt caverns",
        stateOfChargeMin=0.33,
        stateOfChargeMax=1,
        capacityMax=data["Salt caverns (hydrogen), capacityMax"],
        investPerCapacity=0.00011,
        opexPerCapacity=0.00057,
        interestRate=0.08,
        economicLifetime=30,
    )
)

# %% [markdown]
# # 6. Add commodity transmission components to the energy system model

# %% [markdown]
# ## 6.1. Electricity transmission

# %% [markdown]
# ### AC cables

# %% [markdown]
# esM.add(fn.LinearOptimalPowerFlow(esM=esM, name='AC cables', commodity='electricity',
#                                   hasCapacityVariable=True, capacityFix=data['AC cables, capacityFix'],
#                                   reactances=data['AC cables, reactances']))

# %%
esM.add(
    fn.Transmission(
        esM=esM,
        name="AC cables",
        commodity="electricity",
        hasCapacityVariable=True,
        capacityFix=data["AC cables, capacityFix"],
    )
)

# %% [markdown]
# ### DC cables

# %%
esM.add(
    fn.Transmission(
        esM=esM,
        name="DC cables",
        commodity="electricity",
        losses=data["DC cables, losses"],
        distances=data["DC cables, distances"],
        hasCapacityVariable=True,
        capacityFix=data["DC cables, capacityFix"],
    )
)

# %% [markdown]
# ## 6.3 Hydrogen transmission via Pooled Trade

# %% [markdown]
# ### Hydrogen Export

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="hydrogen_exp",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"hydrogen": -1, "hydrogen_trade": 1},
        opexPerOperation=1.5e-5,
    )
)
# Out:
# /fast/home/d-marmullaku/Projects/Hackathon_5/fine/fine/component.py:737: UserWarning: Component identifier hydrogen_exp already exists. Data will be overwritten.
#   warnings.warn(

# %% [markdown]
# ### Hydrogen Import

# %%
esM.add(
    fn.Conversion(
        esM=esM,
        name="hydrogen_imp",
        physicalUnit=r"GW$_{el}$",
        commodityConversionFactors={"hydrogen_trade": -1, "hydrogen": 1},
        opexPerOperation=1.5e-5,
    )
)
# Out:
# /fast/home/d-marmullaku/Projects/Hackathon_5/fine/fine/component.py:737: UserWarning: Component identifier hydrogen_imp already exists. Data will be overwritten.
#   warnings.warn(

# %% [markdown]
# # 7. Add commodity sinks to the energy system model

# %% [markdown]
# ## 7.1. Electricity sinks

# %% [markdown]
# ### Electricity demand

# %%
esM.add(
    fn.Sink(
        esM=esM,
        name="Electricity demand",
        commodity="electricity",
        hasCapacityVariable=False,
        operationRateFix=data["Electricity demand, operationRateFix"],
    )
)

# %% [markdown]
# ## 7.2. Hydrogen sinks

# %% [markdown]
# ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration = 1
esM.add(
    fn.Sink(
        esM=esM,
        name="Hydrogen demand",
        commodity="hydrogen",
        hasCapacityVariable=False,
        operationRateFix=data["Hydrogen demand, operationRateFix"] * FCEV_penetration,
    )
)

# %% [markdown]
# All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %% [markdown]
# # 8 Temporal Aggregation

# %%
esM.aggregateTemporally(numberOfTypicalPeriods=7)

# %% [markdown]
# ### Optimization

# %%
# The `optimizationSpecs` only work with the Gurobi solver. If you are using another solver you need to choose
# specs spcecific to this solver or no specs.
esM.optimize(
    timeSeriesAggregation=True,
    optimizationSpecs="OptimalityTol=1e-3 method=2 cuts=0 MIPGap=5e-3",
    solver=fn.utils.ImplementedSolvers.GUROBI.value,
)
# Out:
# Set parameter Threads to value 3
# Set parameter LogFile to value ""
# Set parameter OptimalityTol to value 0.001
# Set parameter Method to value 2
# Set parameter Cuts to value 0
# Set parameter MIPGap to value 0.005
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 13.0.2 build v13.0.2rc1 (linux64 - "Rocky Linux 8.8 (Green Obsidian)")
#
# CPU model: Intel(R) Xeon(R) Gold 6154 CPU @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 36 physical cores, 72 logical processors, using up to 3 threads
#
# Non-default parameters:
# MIPGap  0.005
# OptimalityTol  0.001
# Method  2
# Cuts  0
# TSPort  41955
# QCPDual  1
# Threads  3
#
# Optimize a model with 34441 rows, 17591 columns and 98106 nonzeros (Min)
# Model fingerprint: 0x56ab9ad1
# Model has 1393 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [2e-08, 1e+04]
#   Objective range  [4e-04, 3e-01]
#   Bounds range     [3e-01, 3e+04]
#   RHS range        [1e+00, 1e+00]
#
# Presolve removed 14586 rows and 7639 columns
# Presolve time: 0.06s
# Presolved: 19855 rows, 9952 columns, 83926 nonzeros
#
# Ordering time: 0.17s
#
# Barrier statistics:
#  Dense cols : 184
#  Free vars  : 56
#  AA' NZ     : 3.392e+05
#  Factor NZ  : 1.176e+06 (roughly 20 MB of memory)
#  Factor Ops : 1.692e+08 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.21694231e+02 -1.18783261e+03  4.12e+02 6.60e-01  8.41e+01     0s
#    1   5.01117111e+02 -1.17800132e+03  2.63e+02 8.78e-01  6.29e+01     0s
#    2   4.65012993e+02 -1.24732351e+03  1.91e+02 2.58e-01  3.21e+01     0s
#    3   3.63404213e+02 -1.29312784e+03  6.82e+01 7.91e-02  1.15e+01     0s
#    4   2.97061520e+02 -9.48441521e+02  1.65e+01 1.52e-02  2.74e+00     0s
#    5   1.92235014e+02 -3.41942322e+02  1.35e+00 2.56e-03  5.71e-01     0s
#    6   1.44814884e+02 -5.80360546e+01  4.14e-01 8.16e-04  1.91e-01     0s
#    7   1.37677260e+02 -5.35412256e+01  3.53e-01 7.74e-04  1.79e-01     0s
#    8   1.27792704e+02 -3.44582660e+01  2.71e-01 6.48e-04  1.49e-01     0s
#    9   1.10814493e+02 -8.51105654e+00  1.72e-01 4.75e-04  1.06e-01     0s
#   10   9.48793213e+01  3.52864951e+01  9.20e-02 1.83e-04  4.75e-02     0s
#   11   8.43101890e+01  5.97747654e+01  5.20e-02 2.73e-05  1.62e-02     1s
#   12   7.57182133e+01  6.48960082e+01  2.10e-02 8.80e-06  6.83e-03     1s
#   13   7.28183886e+01  6.69430621e+01  1.19e-02 3.66e-06  3.64e-03     1s
#   14   7.11375840e+01  6.75235853e+01  6.40e-03 2.54e-06  2.25e-03     1s
#   15   7.03891203e+01  6.83035823e+01  3.82e-03 1.32e-06  1.29e-03     1s
#   16   6.97895244e+01  6.88011215e+01  1.65e-03 7.01e-07  6.10e-04     1s
#   17   6.96103247e+01  6.90412592e+01  1.04e-03 5.74e-07  3.48e-04     1s
#   18   6.94950123e+01  6.91075895e+01  6.36e-04 3.70e-07  2.37e-04     1s
#   19   6.94386990e+01  6.91789576e+01  4.47e-04 3.19e-07  1.59e-04     1s
#   20   6.93995434e+01  6.92184142e+01  2.98e-04 2.73e-07  1.11e-04     1s
#   21   6.93648915e+01  6.92630290e+01  1.75e-04 4.19e-07  6.21e-05     1s
#   22   6.93441647e+01  6.92789879e+01  1.04e-04 5.39e-07  3.96e-05     1s
#   23   6.93354341e+01  6.92941697e+01  7.37e-05 2.81e-07  2.50e-05     1s
#   24   6.93321378e+01  6.92988527e+01  6.19e-05 1.82e-07  2.01e-05     1s
#   25   6.93252395e+01  6.93045626e+01  3.75e-05 1.06e-07  1.25e-05     1s
#   26   6.93183316e+01  6.93122860e+01  1.21e-05 9.68e-08  3.63e-06     1s
#   27   6.93154418e+01  6.93142453e+01  2.39e-06 2.66e-08  7.14e-07     1s
#   28   6.93147909e+01  6.93145866e+01  3.91e-07 3.41e-09  1.22e-07     1s
#   29   6.93146740e+01  6.93146489e+01  6.00e-08 5.62e-10  1.53e-08     1s
#   30   6.93146651e+01  6.93146577e+01  2.27e-08 8.14e-09  4.95e-09     1s
#   31   6.93146611e+01  6.93146599e+01  1.10e-07 2.49e-09  9.83e-10     1s
#   32   6.93146611e+01  6.93146599e+01  3.12e-07 2.48e-09  9.81e-10     1s
#   33   6.93146611e+01  6.93146600e+01  6.01e-07 2.44e-09  9.64e-10     1s
#   34   6.93146608e+01  6.93146604e+01  3.24e-07 6.10e-09  4.26e-10     1s
#
# Barrier solved model in 34 iterations and 0.88 seconds (0.71 work units)
# Optimal objective 6.93146608e+01
#
# Crossover log...
#
#     3322 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 4.3961059e-02                 1s
#
#     3599 PPushes remaining with PInf 1.7490059e-03                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.3604097e-02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5188    6.9314661e+01   0.000000e+00   3.693615e-02      1s
# Crossover time: 0.23 seconds (0.28 work units)
#     5200    6.9314661e+01   0.000000e+00   0.000000e+00      1s
#
# Solved in 5200 iterations and 1.13 seconds (0.99 work units)
# Optimal objective  6.931466065e+01
# /fast/home/d-marmullaku/Projects/Hackathon_5/fine/fine/storage.py:2133: UserWarning: Charge and discharge at the same time for component Li-ion batteries
#   warnings.warn(
# /fast/home/d-marmullaku/Projects/Hackathon_5/fine/fine/storage.py:2133: UserWarning: Charge and discharge at the same time for component Salt caverns (hydrogen)
#   warnings.warn(

# %% [markdown]
# # 9. Selected results output
#
# Plot locations (GeoPandas required)

# %%
# Import the geopandas package for plotting the locations

# %%
locFilePath = INPUT_DATA_PATH / "SpatialData" / "ShapeFiles" / "clusteredRegions.shp"

# %%
fig, ax = fn.plotLocations(locFilePath, plotLocNames=True, indexColumn="index")

# %% [markdown]
# ### Sources and Sink
#
# Show optimization summary

# %%
esM.getOptimizationSummary("SourceSinkModel", outputLevel=2)
# Out:
#                                                                 cluster_0  \
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           133963.451433
#                    operation_annual [GW$_{el}$*h/a]         133963.451433
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]     31710.458182
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]   31710.458182
# PV                 NPVcontribution  [1e9 Euro]                   3.200554
#                    TAC              [1e9 Euro/a]                 3.200554
#                    capacity         [GW$_{el}$]                 43.314414
#                    capexCap         [1e9 Euro/a]                 2.637467
#                    commissioning    [GW$_{el}$]                 43.314414
#                    invest           [1e9 Euro]                  28.154369
#                    operation        [GW$_{el}$*h]            48159.521871
#                    operation_annual [GW$_{el}$*h/a]          48159.521871
#                    opexCap          [1e9 Euro/a]                 0.563087
# Wind (offshore)    NPVcontribution  [1e9 Euro]                          0
#                    TAC              [1e9 Euro/a]                        0
#                    capacity         [GW$_{el}$]                       NaN
#                    capexCap         [1e9 Euro/a]                      NaN
#                    commissioning    [GW$_{el}$]                       NaN
#                    invest           [1e9 Euro]                        NaN
#                    operation        [GW$_{el}$*h]                     NaN
#                    operation_annual [GW$_{el}$*h/a]                   NaN
#                    opexCap          [1e9 Euro/a]                      NaN
# Wind (onshore)     NPVcontribution  [1e9 Euro]                        0.0
#                    TAC              [1e9 Euro/a]                      0.0
#                    capacity         [GW$_{el}$]                       0.0
#                    capexCap         [1e9 Euro/a]                      0.0
#                    commissioning    [GW$_{el}$]                       0.0
#                    invest           [1e9 Euro]                        0.0
#                    operation        [GW$_{el}$*h]                     0.0
#                    operation_annual [GW$_{el}$*h/a]                   0.0
#                    opexCap          [1e9 Euro/a]                      0.0
#
#                                                                cluster_1  \
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           66115.987455
#                    operation_annual [GW$_{el}$*h/a]         66115.987455
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]    22014.113765
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]  22014.113765
# PV                 NPVcontribution  [1e9 Euro]                  1.909967
#                    TAC              [1e9 Euro/a]                1.909967
#                    capacity         [GW$_{el}$]                25.848365
#                    capexCap         [1e9 Euro/a]                1.573938
#                    commissioning    [GW$_{el}$]                25.848365
#                    invest           [1e9 Euro]                 16.801437
#                    operation        [GW$_{el}$*h]           24295.702975
#                    operation_annual [GW$_{el}$*h/a]         24295.702975
#                    opexCap          [1e9 Euro/a]                0.336029
# Wind (offshore)    NPVcontribution  [1e9 Euro]                   1.12104
#                    TAC              [1e9 Euro/a]                 1.12104
#                    capacity         [GW$_{el}$]                      4.0
#                    capexCap         [1e9 Euro/a]                 0.93704
#                    commissioning    [GW$_{el}$]                      4.0
#                    invest           [1e9 Euro]                       9.2
#                    operation        [GW$_{el}$*h]           14484.530309
#                    operation_annual [GW$_{el}$*h/a]         14484.530309
#                    opexCap          [1e9 Euro/a]                   0.184
# Wind (onshore)     NPVcontribution  [1e9 Euro]                  3.200208
#                    TAC              [1e9 Euro/a]                3.200208
#                    capacity         [GW$_{el}$]                 23.87548
#                    capexCap         [1e9 Euro/a]                2.674947
#                    commissioning    [GW$_{el}$]                 23.87548
#                    invest           [1e9 Euro]                 26.263028
#                    operation        [GW$_{el}$*h]           56114.364673
#                    operation_annual [GW$_{el}$*h/a]         56114.364673
#                    opexCap          [1e9 Euro/a]                0.525261
#
#                                                                 cluster_2  \
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           124796.759468
#                    operation_annual [GW$_{el}$*h/a]         124796.759468
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]     32905.189888
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]   32905.189888
# PV                 NPVcontribution  [1e9 Euro]                   2.491089
#                    TAC              [1e9 Euro/a]                 2.491089
#                    capacity         [GW$_{el}$]                 33.712925
#                    capexCap         [1e9 Euro/a]                 2.052821
#                    commissioning    [GW$_{el}$]                 33.712925
#                    invest           [1e9 Euro]                  21.913401
#                    operation        [GW$_{el}$*h]             26053.31747
#                    operation_annual [GW$_{el}$*h/a]           26053.31747
#                    opexCap          [1e9 Euro/a]                 0.438268
# Wind (offshore)    NPVcontribution  [1e9 Euro]                  14.853784
#                    TAC              [1e9 Euro/a]                14.853784
#                    capacity         [GW$_{el}$]                      53.0
#                    capexCap         [1e9 Euro/a]                12.415784
#                    commissioning    [GW$_{el}$]                      53.0
#                    invest           [1e9 Euro]                      121.9
#                    operation        [GW$_{el}$*h]           197722.767982
#                    operation_annual [GW$_{el}$*h/a]         197722.767982
#                    opexCap          [1e9 Euro/a]                    2.438
# Wind (onshore)     NPVcontribution  [1e9 Euro]                   3.336771
#                    TAC              [1e9 Euro/a]                 3.336771
#                    capacity         [GW$_{el}$]                 24.894326
#                    capexCap         [1e9 Euro/a]                 2.789096
#                    commissioning    [GW$_{el}$]                 24.894326
#                    invest           [1e9 Euro]                  27.383759
#                    operation        [GW$_{el}$*h]             59111.75808
#                    operation_annual [GW$_{el}$*h/a]           59111.75808
#                    opexCap          [1e9 Euro/a]                 0.547675
#
#                                                                cluster_3  \
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           40441.203266
#                    operation_annual [GW$_{el}$*h/a]         40441.203266
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]    10528.263729
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]  10528.263729
# PV                 NPVcontribution  [1e9 Euro]                  1.449702
#                    TAC              [1e9 Euro/a]                1.449702
#                    capacity         [GW$_{el}$]                19.619408
#                    capexCap         [1e9 Euro/a]                1.194649
#                    commissioning    [GW$_{el}$]                19.619408
#                    invest           [1e9 Euro]                 12.752615
#                    operation        [GW$_{el}$*h]           15505.375828
#                    operation_annual [GW$_{el}$*h/a]         15505.375828
#                    opexCap          [1e9 Euro/a]                0.255052
# Wind (offshore)    NPVcontribution  [1e9 Euro]                   1.68156
#                    TAC              [1e9 Euro/a]                 1.68156
#                    capacity         [GW$_{el}$]                      6.0
#                    capexCap         [1e9 Euro/a]                 1.40556
#                    commissioning    [GW$_{el}$]                      6.0
#                    invest           [1e9 Euro]                      13.8
#                    operation        [GW$_{el}$*h]           15069.226561
#                    operation_annual [GW$_{el}$*h/a]         15069.226561
#                    opexCap          [1e9 Euro/a]                   0.276
# Wind (onshore)     NPVcontribution  [1e9 Euro]                  5.967158
#                    TAC              [1e9 Euro/a]                5.967158
#                    capacity         [GW$_{el}$]                44.518593
#                    capexCap         [1e9 Euro/a]                4.987749
#                    commissioning    [GW$_{el}$]                44.518593
#                    invest           [1e9 Euro]                 48.970452
#                    operation        [GW$_{el}$*h]            84734.34018
#                    operation_annual [GW$_{el}$*h/a]          84734.34018
#                    opexCap          [1e9 Euro/a]                0.979409
#
#                                                                cluster_4  \
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           77229.281165
#                    operation_annual [GW$_{el}$*h/a]         77229.281165
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]     20156.53505
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]   20156.53505
# PV                 NPVcontribution  [1e9 Euro]                  2.194013
#                    TAC              [1e9 Euro/a]                2.194013
#                    capacity         [GW$_{el}$]                29.692475
#                    capexCap         [1e9 Euro/a]                1.808011
#                    commissioning    [GW$_{el}$]                29.692475
#                    invest           [1e9 Euro]                 19.300109
#                    operation        [GW$_{el}$*h]           31807.809637
#                    operation_annual [GW$_{el}$*h/a]         31807.809637
#                    opexCap          [1e9 Euro/a]                0.386002
# Wind (offshore)    NPVcontribution  [1e9 Euro]                         0
#                    TAC              [1e9 Euro/a]                       0
#                    capacity         [GW$_{el}$]                      NaN
#                    capexCap         [1e9 Euro/a]                     NaN
#                    commissioning    [GW$_{el}$]                      NaN
#                    invest           [1e9 Euro]                       NaN
#                    operation        [GW$_{el}$*h]                    NaN
#                    operation_annual [GW$_{el}$*h/a]                  NaN
#                    opexCap          [1e9 Euro/a]                     NaN
# Wind (onshore)     NPVcontribution  [1e9 Euro]                  2.411703
#                    TAC              [1e9 Euro/a]                2.411703
#                    capacity         [GW$_{el}$]                17.992755
#                    capexCap         [1e9 Euro/a]                2.015862
#                    commissioning    [GW$_{el}$]                17.992755
#                    invest           [1e9 Euro]                 19.792031
#                    operation        [GW$_{el}$*h]           28296.318251
#                    operation_annual [GW$_{el}$*h/a]         28296.318251
#                    opexCap          [1e9 Euro/a]                0.395841
#
#                                                                cluster_5  \
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           41413.409155
#                    operation_annual [GW$_{el}$*h/a]         41413.409155
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]    11494.847144
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]  11494.847144
# PV                 NPVcontribution  [1e9 Euro]                  1.469767
#                    TAC              [1e9 Euro/a]                1.469767
#                    capacity         [GW$_{el}$]                19.890954
#                    capexCap         [1e9 Euro/a]                1.211184
#                    commissioning    [GW$_{el}$]                19.890954
#                    invest           [1e9 Euro]                  12.92912
#                    operation        [GW$_{el}$*h]           20438.513534
#                    operation_annual [GW$_{el}$*h/a]         20438.513534
#                    opexCap          [1e9 Euro/a]                0.258582
# Wind (offshore)    NPVcontribution  [1e9 Euro]                         0
#                    TAC              [1e9 Euro/a]                       0
#                    capacity         [GW$_{el}$]                      NaN
#                    capexCap         [1e9 Euro/a]                     NaN
#                    commissioning    [GW$_{el}$]                      NaN
#                    invest           [1e9 Euro]                       NaN
#                    operation        [GW$_{el}$*h]                    NaN
#                    operation_annual [GW$_{el}$*h/a]                  NaN
#                    opexCap          [1e9 Euro/a]                     NaN
# Wind (onshore)     NPVcontribution  [1e9 Euro]                       0.0
#                    TAC              [1e9 Euro/a]                     0.0
#                    capacity         [GW$_{el}$]                      0.0
#                    capexCap         [1e9 Euro/a]                     0.0
#                    commissioning    [GW$_{el}$]                      0.0
#                    invest           [1e9 Euro]                       0.0
#                    operation        [GW$_{el}$*h]                    0.0
#                    operation_annual [GW$_{el}$*h/a]                  0.0
#                    opexCap          [1e9 Euro/a]                     0.0
#
#                                                                cluster_6  \
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           28088.766223
#                    operation_annual [GW$_{el}$*h/a]         28088.766223
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]     7420.101028
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]   7420.101028
# PV                 NPVcontribution  [1e9 Euro]                  0.933703
#                    TAC              [1e9 Euro/a]                0.933703
#                    capacity         [GW$_{el}$]                12.636188
#                    capexCap         [1e9 Euro/a]                0.769433
#                    commissioning    [GW$_{el}$]                12.636188
#                    invest           [1e9 Euro]                  8.213522
#                    operation        [GW$_{el}$*h]            9203.261032
#                    operation_annual [GW$_{el}$*h/a]          9203.261032
#                    opexCap          [1e9 Euro/a]                 0.16427
# Wind (offshore)    NPVcontribution  [1e9 Euro]                  5.044681
#                    TAC              [1e9 Euro/a]                5.044681
#                    capacity         [GW$_{el}$]                     18.0
#                    capexCap         [1e9 Euro/a]                4.216681
#                    commissioning    [GW$_{el}$]                     18.0
#                    invest           [1e9 Euro]                      41.4
#                    operation        [GW$_{el}$*h]           51592.062973
#                    operation_annual [GW$_{el}$*h/a]         51592.062973
#                    opexCap          [1e9 Euro/a]                   0.828
# Wind (onshore)     NPVcontribution  [1e9 Euro]                  2.927391
#                    TAC              [1e9 Euro/a]                2.927391
#                    capacity         [GW$_{el}$]                21.840104
#                    capexCap         [1e9 Euro/a]                2.446909
#                    commissioning    [GW$_{el}$]                21.840104
#                    invest           [1e9 Euro]                 24.024115
#                    operation        [GW$_{el}$*h]           49765.499219
#                    operation_annual [GW$_{el}$*h/a]         49765.499219
#                    opexCap          [1e9 Euro/a]                0.480482
#
#                                                                cluster_7
# Component          Property         Unit
# Electricity demand operation        [GW$_{el}$*h]           15851.141245
#                    operation_annual [GW$_{el}$*h/a]         15851.141245
# Hydrogen demand    operation        [GW$_{H_{2},LHV}$*h]     2906.248333
#                    operation_annual [GW$_{H_{2},LHV}$*h/a]   2906.248333
# PV                 NPVcontribution  [1e9 Euro]                  0.366282
#                    TAC              [1e9 Euro/a]                0.366282
#                    capacity         [GW$_{el}$]                 4.957044
#                    capexCap         [1e9 Euro/a]                 0.30184
#                    commissioning    [GW$_{el}$]                 4.957044
#                    invest           [1e9 Euro]                  3.222079
#                    operation        [GW$_{el}$*h]            4874.735286
#                    operation_annual [GW$_{el}$*h/a]          4874.735286
#                    opexCap          [1e9 Euro/a]                0.064442
# Wind (offshore)    NPVcontribution  [1e9 Euro]                         0
#                    TAC              [1e9 Euro/a]                       0
#                    capacity         [GW$_{el}$]                      NaN
#                    capexCap         [1e9 Euro/a]                     NaN
#                    commissioning    [GW$_{el}$]                      NaN
#                    invest           [1e9 Euro]                       NaN
#                    operation        [GW$_{el}$*h]                    NaN
#                    operation_annual [GW$_{el}$*h/a]                  NaN
#                    opexCap          [1e9 Euro/a]                     NaN
# Wind (onshore)     NPVcontribution  [1e9 Euro]                       0.0
#                    TAC              [1e9 Euro/a]                     0.0
#                    capacity         [GW$_{el}$]                      0.0
#                    capexCap         [1e9 Euro/a]                     0.0
#                    commissioning    [GW$_{el}$]                      0.0
#                    invest           [1e9 Euro]                       0.0
#                    operation        [GW$_{el}$*h]                    0.0
#                    operation_annual [GW$_{el}$*h/a]                  0.0
#                    opexCap          [1e9 Euro/a]                     0.0

# %% [markdown]
# Plot installed capacities

# %%
fig, ax = fn.plotLocationalColorMap(
    esM, "Wind (offshore)", locFilePath, "index", perArea=False
)

# %%
fig, ax = fn.plotLocationalColorMap(
    esM, "Wind (onshore)", locFilePath, "index", perArea=False
)

# %%
fig, ax = fn.plotLocationalColorMap(esM, "PV", locFilePath, "index", perArea=False)

# %% [markdown]
# ### Conversion
#
# Show optimization summary

# %%
esM.getOptimizationSummary("ConversionModel", outputLevel=2)
# Out:
#                                                   cluster_0     cluster_1  \
# Component    Property         Unit
# Electrolyzer NPVcontribution  [1e9 Euro]            0.44998      1.064578
#              TAC              [1e9 Euro/a]          0.44998      1.064578
#              capacity         [GW$_{el}$]          5.171308     12.234455
#              capexCap         [1e9 Euro/a]         0.385339      0.911647
#              commissioning    [GW$_{el}$]          5.171308     12.234455
#              invest           [1e9 Euro]           2.585654      6.117227
#              operation        [GW$_{el}$*h]    33536.340729  35783.684508
#              operation_annual [GW$_{el}$*h/a]  33536.340729  35783.684508
#              opexCap          [1e9 Euro/a]         0.064641      0.152931
# hydrogen_exp NPVcontribution  [1e9 Euro]                0.0      0.045517
#              TAC              [1e9 Euro/a]              0.0      0.045517
#              capacity         [GW$_{el}$]               0.0      3.538065
#              commissioning    [GW$_{el}$]               0.0      3.538065
#              operation        [GW$_{el}$*h]             0.0   3034.465391
#              operation_annual [GW$_{el}$*h/a]           0.0   3034.465391
#              opexOp           [1e9 Euro/a]              0.0      0.045517
# hydrogen_imp NPVcontribution  [1e9 Euro]           0.123525           0.0
#              TAC              [1e9 Euro/a]         0.123525           0.0
#              capacity         [GW$_{el}$]          3.619915           0.0
#              commissioning    [GW$_{el}$]          3.619915           0.0
#              operation        [GW$_{el}$*h]     8235.019672           0.0
#              operation_annual [GW$_{el}$*h/a]   8235.019672           0.0
#              opexOp           [1e9 Euro/a]         0.123525           0.0
#
#                                                   cluster_2     cluster_3  \
# Component    Property         Unit
# Electrolyzer NPVcontribution  [1e9 Euro]           1.400383       0.49543
#              TAC              [1e9 Euro/a]         1.400383       0.49543
#              capacity         [GW$_{el}$]         16.093633      5.693631
#              capexCap         [1e9 Euro/a]         1.199213      0.424259
#              commissioning    [GW$_{el}$]         16.093633      5.693631
#              invest           [1e9 Euro]           8.046817      2.846815
#              operation        [GW$_{el}$*h]    48673.353539  18425.489108
#              operation_annual [GW$_{el}$*h/a]  48673.353539  18425.489108
#              opexCap          [1e9 Euro/a]          0.20117       0.07117
# hydrogen_exp NPVcontribution  [1e9 Euro]           0.017492      0.035544
#              TAC              [1e9 Euro/a]         0.017492      0.035544
#              capacity         [GW$_{el}$]          3.198131      1.581828
#              commissioning    [GW$_{el}$]          3.198131      1.581828
#              operation        [GW$_{el}$*h]      1166.15759   2369.578647
#              operation_annual [GW$_{el}$*h/a]    1166.15759   2369.578647
#              opexOp           [1e9 Euro/a]         0.017492      0.035544
# hydrogen_imp NPVcontribution  [1e9 Euro]                0.0           0.0
#              TAC              [1e9 Euro/a]              0.0           0.0
#              capacity         [GW$_{el}$]               0.0           0.0
#              commissioning    [GW$_{el}$]               0.0           0.0
#              operation        [GW$_{el}$*h]             0.0           0.0
#              operation_annual [GW$_{el}$*h/a]           0.0           0.0
#              opexOp           [1e9 Euro/a]              0.0           0.0
#
#                                                   cluster_4     cluster_5  \
# Component    Property         Unit
# Electrolyzer NPVcontribution  [1e9 Euro]           0.286027      0.703994
#              TAC              [1e9 Euro/a]         0.286027      0.703994
#              capacity         [GW$_{el}$]          3.287106      8.090515
#              capexCap         [1e9 Euro/a]         0.244938      0.602863
#              commissioning    [GW$_{el}$]          3.287106      8.090515
#              invest           [1e9 Euro]           1.643553      4.045257
#              operation        [GW$_{el}$*h]    21453.209408  22314.353553
#              operation_annual [GW$_{el}$*h/a]  21453.209408  22314.353553
#              opexCap          [1e9 Euro/a]         0.041089      0.101131
# hydrogen_exp NPVcontribution  [1e9 Euro]                0.0      0.061878
#              TAC              [1e9 Euro/a]              0.0      0.061878
#              capacity         [GW$_{el}$]               0.0      3.038966
#              commissioning    [GW$_{el}$]               0.0      3.038966
#              operation        [GW$_{el}$*h]             0.0   4125.200343
#              operation_annual [GW$_{el}$*h/a]           0.0   4125.200343
#              opexOp           [1e9 Euro/a]              0.0      0.061878
# hydrogen_imp NPVcontribution  [1e9 Euro]           0.077089           0.0
#              TAC              [1e9 Euro/a]         0.077089           0.0
#              capacity         [GW$_{el}$]          2.300974           0.0
#              commissioning    [GW$_{el}$]          2.300974           0.0
#              operation        [GW$_{el}$*h]     5139.288464           0.0
#              operation_annual [GW$_{el}$*h/a]   5139.288464           0.0
#              opexOp           [1e9 Euro/a]         0.077089           0.0
#
#                                                   cluster_6    cluster_7
# Component    Property         Unit
# Electrolyzer NPVcontribution  [1e9 Euro]           0.393652      0.04124
#              TAC              [1e9 Euro/a]         0.393652      0.04124
#              capacity         [GW$_{el}$]          4.523973     0.473948
#              capexCap         [1e9 Euro/a]         0.337103     0.035316
#              commissioning    [GW$_{el}$]          4.523973     0.473948
#              invest           [1e9 Euro]           2.261986     0.236974
#              operation        [GW$_{el}$*h]    15597.804371  2981.132096
#              operation_annual [GW$_{el}$*h/a]  15597.804371  2981.132096
#              opexCap          [1e9 Euro/a]          0.05655     0.005924
# hydrogen_exp NPVcontribution  [1e9 Euro]           0.052475          0.0
#              TAC              [1e9 Euro/a]         0.052475          0.0
#              capacity         [GW$_{el}$]          1.472694          0.0
#              commissioning    [GW$_{el}$]          1.472694          0.0
#              operation        [GW$_{el}$*h]     3498.362032          0.0
#              operation_annual [GW$_{el}$*h/a]   3498.362032          0.0
#              opexOp           [1e9 Euro/a]         0.052475          0.0
# hydrogen_imp NPVcontribution  [1e9 Euro]                0.0     0.012292
#              TAC              [1e9 Euro/a]              0.0     0.012292
#              capacity         [GW$_{el}$]               0.0     0.331764
#              commissioning    [GW$_{el}$]               0.0     0.331764
#              operation        [GW$_{el}$*h]             0.0   819.455866
#              operation_annual [GW$_{el}$*h/a]           0.0   819.455866
#              opexOp           [1e9 Euro/a]              0.0     0.012292

# %%
fig, ax = fn.plotLocationalColorMap(
    esM, "Electrolyzer", locFilePath, "index", perArea=False
)

# %% [markdown]
# Export

# %%
fig, ax = fn.plotLocationalColorMap(
    esM,
    "hydrogen_exp",
    locFilePath,
    "index",
    perArea=False,
    variableName="operationVariablesOptimum",
    doSum=True,
    zlabel="Annual Export [GWh]",
)

# %% [markdown]
# Import

# %%
fig, ax = fn.plotLocationalColorMap(
    esM,
    "hydrogen_imp",
    locFilePath,
    "index",
    perArea=False,
    variableName="operationVariablesOptimum",
    doSum=True,
    zlabel="Annual Import [GWh]",
)

# %% [markdown]
# Trade

# %%
# ------------------------------------------------------------
# 1. Load spatial data
# ------------------------------------------------------------
gdf = gpd.read_file(locFilePath).to_crs("EPSG:3035").set_index("index")

# ------------------------------------------------------------
# 2. Get export/import operation values from optimization summary
# ------------------------------------------------------------
exp = esM.getOptimizationSummary("ConversionModel", outputLevel=2).loc["hydrogen_exp"]
imp = esM.getOptimizationSummary("ConversionModel", outputLevel=2).loc["hydrogen_imp"]

# Use operation or operation_annual
exp_op = exp.loc["operation"].iloc[0]
imp_op = imp.loc["operation"].iloc[0]

# Net trade
net_trade = exp_op - imp_op
# Put into gdf dataframe
gdf["net_trade"] = net_trade.reindex(gdf.index).fillna(0)
gdf["net_trade"] = pd.to_numeric(gdf["net_trade"], errors="coerce")

# ------------------------------------------------------------
# 4. Define color normalization around zero
# ------------------------------------------------------------
max_abs_color = gdf["net_trade"].abs().max()

norm = TwoSlopeNorm(
    vmin=-max_abs_color,
    vcenter=0,
    vmax=max_abs_color,
)

# ------------------------------------------------------------
# 5. Plot map with visible region outlines
# ------------------------------------------------------------
fig, ax = plt.subplots(figsize=(6, 6))

gdf.plot(
    column="net_trade",
    cmap="RdBu",
    norm=norm,
    ax=ax,
    legend=False,
    edgecolor="black",
    linewidth=0.4,
    zorder=1,
)

# colorbar
sm = mpl.cm.ScalarMappable(cmap="RdBu", norm=norm)
sm.set_array([])

cbar = fig.colorbar(
    sm,
    ax=ax,
    shrink=0.6,
    fraction=0.04,
    pad=0.02,
)

cbar.set_label("Annual Trade [GWh]")

# ------------------------------------------------------------
# 6. Create artificial pool node
# ------------------------------------------------------------
centroids = gdf.geometry.centroid
pool_xy = (centroids.x.mean(), centroids.y.mean())
radius = 50000

# ------------------------------------------------------------
# 7. Draw arrows between regions and pool
# ------------------------------------------------------------
max_abs = gdf["net_trade"].abs().max()

for idx, row in gdf.iterrows():
    c = row.geometry.centroid
    trade = row["net_trade"]

    if abs(trade) < 1e-6:
        continue

    lw = 1 + 4 * abs(trade) / max_abs if max_abs > 0 else 1

    if trade > 0:
        # Net exporter: location -> pool
        ax.annotate(
            "",
            xy=pool_xy,
            xytext=(c.x, c.y),
            arrowprops=dict(
                arrowstyle="-|>",
                color="steelblue",
                lw=lw,
                mutation_scale=12,
            ),
            zorder=4,
        )
    else:
        # Net importer: pool -> location
        ax.annotate(
            "",
            xy=(c.x, c.y),
            xytext=pool_xy,
            arrowprops=dict(
                arrowstyle="-|>",
                color="firebrick",
                lw=lw,
                mutation_scale=12,
            ),
            zorder=4,
        )

# ------------------------------------------------------------
# 8. Draw pool circle and label
# ------------------------------------------------------------
pool_patch = plt.Circle(
    pool_xy,
    radius,
    fc="lightyellow",
    ec="black",
    linewidth=1.5,
    zorder=5,
)

ax.add_patch(pool_patch)

ax.text(
    *pool_xy,
    "Pool",
    ha="center",
    va="center",
    fontsize=7,
    fontweight="bold",
    zorder=6,
)

# ------------------------------------------------------------
# 9. Final formatting
# ------------------------------------------------------------
ax.set_title("Net trade\n(blue = net exporter, red = net importer)")
ax.axis("off")

plt.tight_layout()
plt.show()
